# %%
import pandas as pd

# Step 1: Read the CSV file into a DataFrame
df = pd.read_csv('/home/yogen14')

# Step 2: Convert <U4 strings to float64
# Replace 'your_column_name' with the actual name of the column containing <U4 strings
df['your_column_name'] = pd.to_numeric(df['your_column_name'], errors='coerce', downcast='float')

# 'errors' parameter set to 'coerce' will replace non-convertible values with NaN.
# 'downcast' parameter set to 'float' will downcast to float64 if possible.

# Step 3: Save the updated DataFrame to a new CSV file if needed
df.to_csv('updated_file.csv', index=False)
