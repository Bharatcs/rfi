# %%
#imports#
import geopandas as gpd
import pandas as pd
#read geoJSON file#
file_path = '/home/pratush/Downloads/gadm41_IND_3.json'
gdf = gpd.read_file(file_path)

#select J&K row#
JKrow=gdf[gdf['NAME_1']=='JammuandKashmir']
#save the row as geoJSON file#
# output_file = '/home/pratush/Desktop/JKshape.geojson'
# JKrow.to_file(output_file, driver='GeoJSON')

# %%
display(JKrow)
# Out:
#              GID_3 GID_0 COUNTRY     GID_1           NAME_1 NL_NAME_1  \
# 646   Z01.14.1.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 647   Z01.14.2.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 648   Z01.14.3.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 649   Z01.14.4.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 650   Z01.14.5.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 651   Z01.14.6.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 652   Z01.14.6.2_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 653   Z01.14.7.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 654   Z01.14.8.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 655   Z01.14.9.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 656  Z01.14.10.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 657  Z01.14.11.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 658  Z01.14.11.2_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 659  Z01.14.12.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 660  Z01.14.13.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 661  Z01.14.14.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 662  Z01.14.15.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 663  Z01.14.16.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 664  Z01.14.17.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 665  Z01.14.18.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 666  Z01.14.19.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 667  Z01.14.20.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 668  Z01.14.21.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
# 669  Z01.14.22.1_1   Z01   India  Z01.14_1  JammuandKashmir        NA
#
#            GID_2       NAME_2 NL_NAME_2    NAME_3 VARNAME_3 NL_NAME_3 TYPE_3  \
# 646   Z01.14.1_1     Anantnag        NA   n.a.(6)        NA        NA  Taluk
# 647   Z01.14.2_1       Badgam        NA   n.a.(8)        NA        NA  Taluk
# 648   Z01.14.3_1    Bandipore        NA   n.a.(4)        NA        NA  Taluk
# 649   Z01.14.4_1    Baramulla        NA   n.a.(4)        NA        NA  Taluk
# 650   Z01.14.5_1         Doda        NA   n.a.(7)        NA        NA  Taluk
# 651   Z01.14.6_1    Ganderbal        NA  n.a.(5a)        NA        NA  Taluk
# 652   Z01.14.6_1    Ganderbal        NA  n.a.(5b)        NA        NA  Taluk
# 653   Z01.14.7_1        Jammu        NA  n.a.(16)        NA        NA  Taluk
# 654   Z01.14.8_1       Kargil        NA   n.a.(3)        NA        NA  Taluk
# 655   Z01.14.9_1       Kathua        NA  n.a.(20)        NA        NA  Taluk
# 656  Z01.14.10_1     Kishtwar        NA   n.a.(7)        NA        NA  Taluk
# 657  Z01.14.11_1       Kulgam        NA  n.a.(10)        NA        NA  Taluk
# 658  Z01.14.11_1       Kulgam        NA   n.a.(6)        NA        NA  Taluk
# 659  Z01.14.12_1      Kupwara        NA   n.a.(2)        NA        NA  Taluk
# 660  Z01.14.13_1  Leh(Ladakh)        NA   n.a.(1)        NA        NA  Taluk
# 661  Z01.14.14_1       Poonch        NA   n.a.(9)        NA        NA  Taluk
# 662  Z01.14.15_1      Pulwama        NA  n.a.(10)        NA        NA  Taluk
# 663  Z01.14.16_1      Rajouri        NA  n.a.(11)        NA        NA  Taluk
# 664  Z01.14.17_1       Ramban        NA  n.a.(12)        NA        NA  Taluk
# 665  Z01.14.18_1        Reasi        NA  n.a.(12)        NA        NA  Taluk
# 666  Z01.14.19_1        Samba        NA  n.a.(16)        NA        NA  Taluk
# 667  Z01.14.20_1     Shupiyan        NA  n.a.(10)        NA        NA  Taluk
# 668  Z01.14.21_1     Srinagar        NA  n.a.(5c)        NA        NA  Taluk
# 669  Z01.14.22_1     Udhampur        NA  n.a.(15)        NA        NA  Taluk
#
#     ENGTYPE_3 CC_3 HASC_3                                           geometry
# 646     Taluk   NA     NA  MULTIPOLYGON (((75.48600 33.40970, 75.47760 33...
# 647     Taluk   NA     NA  MULTIPOLYGON (((74.56090 33.70290, 74.53520 33...
# 648     Taluk   NA     NA  MULTIPOLYGON (((74.57720 34.76950, 74.58020 34...
# 649     Taluk   NA     NA  MULTIPOLYGON (((74.25460 33.99730, 74.24870 34...
# 650     Taluk   NA     NA  MULTIPOLYGON (((76.21620 33.02860, 76.18830 33...
# 651     Taluk   NA     NA  MULTIPOLYGON (((74.65820 34.34950, 74.67640 34...
# 652     Taluk   NA     NA  MULTIPOLYGON (((75.49280 34.21900, 75.46490 34...
# 653     Taluk   NA     NA  MULTIPOLYGON (((74.47200 32.77840, 74.46610 32...
# 654     Taluk   NA     NA  MULTIPOLYGON (((75.37780 34.55240, 75.39500 34...
# 655     Taluk   NA     NA  MULTIPOLYGON (((75.90460 32.61520, 75.88630 32...
# 656     Taluk   NA     NA  MULTIPOLYGON (((76.72990 33.17940, 76.71420 33...
# 657     Taluk   NA     NA  MULTIPOLYGON (((74.53520 33.68580, 74.56090 33...
# 658     Taluk   NA     NA  MULTIPOLYGON (((75.05780 33.82070, 75.06130 33...
# 659     Taluk   NA     NA  MULTIPOLYGON (((73.98200 34.23910, 73.97620 34...
# 660     Taluk   NA     NA  MULTIPOLYGON (((78.00640 35.29040, 78.01770 35...
# 661     Taluk   NA     NA  MULTIPOLYGON (((74.04130 33.79900, 74.04900 33...
# 662     Taluk   NA     NA  MULTIPOLYGON (((75.13840 34.09780, 75.14910 34...
# 663     Taluk   NA     NA  MULTIPOLYGON (((74.35280 32.99030, 74.35170 33...
# 664     Taluk   NA     NA  MULTIPOLYGON (((75.19510 33.50040, 75.22180 33...
# 665     Taluk   NA     NA  MULTIPOLYGON (((74.95780 32.93080, 74.94640 32...
# 666     Taluk   NA     NA  MULTIPOLYGON (((74.83530 32.49620, 74.84600 32...
# 667     Taluk   NA     NA  MULTIPOLYGON (((75.07130 33.83490, 75.05780 33...
# 668     Taluk   NA     NA  MULTIPOLYGON (((75.12810 34.18860, 75.13200 34...
# 669     Taluk   NA     NA  MULTIPOLYGON (((75.29440 33.10870, 75.30510 33...

# %%
import healpy as hp
import matplotlib.pyplot as plt
import numpy as np
import tifffile as tiff
##---------Read the tif file---------##
image = tiff.imread('./gpw_v4_population_density_adjusted_to_2015_unwpp_country_totals_rev11_2020_15_min.tif')
image_array = np.array(image)


#----------Define the spherical coordinates----------#
theta = np.linspace(np.radians(0), np.radians(180), num=image_array.shape[0],endpoint=False)
phi = np.linspace(-np.radians(180), np.radians(180), num=image_array.shape[1],endpoint=False)

#---------- Set angular resolution----------#
nside = 128

##--------Make empty healpix mask and pixel values vector--------##
healpix_map = np.zeros(hp.nside2npix(nside), dtype=np.double)
pixel_counts = np.zeros(hp.nside2npix(nside), dtype=int)


for i in range(len(theta)):
    for j in range(len(phi)):
        pixel = hp.ang2pix(nside, theta[i], phi[j])
        healpix_map[pixel] += image_array[i, j]
        pixel_counts[pixel] += 1

#--------Average value of each pixel--------#
healpix_map[pixel_counts>0] /= pixel_counts[pixel_counts>0 ]

# %%
hp.mollview(healpix_map, cmap="inferno", flip="geo", norm="hist", min=0)
