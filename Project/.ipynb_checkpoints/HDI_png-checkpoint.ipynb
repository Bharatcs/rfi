# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# Read your data
data = pd.read_csv("/home/pratush/Downloads/Fin_HDI.csv")
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world_data = world.merge(data, left_on='name', right_on='Country')


ax1=world_data.plot(column='Value')
ax1.axis('off')


plt.savefig('world_map3.png', format='png', bbox_inches='tight', pad_inches=0)


plt.show()
# Out:
# /tmp/ipykernel_18824/1971144031.py:6: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/home/pratush/Downloads/Fin_HDI.csv")
# /tmp/ipykernel_18824/1971144031.py:7: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
