# %%
import numpy as np 
import healpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import tifffile as tiff
import glob
import seaborn as sns
# sns.set_style("darkgrid")
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from num2words import num2words
from scipy.optimize import curve_fit
from mpl_toolkits import mplot3d
import os
from distfit import distfit
import sys
import scipy
import rasterio
# sns.set(rc={"xtick.bottom": True, "ytick.left": True})
# %matplotlib inline
# %matplotlib notebook

# %% [markdown]
# ## Read Country DB parameters

# %%
csv_files = ['./database/France.csv']
#France has 9393 Tx

# --Create an empty dataframe to store the combined data-- #
df = pd.DataFrame()

# Loop through each CSV file and append its contents to the combined dataframe
for csv_file in (csv_files):
    df_temp = pd.read_csv(csv_file)
    df = pd.concat([df, df_temp],ignore_index=True) 
# read Tx params into numpy arrays
df=df.dropna()
power=df['EIRP'].to_numpy()
lat_128=df['Latitude in degrees'].to_numpy()
lon_128=df['Longitude in degrees'].to_numpy()
# convert Tx coords into HEALPix pixels
pix=hp.ang2pix(128,lon_128,lat_128,lonlat=True)

# %%
# make number of Tx per pixel map
Tx_num_128=np.zeros(hp.nside2npix(128))
for pi in pix:
    Tx_num_128[pi]+=1
hp.mollview(Tx_num_128,flip='geo',cmap='plasma',norm='hist')
plt.show()

# %%
# making total Tx power in each pixel
Tx_pow_128=np.zeros(hp.nside2npix(128))
for index,p in enumerate(pix):
    Tx_pow_128[p]+=(power[index])
hp.mollview(Tx_pow_128,flip='geo',cmap='viridis',norm='hist',min=300)
plt.show()

# %% [markdown]
# # Fitting PDF to Tx params

# %%
# read Tx params of selected 5k country
fr_df=pd.read_csv('./database/France.csv')
fr_df=fr_df.dropna()
lat=fr_df['Latitude in degrees'].to_numpy()
lon=fr_df['Longitude in degrees'].to_numpy()
power=fr_df['EIRP'].to_numpy()
freq=fr_df['Frequency(MHz)'].to_numpy()

# %%
# Bin width using Freedman Diaconis rule
def FDrule(data):
    # Calculate interquartile range
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    
    # Calculate Freedman-Diaconis bin width
    n = len(data)
    bin_width = 2 * iqr / (n ** (1/3))

    # Calculate number of bins
    data_range = max(data) - min(data)
    num_bins = int(data_range / bin_width) + 1
    
    return num_bins

# %% [markdown]
# ## Country HEALPix map as mask

# %%
# France shapefile was downloaded from https://gadm.org/download_country.html and rasterized using QGIS
# Open the GeoTIFF file
file_path = '/home/pratush/Desktop/France_raster.tif'
src = rasterio.open(file_path)

# Read the raster data as a numpy array
data = src.read(1)  # Assuming a single-band raster

# Find pixels with non-zero values
non_zero_pixels = np.where(data != 0)

# Get the coordinates of non zero pixels
templat=[]
templon=[]
for y, x in zip(*non_zero_pixels):
    lonval, latval = src.xy(y, x)  # Get the longitude and latitude of the pixel
    templat.append(latval)
    templon.append(lonval)

# %%
# Making a mask for generated data
temppix=hp.ang2pix(128,templon,templat,lonlat=True)
template=np.zeros(hp.nside2npix(128))
for pi in temppix:
    template[pi]+=1
template=np.where(template != 0, 1, 0)
hp.mollview(template,flip='geo')

# %% [markdown]
# ### Modelling Latitude

# %%
binw=FDrule(lat)
# Fit a probability density function
distlat = distfit(distr='full',bins=binw)
distlat.fit_transform(lat)

# Plot the fitted distribution
distlat.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlat.model['name'])
print("Parameters:", distlat.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.07 sec] [RSS: 0.0947724] [loc=-14.162 scale=1598.087]
# [distfit] >INFO> [anglit         ] [0.01 sec] [RSS: 0.0821516] [loc=46.072 scale=6.450]
# [distfit] >INFO> [arcsine        ] [0.03 sec] [RSS: 0.231845] [loc=41.231 scale=9.796]
# [distfit] >INFO> [beta           ] [0.06 sec] [RSS: 0.0796843] [loc=41.133 scale=10.023]
# [distfit] >INFO> [betaprime      ] [0.11 sec] [RSS: 0.0957954] [loc=-55.805 scale=39.207]
# [distfit] >INFO> [bradford       ] [0.04 sec] [RSS: 0.116031] [loc=41.231 scale=9.790]
# [distfit] >INFO> [burr           ] [0.32 sec] [RSS: 0.0941221] [loc=-0.276 scale=43.368]
# [distfit] >INFO> [cauchy         ] [0.00 sec] [RSS: 0.12469] [loc=45.697 scale=1.639]
# [distfit] >INFO> [chi            ] [0.02 sec] [RSS: 0.0879514] [loc=40.729 scale=3.433]
# [distfit] >INFO> [chi2           ] [0.05 sec] [RSS: 0.203516] [loc=41.231 scale=3.662]
# [distfit] >INFO> [cosine         ] [0.02 sec] [RSS: 0.0889734] [loc=46.024 scale=1.894]
# [distfit] >INFO> [dgamma         ] [0.02 sec] [RSS: 0.101372] [loc=45.871 scale=0.904]
# [distfit] >INFO> [dweibull       ] [0.02 sec] [RSS: 0.0907854] [loc=45.897 scale=2.187]
# [distfit] >INFO> [erlang         ] [0.07 sec] [RSS: 0.0952062] [loc=14.347 scale=0.162]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.189843] [loc=41.231 scale=4.758]
# [distfit] >INFO> [exponnorm      ] [0.03 sec] [RSS: 0.0966092] [loc=45.779 scale=2.256]
# [distfit] >INFO> [exponweib      ] [0.26 sec] [RSS: 0.606302] [loc=41.231 scale=0.879]
# [distfit] >INFO> [exponpow       ] [0.15 sec] [RSS: 0.565488] [loc=41.231 scale=1.401]
# [distfit] >INFO> [f              ] [0.12 sec] [RSS: 0.0961989] [loc=8.675 scale=37.263]
# [distfit] >INFO> [fatiguelife    ] [0.06 sec] [RSS: 0.0937912] [loc=24.192 scale=21.680]
# [distfit] >INFO> [fisk           ] [0.11 sec] [RSS: 0.102546] [loc=-0.301 scale=46.217]
# [distfit] >INFO> [foldcauchy     ] [0.04 sec] [RSS: 0.124552] [loc=-0.138 scale=1.640]
# [distfit] >INFO> [foldnorm       ] [0.04 sec] [RSS: 0.0933964] [loc=41.231 scale=2.347]
# [distfit] >INFO> [genlogistic    ] [0.03 sec] [RSS: 0.0925566] [loc=41.559 scale=1.875]
# [distfit] >INFO> [genpareto      ] [0.11 sec] [RSS: 0.264801] [loc=0.135 scale=130.027]
# [distfit] >INFO> [gennorm        ] [0.03 sec] [RSS: 0.0743243] [loc=46.073 scale=3.957]
# [distfit] >INFO> [genexpon       ] [0.28 sec] [RSS: 0.0851853] [loc=41.214 scale=1.900]
# [distfit] >INFO> [genextreme     ] [0.09 sec] [RSS: 0.0935981] [loc=45.218 scale=2.240]
# [distfit] >INFO> [gausshyper     ] [0.44 sec] [RSS: 0.110671] [loc=41.229 scale=9.792]
# [distfit] >INFO> [gamma          ] [0.06 sec] [RSS: 0.0951981] [loc=12.179 scale=0.152]
# [distfit] >INFO> [gengamma       ] [0.17 sec] [RSS: 0.553978] [loc=41.231 scale=0.806]
# [distfit] >INFO> [genhalflogistic] [0.13 sec] [RSS: 0.090665] [loc=41.231 scale=5.691]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 0.135842] [loc=41.184 scale=4.123]
# [distfit] >INFO> [gompertz       ] [0.09 sec] [RSS: 0.124214] [loc=41.231 scale=1.897]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.0905637] [loc=44.873 scale=2.034]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.105571] [loc=47.129 scale=2.124]
# [distfit] >INFO> [halfcauchy     ] [0.03 sec] [RSS: 0.173276] [loc=41.231 scale=4.268]
# [distfit] >INFO> [halflogistic   ] [0.02 sec] [RSS: 0.147126] [loc=41.231 scale=3.244]
# [distfit] >INFO> [halfnorm       ] [0.01 sec] [RSS: 0.139542] [loc=41.231 scale=5.273]
# [distfit] >INFO> [halfgennorm    ] [0.13 sec] [RSS: 0.0985825] [loc=41.231 scale=8.989]
# [distfit] >INFO> [hypsecant      ] [0.01 sec] [RSS: 0.109951] [loc=45.906 scale=1.671]
# [distfit] >INFO> [invgamma       ] [0.06 sec] [RSS: 0.0960634] [loc=-77.323 scale=366852.886]
# [distfit] >INFO> [invgauss       ] [0.07 sec] [RSS: 0.0915925] [loc=32.618 scale=438.886]
# [distfit] >INFO> [invweibull     ] [0.17 sec] [RSS: 0.0907478] [loc=-427271775.692 scale=427271820.563]
# [distfit] >INFO> [johnsonsb      ] [0.15 sec] [RSS: 0.0779511] [loc=40.919 scale=10.441]
# [distfit] >INFO> [johnsonsu      ] [0.17 sec] [RSS: 0.0943191] [loc=21.392 scale=5.597]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.118791] [loc=45.543 scale=1.946]
# [distfit] >INFO> [levy           ] [0.03 sec] [RSS: 0.18641] [loc=41.096 scale=3.272]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.103797] [loc=45.950 scale=1.368]
# [distfit] >INFO> [loggamma       ] [0.06 sec] [RSS: 0.0961925] [loc=-357.002 scale=61.262]
# [distfit] >INFO> [loglaplace     ] [0.05 sec] [RSS: 0.1191] [loc=-0.168 scale=45.711]
# [distfit] >INFO> [lognorm        ] [0.00 sec] [RSS: 0.0942625] [loc=20.576 scale=25.312]
# [distfit] >INFO> [lomax          ] [0.07 sec] [RSS: 0.258642] [loc=41.231 scale=27835289359.560]
# [distfit] >INFO> [maxwell        ] [0.00 sec] [RSS: 0.0886625] [loc=40.559 scale=3.397]
# [distfit] >INFO> [mielke         ] [0.19 sec] [RSS: 0.0938215] [loc=-1.386 scale=44.367]
# [distfit] >INFO> [nakagami       ] [0.01 sec] [RSS: 0.0879513] [loc=40.729 scale=5.728]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 0.0966196] [loc=45.990 scale=2.266]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.189843] [loc=-2147483606.769 scale=2147483648.000]
# [distfit] >INFO> [pearson3       ] [0.07 sec] [RSS: 0.0927927] [loc=45.990 scale=2.288]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.11452] [loc=41.229 scale=9.792]
# [distfit] >INFO> [powerlognorm   ] [0.46 sec] [RSS: 0.0903845] [loc=-30.207 scale=73.171]
# [distfit] >INFO> [powernorm      ] [0.16 sec] [RSS: 0.0877011] [loc=42.029 scale=0.563]
# [distfit] >INFO> [rdist          ] [0.05 sec] [RSS: 0.080518] [loc=46.086 scale=5.026]
# [distfit] >INFO> [reciprocal     ] [0.02 sec] [RSS: 0.116404] [loc=-0.865 scale=1.000]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.0851122] [loc=41.176 scale=3.762]
# [distfit] >INFO> [rice           ] [0.05 sec] [RSS: 0.0881405] [loc=41.056 scale=2.653]
# [distfit] >INFO> [recipinvgauss  ] [1.72 sec] [RSS: 0.0934904] [loc=26.635 scale=0.266]
# [distfit] >INFO> [semicircular   ] [0.01 sec] [RSS: 0.0829935] [loc=46.126 scale=4.912]
# [distfit] >INFO> [t              ] [0.35 sec] [RSS: 0.0966257] [loc=45.990 scale=2.265]
# [distfit] >INFO> [triang         ] [0.09 sec] [RSS: 0.0857178] [loc=41.036 scale=10.377]
# [distfit] >INFO> [truncexpon     ] [0.02 sec] [RSS: 0.126652] [loc=41.231 scale=12.660]
# [distfit] >INFO> [truncnorm      ] [0.13 sec] [RSS: 0.206127] [loc=1.532 scale=13.783]
# [distfit] >INFO> [tukeylambda    ] [3.20 sec] [RSS: 0.0799566] [loc=46.081 scale=2.297]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.116338] [loc=41.231 scale=9.790]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 0.249837] [loc=-0.690 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.43 sec] [RSS: 0.0959621] [loc=46.127 scale=1.558]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 0.126817] [loc=40.959 scale=6.416]
# [distfit] >INFO> [weibull_min    ] [0.03 sec] [RSS: 0.0893385] [loc=40.673 scale=5.999]
# [distfit] >INFO> [weibull_max    ] [0.05 sec] [RSS: 0.0935983] [loc=52.476 scale=7.258]
# [distfit] >INFO> [wrapcauchy     ] [0.06 sec] [RSS: 0.116803] [loc=40.770 scale=1.632]
# Best fitted distribution: gennorm
# Parameters: (5.57210759970032, 46.07272875788806, 3.957032892310771)

# %% [markdown]
# ### Model longitude

# %%
binwi=FDrule(lon)
# Fit a probability density function
distlon = distfit(distr='full',bins=binwi)
distlon.fit_transform(lon)

# Plot the fitted distribution
distlon.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlon.model['name'])
print("Parameters:", distlon.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.02 sec] [RSS: 0.383443] [loc=-4.622 scale=1.573]
# [distfit] >INFO> [anglit         ] [0.01 sec] [RSS: 0.0432994] [loc=2.819 scale=9.331]
# [distfit] >INFO> [arcsine        ] [0.03 sec] [RSS: 0.155542] [loc=-4.314 scale=14.414]
# [distfit] >INFO> [beta           ] [0.03 sec] [RSS: 0.040588] [loc=-6.141 scale=16.752]
# [distfit] >INFO> [betaprime      ] [0.12 sec] [RSS: 0.0437916] [loc=-27.170 scale=155.967]
# [distfit] >INFO> [bradford       ] [0.03 sec] [RSS: 0.0956588] [loc=-4.313 scale=14.413]
# [distfit] >INFO> [burr           ] [0.36 sec] [RSS: 0.0406227] [loc=-4.387 scale=11.393]
# [distfit] >INFO> [cauchy         ] [0.00 sec] [RSS: 0.0626643] [loc=2.981 scale=2.001]
# [distfit] >INFO> [chi            ] [0.06 sec] [RSS: 0.0437903] [loc=-35.019 scale=4.160]
# [distfit] >INFO> [chi2           ] [0.07 sec] [RSS: 0.0439958] [loc=-23.765 scale=0.166]
# [distfit] >INFO> [cosine         ] [0.01 sec] [RSS: 0.0411054] [loc=2.881 scale=2.588]
# [distfit] >INFO> [dgamma         ] [0.01 sec] [RSS: 0.0503488] [loc=2.839 scale=1.346]
# [distfit] >INFO> [dweibull       ] [0.02 sec] [RSS: 0.0462193] [loc=2.851 scale=2.707]
# [distfit] >INFO> [erlang         ] [0.06 sec] [RSS: 0.0436728] [loc=-66.984 scale=0.125]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.130936] [loc=-4.313 scale=7.299]
# [distfit] >INFO> [exponnorm      ] [0.03 sec] [RSS: 0.0437307] [loc=2.984 scale=2.931]
# [distfit] >INFO> [exponweib      ] [0.21 sec] [RSS: 0.333883] [loc=-4.313 scale=1.637]
# [distfit] >INFO> [exponpow       ] [0.14 sec] [RSS: 0.330627] [loc=-4.313 scale=1.623]
# [distfit] >INFO> [f              ] [0.12 sec] [RSS: 0.0466863] [loc=-9.402 scale=12.706]
# [distfit] >INFO> [fatiguelife    ] [0.09 sec] [RSS: 0.0437807] [loc=-305.200 scale=308.158]
# [distfit] >INFO> [fisk           ] [0.28 sec] [RSS: 0.0476062] [loc=-266017235.814 scale=266017238.833]
# [distfit] >INFO> [foldcauchy     ] [0.03 sec] [RSS: 0.218203] [loc=-4.313 scale=3.283]
# [distfit] >INFO> [foldnorm       ] [0.10 sec] [RSS: 0.0964887] [loc=-4.313 scale=6.837]
# [distfit] >INFO> [genlogistic    ] [0.01 sec] [RSS: 0.0473852] [loc=2.750 scale=1.786]
# [distfit] >INFO> [genpareto      ] [0.07 sec] [RSS: 0.29806] [loc=-4.313 scale=3.388]
# [distfit] >INFO> [gennorm        ] [0.02 sec] [RSS: 0.0394178] [loc=2.932 scale=4.810]
# [distfit] >INFO> [genexpon       ] [0.25 sec] [RSS: 0.0538363] [loc=-4.345 scale=1.964]
# [distfit] >INFO> [genextreme     ] [0.11 sec] [RSS: 0.0419351] [loc=2.034 scale=3.000]
# [distfit] >INFO> [gausshyper     ] [0.43 sec] [RSS: 0.0405676] [loc=-6.031 scale=16.720]
# [distfit] >INFO> [gamma          ] [0.06 sec] [RSS: 0.0437465] [loc=-69.299 scale=0.120]
# [distfit] >INFO> [gengamma       ] [0.29 sec] [RSS: 0.0465289] [loc=-7.945 scale=0.036]
# [distfit] >INFO> [genhalflogistic] [0.10 sec] [RSS: 0.11541] [loc=-6.245 scale=17.053]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 0.101416] [loc=-4.446 scale=6.603]
# [distfit] >INFO> [gompertz       ] [0.13 sec] [RSS: 0.404168] [loc=-4.313 scale=862650516327.282]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.0483742] [loc=1.508 scale=2.877]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.0458319] [loc=4.433 scale=2.706]
# [distfit] >INFO> [halfcauchy     ] [0.02 sec] [RSS: 0.119513] [loc=-4.313 scale=6.794]
# [distfit] >INFO> [halflogistic   ] [0.03 sec] [RSS: 0.105101] [loc=-4.313 scale=4.913]
# [distfit] >INFO> [halfnorm       ] [0.01 sec] [RSS: 0.100527] [loc=-4.313 scale=7.866]
# [distfit] >INFO> [halfgennorm    ] [0.15 sec] [RSS: 0.0679583] [loc=-4.313 scale=12.804]
# [distfit] >INFO> [hypsecant      ] [0.01 sec] [RSS: 0.0510243] [loc=3.019 scale=2.095]
# [distfit] >INFO> [invgamma       ] [0.06 sec] [RSS: 0.0440938] [loc=-41.093 scale=9557.079]
# [distfit] >INFO> [invgauss       ] [0.07 sec] [RSS: 0.0443862] [loc=-19.882 scale=1295.715]
# [distfit] >INFO> [invweibull     ] [0.17 sec] [RSS: 0.0483709] [loc=-64677.386 scale=64678.895]
# [distfit] >INFO> [johnsonsb      ] [0.17 sec] [RSS: 0.0404506] [loc=-6.916 scale=18.329]
# [distfit] >INFO> [johnsonsu      ] [0.21 sec] [RSS: 0.0437002] [loc=-265561622.737 scale=211581299.861]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.0627401] [loc=3.065 scale=2.444]
# [distfit] >INFO> [levy           ] [0.01 sec] [RSS: 0.130433] [loc=-4.623 scale=5.403]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.0476059] [loc=3.019 scale=1.728]
# [distfit] >INFO> [loggamma       ] [0.04 sec] [RSS: 0.0437521] [loc=-55.214 scale=16.720]
# [distfit] >INFO> [loglaplace     ] [0.13 sec] [RSS: 0.0626362] [loc=-168161124.647 scale=168161127.711]
# [distfit] >INFO> [lognorm        ] [0.16 sec] [RSS: 0.0439157] [loc=-195.411 scale=198.373]
# [distfit] >INFO> [lomax          ] [0.08 sec] [RSS: 0.123111] [loc=-4.313 scale=707692841968.408]
# [distfit] >INFO> [maxwell        ] [0.01 sec] [RSS: 0.0452582] [loc=-4.851 scale=4.831]
# [distfit] >INFO> [mielke         ] [0.20 sec] [RSS: 0.0475913] [loc=-523235837.942 scale=523235834.049]
# [distfit] >INFO> [nakagami       ] [0.07 sec] [RSS: 0.0436751] [loc=-434.220 scale=437.223]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 0.0437307] [loc=2.987 scale=2.931]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.130936] [loc=-4294967300.313 scale=4294967296.000]
# [distfit] >INFO> [pearson3       ] [0.06 sec] [RSS: 0.043687] [loc=2.987 scale=2.937]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.078725] [loc=-4.328 scale=14.428]
# [distfit] >INFO> [powerlognorm   ] [0.47 sec] [RSS: 0.0440094] [loc=-52.172 scale=61.488]
# [distfit] >INFO> [powernorm      ] [0.11 sec] [RSS: 0.043902] [loc=4.941 scale=3.537]
# [distfit] >INFO> [rdist          ] [0.08 sec] [RSS: 0.0410331] [loc=2.890 scale=8.455]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.0533835] [loc=-4.398 scale=5.618]
# [distfit] >INFO> [rice           ] [0.14 sec] [RSS: 0.0533835] [loc=-4.398 scale=5.611]
# [distfit] >INFO> [recipinvgauss  ] [1.83 sec] [RSS: 0.043916] [loc=-40.684 scale=0.201]
# [distfit] >INFO> [semicircular   ] [0.01 sec] [RSS: 0.0546766] [loc=2.878 scale=7.231]
# [distfit] >INFO> [t              ] [0.35 sec] [RSS: 0.0437307] [loc=2.987 scale=2.931]
# [distfit] >INFO> [triang         ] [0.13 sec] [RSS: 0.0433036] [loc=-4.658 scale=14.826]
# [distfit] >INFO> [truncexpon     ] [0.02 sec] [RSS: 0.0950281] [loc=-4.313 scale=16.501]
# [distfit] >INFO> [truncnorm      ] [0.10 sec] [RSS: 0.0431447] [loc=2.918 scale=3.015]
# [distfit] >INFO> [tukeylambda    ] [4.30 sec] [RSS: 0.0409586] [loc=2.893 scale=2.492]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.0818857] [loc=-4.313 scale=14.413]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 0.263512] [loc=0.160 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.44 sec] [RSS: 0.0437245] [loc=2.987 scale=97.035]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 0.0959751] [loc=-4.853 scale=10.436]
# [distfit] >INFO> [weibull_min    ] [0.02 sec] [RSS: 0.0427086] [loc=-7.239 scale=11.302]
# [distfit] >INFO> [weibull_max    ] [0.08 sec] [RSS: 0.455404] [loc=10.100 scale=1.486]
# [distfit] >INFO> [wrapcauchy     ] [0.08 sec] [RSS: 0.0818974] [loc=-4.332 scale=2.316]
# Best fitted distribution: gennorm
# Parameters: (3.057729944348239, 2.93166507060009, 4.810402935187785)

# %% [markdown]
# ### Model Tx power

# %%
powbin=FDrule(power)
# Fit a probability density function
distpow = distfit(distr='powerlaw',bins=powbin)
distpow.fit_transform(power)

# Plot the fitted distribution
distpow.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distpow.model['name'])
print("Parameters:", distpow.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [powerlaw] [0.06 sec] [RSS: 1.84034e-05] [loc=-0.000 scale=398000.000]
# Best fitted distribution: powerlaw
# Parameters: (0.1289913415622871, -2.2250738585072014e-308, 398000.00000000006)

# %% [markdown]
# ### Model Tx Freq

# %%
freqbin=FDrule(freq)
# Fit a probability density function
distfreq = distfit(distr='full',bins=freqbin)
distfreq.fit_transform(freq)

# Plot the fitted distribution
distfreq.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distfreq.model['name'])
print("Parameters:", distfreq.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.07 sec] [RSS: 0.0149654] [loc=-56.721 scale=6224.526]
# [distfit] >INFO> [anglit         ] [0.03 sec] [RSS: 0.112212] [loc=60.000 scale=0.000]
# [distfit] >INFO> [arcsine        ] [0.03 sec] [RSS: 0.0761014] [loc=59.989 scale=39.911]
# [distfit] >INFO> [beta           ] [0.12 sec] [RSS: 0.0157693] [loc=-199.384 scale=309.764]
# [distfit] >INFO> [betaprime      ] [0.11 sec] [RSS: 0.0151486] [loc=-168.324 scale=26.533]
# [distfit] >INFO> [bradford       ] [0.03 sec] [RSS: 0.0776724] [loc=59.398 scale=40.502]
# [distfit] >INFO> [burr           ] [0.25 sec] [RSS: 0.017589] [loc=-0.564 scale=91.688]
# [distfit] >INFO> [cauchy         ] [0.00 sec] [RSS: 0.0280363] [loc=93.701 scale=2.646]
# [distfit] >INFO> [chi            ] [0.09 sec] [RSS: 0.237664] [loc=87.600 scale=1.569]
# [distfit] >INFO> [chi2           ] [0.07 sec] [RSS: 0.0121485] [loc=43.335 scale=0.241]
# [distfit] >INFO> [cosine         ] [0.04 sec] [RSS: 0.112212] [loc=60.000 scale=0.000]
# [distfit] >INFO> [dgamma         ] [0.02 sec] [RSS: 0.0179945] [loc=93.550 scale=1.695]
# [distfit] >INFO> [dweibull       ] [0.02 sec] [RSS: 0.0160816] [loc=93.648 scale=3.417]
# [distfit] >INFO> [erlang         ] [0.07 sec] [RSS: 0.0148951] [loc=2.454 scale=0.145]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.100482] [loc=60.000 scale=33.671]
# [distfit] >INFO> [exponnorm      ] [0.03 sec] [RSS: 0.0153029] [loc=93.668 scale=3.597]
# [distfit] >INFO> [exponweib      ] [0.30 sec] [RSS: 0.0156847] [loc=34.547 scale=54.897]
# [distfit] >INFO> [exponpow       ] [0.24 sec] [RSS: 0.118043] [loc=87.600 scale=1.230]
# [distfit] >INFO> [f              ] [0.08 sec] [RSS: 0.0152578] [loc=-33.685 scale=127.286]
# [distfit] >INFO> [fatiguelife    ] [0.10 sec] [RSS: 0.0152081] [loc=-301.013 scale=394.669]
# [distfit] >INFO> [fisk           ] [0.14 sec] [RSS: 0.0181794] [loc=-1.088 scale=94.724]
# [distfit] >INFO> [foldcauchy     ] [0.05 sec] [RSS: 0.0280076] [loc=-0.235 scale=2.647]
# [distfit] >INFO> [foldnorm       ] [0.09 sec] [RSS: 0.357479] [loc=87.600 scale=1.661]
# [distfit] >INFO> [genlogistic    ] [0.03 sec] [RSS: 0.0171521] [loc=89.701 scale=2.770]
# [distfit] >INFO> [genpareto      ] [0.11 sec] [RSS: 0.0584797] [loc=-1.120 scale=263.828]
# [distfit] >INFO> [gennorm        ] [0.02 sec] [RSS: 0.010734] [loc=93.650 scale=5.675]
# [distfit] >INFO> [genexpon       ] [0.16 sec] [RSS: 0.0995281] [loc=59.993 scale=1.998]
# [distfit] >INFO> [genextreme     ] [0.06 sec] [RSS: 0.0143265] [loc=92.741 scale=3.856]
# [distfit] >INFO> [gausshyper     ] [0.28 sec] [RSS: 0.0457426] [loc=59.864 scale=40.036]
# [distfit] >INFO> [gamma          ] [0.07 sec] [RSS: 0.0150784] [loc=5.268 scale=0.148]
# [distfit] >INFO> [gengamma       ] [0.27 sec] [RSS: 0.0154654] [loc=-33.428 scale=66.886]
# [distfit] >INFO> [genhalflogistic] [0.09 sec] [RSS: 0.0438706] [loc=59.999 scale=42.436]
# [distfit] >INFO> [gibrat         ] [0.04 sec] [RSS: 0.0918128] [loc=59.961 scale=33.481]
# [distfit] >INFO> [gompertz       ] [0.19 sec] [RSS: 0.0073545] [loc=87.600 scale=4.662]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.0154671] [loc=91.993 scale=5.202]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.0179145] [loc=95.449 scale=3.228]
# [distfit] >INFO> [halfcauchy     ] [0.03 sec] [RSS: 0.0973995] [loc=60.000 scale=33.483]
# [distfit] >INFO> [halflogistic   ] [0.03 sec] [RSS: 0.0943094] [loc=60.000 scale=21.868]
# [distfit] >INFO> [halfnorm       ] [0.03 sec] [RSS: 0.0144738] [loc=87.600 scale=7.046]
# [distfit] >INFO> [halfgennorm    ] [0.12 sec] [RSS: 0.11931] [loc=60.000 scale=1.451]
# [distfit] >INFO> [hypsecant      ] [0.01 sec] [RSS: 0.020675] [loc=93.683 scale=2.654]
# [distfit] >INFO> [invgamma       ] [0.07 sec] [RSS: 0.0150801] [loc=-61.944 scale=287957.814]
# [distfit] >INFO> [invgauss       ] [0.07 sec] [RSS: 0.0119086] [loc=52.700 scale=3711.115]
# [distfit] >INFO> [invweibull     ] [0.17 sec] [RSS: 0.0233748] [loc=18.932 scale=73.166]
# [distfit] >INFO> [johnsonsb      ] [0.22 sec] [RSS: 0.0153614] [loc=48.530 scale=61.501]
# [distfit] >INFO> [johnsonsu      ] [0.19 sec] [RSS: 0.0156919] [loc=137.097 scale=17.077]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.0303583] [loc=93.700 scale=3.093]
# [distfit] >INFO> [levy           ] [0.03 sec] [RSS: 0.09778] [loc=59.672 scale=32.956]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.0182306] [loc=93.679 scale=2.171]
# [distfit] >INFO> [loggamma       ] [0.03 sec] [RSS: 0.0156523] [loc=31.236 scale=18.854]
# [distfit] >INFO> [loglaplace     ] [0.05 sec] [RSS: 0.0302437] [loc=-0.332 scale=94.032]
# [distfit] >INFO> [lognorm        ] [0.00 sec] [RSS: 0.0153028] [loc=-237788.889 scale=237882.560]
# [distfit] >INFO> [lomax          ] [0.06 sec] [RSS: 0.100473] [loc=60.000 scale=1620.053]
# [distfit] >INFO> [maxwell        ] [0.02 sec] [RSS: 0.0145114] [loc=85.222 scale=5.298]
# [distfit] >INFO> [mielke         ] [0.15 sec] [RSS: 0.0175584] [loc=-8.065 scale=99.040]
# [distfit] >INFO> [nakagami       ] [0.03 sec] [RSS: 0.0119438] [loc=87.449 scale=7.176]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 0.0153029] [loc=93.671 scale=3.597]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.100482] [loc=-2147483588.000 scale=2147483648.000]
# [distfit] >INFO> [pearson3       ] [0.07 sec] [RSS: 0.0157707] [loc=93.671 scale=3.623]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.0248486] [loc=59.460 scale=40.440]
# [distfit] >INFO> [powerlognorm   ] [0.26 sec] [RSS: 0.11689] [loc=59.477 scale=1.445]
# [distfit] >INFO> [powernorm      ] [0.09 sec] [RSS: 0.0153647] [loc=94.073 scale=3.729]
# [distfit] >INFO> [rdist          ] [0.06 sec] [RSS: 0.112212] [loc=60.000 scale=0.000]
# [distfit] >INFO> [reciprocal     ] [0.02 sec] [RSS: 0.0891425] [loc=-3.794 scale=1.000]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.0747552] [loc=59.993 scale=23.949]
# [distfit] >INFO> [rice           ] [0.10 sec] [RSS: 0.253275] [loc=87.593 scale=1.661]
# [distfit] >INFO> [recipinvgauss  ] [1.80 sec] [RSS: 0.0149205] [loc=12.474 scale=0.162]
# [distfit] >INFO> [semicircular   ] [0.04 sec] [RSS: 0.112212] [loc=60.000 scale=0.000]
# [distfit] >INFO> [t              ] [0.34 sec] [RSS: 0.0154027] [loc=93.670 scale=3.589]
# [distfit] >INFO> [triang         ] [0.08 sec] [RSS: 0.0416025] [loc=59.990 scale=39.959]
# [distfit] >INFO> [truncexpon     ] [0.05 sec] [RSS: 0.0935269] [loc=59.964 scale=61.538]
# [distfit] >INFO> [truncnorm      ] [0.16 sec] [RSS: 0.141807] [loc=8.163 scale=14.913]
# [distfit] >INFO> [tukeylambda    ] [2.77 sec] [RSS: 0.000484221] [loc=93.750 scale=6.223]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.0776648] [loc=60.000 scale=39.900]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 1.06459] [loc=2.274 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.44 sec] [RSS: 0.112212] [loc=60.000 scale=0.000]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 0.087707] [loc=59.577 scale=54.116]
# [distfit] >INFO> [weibull_min    ] [0.04 sec] [RSS: 0.0138039] [loc=86.097 scale=8.567]
# [distfit] >INFO> [weibull_max    ] [0.12 sec] [RSS: 0.17419] [loc=99.900 scale=1.401]
# [distfit] >INFO> [wrapcauchy     ] [0.04 sec] [RSS: 0.0677125] [loc=60.000 scale=6.350]
# Best fitted distribution: tukeylambda
# Parameters: (1.0118494431534355, 93.7500092644645, 6.222883449637017)

# %% [markdown]
# ## Generating data within country

# %%
validpix = np.nonzero(template)[0] 
finval = 10000

newlat = distlat.generate(30000)
newlon = distlon.generate(30000)
newpix = hp.ang2pix(128, newlon, newlat, lonlat=True)
finpix = []
for pixie in newpix:
    if pixie in validpix:  
        finpix.append(pixie)
    if len(finpix)==finval:
        break

# %%
plt.hist(newlat,bins=int(np.sqrt(len(newlat))))
plt.show()

# %%
finlon,finlat=hp.pix2ang(128,finpix,lonlat=True)
print(len(finlat))
print(finval)
# print(i)
# print(len(newlon))
# Out:
# 10000
# 10000

# %%
newwww=np.zeros(hp.nside2npix(128))
for pppp in finpix:
    newwww[pppp]+=1
hp.mollview(newwww,flip='geo',norm='hist')

# %% [markdown]
# ## Generate Freq and power values

# %%
newfreq=distfreq.generate(finval)
newpow=distpow.generate(finval)

# %%
plt.hist(freq,bins=int(np.sqrt(len(freq))))
plt.title('Original frequency')
plt.show()
plt.hist(newfreq,bins=int(np.sqrt(len(newfreq))))
plt.title('Generated frequency data')
plt.show()

# %%
plt.hist(power,bins=int(np.sqrt(len(power))))
plt.title('Original power')
plt.show()
plt.hist(newpow,bins=int(np.sqrt(len(newpow))))
plt.title('Generated power data')
plt.show()
