# %%
import numpy as np 
import healpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import tifffile as tiff
import glob
import seaborn as sns
# sns.set_style("darkgrid")
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from num2words import num2words
from scipy.optimize import curve_fit
from mpl_toolkits import mplot3d
import os
from distfit import distfit
import sys
import scipy
import rasterio
from scipy.interpolate import CubicSpline
from scipy.integrate import quad
from scipy.stats import multivariate_normal
# sns.set(rc={"xtick.bottom": True, "ytick.left": True})
# %matplotlib inline
# %matplotlib notebook

# %% [markdown]
# ## Read Country DB parameters

# %%
csv_files = ['./database/Russia.csv']
#France has 9393 Tx

# --Create an empty dataframe to store the combined data-- #
df = pd.DataFrame()

# Loop through each CSV file and append its contents to the combined dataframe
for csv_file in (csv_files):
    df_temp = pd.read_csv(csv_file)
    df = pd.concat([df, df_temp],ignore_index=True) 
# read Tx params into numpy arrays
df=df.dropna()
power=df['EIRP'].to_numpy()
lat_128=df['Latitude in degrees'].to_numpy()
lon_128=df['Longitude in degrees'].to_numpy()
# convert Tx coords into HEALPix pixels
pix=hp.ang2pix(128,lon_128,lat_128,lonlat=True)

# %%
# make number of Tx per pixel map
Tx_num_128=np.zeros(hp.nside2npix(128))
for pi in pix:
    Tx_num_128[pi]+=1
hp.mollview(Tx_num_128,flip='geo',cmap='plasma',norm='hist',title='')
plt.show()

# %%
# making total Tx power in each pixel
Tx_pow_128=np.zeros(hp.nside2npix(128))
for index,p in enumerate(pix):
    Tx_pow_128[p]+=(power[index])
hp.mollview(Tx_pow_128,flip='geo',cmap='viridis',norm='hist',min=300)
plt.show()

# %% [markdown]
# # Fitting PDF to Tx params

# %%
# read Tx params of selected 5k country
fr_df=pd.read_csv('./database/Russia.csv')
fr_df=fr_df.dropna()
lat=fr_df['Latitude in degrees'].to_numpy()
lon=fr_df['Longitude in degrees'].to_numpy()
power=fr_df['EIRP'].to_numpy()
freq=fr_df['Frequency(MHz)'].to_numpy()

# %%
# Bin width using Freedman Diaconis rule
def FDrule(data):
    # Calculate interquartile range
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    
    # Calculate Freedman-Diaconis bin width
    n = len(data)
    bin_width = 2 * iqr / (n ** (1/3))

    # Calculate number of bins
    data_range = max(data) - min(data)
    num_bins = int(data_range / bin_width) + 1
    
    return num_bins

# %% [markdown]
# ## Country HEALPix map as mask

# %%
# France shapefile was downloaded from https://gadm.org/download_country.html and rasterized using QGIS
# Open the GeoTIFF file
file_path = '/home/pratush/Desktop/Russia_raster.tif'
src = rasterio.open(file_path)

# Read the raster data as a numpy array
data = src.read(1)  # Assuming a single-band raster

# Find pixels with non-zero values
non_zero_pixels = np.where(data != 0)

# Get the coordinates of non zero pixels
templat=[]
templon=[]
for y, x in zip(*non_zero_pixels):
    lonval, latval = src.xy(y, x)  # Get the longitude and latitude of the pixel
    templat.append(latval)
    templon.append(lonval)

# %%
# Making a mask for generated data
temppix=hp.ang2pix(128,templon,templat,lonlat=True)
template=np.zeros(hp.nside2npix(128))
for pi in temppix:
    template[pi]+=1
template=np.where(template != 0, 1, 0)
hp.mollview(template,flip='geo')

# %%
def shapecheck(lon,lat):
    checkpix=hp.ang2pix(128,lon,lat,lonlat=True)
    checkmap=np.zeros(hp.nside2npix(128))
    for pi in checkpix:
        checkmap[pi]+=1
    checkmap=np.where(checkmap != 0, 1, 0)
    return hp.mollview(checkmap,flip='geo')

# %% [markdown]
# ### Modelling Latitude

# %%
binw=FDrule(lat)
# Fit a probability density function
distlat = distfit(distr='full',bins=binw)
distlat.fit_transform(lat)

# Plot the fitted distribution
distlat.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlat.model['name'])
print("Parameters:", distlat.model['params'])
# Out:
# fit
# transform
# [alpha          ] [0.08 sec] [RSS: 0.0173902] [loc=-83.465 scale=3477.132]
# [anglit         ] [0.01 sec] [RSS: 0.032394] [loc=56.488 scale=21.417]
# [arcsine        ] [0.04 sec] [RSS: 0.084393] [loc=41.569 scale=31.733]
# [beta           ] [0.13 sec] [RSS: 0.015669] [loc=-2770.948 scale=3117.567]
# [betaprime      ] [0.12 sec] [RSS: 0.0162485] [loc=-153.409 scale=6.322]
# [bradford       ] [0.03 sec] [RSS: 0.0486402] [loc=41.570 scale=31.733]
# [burr           ] [0.39 sec] [RSS: 0.0117837] [loc=-0.332 scale=56.882]
# [cauchy         ] [0.00 sec] [RSS: 0.0106005] [loc=54.764 scale=2.718]
# [chi            ] [0.08 sec] [RSS: 0.0162913] [loc=-19.148 scale=7.664]
# [chi2           ] [0.07 sec] [RSS: 0.0171554] [loc=0.093 scale=0.277]
# [cosine         ] [0.04 sec] [RSS: 0.0241273] [loc=55.283 scale=5.742]
# [dgamma         ] [0.01 sec] [RSS: 0.00970264] [loc=54.757 scale=3.474]
# [dweibull       ] [0.03 sec] [RSS: 0.0100711] [loc=54.738 scale=4.200]
# [erlang         ] [0.07 sec] [RSS: 0.0159933] [loc=-238.164 scale=0.099]
# [expon          ] [0.00 sec] [RSS: 0.0619202] [loc=41.570 scale=12.736]
# [exponnorm      ] [0.03 sec] [RSS: 0.0158054] [loc=54.300 scale=5.377]
# [exponweib      ] [0.30 sec] [RSS: 0.0154756] [loc=-30.768 scale=77.192]
# [exponpow       ] [0.15 sec] [RSS: 0.133828] [loc=41.570 scale=1.243]
# [f              ] [0.13 sec] [RSS: 0.0159594] [loc=-438.036 scale=492.325]
# [fatiguelife    ] [0.10 sec] [RSS: 0.0159351] [loc=-333.987 scale=388.273]
# [fisk           ] [0.28 sec] [RSS: 0.0128479] [loc=-331783948.656 scale=331784003.072]
# [foldcauchy     ] [0.03 sec] [RSS: 0.0105492] [loc=-0.150 scale=2.724]
# [foldnorm       ] [0.05 sec] [RSS: 0.424804] [loc=41.570 scale=2.164]
# [genlogistic    ] [0.02 sec] [RSS: 0.0119894] [loc=55.493 scale=2.689]
# [genpareto      ] [0.13 sec] [RSS: 0.0699559] [loc=-0.091 scale=102.282]
# [gennorm        ] [0.02 sec] [RSS: 0.0110093] [loc=54.525 scale=5.415]
# [genexpon       ] [0.24 sec] [RSS: 0.0292571] [loc=41.565 scale=1.928]
# [genextreme     ] [0.35 sec] [RSS: 0.195899] [loc=71.861 scale=4.843]
# [gausshyper     ] [0.44 sec] [RSS: 0.0171675] [loc=29.882 scale=48.982]
# [gamma          ] [0.07 sec] [RSS: 0.0159868] [loc=-234.772 scale=0.100]
# [gengamma       ] [0.27 sec] [RSS: 0.0156532] [loc=-123.938 scale=67.841]
# [genhalflogistic] [0.13 sec] [RSS: 0.034518] [loc=41.570 scale=12.208]
# [gibrat         ] [0.05 sec] [RSS: 0.0508863] [loc=41.546 scale=11.097]
# [gompertz       ] [0.10 sec] [RSS: 0.0560812] [loc=41.570 scale=3.164]
# [gumbel_r       ] [0.00 sec] [RSS: 0.0262736] [loc=51.591 scale=5.360]
# [gumbel_l       ] [0.00 sec] [RSS: 0.0198798] [loc=56.989 scale=5.453]
# [halfcauchy     ] [0.03 sec] [RSS: 0.0572488] [loc=41.570 scale=11.852]
# [halflogistic   ] [0.03 sec] [RSS: 0.0505181] [loc=41.570 scale=8.610]
# [halfnorm       ] [0.01 sec] [RSS: 0.0479848] [loc=41.570 scale=13.865]
# [halfgennorm    ] [0.09 sec] [RSS: 0.0977349] [loc=41.570 scale=1.329]
# [hypsecant      ] [0.01 sec] [RSS: 0.011351] [loc=54.505 scale=3.492]
# [invgamma       ] [0.07 sec] [RSS: 0.0168242] [loc=-70.050 scale=65328.815]
# [invgauss       ] [0.07 sec] [RSS: 0.0217715] [loc=24.024 scale=828.630]
# [invweibull     ] [0.17 sec] [RSS: 0.0262723] [loc=-1237313637.730 scale=1237313689.322]
# [johnsonsb      ] [0.26 sec] [RSS: 0.0156722] [loc=-461.972 scale=775.593]
# [johnsonsu      ] [0.08 sec] [RSS: 0.0120446] [loc=55.690 scale=8.421]
# [laplace        ] [0.00 sec] [RSS: 0.0109572] [loc=54.550 scale=4.048]
# [levy           ] [0.03 sec] [RSS: 0.061417] [loc=41.439 scale=8.565]
# [logistic       ] [0.00 sec] [RSS: 0.0128826] [loc=54.416 scale=2.981]
# [loggamma       ] [0.06 sec] [RSS: 0.0156437] [loc=-823.322 scale=135.877]
# [loglaplace     ] [0.05 sec] [RSS: 0.0113961] [loc=-0.177 scale=54.727]
# [lognorm        ] [0.00 sec] [RSS: 0.0158055] [loc=-524246.099 scale=524300.406]
# [lomax          ] [0.07 sec] [RSS: 0.0620015] [loc=41.570 scale=1159.301]
# [maxwell        ] [0.00 sec] [RSS: 0.022333] [loc=40.311 scale=8.656]
# [mielke         ] [0.13 sec] [RSS: 0.0117843] [loc=-0.578 scale=57.121]
# [nakagami       ] [0.07 sec] [RSS: 0.0158717] [loc=-410.887 scale=465.225]
# [norm           ] [0.00 sec] [RSS: 0.0158054] [loc=54.306 scale=5.377]
# [pareto         ] [0.00 sec] [RSS: 0.0619202] [loc=-1073741782.430 scale=1073741824.000]
# [pearson3       ] [0.07 sec] [RSS: 0.0156597] [loc=54.306 scale=5.377]
# [powerlaw       ] [0.01 sec] [RSS: 0.0509675] [loc=41.570 scale=31.733]
# [powerlognorm   ] [0.39 sec] [RSS: 0.0562244] [loc=37.247 scale=4.327]
# [powernorm      ] [0.10 sec] [RSS: 0.0154078] [loc=56.218 scale=5.983]
# [rdist          ] [0.10 sec] [RSS: 0.0158125] [loc=54.309 scale=232.617]
# [reciprocal     ] [0.03 sec] [RSS: 0.0485283] [loc=-3.053 scale=1.000]
# [rayleigh       ] [0.00 sec] [RSS: 0.0274045] [loc=41.556 scale=9.785]
# [rice           ] [0.09 sec] [RSS: 0.324457] [loc=41.570 scale=2.166]
# [recipinvgauss  ] [1.80 sec] [RSS: 0.0171209] [loc=-8.956 scale=0.461]
# [semicircular   ] [0.01 sec] [RSS: 0.0401797] [loc=57.424 scale=15.881]
# [t              ] [0.35 sec] [RSS: 0.0150435] [loc=54.441 scale=5.229]
# [triang         ] [0.14 sec] [RSS: 0.0231494] [loc=40.501 scale=32.812]
# [truncexpon     ] [0.02 sec] [RSS: 0.0479088] [loc=41.570 scale=32.281]
# [truncnorm      ] [0.14 sec] [RSS: 0.0532602] [loc=10.690 scale=26.005]
# [tukeylambda    ] [4.66 sec] [RSS: 0.0132239] [loc=54.400 scale=3.074]
# [uniform        ] [0.00 sec] [RSS: 0.0510472] [loc=41.570 scale=31.732]
# [vonmises       ] [0.00 sec] [RSS: 0.831024] [loc=-0.443 scale=1.000]
# [vonmises_line  ] [0.45 sec] [RSS: 0.0131479] [loc=54.430 scale=6.069]
# [wald           ] [0.02 sec] [RSS: 0.0516063] [loc=41.116 scale=16.664]
# [weibull_min    ] [0.02 sec] [RSS: 0.0167273] [loc=37.336 scale=18.845]
# [weibull_max    ] [0.07 sec] [RSS: 0.204848] [loc=73.303 scale=1.619]
# [wrapcauchy     ] [0.04 sec] [RSS: 0.0513306] [loc=38.888 scale=5.477]
# Best fitted distribution: dgamma
# Parameters: (1.1662224892083912, 54.757142361910454, 3.474293790410162)

# %% [markdown]
# ### Model longitude

# %%
binwi=FDrule(lon)
# Fit a probability density function
distlon = distfit(distr='full',bins=binwi)
distlon.fit_transform(lon)

# Plot the fitted distribution
distlon.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlon.model['name'])
print("Parameters:", distlon.model['params'])
# Out:
# fit
# transform
# [alpha          ] [0.06 sec] [RSS: 0.000398849] [loc=-16.994 scale=227.205]
# [anglit         ] [0.03 sec] [RSS: 0.00128766] [loc=80.284 scale=109.466]
# [arcsine        ] [0.04 sec] [RSS: 0.0018387] [loc=19.550 scale=151.512]
# [beta           ] [0.13 sec] [RSS: 0.00048873] [loc=19.350 scale=20536392.157]
# [betaprime      ] [0.11 sec] [RSS: 0.000435649] [loc=-0.776 scale=1.555]
# [bradford       ] [0.08 sec] [RSS: 0.00112729] [loc=19.550 scale=148.286]
# [burr           ] [0.37 sec] [RSS: 0.000335511] [loc=-0.098 scale=21.600]
# [cauchy         ] [0.01 sec] [RSS: 0.000704834] [loc=50.814 scale=15.355]
# [chi            ] [0.07 sec] [RSS: 0.00326099] [loc=19.550 scale=5.380]
# [chi2           ] [0.04 sec] [RSS: 0.000487422] [loc=19.235 scale=10.109]
# [cosine         ] [0.04 sec] [RSS: 0.00113956] [loc=72.735 scale=30.117]
# [dgamma         ] [0.02 sec] [RSS: 0.000824153] [loc=57.834 scale=18.798]
# [dweibull       ] [0.03 sec] [RSS: 0.000818602] [loc=57.879 scale=25.822]
# [erlang         ] [0.02 sec] [RSS: 0.000487421] [loc=19.235 scale=20.218]
# [expon          ] [0.00 sec] [RSS: 0.0011682] [loc=19.550 scale=46.138]
# [exponnorm      ] [0.04 sec] [RSS: 0.000239902] [loc=32.238 scale=4.791]
# [exponweib      ] [0.30 sec] [RSS: 0.000370624] [loc=14.774 scale=4.750]
# [exponpow       ] [0.16 sec] [RSS: 0.000806036] [loc=19.548 scale=78.542]
# [f              ] [0.13 sec] [RSS: 0.000364349] [loc=8.662 scale=44.337]
# [fatiguelife    ] [0.08 sec] [RSS: 0.00038152] [loc=13.652 scale=43.845]
# [fisk           ] [0.16 sec] [RSS: 0.000405138] [loc=18.462 scale=37.695]
# [foldcauchy     ] [0.06 sec] [RSS: 0.000578433] [loc=19.550 scale=16.416]
# [foldnorm       ] [0.05 sec] [RSS: 0.000833758] [loc=19.550 scale=47.124]
# [genlogistic    ] [0.09 sec] [RSS: 0.000628375] [loc=-106.768 scale=21.955]
# [genpareto      ] [0.16 sec] [RSS: 0.000909765] [loc=19.550 scale=65.833]
# [gennorm        ] [0.03 sec] [RSS: 0.000975519] [loc=64.974 scale=43.700]
# [genexpon       ] [0.20 sec] [RSS: 0.000622704] [loc=12.198 scale=1.918]
# [genextreme     ] [0.27 sec] [RSS: 0.000360393] [loc=48.660 scale=18.729]
# [gausshyper     ] [0.39 sec] [RSS: 0.000497056] [loc=19.316 scale=1386.142]
# [gamma          ] [0.02 sec] [RSS: 0.000487421] [loc=19.235 scale=20.218]
# [gengamma       ] [0.28 sec] [RSS: 0.000692614] [loc=19.535 scale=70.664]
# [genhalflogistic] [0.15 sec] [RSS: 0.000803119] [loc=19.548 scale=39.787]
# [gibrat         ] [0.03 sec] [RSS: 0.000596855] [loc=19.392 scale=36.569]
# [gompertz       ] [0.14 sec] [RSS: 0.00090438] [loc=16.740 scale=57.175]
# [gumbel_r       ] [0.00 sec] [RSS: 0.00062868] [loc=51.771 scale=21.940]
# [gumbel_l       ] [0.00 sec] [RSS: 0.00132031] [loc=82.923 scale=36.819]
# [halfcauchy     ] [0.03 sec] [RSS: 0.00108621] [loc=19.550 scale=36.561]
# [halflogistic   ] [0.04 sec] [RSS: 0.000859075] [loc=19.550 scale=32.212]
# [halfnorm       ] [0.01 sec] [RSS: 0.000835456] [loc=19.550 scale=55.935]
# [halfgennorm    ] [0.15 sec] [RSS: 0.000827883] [loc=19.550 scale=83.729]
# [hypsecant      ] [0.01 sec] [RSS: 0.000859838] [loc=59.030 scale=20.831]
# [invgamma       ] [0.04 sec] [RSS: 0.000363634] [loc=6.978 scale=194.802]
# [invgauss       ] [0.07 sec] [RSS: 0.000372509] [loc=13.003 scale=133.983]
# [invweibull     ] [0.12 sec] [RSS: 0.000360392] [loc=-16.067 scale=64.727]
# [johnsonsb      ] [0.17 sec] [RSS: 0.000419501] [loc=17.718 scale=261.160]
# [johnsonsu      ] [0.08 sec] [RSS: 0.0002788] [loc=27.678 scale=8.369]
# [laplace        ] [0.00 sec] [RSS: 0.000847999] [loc=55.520 scale=24.367]
# [levy           ] [0.03 sec] [RSS: 0.00109343] [loc=18.754 scale=28.081]
# [logistic       ] [0.00 sec] [RSS: 0.000900364] [loc=61.385 scale=17.561]
# [loggamma       ] [0.06 sec] [RSS: 0.000986272] [loc=-10251.315 scale=1379.262]
# [loglaplace     ] [0.04 sec] [RSS: 0.000763193] [loc=-0.146 scale=55.666]
# [lognorm        ] [0.00 sec] [RSS: 0.000381981] [loc=15.377 scale=41.687]
# [lomax          ] [0.07 sec] [RSS: 0.00116571] [loc=19.550 scale=5496.399]
# [maxwell        ] [0.01 sec] [RSS: 0.000841377] [loc=-0.012 scale=42.097]
# [mielke         ] [0.20 sec] [RSS: 0.00036] [loc=-12.195 scale=21.598]
# [nakagami       ] [0.02 sec] [RSS: 0.00066494] [loc=19.533 scale=55.949]
# [norm           ] [0.00 sec] [RSS: 0.000986102] [loc=65.688 scale=31.623]
# [pareto         ] [0.00 sec] [RSS: 0.0011682] [loc=-4294967276.450 scale=4294967296.000]
# [pearson3       ] [0.07 sec] [RSS: 0.000487421] [loc=65.688 scale=30.646]
# [powerlaw       ] [0.00 sec] [RSS: 0.00136402] [loc=19.550 scale=146.570]
# [powerlognorm   ] [0.39 sec] [RSS: 0.00150566] [loc=-11.720 scale=6.561]
# [powernorm      ] [0.20 sec] [RSS: nan] [loc=14.801 scale=0.217]
# [rdist          ] [0.10 sec] [RSS: 0.000986959] [loc=65.730 scale=1096.313]
# [reciprocal     ] [0.06 sec] [RSS: 0.00113567] [loc=-15.417 scale=1.000]
# [rayleigh       ] [0.00 sec] [RSS: 0.000777007] [loc=14.821 scale=42.352]
# [rice           ] [0.10 sec] [RSS: 0.000777007] [loc=14.821 scale=42.352]
# [recipinvgauss  ] [1.70 sec] [RSS: 0.000396118] [loc=14.469 scale=15.448]
# [semicircular   ] [0.03 sec] [RSS: 0.00142583] [loc=89.367 scale=76.793]
# [t              ] [0.33 sec] [RSS: 0.000901153] [loc=61.506 scale=27.047]
# [triang         ] [0.16 sec] [RSS: 0.000607257] [loc=19.127 scale=147.408]
# [truncexpon     ] [0.04 sec] [RSS: 0.00116294] [loc=5.270 scale=149.377]
# [truncnorm      ] [0.03 sec] [RSS: 0.000986102] [loc=65.688 scale=31.623]
# [tukeylambda    ] [5.06 sec] [RSS: 0.000896484] [loc=61.177 scale=17.347]
# [uniform        ] [0.00 sec] [RSS: 0.00147887] [loc=19.550 scale=146.570]
# [vonmises       ] [0.00 sec] [RSS: 0.701477] [loc=2.633 scale=1.000]
# [vonmises_line  ] [0.45 sec] [RSS: 0.000884586] [loc=61.035 scale=34.115]
# [wald           ] [0.01 sec] [RSS: 0.000466723] [loc=17.586 scale=56.837]
# [weibull_min    ] [0.03 sec] [RSS: 0.000584784] [loc=19.528 scale=51.622]
# [weibull_max    ] [0.12 sec] [RSS: 0.00362194] [loc=166.120 scale=1.625]
# [wrapcauchy     ] [0.04 sec] [RSS: 0.00147426] [loc=18.814 scale=23.444]
# Best fitted distribution: exponnorm
# Parameters: (6.981475832217603, 32.23825114230188, 4.791216709090322)

# %% [markdown]
# ### Model Tx power

# %%
powbin=FDrule(power)
# Fit a probability density function
distpow = distfit(distr='powerlaw',bins=powbin)
distpow.fit_transform(power)

# Plot the fitted distribution
distpow.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distpow.model['name'])
print("Parameters:", distpow.model['params'])
# Out:
# fit
# transform
# [powerlaw] [0.07 sec] [RSS: 1.91867e-06] [loc=-0.000 scale=160000.000]
# Best fitted distribution: powerlaw
# Parameters: (0.006728533047148055, -2.2250738585072014e-308, 160000.00000000003)

# %% [markdown]
# ### Model Tx Freq

# %%
freqbin=FDrule(freq)
# Fit a probability density function
distfreq = distfit(distr='full',bins=freqbin)
distfreq.fit_transform(freq)

# Plot the fitted distribution
distfreq.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distfreq.model['name'])
print("Parameters:", distfreq.model['params'])
# Out:
# fit
# transform
# [alpha          ] [0.07 sec] [RSS: 0.0171441] [loc=31.756 scale=213.050]
# [anglit         ] [0.01 sec] [RSS: 0.0211236] [loc=75.928 scale=26.168]
# [arcsine        ] [0.05 sec] [RSS: 0.0230915] [loc=56.250 scale=35.548]
# [beta           ] [0.14 sec] [RSS: 0.0272045] [loc=56.250 scale=35.513]
# [betaprime      ] [0.12 sec] [RSS: 0.0202648] [loc=-1.558 scale=5.230]
# [bradford       ] [0.05 sec] [RSS: 0.0211857] [loc=56.250 scale=35.805]
# [burr           ] [0.38 sec] [RSS: 0.0166886] [loc=-0.284 scale=59.177]
# [cauchy         ] [0.01 sec] [RSS: 0.0104001] [loc=70.192 scale=2.960]
# [chi            ] [0.04 sec] [RSS: 0.0199517] [loc=54.299 scale=13.611]
# [chi2           ] [0.04 sec] [RSS: 0.0186973] [loc=52.494 scale=1.844]
# [cosine         ] [0.01 sec] [RSS: 0.0218638] [loc=76.287 scale=7.732]
# [dgamma         ] [0.03 sec] [RSS: 0.0138957] [loc=70.520 scale=10.046]
# [dweibull       ] [0.06 sec] [RSS: 0.01326] [loc=70.520 scale=7.485]
# [erlang         ] [0.02 sec] [RSS: 0.0186973] [loc=52.494 scale=3.688]
# [expon          ] [0.00 sec] [RSS: 0.0261926] [loc=56.250 scale=19.400]
# [exponnorm      ] [0.03 sec] [RSS: 0.0137777] [loc=66.125 scale=2.711]
# [exponweib      ] [0.29 sec] [RSS: 0.0171325] [loc=32.057 scale=3.518]
# [exponpow       ] [0.17 sec] [RSS: 0.0386467] [loc=65.746 scale=1.332]
# [f              ] [0.13 sec] [RSS: 0.0175023] [loc=43.259 scale=29.953]
# [fatiguelife    ] [0.06 sec] [RSS: 0.0180637] [loc=47.237 scale=26.979]
# [fisk           ] [0.24 sec] [RSS: 0.0166659] [loc=53.459 scale=19.762]
# [foldcauchy     ] [0.08 sec] [RSS: 0.0114315] [loc=56.180 scale=3.033]
# [foldnorm       ] [0.10 sec] [RSS: 0.021994] [loc=56.231 scale=9.568]
# [genlogistic    ] [0.09 sec] [RSS: 0.0175981] [loc=32.553 scale=7.152]
# [genpareto      ] [0.13 sec] [RSS: 0.0222591] [loc=-0.986 scale=206.444]
# [gennorm        ] [0.03 sec] [RSS: 0.0115212] [loc=70.040 scale=1.474]
# [genexpon       ] [0.19 sec] [RSS: 0.0259741] [loc=55.786 scale=1.520]
# [genextreme     ] [0.29 sec] [RSS: 0.0170699] [loc=71.196 scale=7.100]
# [gausshyper     ] [0.35 sec] [RSS: 0.0198976] [loc=56.159 scale=35.591]
# [gamma          ] [0.02 sec] [RSS: 0.0186973] [loc=52.494 scale=3.688]
# [gengamma       ] [0.28 sec] [RSS: 0.0183032] [loc=51.571 scale=0.429]
# [genhalflogistic] [0.09 sec] [RSS: 0.0215525] [loc=56.244 scale=36.660]
# [gibrat         ] [0.03 sec] [RSS: 0.0228736] [loc=55.705 scale=17.600]
# [gompertz       ] [0.11 sec] [RSS: 0.27941] [loc=82.473 scale=0.622]
# [gumbel_r       ] [0.00 sec] [RSS: 0.0175835] [loc=71.335 scale=7.178]
# [gumbel_l       ] [0.00 sec] [RSS: 0.024316] [loc=80.613 scale=9.514]
# [halfcauchy     ] [0.03 sec] [RSS: 0.0252046] [loc=56.250 scale=17.232]
# [halflogistic   ] [0.03 sec] [RSS: 0.0236673] [loc=56.250 scale=13.113]
# [halfnorm       ] [0.02 sec] [RSS: 0.0232822] [loc=56.250 scale=21.563]
# [halfgennorm    ] [0.11 sec] [RSS: 0.0337499] [loc=56.250 scale=1.489]
# [hypsecant      ] [0.01 sec] [RSS: 0.0198666] [loc=73.075 scale=6.461]
# [invgamma       ] [0.07 sec] [RSS: 0.0188365] [loc=28.853 scale=1326.261]
# [invgauss       ] [0.07 sec] [RSS: 0.0180189] [loc=47.117 scale=263.911]
# [invweibull     ] [0.12 sec] [RSS: 0.0170698] [loc=-110.272 scale=181.469]
# [johnsonsb      ] [0.26 sec] [RSS: 0.0179977] [loc=49.290 scale=441.777]
# [johnsonsu      ] [0.17 sec] [RSS: 0.0220041] [loc=787613271.075 scale=917732169.669]
# [laplace        ] [0.00 sec] [RSS: 0.0155532] [loc=71.150 scale=7.204]
# [levy           ] [0.03 sec] [RSS: 0.0261433] [loc=55.177 scale=14.869]
# [logistic       ] [0.00 sec] [RSS: 0.0213572] [loc=74.396 scale=5.595]
# [loggamma       ] [0.06 sec] [RSS: 0.0220652] [loc=-2512.818 scale=356.464]
# [loglaplace     ] [0.04 sec] [RSS: 0.0147107] [loc=-0.195 scale=71.345]
# [lognorm        ] [0.00 sec] [RSS: 0.017882] [loc=48.584 scale=25.539]
# [lomax          ] [0.07 sec] [RSS: 0.0262124] [loc=56.250 scale=2414.586]
# [maxwell        ] [0.00 sec] [RSS: 0.0199937] [loc=54.151 scale=13.550]
# [mielke         ] [0.19 sec] [RSS: 0.0158603] [loc=31.961 scale=31.257]
# [nakagami       ] [0.07 sec] [RSS: 0.0160235] [loc=65.746 scale=13.528]
# [norm           ] [0.00 sec] [RSS: 0.0220281] [loc=75.650 scale=9.412]
# [pareto         ] [0.00 sec] [RSS: 0.0261926] [loc=-2147483591.750 scale=2147483648.000]
# [pearson3       ] [0.06 sec] [RSS: 0.0186973] [loc=75.650 scale=9.242]
# [powerlaw       ] [0.00 sec] [RSS: 0.0205322] [loc=56.001 scale=35.749]
# [powerlognorm   ] [0.37 sec] [RSS: 0.0244391] [loc=43.548 scale=9.316]
# [powernorm      ] [0.11 sec] [RSS: 0.0197918] [loc=60.717 scale=2.275]
# [rdist          ] [0.11 sec] [RSS: 0.0248304] [loc=65.278 scale=9.028]
# [reciprocal     ] [0.02 sec] [RSS: 0.0220525] [loc=-3.394 scale=1.000]
# [rayleigh       ] [0.00 sec] [RSS: 0.0195594] [loc=55.760 scale=15.559]
# [rice           ] [0.13 sec] [RSS: 0.0195617] [loc=55.760 scale=15.286]
# [recipinvgauss  ] [1.71 sec] [RSS: 0.0181011] [loc=47.434 scale=2.818]
# [semicircular   ] [0.01 sec] [RSS: 0.0215033] [loc=78.168 scale=14.718]
# [t              ] [0.35 sec] [RSS: 0.0220282] [loc=75.650 scale=9.412]
# [triang         ] [0.16 sec] [RSS: 0.0220586] [loc=52.290 scale=39.460]
# [truncexpon     ] [0.06 sec] [RSS: 0.0231002] [loc=56.249 scale=41.005]
# [truncnorm      ] [0.06 sec] [RSS: 0.0220281] [loc=75.650 scale=9.412]
# [tukeylambda    ] [2.80 sec] [RSS: 0.0170266] [loc=78.748 scale=13.745]
# [uniform        ] [0.00 sec] [RSS: 0.0211848] [loc=56.250 scale=35.500]
# [vonmises       ] [0.00 sec] [RSS: 0.305874] [loc=1.532 scale=1.000]
# [vonmises_line  ] [0.44 sec] [RSS: 0.0202485] [loc=74.000 scale=5.650]
# [wald           ] [0.01 sec] [RSS: 0.0219418] [loc=54.644 scale=28.209]
# [weibull_min    ] [0.05 sec] [RSS: 0.013935] [loc=65.746 scale=10.121]
# [weibull_max    ] [0.12 sec] [RSS: 0.0271663] [loc=91.750 scale=1.359]
# [wrapcauchy     ] [0.06 sec] [RSS: 0.0212229] [loc=54.193 scale=5.977]
# Best fitted distribution: cauchy
# Parameters: (70.19177971282508, 2.959937880124813)

# %% [markdown]
# ## Generating data within country

# %%
validpix = np.nonzero(template)[0] 
finval = 10000

nayalat = distlat.generate(30000)
nayalon = distlon.generate(30000)

# Filter values within the desired ranges
newlat = [value for value in nayalat if -90 <= value <= 90]
newlon = [value for value in nayalon if -180 <= value <= 180]

# Trim the longer list to match the length of the shorter one
min_length = min(len(newlat), len(newlon))
newlat = newlat[:min_length]
newlon = newlon[:min_length]

newpix = hp.ang2pix(128, newlon, newlat, lonlat=True)
finpix = []
for pixie in newpix:
    if pixie in validpix:  
        finpix.append(pixie)
    if len(finpix)==finval:
        break

# %%
finlon,finlat=hp.pix2ang(128,finpix,lonlat=True)
print(len(finlat))
print(finval)
# Out:
# 10000
# 10000

# %% [markdown]
# ## Spline trial

# %% [markdown]
# ### fit spline pdf to longitude

# %%
data = lon
# Create a histogram
hist, bin_edges = np.histogram(data,bins='fd')
# Calculate midpoints of bins
bin_midpoints = (bin_edges[1:] + bin_edges[:-1]) / 2
# Fit a cubic spline to the histogram
cs = CubicSpline(bin_midpoints, hist)
# Generate x values for the spline plot
x_vals = np.linspace(bin_midpoints.min(), bin_midpoints.max(), finval)
# Plot the histogram and the cubic spline
plt.hist(data, bins=FDrule(lon), label='Histogram')
plt.plot(x_vals, cs(x_vals), 'r-', label='Cubic Spline')

plt.title('Histogram with Cubic Spline Fit')
plt.legend()
plt.show()

# %%
x_values = np.linspace(np.min(lon),np.max(lon),finval) 
corrval=np.min(cs(x_values))
def curve(x):
    curr=cs(x)
    return curr-corrval
# Calculate the area under the curve
area_under_curve, _ = quad(curve,np.min(lon) , np.max(lon))

# Create the unnormalized PDF function
def pdf_unnormalized(x):
    return curve(x) / area_under_curve

# Normalize the PDF manually to ensure the sum equals 1
pdf_values = pdf_unnormalized(x_values)
pdf_normalized = pdf_values / np.sum(pdf_values)

# Plot the original curve
plt.plot(x_values, curve(x_values), label='Original Curve')
plt.show()
# Plot the normalized probability density function (PDF)
plt.plot(x_values, pdf_normalized, label='Normalized PDF')
plt.title('Normalized Probability Density Function (PDF)')
plt.show()

# %% [markdown]
# ### fit spline pdf to latitude

# %%
data = lat

# Create a histogram
hist1, bin_edges1 = np.histogram(data, bins='fd')

# Calculate midpoints of bins
bin_midpoints1 = (bin_edges1[1:] + bin_edges1[:-1]) / 2

# Fit a cubic spline to the histogram
cs1 = CubicSpline(bin_midpoints1, hist1)

# Generate x values for the spline plot
x_vals1 = np.linspace(bin_midpoints1.min(), bin_midpoints1.max(), finval)

# Plot the histogram and the cubic spline
plt.hist(data, bins=FDrule(lat), label='Histogram')
plt.plot(x_vals1, cs1(x_vals1), 'r-', label='Cubic Spline')

plt.title('Histogram with Cubic Spline Fit')
plt.legend()
plt.show()

# %%
x_values1 = np.linspace(np.min(lat),np.max(lat),finval) 
corrval1=np.min(cs1(x_values1))
def curve1(x):
    curr=cs1(x)
    return curr-corrval1


# Calculate the area under the curve
area_under_curve1, _ = quad(curve1,np.min(lat) , np.max(lat))

# Create the unnormalized PDF function
def pdf_unnormalized1(x):
    return curve1(x) / area_under_curve1

# Normalize the PDF manually to ensure the sum equals 1
pdf_values1 = pdf_unnormalized1(x_values1)
pdf_normalized1 = pdf_values1 / np.sum(pdf_values1)
# Plot the original curve
plt.plot(x_values1, curve1(x_values1), label='Original Curve')
plt.show()
# Plot the normalized probability density function (PDF)
plt.plot(x_values1, pdf_normalized1, label='Normalized PDF')
plt.title('Normalized Probability Density Function (PDF)')
plt.show()

# %%
# filter the generated data
validpix = np.nonzero(template)[0] 
finval = 10000

verynew_lat = np.random.choice(x_values1,size=30000,p=pdf_normalized1)
verynew_lon = np.random.choice(x_values,size=30000,p=pdf_normalized)

# Filter values within the desired ranges
newlats = [value for value in verynew_lat if -90 <= value <= 90]
newlons = [value for value in verynew_lon if -180 <= value <= 180]

# Trim the longer list to match the length of the shorter one
min_length = min(len(newlats), len(newlons))
newlats = newlats[:min_length]
newlons = newlons[:min_length]

newpixs = hp.ang2pix(128, newlons, newlats, lonlat=True)
finpix1 = []
for pixie in newpixs:
    if pixie in validpix:  
        finpix1.append(pixie)
    if len(finpix1)==finval:
        break

# %%
spline_lon,spline_lat=hp.pix2ang(128,finpix1,lonlat=True)
plt.hist(newlons,bins=FDrule(newlons))
plt.plot(x_vals, cs(x_vals), 'r-', label='Cubic Spline')
plt.show()

# %%
def pdf_norm(x):
    return pdf_unnormalized(x)/np.sum(pdf_unnormalized(x))
def pdf_norm1(x):
    return pdf_unnormalized1(x)/np.sum(pdf_unnormalized1(x))
# Normalize the PDF manually to ensure the sum equals 1
pdf_values1 = pdf_unnormalized1(x_values1)
pdf_normalized1 = pdf_values1 / np.sum(pdf_values1)
# Define the range of x and y values
x_values = np.linspace(np.min(lon),np.max(lon),finval) 
x_values1 = np.linspace(np.min(lat),np.max(lat),finval) 
# Create a meshgrid for x and y
x, y = np.meshgrid(x_values, x_values1)

# Calculate the joint PDF values for each point in the meshgrid
joint_pdf = pdf_norm(x) * pdf_norm1(y)

# Plot the joint PDF using contour plot
plt.figure(figsize=(8, 6))
plt.contourf(x, y, joint_pdf, cmap='viridis')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Joint Probability Density Function')
plt.colorbar(label='Probability density')
plt.grid(True)
plt.show()

# %%
# Calculate Pearson correlation coefficient
correlation = np.corrcoef(lon, lat)[0, 1]

# Check for independence
# If the variables are independent, correlation should be close to 0
if abs(correlation) < 0.1:  # You can adjust the threshold based on your context
    print("The variables are likely independent.")
else:
    print("The variables might not be independent.")
# Out:
# The variables are likely independent.

# %% [markdown]
# ## CDF trial

# %%
data = lon 

# Creating histogram to estimate the CDF
hist, bins = np.histogram(data, bins=FDrule(lon), density=True)
cumulative = np.cumsum(hist * np.diff(bins))  # Estimating cumulative distribution function (CDF)

# Generating synthetic data based on the CDF
# synthetic_data = np.interp(np.random.uniform(0, 1, finval), cumulative, bins[:-1])

# Plotting original data and synthetic data
plt.figure(figsize=(8, 5))
plt.hist(data, bins=20, alpha=0.5, label='Original Data')
# plt.hist(synthetic_data, bins=20, alpha=0.5, label='Synthetic Data')
plt.legend()
plt.show()

# %%
data = lat

# Creating histogram to estimate the CDF
hist1, bins1 = np.histogram(data, bins=FDrule(lat), density=True)
cumulative1 = np.cumsum(hist1 * np.diff(bins1))  # Estimating cumulative distribution function (CDF)

# Generating synthetic data based on the CDF
# synthetic_data1 = np.interp(np.random.uniform(0, 1, finval), cumulative, bins1[:-1])


plt.hist(data, bins=20, alpha=0.5, label='Original Data')
# plt.hist(synthetic_data1, bins=20, alpha=0.5, label='Synthetic Data')
plt.legend()
plt.show()

# %%
very_new_lat = np.interp(np.random.uniform(0, 1, 30000), cumulative1, bins1[:-1])
very_new_lon = np.interp(np.random.uniform(0, 1, 30000), cumulative, bins[:-1])


# Filter values within the desired ranges
new_lats = [value for value in very_new_lat if -90 <= value <= 90]
new_lons = [value for value in very_new_lon if -180 <= value <= 180]

# Trim the longer list to match the length of the shorter one
min_length = min(len(new_lats), len(new_lons))
new_lats = new_lats[:min_length]
new_lons = new_lons[:min_length]

newpixss = hp.ang2pix(128, new_lons, new_lats, lonlat=True)
finpix2 = []
for pixie in newpixss:
    if pixie in validpix:  
        finpix2.append(pixie)
    if len(finpix2)==finval:
        break

# %%
cdf_lon,cdf_lat=hp.pix2ang(128,finpix2,lonlat=True)

# %% [markdown]
# ## Final checks

# %%
shapecheck(lon,lat)

# %%
# distfit generated map:
shapecheck(np.append(lon,finlon),np.append(lat,finlat))

# %%
# spline generated + original data map:
shapecheck((spline_lon),(spline_lat))
shapecheck(lon,lat)
plt.show()
np.shape(spline_lat)
# Out:
# (10000,)

# %%
data = {'lon': np.append(spline_lon,lon), 'lat': np.append(spline_lat,lat)}
df_check = pd.DataFrame(data)
df_check.to_csv('/home/pratush/Desktop/check_gentot.csv')

# %%
#cdf generated map:
shapecheck(cdf_lon,cdf_lat)

# %% [markdown]
# # Country wise parameter trends

# %%
# Have to make country wise median power as x axis and country pop dens as y axis
# outline of algorithm for this:
# open each csv file and and make median of power, ang2pix of any Tx and corresponding pix of popdens map(country wise)
# then plot them both

# %%
##---------Read the tif file---------##
HDI=tiff.imread('/home/pratush/Desktop/pop_raster_world.tif')
HDI_array=np.array(HDI)

#----------Define the spherical coordinates----------#
theta1 = np.linspace(np.radians(0), np.radians(180), num=HDI_array.shape[0],endpoint=False)
phi1 = np.linspace(-np.radians(180), np.radians(180), num=HDI_array.shape[1],endpoint=False)

#---------- Set angular resolution----------#
nside = 128

##--------Make empty healpix mask and pixel values vector--------##
HDI_map = np.zeros(hp.nside2npix(nside), dtype=np.double)
pixel_counts1 = np.zeros(hp.nside2npix(nside), dtype=int)


for i in range(len(theta1)):
    for j in range(len(phi1)):
        pixel1 = hp.ang2pix(nside, theta1[i], phi1[j])
        HDI_map[pixel1] += HDI_array[i, j]
        pixel_counts1[pixel1] += 1

#--------Average value of each pixel--------#
HDI_map[pixel_counts1>0] /= pixel_counts1[pixel_counts1>0 ]

# %%
csv_files = glob.glob('./database/*.csv')
#France has 9393 Tx
med_vals=[]
y_params=[]
# --Create an empty dataframe to store the combined data-- #
df = pd.DataFrame()

for csv_file in (csv_files):
    df_temp = pd.read_csv(csv_file)
    df_temp=df_temp.dropna(subset=['Latitude in degrees', 'Longitude in degrees','EIRP'])
    temp_pow=df_temp['EIRP'].to_numpy()
    med_vals.append(np.median(temp_pow))
    temp_lat=df_temp['Latitude in degrees'].to_numpy()
    temp_lon=df_temp['Longitude in degrees'].to_numpy()
    sellat,sellon=np.median(temp_lat),np.median(temp_lon)
    tempix=hp.ang2pix(128,sellon,sellat,lonlat=True)
    print(sellat,sellon)
    y_params.append(HDI_map[tempix])
# read Tx params into numpy arrays
# Out:
# 18.4538 -70.2
# -66.394 140.0017
# 10.4151 -61.273
# -17.394 177.515
# -29.1036111111111 26.7086111111111
# 15.3519 32.31
# 1.2105 103.4558
# 13.2623 -6.4533
# 65.18 -19.4212
# 40.2105 47.0126
# 18.1033 -76.7855
# 17.4521 -64.5011
# 38.2451 23.1718
# 35.100049999999996 136.36375
# 58.5432 25.3625
# -10.194 14.141
# 22.2056 114.0914
# 12.3101 -69.5941
# 56.5526 24.2302
# 31.58 35.055
# 52.807325000000006 -2.673359
# 15.11 145.4406
# -28.6838888888889 145.195833333333
# 25.1844 51.3011
# 40.27275 67.1753
# -1.5308 30.0059
# 40.1016 44.5436
# -15.563 -5.43
# 5.051349999999999 -52.4041
# -18.555 30.05705
# -14.192 -170.4442
# 34.3104 68.4046
# 7.205 134.292
# -8.3353 125.3427
# 14.4518 -87.161
# 22.0603 -79.3
# 34.5734 33.094
# 54.55 55.52
# 20.4522 -100.26
# -26.2905 31.148200000000003
# -1.3624 -79.0
# 17.5803 103.065
# 0.2507 9.2824
# 42.4037 24.577550000000002
# 6.3575 -58.0943
# 13.4723 5.1518
# 40.111000000000004 -8.1149
# 25.0958 55.19
# 62.152 25.02295
# 7.56 2.2031
# 48.452 19.05695
# 45.51 25.2233
# -33.061 -55.5703
# 6.3633 -1.1451
# 6.18 -10.2041
# 12.0648 15.48
# 33.53 35.3924
# 44.0859 20.321599999999997
# -5.45 110.22
# 5.1 31.34
# 31.57865 35.5126
# 6.5715 1.12
# 45.1333 16.01
# 24.0171 120.49
# 48.35255 32.557050000000004
# 5.18 -74.58
# 38.744694 -91.29014
# 34.5111 2.5953
# 50.4114 4.3658
# 42.354 19.144
# 51.4536 19.07
# 39.152 33.1643
# 27.2642 89.38
# 9.5829 -83.5132
# 31.54 35.11
# 15.6247 -23.3721
# -6.0754 35.4452
# 28.11 -16.1725
# 8.2659 -12.0317
# 46.7251388888889 275.931111111111
# 35.3138 10.082
# -40.394 174.3453
# 4.28 103.2142
# -21.583 17.0625
# 42.34245 20.5837
# -25.22 -56.28
# 19.5417 96.1017
# 34.5111 2.5953
# 29.1057 48.0255
# 50.8083217 9.7864406
# 14.49 -90.4657
# 10.02255 -12.1501
# 43.48 12.2611
# 58.9960335 14.833333
# 9.0195 38.4312
# 41.0 19.5443
# -15.302 167.104
# 46.4751 -56.1035
# -8.777750000000001 159.5427
# 23.45 90.25
# -19.463 -47.3888
# -4.2008 25.12
# 25.0248 -77.1902
# 13.1223 -61.1247
# -13.203 -176.1109
# 14.4007 -16.0633
# 12.0 104.47
# 49.45855 6.05365
# 47.19 19.02485
# 49.4312 15.25985
# 13.42 -89.12
# -14.242 28.1701
# 18.2608 -64.3814
# 4.44695 114.43535
# 27.42 84.524
# -29.203 27.4216
# 47.2127 13.46275
# 8.4828 -80.2454
# 42.1045 74.3
# 6.79565 80.3745
# 2.4643 45.18
# 16.79235 -12.4319
# 46.0246 14.1701
# 47.0717 28.3722
# -10.45 -76.21
# 52.58540000000001 -7.5602
# 12.15 -2.22
# -6.04 146.592
# 34.4329 112.12
# 0.18 6.43
# 31.335 71.47
# 15.2 38.55
# 4.59 18.34
# 15.22 44.12
# 11.1455 122.57
# 23.15 78.0705
# -17.52 34.5323
# 39.0025 69.37
# 55.447649999999996 9.5839
# 4.0774 10.1755
# 1.2074 172.83710000000002
# 6.4348 -5.1323
# 12.367799999999999 -86.0001
# 34.35 44.2535
# 28.2124 31.39
# -4.3717 55.2818
# -20.201 57.3041
# 35.1421 36.4154
# 45.5431 3.0648
# 47.50095 69.4707
# 12.03 -61.43
# 5.4927 -55.1039
# -0.244 36.4401
# 21.47 -72.17
# 42.013999999999996 43.23
# 32.1236 -6.0846
# 55.2157 23.5606
# 25.0248 -77.1902
# 14.02245 100.31125
# -13.471 34.0609
# 61.5324 9.5
# 46.5153 8.2944
# 16.0706 106.29294999999999
# 34.3827 51.0505
# -22.756999999999998 25.3947
# 36.1802 127.4414
# 7.2337 7.02
# 11.3551 42.5038
# 18.3024 -72.1858
# 38.0523 59.31
# 44.130300000000005 17.5858
# 41.3512 21.3186
# 25.03875 43.0812
# 15.2 -61.2164
# 0.32505 32.185
# -4.1126 15.1501
# 66.5773 -51.5129
# 13.115 -59.3514
# -34.125 -71.27
# -13.504 -171.461
# -21.082 -175.123
# 47.5541 104.90944999999999
# 17.3 -88.23265
# 52.08653175 5.5744905
# 18.0222 -63.0153
# 3.3515 8.48
# 32.2426 14.343
# 40.4811 -2.36
# 38.543 125.56

# %%
csv_file
# Out:
# './database/N Korea.csv'

# %%
plt.scatter(med_vals,y_params)
plt.xscale('log')
plt.yscale('log')

# %%
plt.hist(med_vals,bins=FDrule(med_vals))
# plt.xlim(500,900)
plt.show()

# %%
plt.scatter(spline_lon,spline_lat,label='synthetic')
plt.scatter(lon,lat,label='original')
plt.legend()
plt.show()

# %%
(np.max(lon)-np.min(lon))/FDrule(lon)
# Out:
# 4.885666666666666

# %%
hp.nside2resol(128,arcmin=True)
# Out:
# 27.483891294539248

# %%
# calculate best resolution
print(lon[:50])
# Out:
# [132.17    38.0848  90.3028  94.54    97.09    89.      57.33   146.1136
#  133.      74.38   138.29    72.26   130.43    66.28   106.33    86.32
#   68.46   104.1742  72.26   136.12    93.17   118.39   135.34    92.4736
#   65.18    84.1     65.53    83.37    71.55   133.12   133.39    93.39
#   54.1339  67.49    90.41    96.11    47.4528 131.06   144.01    94.24
#   65.35    39.32    73.5137  93.02    93.45   117.39   143.38   132.
#  119.5    128.16  ]

# %%
4.8*61
# Out:
# 292.8

# %%
0.64*61
# Out:
# 39.04

# %%
londiff=abs(45.01519-45.09705)

# %%
5.01/londiff
# Out:
# 61.20205228438346

# %%
import numpy as np
npix=12*(32**2)
x_ang=np.zeros((npix, npix))

# %%
(x_ang.itemsize*x_ang.size)/1e6
# Out:
# 1207.959552
