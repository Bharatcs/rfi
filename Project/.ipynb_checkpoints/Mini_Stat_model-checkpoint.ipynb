# %%
import numpy as np 
import healpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import tifffile as tiff
import glob
import seaborn as sns
# sns.set_style("darkgrid")
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from num2words import num2words
from scipy.optimize import curve_fit
from mpl_toolkits import mplot3d
import os
from distfit import distfit
import sys
import scipy
# sns.set(rc={"xtick.bottom": True, "ytick.left": True})
# %matplotlib inline
# %matplotlib notebook

# %% [markdown]
# ## Read Country DB parameters

# %%
csv_files = ['./database/France.csv']


#France has 9393 Tx
#DB has 


# --Create an empty dataframe to store the combined data-- #
df = pd.DataFrame()

# Loop through each CSV file and append its contents to the combined dataframe
for csv_file in (csv_files):
    df_temp = pd.read_csv(csv_file)
    df = pd.concat([df, df_temp],ignore_index=True)

df=df.dropna()
power=df['EIRP'].to_numpy()
lat_128=df['Latitude in degrees'].to_numpy()
lon_128=df['Longitude in degrees'].to_numpy()

pix=hp.ang2pix(128,lon_128,lat_128,lonlat=True)

# %%
Tx_num_128=np.zeros(hp.nside2npix(128))
for pi in pix:
    Tx_num_128[pi]+=1
hp.mollview(Tx_num_128,flip='geo',cmap='plasma',norm='hist')
plt.show()

# %%
Tx_pow_128=np.zeros(hp.nside2npix(128))
for index,p in enumerate(pix):
    Tx_pow_128[p]+=(power[index])
hp.mollview(Tx_pow_128,flip='geo',cmap='viridis',norm='hist',min=300)
plt.show()

# %% [markdown]
# ## Fitting PDF to Tx params

# %%
fr_df=pd.read_csv('./database/France.csv')
fr_df=fr_df.dropna()
lat=fr_df['Latitude in degrees'].to_numpy()
lon=fr_df['Longitude in degrees'].to_numpy()
power=fr_df['EIRP'].to_numpy()
freq=fr_df['Frequency(MHz)'].to_numpy()

# %%
#bin width using Freedman Diaconis rule#
def FDrule(inarg):
    qr1,qr2=np.percentile(inarg,[25,75])
    iqr=qr2-qr1
    width=(2*iqr)/(np.size(iqr)**(1/3))
    return int(width)

# %% [markdown]
# ## Model Latitude

# %%
binw=FDrule(lat)
# Fit a probability density function
distlat = distfit(distr='full',bins=binw)
distlat.fit_transform(lat)

# Plot the fitted distribution
distlat.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlat.model['name'])
print("Parameters:", distlat.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.07 sec] [RSS: 0.00987762] [loc=-11.878 scale=1476.418]
# [distfit] >INFO> [anglit         ] [0.01 sec] [RSS: 0.00637268] [loc=46.072 scale=6.449]
# [distfit] >INFO> [arcsine        ] [0.03 sec] [RSS: 0.0372452] [loc=41.231 scale=9.796]
# [distfit] >INFO> [beta           ] [0.06 sec] [RSS: 0.00586578] [loc=41.133 scale=10.022]
# [distfit] >INFO> [betaprime      ] [0.12 sec] [RSS: 0.0100824] [loc=-34.461 scale=31.892]
# [distfit] >INFO> [bradford       ] [0.05 sec] [RSS: 0.0167786] [loc=41.231 scale=9.790]
# [distfit] >INFO> [burr           ] [0.32 sec] [RSS: 0.0100086] [loc=-0.293 scale=43.384]
# [distfit] >INFO> [cauchy         ] [0.00 sec] [RSS: 0.019228] [loc=45.699 scale=1.639]
# [distfit] >INFO> [chi            ] [0.03 sec] [RSS: 0.0085543] [loc=40.730 scale=3.432]
# [distfit] >INFO> [chi2           ] [0.05 sec] [RSS: 0.0394401] [loc=41.231 scale=3.662]
# [distfit] >INFO> [cosine         ] [0.01 sec] [RSS: 0.00827214] [loc=46.024 scale=1.894]
# [distfit] >INFO> [dgamma         ] [0.01 sec] [RSS: 0.00654396] [loc=45.871 scale=0.904]
# [distfit] >INFO> [dweibull       ] [0.02 sec] [RSS: 0.00655414] [loc=45.897 scale=2.187]
# [distfit] >INFO> [erlang         ] [0.07 sec] [RSS: 0.0100607] [loc=13.512 scale=0.158]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.0393007] [loc=41.231 scale=4.758]
# [distfit] >INFO> [exponnorm      ] [0.03 sec] [RSS: 0.0103832] [loc=45.780 scale=2.256]
# [distfit] >INFO> [exponweib      ] [0.25 sec] [RSS: 0.0979123] [loc=41.231 scale=0.879]
# [distfit] >INFO> [exponpow       ] [0.14 sec] [RSS: 0.0825909] [loc=41.231 scale=1.401]
# [distfit] >INFO> [f              ] [0.11 sec] [RSS: 0.00987581] [loc=14.497 scale=31.386]
# [distfit] >INFO> [fatiguelife    ] [0.06 sec] [RSS: 0.00971298] [loc=24.131 scale=21.741]
# [distfit] >INFO> [fisk           ] [0.11 sec] [RSS: 0.012057] [loc=-0.301 scale=46.217]
# [distfit] >INFO> [foldcauchy     ] [0.04 sec] [RSS: 0.0191846] [loc=-0.138 scale=1.640]
# [distfit] >INFO> [foldnorm       ] [0.04 sec] [RSS: 0.00926261] [loc=41.231 scale=2.346]
# [distfit] >INFO> [genlogistic    ] [0.03 sec] [RSS: 0.00969756] [loc=41.555 scale=1.875]
# [distfit] >INFO> [genpareto      ] [0.12 sec] [RSS: 0.0553212] [loc=0.135 scale=130.027]
# [distfit] >INFO> [gennorm        ] [0.03 sec] [RSS: 0.00464985] [loc=46.072 scale=3.957]
# [distfit] >INFO> [genexpon       ] [0.25 sec] [RSS: 0.0086695] [loc=41.231 scale=1.149]
# [distfit] >INFO> [genextreme     ] [0.09 sec] [RSS: 0.00947518] [loc=45.218 scale=2.240]
# [distfit] >INFO> [gausshyper     ] [0.45 sec] [RSS: 0.01575] [loc=41.229 scale=9.792]
# [distfit] >INFO> [gamma          ] [0.06 sec] [RSS: 0.0100644] [loc=15.231 scale=0.166]
# [distfit] >INFO> [gengamma       ] [0.17 sec] [RSS: 0.0905298] [loc=41.231 scale=0.806]
# [distfit] >INFO> [genhalflogistic] [0.10 sec] [RSS: 0.00884245] [loc=41.229 scale=5.582]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 0.0265939] [loc=41.184 scale=4.123]
# [distfit] >INFO> [gompertz       ] [0.09 sec] [RSS: 0.0188318] [loc=41.231 scale=1.897]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.00963107] [loc=44.873 scale=2.034]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.012954] [loc=47.128 scale=2.123]
# [distfit] >INFO> [halfcauchy     ] [0.03 sec] [RSS: 0.0354113] [loc=41.231 scale=4.268]
# [distfit] >INFO> [halflogistic   ] [0.03 sec] [RSS: 0.0271753] [loc=41.231 scale=3.244]
# [distfit] >INFO> [halfnorm       ] [0.01 sec] [RSS: 0.024725] [loc=41.231 scale=5.273]
# [distfit] >INFO> [halfgennorm    ] [0.14 sec] [RSS: 0.0106613] [loc=41.231 scale=8.989]
# [distfit] >INFO> [hypsecant      ] [0.01 sec] [RSS: 0.0143036] [loc=45.906 scale=1.671]
# [distfit] >INFO> [invgamma       ] [0.06 sec] [RSS: 0.010211] [loc=-78.257 scale=374249.945]
# [distfit] >INFO> [invgauss       ] [0.07 sec] [RSS: 0.00929854] [loc=32.618 scale=438.886]
# [distfit] >INFO> [invweibull     ] [0.17 sec] [RSS: 0.00968966] [loc=-713744078.468 scale=713744123.339]
# [distfit] >INFO> [johnsonsb      ] [0.15 sec] [RSS: 0.00544509] [loc=40.920 scale=10.440]
# [distfit] >INFO> [johnsonsu      ] [0.17 sec] [RSS: 0.00982789] [loc=21.013 scale=5.626]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.0166126] [loc=45.544 scale=1.946]
# [distfit] >INFO> [levy           ] [0.04 sec] [RSS: 0.0431889] [loc=41.096 scale=3.272]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.0124177] [loc=45.950 scale=1.368]
# [distfit] >INFO> [loggamma       ] [0.06 sec] [RSS: 0.0103676] [loc=-395.700 scale=65.676]
# [distfit] >INFO> [loglaplace     ] [0.05 sec] [RSS: 0.016578] [loc=-0.168 scale=45.712]
# [distfit] >INFO> [lognorm        ] [0.00 sec] [RSS: 0.00981804] [loc=20.496 scale=25.393]
# [distfit] >INFO> [lomax          ] [0.07 sec] [RSS: 0.0621488] [loc=41.231 scale=27835289359.560]
# [distfit] >INFO> [maxwell        ] [0.00 sec] [RSS: 0.00867755] [loc=40.560 scale=3.397]
# [distfit] >INFO> [mielke         ] [0.20 sec] [RSS: 0.00994993] [loc=-1.359 scale=44.178]
# [distfit] >INFO> [nakagami       ] [0.02 sec] [RSS: 0.00855437] [loc=40.730 scale=5.727]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 0.0103858] [loc=45.990 scale=2.265]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.0393007] [loc=-268435414.769 scale=268435456.000]
# [distfit] >INFO> [pearson3       ] [0.07 sec] [RSS: 0.00950293] [loc=45.990 scale=2.288]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.016639] [loc=41.229 scale=9.792]
# [distfit] >INFO> [powerlognorm   ] [0.45 sec] [RSS: 0.00885855] [loc=-13.972 scale=56.339]
# [distfit] >INFO> [powernorm      ] [0.13 sec] [RSS: 0.00859991] [loc=42.028 scale=0.562]
# [distfit] >INFO> [rdist          ] [0.06 sec] [RSS: 0.00595689] [loc=46.086 scale=5.026]
# [distfit] >INFO> [reciprocal     ] [0.03 sec] [RSS: 0.0168979] [loc=-0.865 scale=1.000]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.00824818] [loc=41.176 scale=3.762]
# [distfit] >INFO> [rice           ] [0.06 sec] [RSS: 0.00840991] [loc=41.057 scale=2.653]
# [distfit] >INFO> [recipinvgauss  ] [1.70 sec] [RSS: 0.0095291] [loc=27.629 scale=0.282]
# [distfit] >INFO> [semicircular   ] [0.01 sec] [RSS: 0.00726826] [loc=46.126 scale=4.912]
# [distfit] >INFO> [t              ] [0.33 sec] [RSS: 0.0103936] [loc=45.990 scale=2.265]
# [distfit] >INFO> [triang         ] [0.09 sec] [RSS: 0.00709392] [loc=41.037 scale=10.375]
# [distfit] >INFO> [truncexpon     ] [0.02 sec] [RSS: 0.0200941] [loc=41.231 scale=12.660]
# [distfit] >INFO> [truncnorm      ] [0.13 sec] [RSS: 0.0443222] [loc=1.532 scale=13.783]
# [distfit] >INFO> [tukeylambda    ] [2.80 sec] [RSS: 0.00580433] [loc=46.081 scale=2.297]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.0168636] [loc=41.231 scale=9.790]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 0.0629543] [loc=-0.692 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.40 sec] [RSS: 0.00988222] [loc=46.127 scale=1.558]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 0.0226925] [loc=40.960 scale=6.416]
# [distfit] >INFO> [weibull_min    ] [0.02 sec] [RSS: 0.00869853] [loc=40.674 scale=5.998]
# [distfit] >INFO> [weibull_max    ] [0.05 sec] [RSS: 0.00947503] [loc=52.471 scale=7.253]
# [distfit] >INFO> [wrapcauchy     ] [0.06 sec] [RSS: 0.0170115] [loc=40.770 scale=1.632]
# Best fitted distribution: gennorm
# Parameters: (5.575675860356261, 46.07245709990866, 3.9566240429450907)

# %% [markdown]
# ## Model longitude

# %%
binwi=FDrule(lon)
# Fit a probability density function
distlon = distfit(distr='full',bins=binwi)
distlon.fit_transform(lon)

# Plot the fitted distribution
distlon.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlon.model['name'])
print("Parameters:", distlon.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.06 sec] [RSS: 0.00799715] [loc=-15.783 scale=105.272]
# [distfit] >INFO> [anglit         ] [0.01 sec] [RSS: 0.00445783] [loc=2.819 scale=9.332]
# [distfit] >INFO> [arcsine        ] [0.03 sec] [RSS: 0.0330502] [loc=-4.314 scale=14.414]
# [distfit] >INFO> [beta           ] [0.03 sec] [RSS: 0.00390954] [loc=-6.124 scale=16.726]
# [distfit] >INFO> [betaprime      ] [0.12 sec] [RSS: 0.00518784] [loc=-181.684 scale=74.333]
# [distfit] >INFO> [bradford       ] [0.03 sec] [RSS: 0.0211544] [loc=-4.313 scale=14.413]
# [distfit] >INFO> [burr           ] [0.38 sec] [RSS: 0.00360944] [loc=-4.606 scale=11.526]
# [distfit] >INFO> [cauchy         ] [0.00 sec] [RSS: 0.0102042] [loc=2.980 scale=2.004]
# [distfit] >INFO> [chi            ] [0.07 sec] [RSS: 0.0052534] [loc=-32.382 scale=4.174]
# [distfit] >INFO> [chi2           ] [0.07 sec] [RSS: 0.00545355] [loc=-25.033 scale=0.157]
# [distfit] >INFO> [cosine         ] [0.01 sec] [RSS: 0.00414002] [loc=2.879 scale=2.589]
# [distfit] >INFO> [dgamma         ] [0.01 sec] [RSS: 0.0206813] [loc=2.839 scale=1.346]
# [distfit] >INFO> [dweibull       ] [0.02 sec] [RSS: 0.0172685] [loc=2.851 scale=2.710]
# [distfit] >INFO> [erlang         ] [0.07 sec] [RSS: 0.00525833] [loc=-66.867 scale=0.124]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.0329109] [loc=-4.313 scale=7.297]
# [distfit] >INFO> [exponnorm      ] [0.03 sec] [RSS: 0.00518641] [loc=2.981 scale=2.933]
# [distfit] >INFO> [exponweib      ] [0.23 sec] [RSS: 0.0804976] [loc=-4.313 scale=1.638]
# [distfit] >INFO> [exponpow       ] [0.14 sec] [RSS: 0.0629674] [loc=-4.313 scale=1.623]
# [distfit] >INFO> [f              ] [0.12 sec] [RSS: 0.00563146] [loc=-20.573 scale=23.341]
# [distfit] >INFO> [fatiguelife    ] [0.09 sec] [RSS: 0.0052351] [loc=-329.797 scale=332.770]
# [distfit] >INFO> [fisk           ] [0.27 sec] [RSS: 0.00636428] [loc=-338947806.502 scale=338947809.519]
# [distfit] >INFO> [foldcauchy     ] [0.03 sec] [RSS: 0.0625078] [loc=-4.313 scale=3.283]
# [distfit] >INFO> [foldnorm       ] [0.10 sec] [RSS: 0.0229643] [loc=-4.313 scale=7.672]
# [distfit] >INFO> [genlogistic    ] [0.02 sec] [RSS: 0.00638023] [loc=2.748 scale=1.787]
# [distfit] >INFO> [genpareto      ] [0.07 sec] [RSS: 0.0873318] [loc=-4.313 scale=3.388]
# [distfit] >INFO> [gennorm        ] [0.02 sec] [RSS: 0.00379732] [loc=2.928 scale=4.817]
# [distfit] >INFO> [genexpon       ] [0.22 sec] [RSS: 0.00874344] [loc=-4.419 scale=2.237]
# [distfit] >INFO> [genextreme     ] [0.10 sec] [RSS: 0.00447454] [loc=2.031 scale=3.002]
# [distfit] >INFO> [gausshyper     ] [0.38 sec] [RSS: 0.00387138] [loc=-4.935 scale=15.237]
# [distfit] >INFO> [gamma          ] [0.06 sec] [RSS: 0.00526702] [loc=-69.299 scale=0.120]
# [distfit] >INFO> [gengamma       ] [0.27 sec] [RSS: 0.00544966] [loc=-20.071 scale=0.435]
# [distfit] >INFO> [genhalflogistic] [0.10 sec] [RSS: 0.0275561] [loc=-6.245 scale=17.053]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 0.0228665] [loc=-4.445 scale=6.599]
# [distfit] >INFO> [gompertz       ] [0.13 sec] [RSS: 0.119911] [loc=-4.313 scale=862650516327.282]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.00723536] [loc=1.504 scale=2.878]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.00528572] [loc=4.431 scale=2.707]
# [distfit] >INFO> [halfcauchy     ] [0.02 sec] [RSS: 0.0293342] [loc=-4.313 scale=6.791]
# [distfit] >INFO> [halflogistic   ] [0.02 sec] [RSS: 0.0245286] [loc=-4.313 scale=4.911]
# [distfit] >INFO> [halfnorm       ] [0.01 sec] [RSS: 0.0230172] [loc=-4.313 scale=7.864]
# [distfit] >INFO> [halfgennorm    ] [0.14 sec] [RSS: 0.0122159] [loc=-4.313 scale=12.796]
# [distfit] >INFO> [hypsecant      ] [0.00 sec] [RSS: 0.00726774] [loc=3.017 scale=2.097]
# [distfit] >INFO> [invgamma       ] [0.06 sec] [RSS: 0.00563062] [loc=-41.393 scale=9890.866]
# [distfit] >INFO> [invgauss       ] [0.07 sec] [RSS: 0.00591831] [loc=-20.055 scale=1322.349]
# [distfit] >INFO> [invweibull     ] [0.17 sec] [RSS: 0.00694292] [loc=-2616267769.395 scale=2616267770.930]
# [distfit] >INFO> [johnsonsb      ] [0.17 sec] [RSS: 0.00384918] [loc=-6.895 scale=18.291]
# [distfit] >INFO> [johnsonsu      ] [0.17 sec] [RSS: 0.00519368] [loc=-52743591.017 scale=612260190.719]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.0107164] [loc=3.065 scale=2.446]
# [distfit] >INFO> [levy           ] [0.01 sec] [RSS: 0.0330206] [loc=-4.622 scale=5.398]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.00636042] [loc=3.016 scale=1.730]
# [distfit] >INFO> [loggamma       ] [0.04 sec] [RSS: 0.00505115] [loc=-54.851 scale=16.658]
# [distfit] >INFO> [loglaplace     ] [0.12 sec] [RSS: 0.0108443] [loc=-111431956.218 scale=111431959.282]
# [distfit] >INFO> [lognorm        ] [0.15 sec] [RSS: 0.00524635] [loc=-190.354 scale=193.316]
# [distfit] >INFO> [lomax          ] [0.07 sec] [RSS: 0.0303256] [loc=-4.313 scale=707692841968.408]
# [distfit] >INFO> [maxwell        ] [0.01 sec] [RSS: 0.0056714] [loc=-4.853 scale=4.831]
# [distfit] >INFO> [mielke         ] [0.19 sec] [RSS: 0.00711453] [loc=-33052742.776 scale=33052738.862]
# [distfit] >INFO> [nakagami       ] [0.07 sec] [RSS: 0.00517447] [loc=-461.602 scale=464.596]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 0.0051864] [loc=2.984 scale=2.933]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.0329109] [loc=-536870916.313 scale=536870912.000]
# [distfit] >INFO> [pearson3       ] [0.05 sec] [RSS: 0.00499079] [loc=2.984 scale=2.939]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.0157885] [loc=-4.328 scale=14.428]
# [distfit] >INFO> [powerlognorm   ] [0.45 sec] [RSS: 0.00511987] [loc=-125.202 scale=131.865]
# [distfit] >INFO> [powernorm      ] [0.11 sec] [RSS: 0.00512381] [loc=4.951 scale=3.544]
# [distfit] >INFO> [rdist          ] [0.07 sec] [RSS: 0.00412865] [loc=2.887 scale=8.433]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.0077998] [loc=-4.398 scale=5.617]
# [distfit] >INFO> [rice           ] [0.15 sec] [RSS: 0.00779975] [loc=-4.398 scale=5.610]
# [distfit] >INFO> [recipinvgauss  ] [1.76 sec] [RSS: 0.00539036] [loc=-37.914 scale=0.216]
# [distfit] >INFO> [semicircular   ] [0.01 sec] [RSS: 0.00798898] [loc=2.878 scale=7.231]
# [distfit] >INFO> [t              ] [0.35 sec] [RSS: 0.00518641] [loc=2.984 scale=2.933]
# [distfit] >INFO> [triang         ] [0.12 sec] [RSS: 0.00412678] [loc=-4.659 scale=14.827]
# [distfit] >INFO> [truncexpon     ] [0.02 sec] [RSS: 0.0209853] [loc=-4.313 scale=16.501]
# [distfit] >INFO> [truncnorm      ] [0.09 sec] [RSS: 0.00495227] [loc=2.915 scale=3.018]
# [distfit] >INFO> [tukeylambda    ] [4.44 sec] [RSS: 0.00411113] [loc=2.889 scale=2.498]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.0166782] [loc=-4.313 scale=14.413]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 0.0805679] [loc=0.154 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.41 sec] [RSS: 0.00518844] [loc=2.986 scale=97.795]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 0.020679] [loc=-4.852 scale=10.428]
# [distfit] >INFO> [weibull_min    ] [0.02 sec] [RSS: 0.00466962] [loc=-7.243 scale=11.303]
# [distfit] >INFO> [weibull_max    ] [0.08 sec] [RSS: 0.0823924] [loc=10.100 scale=1.486]
# [distfit] >INFO> [wrapcauchy     ] [0.08 sec] [RSS: 0.0166823] [loc=-4.332 scale=2.316]
# Best fitted distribution: burr
# Parameters: (15.521535835964318, 0.11964076322614134, -4.6063053511503, 11.526393547303977)

# %% [markdown]
# ## Generate lon lat vals

# %%
newlat=distlat.generate(9393)

# %%
newlon=distlon.generate(9393)
plt.hist(newlon,bins=int(np.sqrt(np.size(newlon))))
plt.show()

# %%
newfrpix=hp.ang2pix(128,newlon,newlat,lonlat=True)
newmap=np.zeros(hp.nside2npix(128))
for pp in newfrpix:
    newmap[pp]+=1
hp.mollview(newmap,flip='geo',norm='hist')

# %%
valpix=np.argwhere(Tx_num_128)
diff=Tx_num_128[valpix]-newmap[valpix]

# %% [markdown]
# ## Model Tx power

# %%
powbin=FDrule(power)
# Fit a probability density function
distpow = distfit(distr='full',bins=powbin)
distpow.fit_transform(power)

# Plot the fitted distribution
distpow.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distpow.model['name'])
print("Parameters:", distpow.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.03 sec] [RSS: 4.07864e-06] [loc=-0.925 scale=2.483]
# [distfit] >INFO> [anglit         ] [0.03 sec] [RSS: 4.46784e-06] [loc=46476.566 scale=195627.138]
# [distfit] >INFO> [arcsine        ] [0.05 sec] [RSS: 4.28498e-06] [loc=-0.000 scale=399449.765]
# [distfit] >INFO> [beta           ] [0.13 sec] [RSS: 1.81261e-06] [loc=-0.000 scale=1719228.803]
# [distfit] >INFO> [betaprime      ] [0.06 sec] [RSS: 2.16907e-06] [loc=-0.167 scale=2.663]
# [distfit] >INFO> [bradford       ] [0.07 sec] [RSS: 4.35821e-06] [loc=-4296.867 scale=402296.867]
# [distfit] >INFO> [burr           ] [0.38 sec] [RSS: 2.37084e-06] [loc=-0.000 scale=1.775]
# [distfit] >INFO> [cauchy         ] [0.01 sec] [RSS: 2.89128e-06] [loc=356.890 scale=326.337]
# [distfit] >INFO> [chi            ] [0.08 sec] [RSS: 2.57279e-06] [loc=-0.000 scale=19299.060]
# [distfit] >INFO> [chi2           ] [0.08 sec] [RSS: 2.77098e-06] [loc=-0.000 scale=30996.787]
# [distfit] >INFO> [cosine         ] [0.04 sec] [RSS: 4.46113e-06] [loc=30470.897 scale=54041.668]
# [distfit] >INFO> [dgamma         ] [0.06 sec] [RSS: 3.39867e-06] [loc=1000.000 scale=7499.743]
# [distfit] >INFO> [dweibull       ] [0.06 sec] [RSS: 3.24878e-06] [loc=1000.000 scale=1101.694]
# [distfit] >INFO> [erlang         ] [0.07 sec] [RSS: 2.26384e-06] [loc=-0.000 scale=2772.407]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 3.01177e-06] [loc=0.000 scale=2779.365]
# [distfit] >INFO> [exponnorm      ] [0.10 sec] [RSS: 3.00696e-06] [loc=-1.468 scale=2.246]
# [distfit] >INFO> [exponweib      ] [0.29 sec] [RSS: 2.13713e-06] [loc=-0.000 scale=4473.009]
# [distfit] >INFO> [exponpow       ] [0.21 sec] [RSS: 3.06676e-06] [loc=-0.000 scale=83129.237]
# [distfit] >INFO> [f              ] [0.06 sec] [RSS: 2.82914e-06] [loc=-0.021 scale=2.875]
# [distfit] >INFO> [fatiguelife    ] [0.05 sec] [RSS: 1.62111e-06] [loc=-14.687 scale=1025.192]
# [distfit] >INFO> [fisk           ] [0.28 sec] [RSS: 3.36362e-06] [loc=-0.000 scale=3.057]
# [distfit] >INFO> [foldcauchy     ] [0.05 sec] [RSS: 3.91875e-06] [loc=-0.000 scale=4.328]
# [distfit] >INFO> [foldnorm       ] [0.09 sec] [RSS: 4.26591e-06] [loc=-0.000 scale=17723.653]
# [distfit] >INFO> [genlogistic    ] [0.08 sec] [RSS: 3.63024e-06] [loc=-16422.127 scale=2270.866]
# [distfit] >INFO> [genpareto      ] [0.12 sec] [RSS: 2.61362e-06] [loc=-0.000 scale=8.444]
# [distfit] >INFO> [gennorm        ] [0.05 sec] [RSS: 3.1667e-06] [loc=1000.000 scale=91.819]
# [distfit] >INFO> [genexpon       ] [0.22 sec] [RSS: 3.01177e-06] [loc=-0.000 scale=6086.873]
# [distfit] >INFO> [genextreme     ] [0.19 sec] [RSS: 2.81615e-06] [loc=2.947 scale=11.726]
# [distfit] >INFO> [gausshyper     ] [0.44 sec] [RSS: 2.9398e-06] [loc=-0.000 scale=430025.261]
# [distfit] >INFO> [gamma          ] [0.07 sec] [RSS: 4.49185e-06] [loc=-0.000 scale=4.280]
# [distfit] >INFO> [gengamma       ] [0.28 sec] [RSS: 2.02811e-06] [loc=-0.000 scale=5125.449]
# [distfit] >INFO> [genhalflogistic] [0.11 sec] [RSS: 3.48288e-06] [loc=-0.000 scale=2317.664]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 1.91788e-06] [loc=-38.738 scale=537.707]
# [distfit] >INFO> [gompertz       ] [0.12 sec] [RSS: 2.68521e-06] [loc=-0.000 scale=16485845922316764.000]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 3.63136e-06] [loc=677.324 scale=2275.263]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 4.45845e-06] [loc=17561.031 scale=69140.095]
# [distfit] >INFO> [halfcauchy     ] [0.03 sec] [RSS: 4.22585e-06] [loc=0.000 scale=1.947]
# [distfit] >INFO> [halflogistic   ] [0.03 sec] [RSS: 3.48242e-06] [loc=-0.000 scale=2316.462]
# [distfit] >INFO> [halfnorm       ] [0.02 sec] [RSS: 4.26591e-06] [loc=-0.000 scale=17723.654]
# [distfit] >INFO> [halfgennorm    ] [0.16 sec] [RSS: 1.55373e-06] [loc=-0.000 scale=69.072]
# [distfit] >INFO> [hypsecant      ] [0.02 sec] [RSS: 3.7048e-06] [loc=744.636 scale=2293.011]
# [distfit] >INFO> [invgamma       ] [0.03 sec] [RSS: 2.19217e-06] [loc=-0.827 scale=3.087]
# [distfit] >INFO> [invgauss       ] [0.03 sec] [RSS: 1.46434e-06] [loc=-19.884 scale=287.629]
# [distfit] >INFO> [invweibull     ] [0.08 sec] [RSS: 2.85115e-06] [loc=-0.004 scale=2.476]
# [distfit] >INFO> [johnsonsb      ] [0.26 sec] [RSS: 1.79628e-06] [loc=-0.098 scale=402519.977]
# [distfit] >INFO> [johnsonsu      ] [0.12 sec] [RSS: 3.20484e-06] [loc=87.071 scale=21.930]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 3.52427e-06] [loc=500.000 scale=2583.971]
# [distfit] >INFO> [levy           ] [0.03 sec] [RSS: 1.44536e-06] [loc=-16.588 scale=251.414]
# [distfit] >INFO> [logistic       ] [0.01 sec] [RSS: 3.8408e-06] [loc=862.784 scale=2210.146]
# [distfit] >INFO> [loggamma       ] [0.06 sec] [RSS: 4.36139e-06] [loc=-4938028.159 scale=689401.395]
# [distfit] >INFO> [loglaplace     ] [0.13 sec] [RSS: 3.29488e-06] [loc=-0.000 scale=2.435]
# [distfit] >INFO> [lognorm        ] [0.07 sec] [RSS: 1.53174e-06] [loc=-3.384 scale=468.303]
# [distfit] >INFO> [lomax          ] [0.03 sec] [RSS: 2.41677e-06] [loc=-0.000 scale=2.433]
# [distfit] >INFO> [maxwell        ] [0.01 sec] [RSS: 4.30413e-06] [loc=-24508.754 scale=18717.592]
# [distfit] >INFO> [mielke         ] [0.15 sec] [RSS: 1.69921e-06] [loc=-45.079 scale=15.111]
# [distfit] >INFO> [nakagami       ] [0.09 sec] [RSS: 2.76225e-06] [loc=2.000 scale=17225.422]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 4.35151e-06] [loc=2779.365 scale=17504.379]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 1.55128e-06] [loc=-719.238 scale=719.238]
# [distfit] >INFO> [pearson3       ] [0.18 sec] [RSS: 2.05906e-06] [loc=1537.143 scale=1787.061]
# [distfit] >INFO> [powerlaw       ] [0.06 sec] [RSS: 3.18465e-06] [loc=-0.000 scale=398000.000]
# [distfit] >INFO> [powerlognorm   ] [0.42 sec] [RSS: 1.54984e-06] [loc=-27.846 scale=66.879]
# [distfit] >INFO> [powernorm      ] [0.16 sec] [RSS: nan] [loc=-16512.703 scale=62.292]
# [distfit] >INFO> [rdist          ] [0.10 sec] [RSS: 4.35155e-06] [loc=2753.801 scale=15458452.491]
# [distfit] >INFO> [reciprocal     ] [0.07 sec] [RSS: 3.00648e-06] [loc=-0.005 scale=1.000]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 4.29789e-06] [loc=-16535.226 scale=18431.721]
# [distfit] >INFO> [rice           ] [0.11 sec] [RSS: 4.29789e-06] [loc=-16535.226 scale=18431.721]
# [distfit] >INFO> [recipinvgauss  ] [1.67 sec] [RSS: 2.2142e-06] [loc=-2.262 scale=2607.490]
# [distfit] >INFO> [semicircular   ] [0.03 sec] [RSS: 4.47244e-06] [loc=67683.655 scale=132376.639]
# [distfit] >INFO> [t              ] [0.28 sec] [RSS: 2.88808e-06] [loc=391.374 scale=356.082]
# [distfit] >INFO> [triang         ] [0.22 sec] [RSS: 4.46539e-06] [loc=-1.582 scale=400854.447]
# [distfit] >INFO> [truncexpon     ] [0.05 sec] [RSS: 4.47062e-06] [loc=-38482.288 scale=328365.927]
# [distfit] >INFO> [truncnorm      ] [0.12 sec] [RSS: 4.26402e-06] [loc=-150.073 scale=17710.935]
# [distfit] >INFO> [tukeylambda    ] [4.05 sec] [RSS: 2.53308e-06] [loc=262.788 scale=503.595]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 4.48175e-06] [loc=0.000 scale=398000.000]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 47.1794] [loc=-0.373 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.45 sec] [RSS: 4.29268e-06] [loc=2068.570 scale=78919.025]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 2.5296e-06] [loc=-332.663 scale=1937.670]
# [distfit] >INFO> [weibull_min    ] [0.12 sec] [RSS: 1.98876e-06] [loc=-0.000 scale=1703.721]
# [distfit] >INFO> [weibull_max    ] [0.08 sec] [RSS: 4.53176e-06] [loc=398000.000 scale=1.759]
# [distfit] >INFO> [wrapcauchy     ] [0.05 sec] [RSS: 3.10269e-06] [loc=-0.001 scale=63343.668]
# Best fitted distribution: levy
# Parameters: (-16.587575654657137, 251.4143789713558)

# %%
newpow=distpow.generate(9393)

# %%
new_powmap=np.zeros(hp.nside2npix(128))
for index,p in enumerate(newfrpix):
    new_powmap[p]+=(newpow[index])
hp.mollview(new_powmap,flip='geo',cmap='viridis',norm='hist')
plt.show()

# %% [markdown]
# ## Border data as  limits for generated data

# %%
border_data=pd.read_json('./france_lon_lat_arrays.json')

# %%
ruslon=border_data['longitude'].to_numpy()
ruslat=border_data['latitude'].to_numpy()

# %%
rusborder=np.zeros(hp.nside2npix(128))
rusborpix=hp.ang2pix(128,ruslon,ruslat,lonlat=True)
for pixe in rusborpix:
    rusborder[pixe]+=1
rusborder=np.where(rusborder != 0, 1, 0)
hp.mollview(rusborder,flip='geo',norm='hist')

# %% [markdown]
# ## filter out bad pixels from generated data

# %%
#idk how to do this#

# %% [markdown]
# ## Tx number per pixel residuals

# %%
plt.scatter(newmap[valpix],diff)
plt.xlabel('predicted Tx no')
plt.ylabel('Residuals')
plt.show()

# %%
power_res=Tx_pow_128[valpix]-new_powmap[valpix]

# %%
plt.scatter(new_powmap[valpix],power_res)
plt.xlabel('predicted Tx power')
plt.ylabel('Residuals')
# plt.xlim(left=1e0)
plt.xscale('log')
# plt.yscale('log')
plt.show()
