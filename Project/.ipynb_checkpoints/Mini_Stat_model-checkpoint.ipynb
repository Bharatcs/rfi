# %%
import numpy as np 
import healpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import tifffile as tiff
import glob
import seaborn as sns
# sns.set_style("darkgrid")
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from num2words import num2words
from scipy.optimize import curve_fit
from mpl_toolkits import mplot3d
import os
from distfit import distfit
import sys
import scipy
import rasterio
from scipy.interpolate import CubicSpline
from scipy.integrate import quad
from scipy.stats import multivariate_normal
# sns.set(rc={"xtick.bottom": True, "ytick.left": True})
# %matplotlib inline
# %matplotlib notebook

# %% [markdown]
# ## Read Country DB parameters

# %%
csv_files = ['./database/Russia.csv']
#France has 9393 Tx

# --Create an empty dataframe to store the combined data-- #
df = pd.DataFrame()

# Loop through each CSV file and append its contents to the combined dataframe
for csv_file in (csv_files):
    df_temp = pd.read_csv(csv_file)
    df = pd.concat([df, df_temp],ignore_index=True) 
# read Tx params into numpy arrays
df=df.dropna()
power=df['EIRP'].to_numpy()
lat_128=df['Latitude in degrees'].to_numpy()
lon_128=df['Longitude in degrees'].to_numpy()
# convert Tx coords into HEALPix pixels
pix=hp.ang2pix(128,lon_128,lat_128,lonlat=True)

# %%
# make number of Tx per pixel map
Tx_num_128=np.zeros(hp.nside2npix(128))
for pi in pix:
    Tx_num_128[pi]+=1
hp.mollview(Tx_num_128,flip='geo',cmap='plasma',norm='hist',title='')
plt.show()

# %%
# making total Tx power in each pixel
Tx_pow_128=np.zeros(hp.nside2npix(128))
for index,p in enumerate(pix):
    Tx_pow_128[p]+=(power[index])
hp.mollview(Tx_pow_128,flip='geo',cmap='viridis',norm='hist',min=300)
plt.show()

# %% [markdown]
# # Fitting PDF to Tx params

# %%
# read Tx params of selected 5k country
fr_df=pd.read_csv('./database/updated_USA_file_final.csv')
fr_df=fr_df.dropna()
lat=fr_df['Latitude in degrees'].to_numpy()
lon=fr_df['Longitude in degrees'].to_numpy()
power=fr_df['EIRP'].to_numpy()
freq=fr_df['Frequency(MHz)'].to_numpy()

# %%
# Bin width using Freedman Diaconis rule
def FDrule(data):
    # Calculate interquartile range
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    
    # Calculate Freedman-Diaconis bin width
    n = len(data)
    bin_width = 2 * iqr / (n ** (1/3))

    # Calculate number of bins
    data_range = max(data) - min(data)
    num_bins = int(data_range / bin_width) + 1
    
    return num_bins

# %% [markdown]
# ## Country HEALPix map as mask

# %%
# France shapefile was downloaded from https://gadm.org/download_country.html and rasterized using QGIS
# Open the GeoTIFF file
file_path = '/home/pratush/Desktop/USA_shpraster.tif'
src = rasterio.open(file_path)

# Read the raster data as a numpy array
data = src.read(1)  # Assuming a single-band raster

# Find pixels with non-zero values
non_zero_pixels = np.where(data != 0)

# Get the coordinates of non zero pixels
templat=[]
templon=[]
for y, x in zip(*non_zero_pixels):
    lonval, latval = src.xy(y, x)  # Get the longitude and latitude of the pixel
    templat.append(latval)
    templon.append(lonval)

# %%
# Making a mask for generated data
temppix=hp.ang2pix(128,templon,templat,lonlat=True)
template=np.zeros(hp.nside2npix(128))
for pi in temppix:
    template[pi]+=1
template=np.where(template != 0, 1, 0)
hp.mollview(template,flip='geo')

# %% [markdown]
# ## FMSCAN template

# %% [markdown]
# ![Screenshot%20from%202023-12-27%2016-45-22.png](attachment:Screenshot%20from%202023-12-27%2016-45-22.png)

# %%
##Read the tif file##
FM = tiff.imread('/home/pratush/hires_fmscan.tif')
FM_array = np.array(FM)
# Define the spherical coordinates#
theta2 = np.linspace(np.radians(0), np.radians(180), num=FM_array.shape[0],endpoint=False)
phi2 = np.linspace(-np.radians(180), np.radians(180), num=FM_array.shape[1],endpoint=False)

# Set angular resolution#
nside = 128

## Make empty healpix mask and pixel values vector##
FMSCAN_map = np.zeros(hp.nside2npix(nside), dtype=np.double)
pixel_counts2 = np.zeros(hp.nside2npix(nside), dtype=int)
for i in range(len(theta2)):
    for j in range(len(phi2)):
        pixel2 = hp.ang2pix(nside, theta2[i], phi2[j])
        FMSCAN_map[pixel2] += FM_array[i, j]
        pixel_counts2[pixel2] += 1

# Average value of each pixel#
FMSCAN_map[pixel_counts2>0] /= pixel_counts2[pixel_counts2>0 ]

# %%
FMSCAN_map[FMSCAN_map<2.8]=0
FMSCAN_map=np.where(FMSCAN_map != 0, 1, 0)

# %%
hp.mollview(FMSCAN_map,flip='geo',norm='hist')

# %% [markdown]
# ## Final template combining shp and FMSCAN

# %%
def shapecheck(lon,lat):
    checkpix=hp.ang2pix(128,lon,lat,lonlat=True)
    checkmap=np.zeros(hp.nside2npix(128))
    for pi in checkpix:
        checkmap[pi]+=1
    checkmap=np.where(checkmap != 0, 1, 0)
    return hp.mollview(checkmap,flip='geo')

# %% [markdown]
# ### Modelling Latitude

# %%
binw=FDrule(lat)
# Fit a probability density function
distlat = distfit(distr='full',bins=binw)
distlat.fit_transform(lat)

# Plot the fitted distribution
distlat.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlat.model['name'])
print("Parameters:", distlat.model['params'])
# Out:
# fit
# transform
# [alpha          ] [0.22 sec] [RSS: 0.00492869] [loc=-110.219 scale=3378.722]
# [anglit         ] [0.08 sec] [RSS: 0.0411072] [loc=42.307 scale=36.907]
# [arcsine        ] [0.16 sec] [RSS: 0.0969022] [loc=13.431 scale=57.861]
# [beta           ] [0.46 sec] [RSS: 0.00401083] [loc=-218.301 scale=6383.059]
# [betaprime      ] [0.43 sec] [RSS: 0.00532468] [loc=-61.780 scale=1.468]
# [bradford       ] [0.10 sec] [RSS: 0.0630203] [loc=13.431 scale=57.860]
# [burr           ] [1.03 sec] [RSS: 0.00322262] [loc=-0.347 scale=42.110]
# [cauchy         ] [0.02 sec] [RSS: 0.0116992] [loc=38.792 scale=3.637]
# [chi            ] [0.22 sec] [RSS: 0.116485] [loc=13.431 scale=3.017]
# [chi2           ] [0.21 sec] [RSS: 0.00462356] [loc=-35.711 scale=0.285]
# [cosine         ] [0.12 sec] [RSS: 0.0304933] [loc=41.372 scale=9.526]
# [dgamma         ] [0.07 sec] [RSS: 0.00411186] [loc=38.147 scale=3.455]
# [dweibull       ] [0.09 sec] [RSS: 0.0035814] [loc=38.236 scale=5.231]
# [erlang         ] [0.20 sec] [RSS: 0.00414959] [loc=-113.847 scale=0.273]
# [expon          ] [0.00 sec] [RSS: 0.0759082] [loc=13.431 scale=24.949]
# [exponnorm      ] [0.13 sec] [RSS: 0.0040621] [loc=35.340 scale=5.600]
# [exponweib      ] [0.94 sec] [RSS: 0.00458048] [loc=-100.887 scale=121.566]
# [exponpow       ] [0.35 sec] [RSS: 0.0170661] [loc=13.310 scale=32.974]
# [f              ] [0.40 sec] [RSS: 0.00401437] [loc=-235.196 scale=273.567]
# [fatiguelife    ] [0.30 sec] [RSS: 0.00402271] [loc=-327.446 scale=365.771]
# [fisk           ] [1.02 sec] [RSS: 0.00374188] [loc=-11128.581 scale=11167.016]
# [foldcauchy     ] [0.08 sec] [RSS: 0.0114623] [loc=-0.038 scale=3.662]
# [foldnorm       ] [0.35 sec] [RSS: 0.0622992] [loc=13.370 scale=22.963]
# [genlogistic    ] [0.06 sec] [RSS: 0.00353574] [loc=39.236 scale=3.278]
# [genpareto      ] [0.48 sec] [RSS: 0.0637076] [loc=13.431 scale=31.563]
# [gennorm        ] [0.07 sec] [RSS: 0.00483692] [loc=38.534 scale=7.052]
# [genexpon       ] [0.61 sec] [RSS: 0.0675973] [loc=13.431 scale=2.190]
# [genextreme     ] [0.86 sec] [RSS: 0.00701865] [loc=35.796 scale=6.594]
# [gausshyper     ] [1.78 sec] [RSS: 0.0174223] [loc=12.964 scale=789.732]
# [gamma          ] [0.20 sec] [RSS: 0.00416912] [loc=-109.852 scale=0.281]
# [gengamma       ] [1.03 sec] [RSS: 0.00385719] [loc=-252.979 scale=75.469]
# [genhalflogistic] [0.22 sec] [RSS: 0.0558383] [loc=13.431 scale=36.557]
# [gibrat         ] [0.10 sec] [RSS: 0.0620878] [loc=13.364 scale=23.947]
# [gompertz       ] [0.26 sec] [RSS: 0.01361] [loc=13.431 scale=8.151]
# [gumbel_r       ] [0.00 sec] [RSS: 0.0131853] [loc=35.156 scale=6.996]
# [gumbel_l       ] [0.00 sec] [RSS: 0.0135168] [loc=41.651 scale=7.721]
# [halfcauchy     ] [0.09 sec] [RSS: 0.0704461] [loc=13.431 scale=24.212]
# [halflogistic   ] [0.09 sec] [RSS: 0.0657823] [loc=13.431 scale=16.400]
# [halfnorm       ] [0.04 sec] [RSS: 0.0640231] [loc=13.431 scale=25.766]
# [halfgennorm    ] [0.36 sec] [RSS: 0.0482502] [loc=13.431 scale=39.480]
# [hypsecant      ] [0.03 sec] [RSS: 0.00480466] [loc=38.519 scale=4.158]
# [invgamma       ] [0.19 sec] [RSS: 0.00507494] [loc=-61.466 scale=23339.053]
# [invgauss       ] [0.21 sec] [RSS: 0.00753716] [loc=-6.056 scale=1719.759]
# [invweibull     ] [0.73 sec] [RSS: 0.0131798] [loc=-49772615.248 scale=49772650.407]
# [johnsonsb      ] [0.64 sec] [RSS: 0.00388657] [loc=-686237791.245 scale=1203615087.868]
# [johnsonsu      ] [0.27 sec] [RSS: 0.00369155] [loc=39.619 scale=9.404]
# [laplace        ] [0.00 sec] [RSS: 0.00976754] [loc=38.745 scale=4.877]
# [levy           ] [0.08 sec] [RSS: 0.0712529] [loc=12.982 scale=22.130]
# [logistic       ] [0.00 sec] [RSS: 0.00372728] [loc=38.447 scale=3.474]
# [loggamma       ] [0.17 sec] [RSS: 0.00396694] [loc=-1598.996 scale=229.617]
# [loglaplace     ] [0.16 sec] [RSS: 0.00952071] [loc=-0.104 scale=38.849]
# [lognorm        ] [0.01 sec] [RSS: 0.0040287] [loc=-310.619 scale=348.940]
# [lomax          ] [0.19 sec] [RSS: 0.0765824] [loc=13.431 scale=1966267.606]
# [maxwell        ] [0.04 sec] [RSS: 0.0248636] [loc=13.392 scale=14.898]
# [mielke         ] [0.55 sec] [RSS: 0.00321978] [loc=-0.163 scale=41.937]
# [nakagami       ] [0.14 sec] [RSS: 0.00396425] [loc=-174.266 scale=212.744]
# [norm           ] [0.00 sec] [RSS: 0.00388816] [loc=38.380 scale=6.437]
# [pareto         ] [0.01 sec] [RSS: 0.0759082] [loc=-4294967282.569 scale=4294967296.000]
# [pearson3       ] [0.37 sec] [RSS: 0.00401234] [loc=38.380 scale=6.435]
# [powerlaw       ] [0.00 sec] [RSS: 0.0629523] [loc=13.430 scale=57.861]
# [powerlognorm   ] [1.01 sec] [RSS: 0.0935972] [loc=11.552 scale=1.946]
# [powernorm      ] [0.22 sec] [RSS: 0.00382595] [loc=39.004 scale=6.641]
# [rdist          ] [0.34 sec] [RSS: 0.00389458] [loc=38.389 scale=632.659]
# [reciprocal     ] [0.19 sec] [RSS: 0.0626894] [loc=-70.432 scale=1.000]
# [rayleigh       ] [0.00 sec] [RSS: 0.0373999] [loc=13.423 scale=18.225]
# [rice           ] [0.89 sec] [RSS: 0.0828168] [loc=-401.739 scale=98.428]
# [recipinvgauss  ] [2.09 sec] [RSS: 0.00464286] [loc=-61.687 scale=0.425]
# [semicircular   ] [0.06 sec] [RSS: 0.0506911] [loc=42.356 scale=28.937]
# [t              ] [1.20 sec] [RSS: 0.00447373] [loc=38.370 scale=6.450]
# [triang         ] [0.30 sec] [RSS: 0.0303012] [loc=13.385 scale=57.911]
# [truncexpon     ] [0.12 sec] [RSS: 0.062421] [loc=10.671 scale=82.281]
# [truncnorm      ] [0.05 sec] [RSS: 0.00388816] [loc=38.380 scale=6.437]
# [tukeylambda    ] [26.4 sec] [RSS: 0.00409116] [loc=38.471 scale=3.282]
# [uniform        ] [0.00 sec] [RSS: 0.0630546] [loc=13.431 scale=57.860]
# [vonmises       ] [0.00 sec] [RSS: 2.32685] [loc=-2.896 scale=1.000]
# [vonmises_line  ] [0.58 sec] [RSS: 0.00325444] [loc=38.416 scale=10.465]
# [wald           ] [0.11 sec] [RSS: 0.0574247] [loc=12.777 scale=37.928]
# [weibull_min    ] [0.28 sec] [RSS: 0.00572096] [loc=11.921 scale=28.880]
# [weibull_max    ] [0.32 sec] [RSS: 0.24202] [loc=71.291 scale=1.451]
# [wrapcauchy     ] [0.36 sec] [RSS: 0.0706954] [loc=13.431 scale=9.209]
# Best fitted distribution: mielke
# Parameters: (7.26657780159954, 15.405690086686038, -0.16286624892550708, 41.936506627519805)

# %% [markdown]
# ### Model longitude

# %%
binwi=FDrule(lon)
# Fit a probability density function
distlon = distfit(distr='full',bins=binwi)
distlon.fit_transform(lon)

# Plot the fitted distribution
distlon.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlon.model['name'])
print("Parameters:", distlon.model['params'])
# Out:
# fit
# transform
# [alpha          ] [0.21 sec] [RSS: 0.00729528] [loc=-179.557 scale=77.460]
# [anglit         ] [0.07 sec] [RSS: 0.00493825] [loc=-108.496 scale=80.517]
# [arcsine        ] [0.16 sec] [RSS: 0.0105021] [loc=-171.730 scale=110.358]
# [beta           ] [0.42 sec] [RSS: 0.00108685] [loc=-196069.425 scale=196008.336]
# [betaprime      ] [0.43 sec] [RSS: 0.00216056] [loc=-662.976 scale=1515.808]
# [bradford       ] [0.11 sec] [RSS: 0.00851336] [loc=-171.730 scale=110.349]
# [burr           ] [1.44 sec] [RSS: 0.0033684] [loc=-64356.823 scale=64014.558]
# [cauchy         ] [0.02 sec] [RSS: 0.00212448] [loc=-89.683 scale=9.887]
# [chi            ] [0.21 sec] [RSS: 0.00218924] [loc=-557.942 scale=25.420]
# [chi2           ] [0.21 sec] [RSS: 0.00238899] [loc=-307.410 scale=0.832]
# [cosine         ] [0.10 sec] [RSS: 0.00377241] [loc=-102.629 scale=21.999]
# [dgamma         ] [0.07 sec] [RSS: 0.00206605] [loc=-92.818 scale=9.840]
# [dweibull       ] [0.12 sec] [RSS: 0.00194712] [loc=-92.835 scale=14.852]
# [erlang         ] [0.20 sec] [RSS: 0.00226193] [loc=-432.187 scale=0.978]
# [expon          ] [0.00 sec] [RSS: 0.00982258] [loc=-171.730 scale=76.534]
# [exponnorm      ] [0.10 sec] [RSS: 0.00212939] [loc=-95.208 scale=17.635]
# [exponweib      ] [0.99 sec] [RSS: 0.0247939] [loc=-171.730 scale=0.662]
# [exponpow       ] [0.61 sec] [RSS: 0.0149426] [loc=-171.730 scale=1.722]
# [f              ] [0.39 sec] [RSS: 0.00213186] [loc=-25014.182 scale=24918.970]
# [fatiguelife    ] [0.31 sec] [RSS: 0.00216173] [loc=-1269.284 scale=1174.050]
# [fisk           ] [1.08 sec] [RSS: 0.0270286] [loc=-171.730 scale=1.384]
# [foldcauchy     ] [0.21 sec] [RSS: 0.00206724] [loc=-242.105 scale=10.193]
# [foldnorm       ] [0.28 sec] [RSS: 0.00212939] [loc=-196.153 scale=17.635]
# [genlogistic    ] [0.08 sec] [RSS: 0.00102837] [loc=-77.566 scale=3.636]
# [genpareto      ] [0.43 sec] [RSS: 0.00714966] [loc=-245.946 scale=202.527]
# [gennorm        ] [0.10 sec] [RSS: 0.00210573] [loc=-94.342 scale=23.069]
# [genexpon       ] [0.66 sec] [RSS: 0.00957396] [loc=-171.733 scale=2.857]
# [genextreme     ] [1.14 sec] [RSS: 0.0223246] [loc=-62.209 scale=3.564]
# [gausshyper     ] [1.91 sec] [RSS: 9.31261e+175] [loc=-1813.918 scale=1752.553]
# [gamma          ] [0.19 sec] [RSS: 0.00227704] [loc=-433.666 scale=0.985]
# [gengamma       ] [1.04 sec] [RSS: 0.00215619] [loc=-616.542 scale=66.320]
# [genhalflogistic] [0.34 sec] [RSS: 0.00593394] [loc=-171.731 scale=123.997]
# [gibrat         ] [0.14 sec] [RSS: 0.00834754] [loc=-171.755 scale=73.596]
# [gompertz       ] [0.24 sec] [RSS: 0.161639] [loc=-171.730 scale=55215562228792.688]
# [gumbel_r       ] [0.00 sec] [RSS: 0.00336048] [loc=-104.711 scale=21.692]
# [gumbel_l       ] [0.00 sec] [RSS: 0.00117102] [loc=-87.202 scale=13.519]
# [halfcauchy     ] [0.10 sec] [RSS: 0.0092772] [loc=-171.730 scale=74.796]
# [halflogistic   ] [0.09 sec] [RSS: 0.00906018] [loc=-171.730 scale=47.047]
# [halfnorm       ] [0.05 sec] [RSS: 0.00859171] [loc=-171.730 scale=78.539]
# [halfgennorm    ] [0.25 sec] [RSS: 0.0137874] [loc=-171.730 scale=1.671]
# [hypsecant      ] [0.03 sec] [RSS: 0.00203061] [loc=-92.618 scale=11.831]
# [invgamma       ] [0.19 sec] [RSS: 0.00255101] [loc=-357.790 scale=49659.837]
# [invgauss       ] [0.21 sec] [RSS: 0.00291534] [loc=-212.593 scale=3626.759]
# [invweibull     ] [0.77 sec] [RSS: 0.00333918] [loc=-19323966.443 scale=19323862.279]
# [johnsonsb      ] [0.66 sec] [RSS: 0.00102904] [loc=-264.841 scale=206.276]
# [johnsonsu      ] [0.68 sec] [RSS: 0.0010544] [loc=-53.285 scale=2.931]
# [laplace        ] [0.00 sec] [RSS: 0.0023074] [loc=-91.290 scale=13.800]
# [levy           ] [0.08 sec] [RSS: 0.00939421] [loc=-172.251 scale=67.488]
# [logistic       ] [0.00 sec] [RSS: 0.00206935] [loc=-93.535 scale=9.890]
# [loggamma       ] [0.04 sec] [RSS: 0.00103117] [loc=-80.469 scale=9.780]
# [loglaplace     ] [0.44 sec] [RSS: 0.00227222] [loc=-53205.242 scale=53114.062]
# [lognorm        ] [0.20 sec] [RSS: 0.0308902] [loc=-171.730 scale=3.100]
# [lomax          ] [0.20 sec] [RSS: 0.0102853] [loc=-171.730 scale=26984397.770]
# [maxwell        ] [0.06 sec] [RSS: 0.00448015] [loc=-171.740 scale=45.351]
# [mielke         ] [0.76 sec] [RSS: 0.00102213] [loc=-3354.404 scale=3276.638]
# [nakagami       ] [0.19 sec] [RSS: 0.00212487] [loc=-13441.893 scale=13346.741]
# [norm           ] [0.00 sec] [RSS: 0.00212939] [loc=-95.196 scale=17.635]
# [pareto         ] [0.01 sec] [RSS: 0.00982258] [loc=-8589934763.730 scale=8589934592.000]
# [pearson3       ] [0.32 sec] [RSS: 0.00108576] [loc=-95.196 scale=17.541]
# [powerlaw       ] [0.00 sec] [RSS: 0.00434036] [loc=-171.889 scale=110.507]
# [powerlognorm   ] [0.97 sec] [RSS: 0.0161216] [loc=-171.797 scale=0.825]
# [powernorm      ] [0.64 sec] [RSS: 0.00127945] [loc=139.846 scale=57.907]
# [rdist          ] [0.24 sec] [RSS: 0.00702238] [loc=-116.556 scale=55.175]
# [rayleigh       ] [0.00 sec] [RSS: 0.00578399] [loc=-171.734 scale=55.538]
# [rice           ] [0.96 sec] [RSS: 0.00213032] [loc=-4954.020 scale=17.610]
# [recipinvgauss  ] [2.01 sec] [RSS: 0.00230599] [loc=-447.065 scale=0.931]
# [semicircular   ] [0.04 sec] [RSS: 0.0058846] [loc=-115.355 scale=56.377]
# [t              ] [0.76 sec] [RSS: 0.00212938] [loc=-95.196 scale=17.635]
# [triang         ] [0.34 sec] [RSS: 0.00230648] [loc=-171.738 scale=110.365]
# [truncexpon     ] [0.12 sec] [RSS: 0.00830849] [loc=-171.740 scale=157.735]
# [truncnorm      ] [0.07 sec] [RSS: 0.00212939] [loc=-95.196 scale=17.635]
# [tukeylambda    ] [12.3 sec] [RSS: 0.00208149] [loc=-93.904 scale=10.400]
# [uniform        ] [0.00 sec] [RSS: 0.00653463] [loc=-171.730 scale=110.349]
# [vonmises       ] [0.00 sec] [RSS: 1.53779] [loc=2.060 scale=1.000]
# [vonmises_line  ] [0.50 sec] [RSS: 0.00208776] [loc=-93.881 scale=24.780]
# [wald           ] [0.06 sec] [RSS: 0.00781829] [loc=-172.702 scale=114.891]
# [weibull_min    ] [0.40 sec] [RSS: 0.00117109] [loc=-2597446854.938 scale=2597446767.738]
# [weibull_max    ] [0.47 sec] [RSS: 0.023965] [loc=-61.381 scale=1.325]
# [wrapcauchy     ] [0.19 sec] [RSS: 0.00653463] [loc=-171.730 scale=17.563]
# Best fitted distribution: mielke
# Parameters: (176.1434371635503, 865.3643873383089, -3354.403868035739, 3276.637810710956)

# %% [markdown]
# ### Model Tx power

# %%
powbin=FDrule(power)
# Fit a probability density function
distpow = distfit(distr='powerlaw',bins=powbin)
distpow.fit_transform(power)

# Plot the fitted distribution
distpow.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distpow.model['name'])
print("Parameters:", distpow.model['params'])
# Out:
# fit
# transform
# [powerlaw] [0.26 sec] [RSS: 2.27913e-07] [loc=-0.000 scale=537401.000]
# Best fitted distribution: powerlaw
# Parameters: (0.14638354798802852, -2.2250738585072014e-308, 537401.0000000001)

# %% [markdown]
# ### Model Tx Freq

# %%
freqbin=FDrule(freq)
# Fit a probability density function
distfreq = distfit(distr='full',bins=freqbin)
distfreq.fit_transform(freq)

# Plot the fitted distribution
distfreq.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distfreq.model['name'])
print("Parameters:", distfreq.model['params'])
# Out:
# fit
# transform
# [alpha          ] [0.22 sec] [RSS: 0.0144507] [loc=-33.335 scale=2880.415]
# [anglit         ] [0.03 sec] [RSS: 0.0116358] [loc=97.663 scale=15.536]
# [arcsine        ] [0.15 sec] [RSS: 0.0106303] [loc=87.958 scale=19.942]
# [beta           ] [0.32 sec] [RSS: 0.00291114] [loc=88.099 scale=19.801]
# [betaprime      ] [0.21 sec] [RSS: 0.0144631] [loc=-7.107 scale=47.218]
# [bradford       ] [0.19 sec] [RSS: 0.00209112] [loc=88.069 scale=19.831]
# [burr           ] [1.43 sec] [RSS: 0.0141802] [loc=-59.103 scale=109.494]
# [cauchy         ] [0.02 sec] [RSS: 0.0223298] [loc=97.161 scale=4.496]
# [chi            ] [0.09 sec] [RSS: 0.00897968] [loc=88.060 scale=10.554]
# [chi2           ] [0.23 sec] [RSS: 0.193132] [loc=88.100 scale=1.481]
# [cosine         ] [0.05 sec] [RSS: 0.0130629] [loc=97.573 scale=4.833]
# [dgamma         ] [0.07 sec] [RSS: 0.0164563] [loc=97.399 scale=2.720]
# [dweibull       ] [0.11 sec] [RSS: 0.014017] [loc=97.401 scale=5.742]
# [erlang         ] [0.20 sec] [RSS: 0.014638] [loc=8.939 scale=0.394]
# [expon          ] [0.00 sec] [RSS: 0.0144906] [loc=88.100 scale=9.378]
# [exponnorm      ] [0.11 sec] [RSS: 0.0146224] [loc=97.040 scale=5.921]
# [exponweib      ] [0.99 sec] [RSS: 0.102633] [loc=88.100 scale=1.249]
# [exponpow       ] [0.62 sec] [RSS: 0.0803155] [loc=88.100 scale=1.330]
# [f              ] [0.39 sec] [RSS: 0.0144648] [loc=-17.534 scale=114.792]
# [fatiguelife    ] [0.20 sec] [RSS: 0.0142269] [loc=65.829 scale=31.083]
# [fisk           ] [0.43 sec] [RSS: 0.0161495] [loc=-0.564 scale=97.843]
# [foldcauchy     ] [0.10 sec] [RSS: 0.0222664] [loc=0.013 scale=4.503]
# [foldnorm       ] [0.22 sec] [RSS: 0.00756878] [loc=88.100 scale=6.771]
# [genlogistic    ] [0.30 sec] [RSS: 0.0145438] [loc=62.968 scale=5.206]
# [genpareto      ] [0.34 sec] [RSS: 0.0363295] [loc=-1.094 scale=254.840]
# [gennorm        ] [0.33 sec] [RSS: 0.00280276] [loc=98.000 scale=9.900]
# [genexpon       ] [0.68 sec] [RSS: 0.0143717] [loc=88.100 scale=1.873]
# [genextreme     ] [0.36 sec] [RSS: 0.0139925] [loc=95.633 scale=6.020]
# [gausshyper     ] [1.92 sec] [RSS: 0.0027035] [loc=88.048 scale=19.852]
# [gamma          ] [0.19 sec] [RSS: 0.0144722] [loc=7.698 scale=0.392]
# [gengamma       ] [1.01 sec] [RSS: 0.107816] [loc=88.100 scale=1.209]
# [genhalflogistic] [0.33 sec] [RSS: 0.0182419] [loc=87.703 scale=20.327]
# [gibrat         ] [0.09 sec] [RSS: 0.0159006] [loc=87.450 scale=7.630]
# [gompertz       ] [0.26 sec] [RSS: 0.00785331] [loc=88.090 scale=8.775]
# [gumbel_r       ] [0.00 sec] [RSS: 0.0145377] [loc=94.553 scale=5.214]
# [gumbel_l       ] [0.00 sec] [RSS: 0.0162926] [loc=100.458 scale=5.467]
# [halfcauchy     ] [0.10 sec] [RSS: 0.014959] [loc=88.100 scale=7.762]
# [halflogistic   ] [0.11 sec] [RSS: 0.00999598] [loc=88.100 scale=6.678]
# [halfnorm       ] [0.04 sec] [RSS: 0.00917016] [loc=88.100 scale=10.942]
# [halfgennorm    ] [0.26 sec] [RSS: 0.0365548] [loc=88.100 scale=1.262]
# [hypsecant      ] [0.03 sec] [RSS: 0.0178173] [loc=97.344 scale=4.444]
# [invgamma       ] [0.18 sec] [RSS: 0.0144052] [loc=27.079 scale=9819.706]
# [invgauss       ] [0.21 sec] [RSS: 0.0140922] [loc=71.718 scale=445.915]
# [invweibull     ] [0.74 sec] [RSS: 0.0144831] [loc=-1116012221.790 scale=1116012316.347]
# [johnsonsb      ] [0.33 sec] [RSS: 0.00170958] [loc=87.975 scale=20.062]
# [johnsonsu      ] [0.63 sec] [RSS: 0.0146716] [loc=3681036.494 scale=702526.852]
# [laplace        ] [0.00 sec] [RSS: 0.0234225] [loc=97.300 scale=5.182]
# [levy           ] [0.10 sec] [RSS: 0.0234323] [loc=87.541 scale=4.528]
# [logistic       ] [0.00 sec] [RSS: 0.0162621] [loc=97.397 scale=3.624]
# [loggamma       ] [0.17 sec] [RSS: 0.0144214] [loc=-982.246 scale=163.279]
# [loglaplace     ] [0.17 sec] [RSS: 0.0234057] [loc=-0.334 scale=97.634]
# [lognorm        ] [0.01 sec] [RSS: 0.0143617] [loc=53.175 scale=43.904]
# [lomax          ] [0.20 sec] [RSS: 0.0526582] [loc=88.098 scale=53921984.189]
# [maxwell        ] [0.02 sec] [RSS: 0.013572] [loc=83.695 scale=8.665]
# [mielke         ] [0.76 sec] [RSS: nan] [loc=-1.356 scale=72.250]
# [nakagami       ] [0.06 sec] [RSS: 0.00897984] [loc=88.060 scale=11.133]
# [norm           ] [0.00 sec] [RSS: 0.0146227] [loc=97.478 scale=5.937]
# [pareto         ] [0.01 sec] [RSS: 0.0144906] [loc=-2147483559.900 scale=2147483648.000]
# [pearson3       ] [0.20 sec] [RSS: 0.0133797] [loc=97.478 scale=6.564]
# [powerlaw       ] [0.02 sec] [RSS: 0.0114762] [loc=88.100 scale=19.800]
# [powerlognorm   ] [1.00 sec] [RSS: 0.0151363] [loc=82.440 scale=5.025]
# [powernorm      ] [0.45 sec] [RSS: nan] [loc=86.308 scale=0.052]
# [rdist          ] [0.35 sec] [RSS: 0.00622426] [loc=98.075 scale=9.975]
# [reciprocal     ] [0.10 sec] [RSS: 0.00225672] [loc=-3.795 scale=1.000]
# [rayleigh       ] [0.00 sec] [RSS: 0.0127458] [loc=86.292 scale=8.955]
# [rice           ] [0.17 sec] [RSS: 0.0127728] [loc=86.079 scale=7.375]
# [recipinvgauss  ] [2.02 sec] [RSS: 0.0142172] [loc=66.613 scale=1.154]
# [semicircular   ] [0.02 sec] [RSS: 0.00863229] [loc=97.826 scale=10.571]
# [t              ] [1.13 sec] [RSS: 0.014622] [loc=97.478 scale=5.937]
# [triang         ] [0.22 sec] [RSS: 0.00682642] [loc=88.100 scale=25.804]
# [truncexpon     ] [0.05 sec] [RSS: 0.00334303] [loc=88.100 scale=24.249]
# [truncnorm      ] [0.22 sec] [RSS: 0.00762389] [loc=88.394 scale=11.529]
# [tukeylambda    ] [27.1 sec] [RSS: 0.00261384] [loc=97.979 scale=10.348]
# [uniform        ] [0.00 sec] [RSS: 0.00280276] [loc=88.100 scale=19.800]
# [vonmises       ] [0.00 sec] [RSS: 0.342096] [loc=0.879 scale=1.000]
# [vonmises_line  ] [0.51 sec] [RSS: 0.00280276] [loc=98.000 scale=3.151]
# [wald           ] [0.04 sec] [RSS: 0.0164507] [loc=86.697 scale=12.166]
# [weibull_min    ] [0.11 sec] [RSS: 0.0122218] [loc=87.081 scale=11.646]
# [weibull_max    ] [0.46 sec] [RSS: 0.148416] [loc=107.900 scale=1.782]
# [wrapcauchy     ] [0.12 sec] [RSS: 0.00226852] [loc=88.100 scale=3.183]
# Best fitted distribution: johnsonsb
# Parameters: (0.09307466778138224, 0.5391455280329212, 87.97547463408179, 20.062006058303446)

# %% [markdown]
# ### Distfit Gen

# %%
validpix = np.nonzero(template)[0] 
finval = 10000

nayalat = distlat.generate(30000)
nayalon = distlon.generate(30000)

# Filter values within the desired ranges
newlat = [value for value in nayalat if -90 <= value <= 90]
newlon = [value for value in nayalon if -180 <= value <= 180]

# Trim the longer list to match the length of the shorter one
min_length = min(len(newlat), len(newlon))
newlat = newlat[:min_length]
newlon = newlon[:min_length]

newpix = hp.ang2pix(128, newlon, newlat, lonlat=True)
finpix = []
for pixie in newpix:
    if pixie in validpix:  
        finpix.append(pixie)
    if len(finpix)==finval:
        break

# %%
finlon,finlat=hp.pix2ang(128,finpix,lonlat=True)
print(len(finlat))
print(finval)
# Out:
# 10000
# 10000

# %% [markdown]
# ## Spline trial

# %% [markdown]
# ### fit spline pdf to longitude

# %%
data = lon
(max(lon)-min(lon))/0.458
# Create a histogram
hist, bin_edges = np.histogram(data,bins='fd')
# Calculate midpoints of bins
bin_midpoints = (bin_edges[1:] + bin_edges[:-1]) / 2
# Fit a cubic spline to the histogram
cs = CubicSpline(bin_midpoints, hist)
# Generate x values for the spline plot
x_vals = np.linspace(bin_midpoints.min(), bin_midpoints.max(), finval)
# Plot the histogram and the cubic spline
plt.hist(data, bins=FDrule(data), label='Histogram')
plt.plot(x_vals, cs(x_vals), 'r-', label='Cubic Spline')

plt.title('Histogram with Cubic Spline Fit')
plt.legend()
plt.show()

# %%
x_values = np.linspace(np.min(lon),np.max(lon),finval) 
corrval=np.min(cs(x_values))
def curve(x):
    curr=cs(x)
    return curr-corrval
# Calculate the area under the curve
area_under_curve, _ = quad(curve,np.min(lon) , np.max(lon))

# Create the unnormalized PDF function
def pdf_unnormalized(x):
    return curve(x) / area_under_curve

# Normalize the PDF manually to ensure the sum equals 1
pdf_values = pdf_unnormalized(x_values)
pdf_normalized = pdf_values / np.sum(pdf_values)

# Plot the original curve
plt.plot(x_values, curve(x_values), label='Original Curve')
plt.show()
# Plot the normalized probability density function (PDF)
plt.plot(x_values, pdf_normalized, label='Normalized PDF')
plt.title('Normalized Probability Density Function (PDF)')
plt.show()

# %% [markdown]
# ### fit spline pdf to latitude

# %%
data = lat

# Create a histogram
hist1, bin_edges1 = np.histogram(data, bins='fd')

# Calculate midpoints of bins
bin_midpoints1 = (bin_edges1[1:] + bin_edges1[:-1]) / 2

# Fit a cubic spline to the histogram
cs1 = CubicSpline(bin_midpoints1, hist1)

# Generate x values for the spline plot
x_vals1 = np.linspace(bin_midpoints1.min(), bin_midpoints1.max(), finval)

# Plot the histogram and the cubic spline
plt.hist(data, bins=FDrule(lat), label='Histogram')
plt.plot(x_vals1, cs1(x_vals1), 'r-', label='Cubic Spline')

plt.title('Histogram with Cubic Spline Fit')
plt.legend()
plt.show()

# %%
x_values1 = np.linspace(np.min(lat),np.max(lat),finval) 
corrval1=np.min(cs1(x_values1))
def curve1(x):
    curr=cs1(x)
    return curr-corrval1


# Calculate the area under the curve
area_under_curve1, _ = quad(curve1,np.min(lat) , np.max(lat))

# Create the unnormalized PDF function
def pdf_unnormalized1(x):
    return curve1(x) / area_under_curve1

# Normalize the PDF manually to ensure the sum equals 1
pdf_values1 = pdf_unnormalized1(x_values1)
pdf_normalized1 = pdf_values1 / np.sum(pdf_values1)
# Plot the original curve
plt.plot(x_values1, curve1(x_values1), label='Original Curve')
plt.show()
# Plot the normalized probability density function (PDF)
plt.plot(x_values1, pdf_normalized1, label='Normalized PDF')
plt.title('Normalized Probability Density Function (PDF)')
plt.show()

# %% [markdown]
# ### Spline Gen

# %%
# filter the generated data
validpix = np.nonzero(template)[0] 
finval = 10000

verynew_lat = np.random.choice(x_values1,size=30000,p=pdf_normalized1)
verynew_lon = np.random.choice(x_values,size=30000,p=pdf_normalized)

# Filter values within the desired ranges
newlats = [value for value in verynew_lat if -90 <= value <= 90]
newlons = [value for value in verynew_lon if -180 <= value <= 180]

# Trim the longer list to match the length of the shorter one
min_length = min(len(newlats), len(newlons))
newlats = newlats[:min_length]
newlons = newlons[:min_length]

newpixs = hp.ang2pix(128, newlons, newlats, lonlat=True)
finpix1 = []
for pixie in newpixs:
    if pixie in validpix:  
        finpix1.append(pixie)
    if len(finpix1)==finval:
        break

# %%
spline_lon,spline_lat=hp.pix2ang(128,finpix1,lonlat=True)
saverdf=pd.DataFrame({'Longitude':spline_lon,'Latitude':spline_lat})
saverdf.to_csv('/home/pratush/Downloads/USA_Splinepoints.csv')

# %% [markdown]
# ### Joint PDF trial

# %%
def pdf_norm(x):
    return pdf_unnormalized(x)/np.sum(pdf_unnormalized(x))
def pdf_norm1(x):
    return pdf_unnormalized1(x)/np.sum(pdf_unnormalized1(x))
# Normalize the PDF manually to ensure the sum equals 1
pdf_values1 = pdf_unnormalized1(x_values1)
pdf_normalized1 = pdf_values1 / np.sum(pdf_values1)
# Define the range of x and y values
x_values = np.linspace(np.min(lon),np.max(lon),finval) 
x_values1 = np.linspace(np.min(lat),np.max(lat),finval) 
# Create a meshgrid for x and y
x, y = np.meshgrid(x_values, x_values1)

# Calculate the joint PDF values for each point in the meshgrid
joint_pdf = pdf_norm(x) * pdf_norm1(y)

# Plot the joint PDF using contour plot
plt.figure(figsize=(8, 6))
plt.contourf(x, y, joint_pdf, cmap='viridis')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Joint Probability Density Function')
plt.colorbar(label='Probability density')
plt.grid(True)
plt.show()

# %%
# Calculate Pearson correlation coefficient
correlation = np.corrcoef(lon, lat)[0, 1]

# Check for independence
# If the variables are independent, correlation should be close to 0
if abs(correlation) < 0.1:  # You can adjust the threshold based on your context
    print("The variables are likely independent.")
else:
    print("The variables might not be independent.")
# Out:
# The variables might not be independent.

# %% [markdown]
# ## CDF trial

# %%
data = lon 

# Creating histogram to estimate the CDF
hist, bins = np.histogram(data, bins=FDrule(lon), density=True)
cumulative = np.cumsum(hist * np.diff(bins))  # Estimating cumulative distribution function (CDF)

# Generating synthetic data based on the CDF
# synthetic_data = np.interp(np.random.uniform(0, 1, finval), cumulative, bins[:-1])

# Plotting original data and synthetic data
plt.figure(figsize=(8, 5))
plt.hist(data, bins=20, alpha=0.5, label='Original Data')
# plt.hist(synthetic_data, bins=20, alpha=0.5, label='Synthetic Data')
plt.legend()
plt.show()

# %%
data = lat

# Creating histogram to estimate the CDF
hist1, bins1 = np.histogram(data, bins=FDrule(lat), density=True)
cumulative1 = np.cumsum(hist1 * np.diff(bins1))  # Estimating cumulative distribution function (CDF)

# Generating synthetic data based on the CDF
# synthetic_data1 = np.interp(np.random.uniform(0, 1, finval), cumulative, bins1[:-1])


plt.hist(data, bins=20, alpha=0.5, label='Original Data')
# plt.hist(synthetic_data1, bins=20, alpha=0.5, label='Synthetic Data')
plt.legend()
plt.show()

# %% [markdown]
# ### CDF Gen

# %%
very_new_lat = np.interp(np.random.uniform(0, 1, 30000), cumulative1, bins1[:-1])
very_new_lon = np.interp(np.random.uniform(0, 1, 30000), cumulative, bins[:-1])


# Filter values within the desired ranges
new_lats = [value for value in very_new_lat if -90 <= value <= 90]
new_lons = [value for value in very_new_lon if -180 <= value <= 180]

# Trim the longer list to match the length of the shorter one
min_length = min(len(new_lats), len(new_lons))
new_lats = new_lats[:min_length]
new_lons = new_lons[:min_length]

newpixss = hp.ang2pix(128, new_lons, new_lats, lonlat=True)
finpix2 = []
for pixie in newpixss:
    if pixie in validpix:  
        finpix2.append(pixie)
    if len(finpix2)==finval:
        break

# %%
cdf_lon,cdf_lat=hp.pix2ang(128,finpix2,lonlat=True)

# %% [markdown]
# ## Final checks

# %%
shapecheck(lon,lat)

# %%
# distfit generated map:
shapecheck(finlon,finlat)

# %%
shapecheck((spline_lon),(spline_lat))
shapecheck(lon,lat)

plt.show()
np.shape(spline_lat)
# Out:
# (10000,)

# %%
data = {'lon': np.append(spline_lon,lon), 'lat': np.append(spline_lat,lat)}
df_check = pd.DataFrame(data)
df_check.to_csv('/home/pratush/Desktop/check_gentot.csv')

# %%
#cdf generated map:
shapecheck(cdf_lon,cdf_lat)

# %% [markdown]
# # Country wise parameter trends

# %%
# Have to make country wise median power as x axis and country pop dens as y axis
# outline of algorithm for this:
# open each csv file and and make median of power, ang2pix of any Tx and corresponding pix of popdens map(country wise)
# then plot them both

# %%
##---------Read the tif file---------##
HDI=tiff.imread('/home/pratush/Desktop/pop_raster_world.tif')
HDI_array=np.array(HDI)

#----------Define the spherical coordinates----------#
theta1 = np.linspace(np.radians(0), np.radians(180), num=HDI_array.shape[0],endpoint=False)
phi1 = np.linspace(-np.radians(180), np.radians(180), num=HDI_array.shape[1],endpoint=False)

#---------- Set angular resolution----------#
nside = 128

##--------Make empty healpix mask and pixel values vector--------##
HDI_map = np.zeros(hp.nside2npix(nside), dtype=np.double)
pixel_counts1 = np.zeros(hp.nside2npix(nside), dtype=int)


for i in range(len(theta1)):
    for j in range(len(phi1)):
        pixel1 = hp.ang2pix(nside, theta1[i], phi1[j])
        HDI_map[pixel1] += HDI_array[i, j]
        pixel_counts1[pixel1] += 1

#--------Average value of each pixel--------#
HDI_map[pixel_counts1>0] /= pixel_counts1[pixel_counts1>0 ]

# %%
csv_files = glob.glob('./database/*.csv')
#France has 9393 Tx
med_vals=[]
y_params=[]
# --Create an empty dataframe to store the combined data-- #
df = pd.DataFrame()

for csv_file in (csv_files):
    df_temp = pd.read_csv(csv_file)
    df_temp=df_temp.dropna(subset=['Latitude in degrees', 'Longitude in degrees','EIRP'])
    temp_pow=df_temp['EIRP'].to_numpy()
    med_vals.append(np.median(temp_pow))
    temp_lat=df_temp['Latitude in degrees'].to_numpy()
    temp_lon=df_temp['Longitude in degrees'].to_numpy()
    sellat,sellon=np.median(temp_lat),np.median(temp_lon)
    tempix=hp.ang2pix(128,sellon,sellat,lonlat=True)
    print(sellat,sellon)
    y_params.append(HDI_map[tempix])
# read Tx params into numpy arrays
# Out:
# 18.4538 -70.2
# -66.394 140.0017
# 10.4151 -61.273
# -17.394 177.515
# -29.1036111111111 26.7086111111111
# 15.3519 32.31
# 1.2105 103.4558
# 13.2623 -6.4533
# 65.18 -19.4212
# 40.2105 47.0126
# 18.1033 -76.7855
# 17.4521 -64.5011
# 38.2451 23.1718
# 35.100049999999996 136.36375
# 58.5432 25.3625
# -10.194 14.141
# 22.2056 114.0914
# 12.3101 -69.5941
# 56.5526 24.2302
# 31.58 35.055
# 52.807325000000006 -2.673359
# 15.11 145.4406
# -28.6838888888889 145.195833333333
# 25.1844 51.3011
# 40.27275 67.1753
# -1.5308 30.0059
# 40.1016 44.5436
# -15.563 -5.43
# 5.051349999999999 -52.4041
# -18.555 30.05705
# -14.192 -170.4442
# 34.3104 68.4046
# 7.205 134.292
# -8.3353 125.3427
# 14.4518 -87.161
# 22.0603 -79.3
# 34.5734 33.094
# 54.55 55.52
# 20.4522 -100.26
# -26.2905 31.148200000000003
# -1.3624 -79.0
# 17.5803 103.065
# 0.2507 9.2824
# 42.4037 24.577550000000002
# 6.3575 -58.0943
# 13.4723 5.1518
# 40.111000000000004 -8.1149
# 25.0958 55.19
# 62.152 25.02295
# 7.56 2.2031
# 48.452 19.05695
# 45.51 25.2233
# -33.061 -55.5703
# 6.3633 -1.1451
# 6.18 -10.2041
# 12.0648 15.48
# 33.53 35.3924
# 44.0859 20.321599999999997
# -5.45 110.22
# 5.1 31.34
# 31.57865 35.5126
# 6.5715 1.12
# 45.1333 16.01
# 24.0171 120.49
# 48.35255 32.557050000000004
# 5.18 -74.58
# 38.744694 -91.29014
# 34.5111 2.5953
# 50.4114 4.3658
# 42.354 19.144
# 51.4536 19.07
# 39.152 33.1643
# 27.2642 89.38
# 9.5829 -83.5132
# 31.54 35.11
# 15.6247 -23.3721
# -6.0754 35.4452
# 28.11 -16.1725
# 8.2659 -12.0317
# 46.7251388888889 275.931111111111
# 35.3138 10.082
# -40.394 174.3453
# 4.28 103.2142
# -21.583 17.0625
# 42.34245 20.5837
# -25.22 -56.28
# 19.5417 96.1017
# 34.5111 2.5953
# 29.1057 48.0255
# 50.8083217 9.7864406
# 14.49 -90.4657
# 10.02255 -12.1501
# 43.48 12.2611
# 58.9960335 14.833333
# 9.0195 38.4312
# 41.0 19.5443
# -15.302 167.104
# 46.4751 -56.1035
# -8.777750000000001 159.5427
# 23.45 90.25
# -19.463 -47.3888
# -4.2008 25.12
# 25.0248 -77.1902
# 13.1223 -61.1247
# -13.203 -176.1109
# 14.4007 -16.0633
# 12.0 104.47
# 49.45855 6.05365
# 47.19 19.02485
# 49.4312 15.25985
# 13.42 -89.12
# -14.242 28.1701
# 18.2608 -64.3814
# 4.44695 114.43535
# 27.42 84.524
# -29.203 27.4216
# 47.2127 13.46275
# 8.4828 -80.2454
# 42.1045 74.3
# 6.79565 80.3745
# 2.4643 45.18
# 16.79235 -12.4319
# 46.0246 14.1701
# 47.0717 28.3722
# -10.45 -76.21
# 52.58540000000001 -7.5602
# 12.15 -2.22
# -6.04 146.592
# 34.4329 112.12
# 0.18 6.43
# 31.335 71.47
# 15.2 38.55
# 4.59 18.34
# 15.22 44.12
# 11.1455 122.57
# 23.15 78.0705
# -17.52 34.5323
# 39.0025 69.37
# 55.447649999999996 9.5839
# 4.0774 10.1755
# 1.2074 172.83710000000002
# 6.4348 -5.1323
# 12.367799999999999 -86.0001
# 34.35 44.2535
# 28.2124 31.39
# -4.3717 55.2818
# -20.201 57.3041
# 35.1421 36.4154
# 45.5431 3.0648
# 47.50095 69.4707
# 12.03 -61.43
# 5.4927 -55.1039
# -0.244 36.4401
# 21.47 -72.17
# 42.013999999999996 43.23
# 32.1236 -6.0846
# 55.2157 23.5606
# 25.0248 -77.1902
# 14.02245 100.31125
# -13.471 34.0609
# 61.5324 9.5
# 46.5153 8.2944
# 16.0706 106.29294999999999
# 34.3827 51.0505
# -22.756999999999998 25.3947
# 36.1802 127.4414
# 7.2337 7.02
# 11.3551 42.5038
# 18.3024 -72.1858
# 38.0523 59.31
# 44.130300000000005 17.5858
# 41.3512 21.3186
# 25.03875 43.0812
# 15.2 -61.2164
# 0.32505 32.185
# -4.1126 15.1501
# 66.5773 -51.5129
# 13.115 -59.3514
# -34.125 -71.27
# -13.504 -171.461
# -21.082 -175.123
# 47.5541 104.90944999999999
# 17.3 -88.23265
# 52.08653175 5.5744905
# 18.0222 -63.0153
# 3.3515 8.48
# 32.2426 14.343
# 40.4811 -2.36
# 38.543 125.56

# %%
csv_file
# Out:
# './database/N Korea.csv'

# %%
plt.scatter(med_vals,y_params)
plt.xscale('log')
plt.yscale('log')

# %%
plt.hist(med_vals,bins=FDrule(med_vals))
# plt.xlim(500,900)
plt.show()
