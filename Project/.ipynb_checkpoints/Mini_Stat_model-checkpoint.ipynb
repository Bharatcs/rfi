# %%
import numpy as np 
import healpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import tifffile as tiff
import glob
import seaborn as sns
# sns.set_style("darkgrid")
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from num2words import num2words
from scipy.optimize import curve_fit
from mpl_toolkits import mplot3d
import os
from distfit import distfit
import sys
import scipy
import rasterio
from scipy.interpolate import CubicSpline
# sns.set(rc={"xtick.bottom": True, "ytick.left": True})
# %matplotlib inline
# %matplotlib notebook

# %% [markdown]
# ## Read Country DB parameters

# %%
csv_files = ['./database/Russia.csv']
#France has 9393 Tx

# --Create an empty dataframe to store the combined data-- #
df = pd.DataFrame()

# Loop through each CSV file and append its contents to the combined dataframe
for csv_file in (csv_files):
    df_temp = pd.read_csv(csv_file)
    df = pd.concat([df, df_temp],ignore_index=True) 
# read Tx params into numpy arrays
df=df.dropna()
power=df['EIRP'].to_numpy()
lat_128=df['Latitude in degrees'].to_numpy()
lon_128=df['Longitude in degrees'].to_numpy()
# convert Tx coords into HEALPix pixels
pix=hp.ang2pix(128,lon_128,lat_128,lonlat=True)

# %%
# make number of Tx per pixel map
Tx_num_128=np.zeros(hp.nside2npix(128))
for pi in pix:
    Tx_num_128[pi]+=1
hp.mollview(Tx_num_128,flip='geo',cmap='plasma',norm='hist',title='')
plt.show()

# %%
# making total Tx power in each pixel
Tx_pow_128=np.zeros(hp.nside2npix(128))
for index,p in enumerate(pix):
    Tx_pow_128[p]+=(power[index])
hp.mollview(Tx_pow_128,flip='geo',cmap='viridis',norm='hist',min=300)
plt.show()

# %% [markdown]
# # Fitting PDF to Tx params

# %%
# read Tx params of selected 5k country
fr_df=pd.read_csv('./database/Russia.csv')
fr_df=fr_df.dropna()
lat=fr_df['Latitude in degrees'].to_numpy()
lon=fr_df['Longitude in degrees'].to_numpy()
power=fr_df['EIRP'].to_numpy()
freq=fr_df['Frequency(MHz)'].to_numpy()

# %%
# Bin width using Freedman Diaconis rule
def FDrule(data):
    # Calculate interquartile range
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    
    # Calculate Freedman-Diaconis bin width
    n = len(data)
    bin_width = 2 * iqr / (n ** (1/3))

    # Calculate number of bins
    data_range = max(data) - min(data)
    num_bins = int(data_range / bin_width) + 1
    
    return num_bins

# %% [markdown]
# ## Country HEALPix map as mask

# %%
# France shapefile was downloaded from https://gadm.org/download_country.html and rasterized using QGIS
# Open the GeoTIFF file
file_path = '/home/pratush/Desktop/Russia_raster.tif'
src = rasterio.open(file_path)

# Read the raster data as a numpy array
data = src.read(1)  # Assuming a single-band raster

# Find pixels with non-zero values
non_zero_pixels = np.where(data != 0)

# Get the coordinates of non zero pixels
templat=[]
templon=[]
for y, x in zip(*non_zero_pixels):
    lonval, latval = src.xy(y, x)  # Get the longitude and latitude of the pixel
    templat.append(latval)
    templon.append(lonval)

# %%
# Making a mask for generated data
temppix=hp.ang2pix(128,templon,templat,lonlat=True)
template=np.zeros(hp.nside2npix(128))
for pi in temppix:
    template[pi]+=1
template=np.where(template != 0, 1, 0)
hp.mollview(template,flip='geo')

# %%
def shapecheck(lon,lat):
    checkpix=hp.ang2pix(128,lon,lat,lonlat=True)
    checkmap=np.zeros(hp.nside2npix(128))
    for pi in checkpix:
        checkmap[pi]+=1
    checkmap=np.where(checkmap != 0, 1, 0)
    return hp.mollview(checkmap,flip='geo')

# %% [markdown]
# ### Modelling Latitude

# %%
binw=FDrule(lat)
# Fit a probability density function
distlat = distfit(distr='full',bins=binw)
distlat.fit_transform(lat)

# Plot the fitted distribution
distlat.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlat.model['name'])
print("Parameters:", distlat.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.07 sec] [RSS: 0.0173902] [loc=-83.465 scale=3477.132]
# [distfit] >INFO> [anglit         ] [0.01 sec] [RSS: 0.032394] [loc=56.488 scale=21.417]
# [distfit] >INFO> [arcsine        ] [0.04 sec] [RSS: 0.084393] [loc=41.569 scale=31.733]
# [distfit] >INFO> [beta           ] [0.12 sec] [RSS: 0.015669] [loc=-2770.948 scale=3117.567]
# [distfit] >INFO> [betaprime      ] [0.12 sec] [RSS: 0.0162485] [loc=-153.409 scale=6.322]
# [distfit] >INFO> [bradford       ] [0.03 sec] [RSS: 0.0486402] [loc=41.570 scale=31.733]
# [distfit] >INFO> [burr           ] [0.36 sec] [RSS: 0.0117837] [loc=-0.332 scale=56.882]
# [distfit] >INFO> [cauchy         ] [0.00 sec] [RSS: 0.0106005] [loc=54.764 scale=2.718]
# [distfit] >INFO> [chi            ] [0.07 sec] [RSS: 0.0162913] [loc=-19.148 scale=7.664]
# [distfit] >INFO> [chi2           ] [0.07 sec] [RSS: 0.0171554] [loc=0.093 scale=0.277]
# [distfit] >INFO> [cosine         ] [0.04 sec] [RSS: 0.0241273] [loc=55.283 scale=5.742]
# [distfit] >INFO> [dgamma         ] [0.01 sec] [RSS: 0.00970264] [loc=54.757 scale=3.474]
# [distfit] >INFO> [dweibull       ] [0.03 sec] [RSS: 0.0100711] [loc=54.738 scale=4.200]
# [distfit] >INFO> [erlang         ] [0.07 sec] [RSS: 0.0159933] [loc=-238.164 scale=0.099]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.0619202] [loc=41.570 scale=12.736]
# [distfit] >INFO> [exponnorm      ] [0.03 sec] [RSS: 0.0158054] [loc=54.300 scale=5.377]
# [distfit] >INFO> [exponweib      ] [0.29 sec] [RSS: 0.0154756] [loc=-30.768 scale=77.192]
# [distfit] >INFO> [exponpow       ] [0.14 sec] [RSS: 0.133828] [loc=41.570 scale=1.243]
# [distfit] >INFO> [f              ] [0.12 sec] [RSS: 0.0159594] [loc=-438.036 scale=492.325]
# [distfit] >INFO> [fatiguelife    ] [0.09 sec] [RSS: 0.0159351] [loc=-333.987 scale=388.273]
# [distfit] >INFO> [fisk           ] [0.27 sec] [RSS: 0.0128479] [loc=-331783948.656 scale=331784003.072]
# [distfit] >INFO> [foldcauchy     ] [0.03 sec] [RSS: 0.0105492] [loc=-0.150 scale=2.724]
# [distfit] >INFO> [foldnorm       ] [0.05 sec] [RSS: 0.424804] [loc=41.570 scale=2.164]
# [distfit] >INFO> [genlogistic    ] [0.02 sec] [RSS: 0.0119894] [loc=55.493 scale=2.689]
# [distfit] >INFO> [genpareto      ] [0.12 sec] [RSS: 0.0699559] [loc=-0.091 scale=102.282]
# [distfit] >INFO> [gennorm        ] [0.02 sec] [RSS: 0.0110093] [loc=54.525 scale=5.415]
# [distfit] >INFO> [genexpon       ] [0.22 sec] [RSS: 0.0292571] [loc=41.565 scale=1.928]
# [distfit] >INFO> [genextreme     ] [0.31 sec] [RSS: 0.195899] [loc=71.861 scale=4.843]
# [distfit] >INFO> [gausshyper     ] [0.41 sec] [RSS: 0.0171675] [loc=29.882 scale=48.982]
# [distfit] >INFO> [gamma          ] [0.06 sec] [RSS: 0.0159868] [loc=-234.772 scale=0.100]
# [distfit] >INFO> [gengamma       ] [0.26 sec] [RSS: 0.0156532] [loc=-123.938 scale=67.841]
# [distfit] >INFO> [genhalflogistic] [0.12 sec] [RSS: 0.034518] [loc=41.570 scale=12.208]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 0.0508863] [loc=41.546 scale=11.097]
# [distfit] >INFO> [gompertz       ] [0.10 sec] [RSS: 0.0560812] [loc=41.570 scale=3.164]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.0262736] [loc=51.591 scale=5.360]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.0198798] [loc=56.989 scale=5.453]
# [distfit] >INFO> [halfcauchy     ] [0.03 sec] [RSS: 0.0572488] [loc=41.570 scale=11.852]
# [distfit] >INFO> [halflogistic   ] [0.03 sec] [RSS: 0.0505181] [loc=41.570 scale=8.610]
# [distfit] >INFO> [halfnorm       ] [0.01 sec] [RSS: 0.0479848] [loc=41.570 scale=13.865]
# [distfit] >INFO> [halfgennorm    ] [0.09 sec] [RSS: 0.0977349] [loc=41.570 scale=1.329]
# [distfit] >INFO> [hypsecant      ] [0.01 sec] [RSS: 0.011351] [loc=54.505 scale=3.492]
# [distfit] >INFO> [invgamma       ] [0.06 sec] [RSS: 0.0168242] [loc=-70.050 scale=65328.815]
# [distfit] >INFO> [invgauss       ] [0.07 sec] [RSS: 0.0217715] [loc=24.024 scale=828.630]
# [distfit] >INFO> [invweibull     ] [0.17 sec] [RSS: 0.0262723] [loc=-1237313637.730 scale=1237313689.322]
# [distfit] >INFO> [johnsonsb      ] [0.25 sec] [RSS: 0.0156722] [loc=-461.972 scale=775.593]
# [distfit] >INFO> [johnsonsu      ] [0.07 sec] [RSS: 0.0120446] [loc=55.690 scale=8.421]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.0109572] [loc=54.550 scale=4.048]
# [distfit] >INFO> [levy           ] [0.03 sec] [RSS: 0.061417] [loc=41.439 scale=8.565]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.0128826] [loc=54.416 scale=2.981]
# [distfit] >INFO> [loggamma       ] [0.06 sec] [RSS: 0.0156437] [loc=-823.322 scale=135.877]
# [distfit] >INFO> [loglaplace     ] [0.05 sec] [RSS: 0.0113961] [loc=-0.177 scale=54.727]
# [distfit] >INFO> [lognorm        ] [0.00 sec] [RSS: 0.0158055] [loc=-524246.099 scale=524300.406]
# [distfit] >INFO> [lomax          ] [0.07 sec] [RSS: 0.0620015] [loc=41.570 scale=1159.301]
# [distfit] >INFO> [maxwell        ] [0.00 sec] [RSS: 0.022333] [loc=40.311 scale=8.656]
# [distfit] >INFO> [mielke         ] [0.12 sec] [RSS: 0.0117843] [loc=-0.578 scale=57.121]
# [distfit] >INFO> [nakagami       ] [0.07 sec] [RSS: 0.0158717] [loc=-410.887 scale=465.225]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 0.0158054] [loc=54.306 scale=5.377]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.0619202] [loc=-1073741782.430 scale=1073741824.000]
# [distfit] >INFO> [pearson3       ] [0.07 sec] [RSS: 0.0156597] [loc=54.306 scale=5.377]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.0509675] [loc=41.570 scale=31.733]
# [distfit] >INFO> [powerlognorm   ] [0.37 sec] [RSS: 0.0562244] [loc=37.247 scale=4.327]
# [distfit] >INFO> [powernorm      ] [0.10 sec] [RSS: 0.0154078] [loc=56.218 scale=5.983]
# [distfit] >INFO> [rdist          ] [0.09 sec] [RSS: 0.0158125] [loc=54.309 scale=232.617]
# [distfit] >INFO> [reciprocal     ] [0.02 sec] [RSS: 0.0485283] [loc=-3.053 scale=1.000]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.0274045] [loc=41.556 scale=9.785]
# [distfit] >INFO> [rice           ] [0.09 sec] [RSS: 0.324457] [loc=41.570 scale=2.166]
# [distfit] >INFO> [recipinvgauss  ] [1.67 sec] [RSS: 0.0171209] [loc=-8.956 scale=0.461]
# [distfit] >INFO> [semicircular   ] [0.01 sec] [RSS: 0.0401797] [loc=57.424 scale=15.881]
# [distfit] >INFO> [t              ] [0.32 sec] [RSS: 0.0150435] [loc=54.441 scale=5.229]
# [distfit] >INFO> [triang         ] [0.13 sec] [RSS: 0.0231494] [loc=40.501 scale=32.812]
# [distfit] >INFO> [truncexpon     ] [0.02 sec] [RSS: 0.0479088] [loc=41.570 scale=32.281]
# [distfit] >INFO> [truncnorm      ] [0.13 sec] [RSS: 0.0532602] [loc=10.690 scale=26.005]
# [distfit] >INFO> [tukeylambda    ] [4.50 sec] [RSS: 0.0132239] [loc=54.400 scale=3.074]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.0510472] [loc=41.570 scale=31.732]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 0.831024] [loc=-0.443 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.41 sec] [RSS: 0.0131479] [loc=54.430 scale=6.069]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 0.0516063] [loc=41.116 scale=16.664]
# [distfit] >INFO> [weibull_min    ] [0.02 sec] [RSS: 0.0167273] [loc=37.336 scale=18.845]
# [distfit] >INFO> [weibull_max    ] [0.07 sec] [RSS: 0.204848] [loc=73.303 scale=1.619]
# [distfit] >INFO> [wrapcauchy     ] [0.04 sec] [RSS: 0.0513306] [loc=38.888 scale=5.477]
# Best fitted distribution: dgamma
# Parameters: (1.1662224892083912, 54.757142361910454, 3.474293790410162)

# %% [markdown]
# ### Model longitude

# %%
binwi=FDrule(lon)
# Fit a probability density function
distlon = distfit(distr='full',bins=binwi)
distlon.fit_transform(lon)

# Plot the fitted distribution
distlon.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlon.model['name'])
print("Parameters:", distlon.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.06 sec] [RSS: 0.000398849] [loc=-16.994 scale=227.205]
# [distfit] >INFO> [anglit         ] [0.03 sec] [RSS: 0.00128766] [loc=80.284 scale=109.466]
# [distfit] >INFO> [arcsine        ] [0.04 sec] [RSS: 0.0018387] [loc=19.550 scale=151.512]
# [distfit] >INFO> [beta           ] [0.12 sec] [RSS: 0.00048873] [loc=19.350 scale=20536392.157]
# [distfit] >INFO> [betaprime      ] [0.10 sec] [RSS: 0.000435649] [loc=-0.776 scale=1.555]
# [distfit] >INFO> [bradford       ] [0.07 sec] [RSS: 0.00112729] [loc=19.550 scale=148.286]
# [distfit] >INFO> [burr           ] [0.37 sec] [RSS: 0.000335511] [loc=-0.098 scale=21.600]
# [distfit] >INFO> [cauchy         ] [0.01 sec] [RSS: 0.000704834] [loc=50.814 scale=15.355]
# [distfit] >INFO> [chi            ] [0.06 sec] [RSS: 0.00326099] [loc=19.550 scale=5.380]
# [distfit] >INFO> [chi2           ] [0.04 sec] [RSS: 0.000487422] [loc=19.235 scale=10.109]
# [distfit] >INFO> [cosine         ] [0.03 sec] [RSS: 0.00113956] [loc=72.735 scale=30.117]
# [distfit] >INFO> [dgamma         ] [0.02 sec] [RSS: 0.000824153] [loc=57.834 scale=18.798]
# [distfit] >INFO> [dweibull       ] [0.03 sec] [RSS: 0.000818602] [loc=57.879 scale=25.822]
# [distfit] >INFO> [erlang         ] [0.02 sec] [RSS: 0.000487421] [loc=19.235 scale=20.218]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.0011682] [loc=19.550 scale=46.138]
# [distfit] >INFO> [exponnorm      ] [0.04 sec] [RSS: 0.000239902] [loc=32.238 scale=4.791]
# [distfit] >INFO> [exponweib      ] [0.29 sec] [RSS: 0.000370624] [loc=14.774 scale=4.750]
# [distfit] >INFO> [exponpow       ] [0.16 sec] [RSS: 0.000806036] [loc=19.548 scale=78.542]
# [distfit] >INFO> [f              ] [0.12 sec] [RSS: 0.000364349] [loc=8.662 scale=44.337]
# [distfit] >INFO> [fatiguelife    ] [0.07 sec] [RSS: 0.00038152] [loc=13.652 scale=43.845]
# [distfit] >INFO> [fisk           ] [0.16 sec] [RSS: 0.000405138] [loc=18.462 scale=37.695]
# [distfit] >INFO> [foldcauchy     ] [0.06 sec] [RSS: 0.000578433] [loc=19.550 scale=16.416]
# [distfit] >INFO> [foldnorm       ] [0.05 sec] [RSS: 0.000833758] [loc=19.550 scale=47.124]
# [distfit] >INFO> [genlogistic    ] [0.09 sec] [RSS: 0.000628375] [loc=-106.768 scale=21.955]
# [distfit] >INFO> [genpareto      ] [0.15 sec] [RSS: 0.000909765] [loc=19.550 scale=65.833]
# [distfit] >INFO> [gennorm        ] [0.03 sec] [RSS: 0.000975519] [loc=64.974 scale=43.700]
# [distfit] >INFO> [genexpon       ] [0.18 sec] [RSS: 0.000622704] [loc=12.198 scale=1.918]
# [distfit] >INFO> [genextreme     ] [0.24 sec] [RSS: 0.000360393] [loc=48.660 scale=18.729]
# [distfit] >INFO> [gausshyper     ] [0.36 sec] [RSS: 0.000497056] [loc=19.316 scale=1386.142]
# [distfit] >INFO> [gamma          ] [0.02 sec] [RSS: 0.000487421] [loc=19.235 scale=20.218]
# [distfit] >INFO> [gengamma       ] [0.26 sec] [RSS: 0.000692614] [loc=19.535 scale=70.664]
# [distfit] >INFO> [genhalflogistic] [0.12 sec] [RSS: 0.000803119] [loc=19.548 scale=39.787]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 0.000596855] [loc=19.392 scale=36.569]
# [distfit] >INFO> [gompertz       ] [0.13 sec] [RSS: 0.00090438] [loc=16.740 scale=57.175]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.00062868] [loc=51.771 scale=21.940]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.00132031] [loc=82.923 scale=36.819]
# [distfit] >INFO> [halfcauchy     ] [0.03 sec] [RSS: 0.00108621] [loc=19.550 scale=36.561]
# [distfit] >INFO> [halflogistic   ] [0.05 sec] [RSS: 0.000859075] [loc=19.550 scale=32.212]
# [distfit] >INFO> [halfnorm       ] [0.01 sec] [RSS: 0.000835456] [loc=19.550 scale=55.935]
# [distfit] >INFO> [halfgennorm    ] [0.15 sec] [RSS: 0.000827883] [loc=19.550 scale=83.729]
# [distfit] >INFO> [hypsecant      ] [0.01 sec] [RSS: 0.000859838] [loc=59.030 scale=20.831]
# [distfit] >INFO> [invgamma       ] [0.04 sec] [RSS: 0.000363634] [loc=6.978 scale=194.802]
# [distfit] >INFO> [invgauss       ] [0.06 sec] [RSS: 0.000372509] [loc=13.003 scale=133.983]
# [distfit] >INFO> [invweibull     ] [0.12 sec] [RSS: 0.000360392] [loc=-16.067 scale=64.727]
# [distfit] >INFO> [johnsonsb      ] [0.17 sec] [RSS: 0.000419501] [loc=17.718 scale=261.160]
# [distfit] >INFO> [johnsonsu      ] [0.08 sec] [RSS: 0.0002788] [loc=27.678 scale=8.369]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.000847999] [loc=55.520 scale=24.367]
# [distfit] >INFO> [levy           ] [0.02 sec] [RSS: 0.00109343] [loc=18.754 scale=28.081]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.000900364] [loc=61.385 scale=17.561]
# [distfit] >INFO> [loggamma       ] [0.06 sec] [RSS: 0.000986272] [loc=-10251.315 scale=1379.262]
# [distfit] >INFO> [loglaplace     ] [0.04 sec] [RSS: 0.000763193] [loc=-0.146 scale=55.666]
# [distfit] >INFO> [lognorm        ] [0.00 sec] [RSS: 0.000381981] [loc=15.377 scale=41.687]
# [distfit] >INFO> [lomax          ] [0.07 sec] [RSS: 0.00116571] [loc=19.550 scale=5496.399]
# [distfit] >INFO> [maxwell        ] [0.01 sec] [RSS: 0.000841377] [loc=-0.012 scale=42.097]
# [distfit] >INFO> [mielke         ] [0.19 sec] [RSS: 0.00036] [loc=-12.195 scale=21.598]
# [distfit] >INFO> [nakagami       ] [0.02 sec] [RSS: 0.00066494] [loc=19.533 scale=55.949]
# [distfit] >INFO> [norm           ] [0.06 sec] [RSS: 0.000986102] [loc=65.688 scale=31.623]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.0011682] [loc=-4294967276.450 scale=4294967296.000]
# [distfit] >INFO> [pearson3       ] [0.06 sec] [RSS: 0.000487421] [loc=65.688 scale=30.646]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.00136402] [loc=19.550 scale=146.570]
# [distfit] >INFO> [powerlognorm   ] [0.37 sec] [RSS: 0.00150566] [loc=-11.720 scale=6.561]
# [distfit] >INFO> [powernorm      ] [0.18 sec] [RSS: nan] [loc=14.801 scale=0.217]
# [distfit] >INFO> [rdist          ] [0.09 sec] [RSS: 0.000986959] [loc=65.730 scale=1096.313]
# [distfit] >INFO> [reciprocal     ] [0.06 sec] [RSS: 0.00113567] [loc=-15.417 scale=1.000]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.000777007] [loc=14.821 scale=42.352]
# [distfit] >INFO> [rice           ] [0.10 sec] [RSS: 0.000777007] [loc=14.821 scale=42.352]
# [distfit] >INFO> [recipinvgauss  ] [1.61 sec] [RSS: 0.000396118] [loc=14.469 scale=15.448]
# [distfit] >INFO> [semicircular   ] [0.03 sec] [RSS: 0.00142583] [loc=89.367 scale=76.793]
# [distfit] >INFO> [t              ] [0.32 sec] [RSS: 0.000901153] [loc=61.506 scale=27.047]
# [distfit] >INFO> [triang         ] [0.15 sec] [RSS: 0.000607257] [loc=19.127 scale=147.408]
# [distfit] >INFO> [truncexpon     ] [0.04 sec] [RSS: 0.00116294] [loc=5.270 scale=149.377]
# [distfit] >INFO> [truncnorm      ] [0.03 sec] [RSS: 0.000986102] [loc=65.688 scale=31.623]
# [distfit] >INFO> [tukeylambda    ] [4.95 sec] [RSS: 0.000896484] [loc=61.177 scale=17.347]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.00147887] [loc=19.550 scale=146.570]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 0.701477] [loc=2.633 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.43 sec] [RSS: 0.000884586] [loc=61.035 scale=34.115]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 0.000466723] [loc=17.586 scale=56.837]
# [distfit] >INFO> [weibull_min    ] [0.03 sec] [RSS: 0.000584784] [loc=19.528 scale=51.622]
# [distfit] >INFO> [weibull_max    ] [0.12 sec] [RSS: 0.00362194] [loc=166.120 scale=1.625]
# [distfit] >INFO> [wrapcauchy     ] [0.04 sec] [RSS: 0.00147426] [loc=18.814 scale=23.444]
# Best fitted distribution: exponnorm
# Parameters: (6.981475832217603, 32.23825114230188, 4.791216709090322)

# %% [markdown]
# ### Model Tx power

# %%
powbin=FDrule(power)
# Fit a probability density function
distpow = distfit(distr='powerlaw',bins=powbin)
distpow.fit_transform(power)

# Plot the fitted distribution
distpow.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distpow.model['name'])
print("Parameters:", distpow.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [powerlaw] [0.07 sec] [RSS: 1.91867e-06] [loc=-0.000 scale=160000.000]
# Best fitted distribution: powerlaw
# Parameters: (0.006728533047148055, -2.2250738585072014e-308, 160000.00000000003)

# %% [markdown]
# ### Model Tx Freq

# %%
freqbin=FDrule(freq)
# Fit a probability density function
distfreq = distfit(distr='full',bins=freqbin)
distfreq.fit_transform(freq)

# Plot the fitted distribution
distfreq.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distfreq.model['name'])
print("Parameters:", distfreq.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.08 sec] [RSS: 0.0171441] [loc=31.756 scale=213.050]
# [distfit] >INFO> [anglit         ] [0.01 sec] [RSS: 0.0211236] [loc=75.928 scale=26.168]
# [distfit] >INFO> [arcsine        ] [0.05 sec] [RSS: 0.0230915] [loc=56.250 scale=35.548]
# [distfit] >INFO> [beta           ] [0.13 sec] [RSS: 0.0272045] [loc=56.250 scale=35.513]
# [distfit] >INFO> [betaprime      ] [0.12 sec] [RSS: 0.0202648] [loc=-1.558 scale=5.230]
# [distfit] >INFO> [bradford       ] [0.05 sec] [RSS: 0.0211857] [loc=56.250 scale=35.805]
# [distfit] >INFO> [burr           ] [0.36 sec] [RSS: 0.0166886] [loc=-0.284 scale=59.177]
# [distfit] >INFO> [cauchy         ] [0.01 sec] [RSS: 0.0104001] [loc=70.192 scale=2.960]
# [distfit] >INFO> [chi            ] [0.04 sec] [RSS: 0.0199517] [loc=54.299 scale=13.611]
# [distfit] >INFO> [chi2           ] [0.04 sec] [RSS: 0.0186973] [loc=52.494 scale=1.844]
# [distfit] >INFO> [cosine         ] [0.01 sec] [RSS: 0.0218638] [loc=76.287 scale=7.732]
# [distfit] >INFO> [dgamma         ] [0.03 sec] [RSS: 0.0138957] [loc=70.520 scale=10.046]
# [distfit] >INFO> [dweibull       ] [0.06 sec] [RSS: 0.01326] [loc=70.520 scale=7.485]
# [distfit] >INFO> [erlang         ] [0.02 sec] [RSS: 0.0186973] [loc=52.494 scale=3.688]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.0261926] [loc=56.250 scale=19.400]
# [distfit] >INFO> [exponnorm      ] [0.03 sec] [RSS: 0.0137777] [loc=66.125 scale=2.711]
# [distfit] >INFO> [exponweib      ] [0.28 sec] [RSS: 0.0171325] [loc=32.057 scale=3.518]
# [distfit] >INFO> [exponpow       ] [0.16 sec] [RSS: 0.0386467] [loc=65.746 scale=1.332]
# [distfit] >INFO> [f              ] [0.12 sec] [RSS: 0.0175023] [loc=43.259 scale=29.953]
# [distfit] >INFO> [fatiguelife    ] [0.06 sec] [RSS: 0.0180637] [loc=47.237 scale=26.979]
# [distfit] >INFO> [fisk           ] [0.22 sec] [RSS: 0.0166659] [loc=53.459 scale=19.762]
# [distfit] >INFO> [foldcauchy     ] [0.07 sec] [RSS: 0.0114315] [loc=56.180 scale=3.033]
# [distfit] >INFO> [foldnorm       ] [0.10 sec] [RSS: 0.021994] [loc=56.231 scale=9.568]
# [distfit] >INFO> [genlogistic    ] [0.09 sec] [RSS: 0.0175981] [loc=32.553 scale=7.152]
# [distfit] >INFO> [genpareto      ] [0.12 sec] [RSS: 0.0222591] [loc=-0.986 scale=206.444]
# [distfit] >INFO> [gennorm        ] [0.03 sec] [RSS: 0.0115212] [loc=70.040 scale=1.474]
# [distfit] >INFO> [genexpon       ] [0.17 sec] [RSS: 0.0259741] [loc=55.786 scale=1.520]
# [distfit] >INFO> [genextreme     ] [0.26 sec] [RSS: 0.0170699] [loc=71.196 scale=7.100]
# [distfit] >INFO> [gausshyper     ] [0.33 sec] [RSS: 0.0198976] [loc=56.159 scale=35.591]
# [distfit] >INFO> [gamma          ] [0.02 sec] [RSS: 0.0186973] [loc=52.494 scale=3.688]
# [distfit] >INFO> [gengamma       ] [0.26 sec] [RSS: 0.0183032] [loc=51.571 scale=0.429]
# [distfit] >INFO> [genhalflogistic] [0.09 sec] [RSS: 0.0215525] [loc=56.244 scale=36.660]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 0.0228736] [loc=55.705 scale=17.600]
# [distfit] >INFO> [gompertz       ] [0.11 sec] [RSS: 0.27941] [loc=82.473 scale=0.622]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.0175835] [loc=71.335 scale=7.178]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.024316] [loc=80.613 scale=9.514]
# [distfit] >INFO> [halfcauchy     ] [0.03 sec] [RSS: 0.0252046] [loc=56.250 scale=17.232]
# [distfit] >INFO> [halflogistic   ] [0.03 sec] [RSS: 0.0236673] [loc=56.250 scale=13.113]
# [distfit] >INFO> [halfnorm       ] [0.02 sec] [RSS: 0.0232822] [loc=56.250 scale=21.563]
# [distfit] >INFO> [halfgennorm    ] [0.11 sec] [RSS: 0.0337499] [loc=56.250 scale=1.489]
# [distfit] >INFO> [hypsecant      ] [0.01 sec] [RSS: 0.0198666] [loc=73.075 scale=6.461]
# [distfit] >INFO> [invgamma       ] [0.06 sec] [RSS: 0.0188365] [loc=28.853 scale=1326.261]
# [distfit] >INFO> [invgauss       ] [0.06 sec] [RSS: 0.0180189] [loc=47.117 scale=263.911]
# [distfit] >INFO> [invweibull     ] [0.12 sec] [RSS: 0.0170698] [loc=-110.272 scale=181.469]
# [distfit] >INFO> [johnsonsb      ] [0.25 sec] [RSS: 0.0179977] [loc=49.290 scale=441.777]
# [distfit] >INFO> [johnsonsu      ] [0.16 sec] [RSS: 0.0220041] [loc=787613271.075 scale=917732169.669]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.0155532] [loc=71.150 scale=7.204]
# [distfit] >INFO> [levy           ] [0.03 sec] [RSS: 0.0261433] [loc=55.177 scale=14.869]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.0213572] [loc=74.396 scale=5.595]
# [distfit] >INFO> [loggamma       ] [0.06 sec] [RSS: 0.0220652] [loc=-2512.818 scale=356.464]
# [distfit] >INFO> [loglaplace     ] [0.04 sec] [RSS: 0.0147107] [loc=-0.195 scale=71.345]
# [distfit] >INFO> [lognorm        ] [0.00 sec] [RSS: 0.017882] [loc=48.584 scale=25.539]
# [distfit] >INFO> [lomax          ] [0.07 sec] [RSS: 0.0262124] [loc=56.250 scale=2414.586]
# [distfit] >INFO> [maxwell        ] [0.01 sec] [RSS: 0.0199937] [loc=54.151 scale=13.550]
# [distfit] >INFO> [mielke         ] [0.19 sec] [RSS: 0.0158603] [loc=31.961 scale=31.257]
# [distfit] >INFO> [nakagami       ] [0.06 sec] [RSS: 0.0160235] [loc=65.746 scale=13.528]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 0.0220281] [loc=75.650 scale=9.412]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.0261926] [loc=-2147483591.750 scale=2147483648.000]
# [distfit] >INFO> [pearson3       ] [0.06 sec] [RSS: 0.0186973] [loc=75.650 scale=9.242]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.0205322] [loc=56.001 scale=35.749]
# [distfit] >INFO> [powerlognorm   ] [0.36 sec] [RSS: 0.0244391] [loc=43.548 scale=9.316]
# [distfit] >INFO> [powernorm      ] [0.11 sec] [RSS: 0.0197918] [loc=60.717 scale=2.275]
# [distfit] >INFO> [rdist          ] [0.10 sec] [RSS: 0.0248304] [loc=65.278 scale=9.028]
# [distfit] >INFO> [reciprocal     ] [0.02 sec] [RSS: 0.0220525] [loc=-3.394 scale=1.000]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.0195594] [loc=55.760 scale=15.559]
# [distfit] >INFO> [rice           ] [0.13 sec] [RSS: 0.0195617] [loc=55.760 scale=15.286]
# [distfit] >INFO> [recipinvgauss  ] [1.60 sec] [RSS: 0.0181011] [loc=47.434 scale=2.818]
# [distfit] >INFO> [semicircular   ] [0.01 sec] [RSS: 0.0215033] [loc=78.168 scale=14.718]
# [distfit] >INFO> [t              ] [0.34 sec] [RSS: 0.0220282] [loc=75.650 scale=9.412]
# [distfit] >INFO> [triang         ] [0.16 sec] [RSS: 0.0220586] [loc=52.290 scale=39.460]
# [distfit] >INFO> [truncexpon     ] [0.06 sec] [RSS: 0.0231002] [loc=56.249 scale=41.005]
# [distfit] >INFO> [truncnorm      ] [0.06 sec] [RSS: 0.0220281] [loc=75.650 scale=9.412]
# [distfit] >INFO> [tukeylambda    ] [2.77 sec] [RSS: 0.0170266] [loc=78.748 scale=13.745]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.0211848] [loc=56.250 scale=35.500]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 0.305874] [loc=1.532 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.40 sec] [RSS: 0.0202485] [loc=74.000 scale=5.650]
# [distfit] >INFO> [wald           ] [0.02 sec] [RSS: 0.0219418] [loc=54.644 scale=28.209]
# [distfit] >INFO> [weibull_min    ] [0.05 sec] [RSS: 0.013935] [loc=65.746 scale=10.121]
# [distfit] >INFO> [weibull_max    ] [0.12 sec] [RSS: 0.0271663] [loc=91.750 scale=1.359]
# [distfit] >INFO> [wrapcauchy     ] [0.06 sec] [RSS: 0.0212229] [loc=54.193 scale=5.977]
# Best fitted distribution: cauchy
# Parameters: (70.19177971282508, 2.959937880124813)

# %% [markdown]
# ## Generating data within country

# %%
validpix = np.nonzero(template)[0] 
finval = 15470-len(lat)

nayalat = distlat.generate(30000)
nayalon = distlon.generate(30000)

# Filter values within the desired ranges
newlat = [value for value in nayalat if -90 <= value <= 90]
newlon = [value for value in nayalon if -180 <= value <= 180]

# Trim the longer list to match the length of the shorter one
min_length = min(len(newlat), len(newlon))
newlat = newlat[:min_length]
newlon = newlon[:min_length]

newpix = hp.ang2pix(128, newlon, newlat, lonlat=True)
finpix = []
for pixie in newpix:
    if pixie in validpix:  
        finpix.append(pixie)
    if len(finpix)==finval:
        break

# %%
finlon,finlat=hp.pix2ang(128,finpix,lonlat=True)
print(len(finlat))
print(finval)
# Out:
# 10473
# 10473

# %%
plt.hist(newlon,bins=int(np.sqrt(len(newlon))))
plt.show()

# %%
newwww=np.zeros(hp.nside2npix(128))
for pppp in finpix:
    newwww[pppp]+=1
hp.mollview(newwww,flip='geo',norm='hist')

# %% [markdown]
# ## Generate Freq and power values

# %%
newfreq=distfreq.generate(finval)
newpow=distpow.generate(finval)

# %%
plt.hist(freq,bins=int(np.sqrt(len(freq))))
plt.title('Original frequency')
plt.show()
plt.hist(newfreq,bins=int(np.sqrt(len(newfreq))))
plt.title('Generated frequency data')
# plt.savefig('/home/pratush/Yogen_STARFIRE/STARFIRE_paper images/trial.pdf',format='pdf',dpi=600)
plt.show()

# %%
plt.hist(power,bins=int(np.sqrt(len(power))))
plt.title('Original power')
plt.show()
plt.hist(newpow,bins=int(np.sqrt(len(newpow))))
plt.title('Generated power data')
plt.show()

# %%
# Generate random data for the histogram
data = lon

# Create a histogram
hist, bin_edges = np.histogram(data, bins=FDrule(lon),density=True)

# Calculate midpoints of bins
bin_midpoints = (bin_edges[1:] + bin_edges[:-1]) / 2

# Fit a cubic spline to the histogram
cs = CubicSpline(bin_midpoints, hist)

# Generate x values for the spline plot
x_vals = np.linspace(bin_midpoints.min(), bin_midpoints.max(), finval)

# Plot the histogram and the cubic spline
plt.hist(data, bins=FDrule(lon), label='Histogram',density=True)
plt.plot(x_vals, cs(x_vals), 'r-', label='Cubic Spline')

plt.title('Histogram with Cubic Spline Fit')
plt.legend()
plt.show()

# %%
data = lon 

# Creating histogram to estimate the CDF
hist, bins = np.histogram(data, bins=FDrule(lon), density=True)
cumulative = np.cumsum(hist * np.diff(bins))  # Estimating cumulative distribution function (CDF)

# Generating synthetic data based on the CDF
synthetic_data = np.interp(np.random.uniform(0, 1, finval), cumulative, bins[:-1])

# Plotting original data and synthetic data
plt.figure(figsize=(8, 5))
plt.hist(data, bins=20, alpha=0.5, label='Original Data')
plt.hist(synthetic_data, bins=20, alpha=0.5, label='Synthetic Data')
plt.legend()
plt.show()

# %%
data = lat

# Creating histogram to estimate the CDF
hist, bins = np.histogram(data, bins=FDrule(lat), density=True)
cumulative = np.cumsum(hist * np.diff(bins))  # Estimating cumulative distribution function (CDF)

# Generating synthetic data based on the CDF
synthetic_data1 = np.interp(np.random.uniform(0, 1, finval), cumulative, bins[:-1])

# Plotting original data and synthetic data
plt.figure(figsize=(8, 5))
plt.hist(data, bins=20, alpha=0.5, label='Original Data')
plt.hist(synthetic_data, bins=20, alpha=0.5, label='Synthetic Data')
plt.legend()
plt.show()

# %%
shapecheck(synthetic_data,synthetic_data1)
