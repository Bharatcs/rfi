# %%
import numpy as np 
import healpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import tifffile as tiff
import glob
import seaborn as sns
# sns.set_style("darkgrid")
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from num2words import num2words
from scipy.optimize import curve_fit
from mpl_toolkits import mplot3d
import os
from distfit import distfit

# sns.set(rc={"xtick.bottom": True, "ytick.left": True})
# %matplotlib inline
# %matplotlib notebook

# %% [markdown]
# ## Read Country DB parameters

# %%
csv_files = ['./database/France.csv']


#France has 9393 Tx
#DB has 


# --Create an empty dataframe to store the combined data-- #
df = pd.DataFrame()

# Loop through each CSV file and append its contents to the combined dataframe
for csv_file in (csv_files):
    df_temp = pd.read_csv(csv_file)
    df = pd.concat([df, df_temp],ignore_index=True)

df=df.dropna()
power=df['EIRP'].to_numpy()
lat_128=df['Latitude in degrees'].to_numpy()
lon_128=df['Longitude in degrees'].to_numpy()

pix=hp.ang2pix(128,lon_128,lat_128,lonlat=True)

# %%
Tx_num_128=np.zeros(hp.nside2npix(128))
for pi in pix:
    Tx_num_128[pi]+=1
hp.cartview(Tx_num_128,flip='geo',cmap='plasma',norm='hist')
plt.show()

# %%
Tx_pow_128=np.zeros(hp.nside2npix(128))
for index,p in enumerate(pix):
    Tx_pow_128[p]+=(power[index])
hp.mollview(Tx_pow_128,flip='geo',cmap='viridis',norm='hist',min=300)
plt.show()

# %%
for file in csv_files:
    filename = os.path.basename(file)  
    tempdf = pd.read_csv(file)
    data = tempdf['EIRP'].to_numpy()
    plt.hist(data, stacked=True, bins=np.linspace(1e3, 4e5, int(np.sqrt(len(power)))), label=filename)

plt.yscale('log')
plt.legend()
plt.show()

# %%
def power_law(x, a, b):
    return a * np.power(x, b)

# %%
# x_data =  bin_centers
# y_data = n
# # Fit the power law curve to the data
# params, covariance = curve_fit(power_law, x_data, y_data)

# # Get the fitted parameters
# a_fit, b_fit = params

# # Generate points for the fitted curve
# x_fit = np.linspace(min(x_data), max(x_data), 100)
# y_fit = power_law(x_fit, a_fit, b_fit)

# # Plotting the original data and the fitted curve
# plt.scatter(x_data, y_data, label='Original Data',marker='*')
# plt.plot(x_fit, y_fit, 'r-', label='Fitted Power Law Curve')

# plt.legend()

# plt.show()


# print(f"Fitted parameters: a = {a_fit}, b = {b_fit}")

# %% [markdown]
# ## Trends in Tx distribution coordinate wise

# %%
fr_df=pd.read_csv('./database/France.csv')
fr_df=fr_df.dropna()
lat=fr_df['Latitude in degrees'].to_numpy()
lon=fr_df['Longitude in degrees'].to_numpy()

# %%
size=np.size(lat)

# %%
# Fit a probability density function
distlat = distfit(distr='full',bins=int(1+3.22*np.log10(size)))
distlat.fit_transform(lat)

# Plot the fitted distribution
distlat.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlat.model['name'])
print("Parameters:", distlat.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.08 sec] [RSS: 0.0222981] [loc=-11.878 scale=1476.418]
# [distfit] >INFO> [anglit         ] [0.01 sec] [RSS: 0.0144361] [loc=46.072 scale=6.449]
# [distfit] >INFO> [arcsine        ] [0.03 sec] [RSS: 0.0827399] [loc=41.231 scale=9.796]
# [distfit] >INFO> [beta           ] [0.06 sec] [RSS: 0.0129682] [loc=41.133 scale=10.022]
# [distfit] >INFO> [betaprime      ] [0.11 sec] [RSS: 0.0224159] [loc=-34.461 scale=31.892]
# [distfit] >INFO> [bradford       ] [0.05 sec] [RSS: 0.0334204] [loc=41.231 scale=9.790]
# [distfit] >INFO> [burr           ] [0.30 sec] [RSS: 0.0237301] [loc=-0.293 scale=43.384]
# [distfit] >INFO> [cauchy         ] [0.00 sec] [RSS: 0.0423203] [loc=45.699 scale=1.639]
# [distfit] >INFO> [chi            ] [0.02 sec] [RSS: 0.0185509] [loc=40.730 scale=3.432]
# [distfit] >INFO> [chi2           ] [0.05 sec] [RSS: 0.0776399] [loc=41.231 scale=3.662]
# [distfit] >INFO> [cosine         ] [0.01 sec] [RSS: 0.0182044] [loc=46.024 scale=1.894]
# [distfit] >INFO> [dgamma         ] [0.01 sec] [RSS: 0.0294737] [loc=45.871 scale=0.904]
# [distfit] >INFO> [dweibull       ] [0.02 sec] [RSS: 0.0181855] [loc=45.897 scale=2.187]
# [distfit] >INFO> [erlang         ] [0.07 sec] [RSS: 0.0224569] [loc=13.512 scale=0.158]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.0725092] [loc=41.231 scale=4.758]
# [distfit] >INFO> [exponnorm      ] [0.03 sec] [RSS: 0.0227672] [loc=45.780 scale=2.256]
# [distfit] >INFO> [exponweib      ] [0.25 sec] [RSS: 0.239453] [loc=41.231 scale=0.879]
# [distfit] >INFO> [exponpow       ] [0.14 sec] [RSS: 0.200167] [loc=41.231 scale=1.401]
# [distfit] >INFO> [f              ] [0.12 sec] [RSS: 0.0222967] [loc=14.497 scale=31.386]
# [distfit] >INFO> [fatiguelife    ] [0.06 sec] [RSS: 0.022066] [loc=24.131 scale=21.741]
# [distfit] >INFO> [fisk           ] [0.11 sec] [RSS: 0.0270615] [loc=-0.301 scale=46.217]
# [distfit] >INFO> [foldcauchy     ] [0.04 sec] [RSS: 0.0422384] [loc=-0.138 scale=1.640]
# [distfit] >INFO> [foldnorm       ] [0.04 sec] [RSS: 0.0210496] [loc=41.231 scale=2.346]
# [distfit] >INFO> [genlogistic    ] [0.03 sec] [RSS: 0.0225939] [loc=41.555 scale=1.875]
# [distfit] >INFO> [genpareto      ] [0.12 sec] [RSS: 0.105538] [loc=0.135 scale=130.027]
# [distfit] >INFO> [gennorm        ] [0.03 sec] [RSS: 0.00943406] [loc=46.072 scale=3.957]
# [distfit] >INFO> [genexpon       ] [0.25 sec] [RSS: 0.0166821] [loc=41.231 scale=1.149]
# [distfit] >INFO> [genextreme     ] [0.09 sec] [RSS: 0.0210644] [loc=45.218 scale=2.240]
# [distfit] >INFO> [gausshyper     ] [0.45 sec] [RSS: 0.030469] [loc=41.229 scale=9.792]
# [distfit] >INFO> [gamma          ] [0.06 sec] [RSS: 0.022482] [loc=15.231 scale=0.166]
# [distfit] >INFO> [gengamma       ] [0.17 sec] [RSS: 0.218209] [loc=41.231 scale=0.806]
# [distfit] >INFO> [genhalflogistic] [0.11 sec] [RSS: 0.0193149] [loc=41.229 scale=5.582]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 0.0411834] [loc=41.184 scale=4.123]
# [distfit] >INFO> [gompertz       ] [0.09 sec] [RSS: 0.0335848] [loc=41.231 scale=1.897]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.0210948] [loc=44.873 scale=2.034]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.0249788] [loc=47.128 scale=2.123]
# [distfit] >INFO> [halfcauchy     ] [0.03 sec] [RSS: 0.0637462] [loc=41.231 scale=4.268]
# [distfit] >INFO> [halflogistic   ] [0.02 sec] [RSS: 0.049583] [loc=41.231 scale=3.244]
# [distfit] >INFO> [halfnorm       ] [0.01 sec] [RSS: 0.0454637] [loc=41.231 scale=5.273]
# [distfit] >INFO> [halfgennorm    ] [0.14 sec] [RSS: 0.0237273] [loc=41.231 scale=8.989]
# [distfit] >INFO> [hypsecant      ] [0.01 sec] [RSS: 0.0313458] [loc=45.906 scale=1.671]
# [distfit] >INFO> [invgamma       ] [0.06 sec] [RSS: 0.0226114] [loc=-78.257 scale=374249.945]
# [distfit] >INFO> [invgauss       ] [0.07 sec] [RSS: 0.021203] [loc=32.618 scale=438.886]
# [distfit] >INFO> [invweibull     ] [0.17 sec] [RSS: 0.0212103] [loc=-713744078.468 scale=713744123.339]
# [distfit] >INFO> [johnsonsb      ] [0.15 sec] [RSS: 0.0118742] [loc=40.920 scale=10.440]
# [distfit] >INFO> [johnsonsu      ] [0.17 sec] [RSS: 0.0222301] [loc=21.013 scale=5.626]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.042293] [loc=45.544 scale=1.946]
# [distfit] >INFO> [levy           ] [0.03 sec] [RSS: 0.0691655] [loc=41.096 scale=3.272]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.0272877] [loc=45.950 scale=1.368]
# [distfit] >INFO> [loggamma       ] [0.06 sec] [RSS: 0.0226463] [loc=-395.700 scale=65.676]
# [distfit] >INFO> [loglaplace     ] [0.04 sec] [RSS: 0.0427333] [loc=-0.168 scale=45.712]
# [distfit] >INFO> [lognorm        ] [0.00 sec] [RSS: 0.0222247] [loc=20.496 scale=25.393]
# [distfit] >INFO> [lomax          ] [0.06 sec] [RSS: 0.111254] [loc=41.231 scale=27835289359.560]
# [distfit] >INFO> [maxwell        ] [0.00 sec] [RSS: 0.0190151] [loc=40.560 scale=3.397]
# [distfit] >INFO> [mielke         ] [0.19 sec] [RSS: 0.0234243] [loc=-1.359 scale=44.178]
# [distfit] >INFO> [nakagami       ] [0.02 sec] [RSS: 0.0185512] [loc=40.730 scale=5.727]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 0.0227681] [loc=45.990 scale=2.265]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.0725092] [loc=-268435414.769 scale=268435456.000]
# [distfit] >INFO> [pearson3       ] [0.06 sec] [RSS: 0.021672] [loc=45.990 scale=2.288]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.032877] [loc=41.229 scale=9.792]
# [distfit] >INFO> [powerlognorm   ] [0.44 sec] [RSS: 0.0191434] [loc=-13.972 scale=56.339]
# [distfit] >INFO> [powernorm      ] [0.13 sec] [RSS: 0.0184262] [loc=42.028 scale=0.562]
# [distfit] >INFO> [rdist          ] [0.06 sec] [RSS: 0.0135511] [loc=46.086 scale=5.026]
# [distfit] >INFO> [reciprocal     ] [0.03 sec] [RSS: 0.0335709] [loc=-0.865 scale=1.000]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.0162804] [loc=41.176 scale=3.762]
# [distfit] >INFO> [rice           ] [0.06 sec] [RSS: 0.0180997] [loc=41.057 scale=2.653]
# [distfit] >INFO> [recipinvgauss  ] [1.64 sec] [RSS: 0.0217553] [loc=27.629 scale=0.282]
# [distfit] >INFO> [semicircular   ] [0.01 sec] [RSS: 0.015375] [loc=46.126 scale=4.912]
# [distfit] >INFO> [t              ] [0.32 sec] [RSS: 0.0227832] [loc=45.990 scale=2.265]
# [distfit] >INFO> [triang         ] [0.09 sec] [RSS: 0.0191864] [loc=41.037 scale=10.375]
# [distfit] >INFO> [truncexpon     ] [0.02 sec] [RSS: 0.0387937] [loc=41.231 scale=12.660]
# [distfit] >INFO> [truncnorm      ] [0.13 sec] [RSS: 0.0811808] [loc=1.532 scale=13.783]
# [distfit] >INFO> [tukeylambda    ] [2.79 sec] [RSS: 0.0131981] [loc=46.081 scale=2.297]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.0336635] [loc=41.231 scale=9.790]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 0.1078] [loc=-0.692 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.40 sec] [RSS: 0.0225569] [loc=46.127 scale=1.558]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 0.0355441] [loc=40.960 scale=6.416]
# [distfit] >INFO> [weibull_min    ] [0.02 sec] [RSS: 0.0189758] [loc=40.674 scale=5.998]
# [distfit] >INFO> [weibull_max    ] [0.05 sec] [RSS: 0.0210641] [loc=52.471 scale=7.253]
# [distfit] >INFO> [wrapcauchy     ] [0.05 sec] [RSS: 0.033917] [loc=40.770 scale=1.632]
# Best fitted distribution: gennorm
# Parameters: (5.575675860356261, 46.07245709990866, 3.9566240429450907)

# %%
# Fit a probability density function
distlon = distfit(distr='full')
distlon.fit_transform(lon)

# Plot the fitted distribution
distlon.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlon.model['name'])
print("Parameters:", distlon.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.07 sec] [RSS: 0.0500738] [loc=-15.783 scale=105.272]
# [distfit] >INFO> [anglit         ] [0.02 sec] [RSS: 0.0432508] [loc=2.819 scale=9.332]
# [distfit] >INFO> [arcsine        ] [0.03 sec] [RSS: 0.155358] [loc=-4.314 scale=14.414]
# [distfit] >INFO> [beta           ] [0.03 sec] [RSS: 0.0405821] [loc=-6.124 scale=16.726]
# [distfit] >INFO> [betaprime      ] [0.12 sec] [RSS: 0.0436675] [loc=-181.684 scale=74.333]
# [distfit] >INFO> [bradford       ] [0.03 sec] [RSS: 0.0954641] [loc=-4.313 scale=14.413]
# [distfit] >INFO> [burr           ] [0.36 sec] [RSS: 0.0411165] [loc=-4.606 scale=11.526]
# [distfit] >INFO> [cauchy         ] [0.00 sec] [RSS: 0.0627086] [loc=2.980 scale=2.004]
# [distfit] >INFO> [chi            ] [0.07 sec] [RSS: 0.0437558] [loc=-32.382 scale=4.174]
# [distfit] >INFO> [chi2           ] [0.07 sec] [RSS: 0.0440233] [loc=-25.033 scale=0.157]
# [distfit] >INFO> [cosine         ] [0.01 sec] [RSS: 0.0411121] [loc=2.879 scale=2.589]
# [distfit] >INFO> [dgamma         ] [0.01 sec] [RSS: 0.0503623] [loc=2.839 scale=1.346]
# [distfit] >INFO> [dweibull       ] [0.02 sec] [RSS: 0.0462071] [loc=2.851 scale=2.710]
# [distfit] >INFO> [erlang         ] [0.07 sec] [RSS: 0.0437754] [loc=-66.867 scale=0.124]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.130724] [loc=-4.313 scale=7.297]
# [distfit] >INFO> [exponnorm      ] [0.03 sec] [RSS: 0.0437587] [loc=2.981 scale=2.933]
# [distfit] >INFO> [exponweib      ] [0.22 sec] [RSS: 0.333532] [loc=-4.313 scale=1.638]
# [distfit] >INFO> [exponpow       ] [0.14 sec] [RSS: 0.330389] [loc=-4.313 scale=1.623]
# [distfit] >INFO> [f              ] [0.12 sec] [RSS: 0.0443287] [loc=-20.573 scale=23.341]
# [distfit] >INFO> [fatiguelife    ] [0.09 sec] [RSS: 0.0438276] [loc=-329.797 scale=332.770]
# [distfit] >INFO> [fisk           ] [0.27 sec] [RSS: 0.0476516] [loc=-338947806.502 scale=338947809.519]
# [distfit] >INFO> [foldcauchy     ] [0.03 sec] [RSS: 0.217862] [loc=-4.313 scale=3.283]
# [distfit] >INFO> [foldnorm       ] [0.11 sec] [RSS: 0.100181] [loc=-4.313 scale=7.672]
# [distfit] >INFO> [genlogistic    ] [0.02 sec] [RSS: 0.0474233] [loc=2.748 scale=1.787]
# [distfit] >INFO> [genpareto      ] [0.07 sec] [RSS: 0.297667] [loc=-4.313 scale=3.388]
# [distfit] >INFO> [gennorm        ] [0.02 sec] [RSS: 0.0394024] [loc=2.928 scale=4.817]
# [distfit] >INFO> [genexpon       ] [0.22 sec] [RSS: 0.0563663] [loc=-4.419 scale=2.237]
# [distfit] >INFO> [genextreme     ] [0.10 sec] [RSS: 0.0419483] [loc=2.031 scale=3.002]
# [distfit] >INFO> [gausshyper     ] [0.37 sec] [RSS: 0.040541] [loc=-4.935 scale=15.237]
# [distfit] >INFO> [gamma          ] [0.06 sec] [RSS: 0.0437991] [loc=-69.299 scale=0.120]
# [distfit] >INFO> [gengamma       ] [0.25 sec] [RSS: 0.0439608] [loc=-20.071 scale=0.435]
# [distfit] >INFO> [genhalflogistic] [0.10 sec] [RSS: 0.115298] [loc=-6.245 scale=17.053]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 0.101247] [loc=-4.445 scale=6.599]
# [distfit] >INFO> [gompertz       ] [0.12 sec] [RSS: 0.403726] [loc=-4.313 scale=862650516327.282]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.0484015] [loc=1.504 scale=2.878]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.0458082] [loc=4.431 scale=2.707]
# [distfit] >INFO> [halfcauchy     ] [0.02 sec] [RSS: 0.119321] [loc=-4.313 scale=6.791]
# [distfit] >INFO> [halflogistic   ] [0.03 sec] [RSS: 0.10491] [loc=-4.313 scale=4.911]
# [distfit] >INFO> [halfnorm       ] [0.01 sec] [RSS: 0.100338] [loc=-4.313 scale=7.864]
# [distfit] >INFO> [halfgennorm    ] [0.14 sec] [RSS: 0.0677902] [loc=-4.313 scale=12.796]
# [distfit] >INFO> [hypsecant      ] [0.01 sec] [RSS: 0.0510655] [loc=3.017 scale=2.097]
# [distfit] >INFO> [invgamma       ] [0.06 sec] [RSS: 0.0443691] [loc=-41.393 scale=9890.866]
# [distfit] >INFO> [invgauss       ] [0.07 sec] [RSS: 0.0449337] [loc=-20.055 scale=1322.349]
# [distfit] >INFO> [invweibull     ] [0.17 sec] [RSS: 0.0478295] [loc=-2616267769.395 scale=2616267770.930]
# [distfit] >INFO> [johnsonsb      ] [0.16 sec] [RSS: 0.0404403] [loc=-6.895 scale=18.291]
# [distfit] >INFO> [johnsonsu      ] [0.18 sec] [RSS: 0.0437765] [loc=-52743591.017 scale=612260190.719]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.0628054] [loc=3.065 scale=2.446]
# [distfit] >INFO> [levy           ] [0.01 sec] [RSS: 0.130242] [loc=-4.622 scale=5.398]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.0476409] [loc=3.016 scale=1.730]
# [distfit] >INFO> [loggamma       ] [0.04 sec] [RSS: 0.0437747] [loc=-54.851 scale=16.658]
# [distfit] >INFO> [loglaplace     ] [0.12 sec] [RSS: 0.0631358] [loc=-111431956.218 scale=111431959.282]
# [distfit] >INFO> [lognorm        ] [0.15 sec] [RSS: 0.0438181] [loc=-190.354 scale=193.316]
# [distfit] >INFO> [lomax          ] [0.07 sec] [RSS: 0.122876] [loc=-4.313 scale=707692841968.408]
# [distfit] >INFO> [maxwell        ] [0.01 sec] [RSS: 0.0452634] [loc=-4.853 scale=4.831]
# [distfit] >INFO> [mielke         ] [0.18 sec] [RSS: 0.0475136] [loc=-33052742.776 scale=33052738.862]
# [distfit] >INFO> [nakagami       ] [0.06 sec] [RSS: 0.0437179] [loc=-461.602 scale=464.596]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 0.0437587] [loc=2.984 scale=2.933]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.130724] [loc=-536870916.313 scale=536870912.000]
# [distfit] >INFO> [pearson3       ] [0.05 sec] [RSS: 0.0437069] [loc=2.984 scale=2.939]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.0785964] [loc=-4.328 scale=14.428]
# [distfit] >INFO> [powerlognorm   ] [0.43 sec] [RSS: 0.0439964] [loc=-125.202 scale=131.865]
# [distfit] >INFO> [powernorm      ] [0.11 sec] [RSS: 0.043927] [loc=4.951 scale=3.544]
# [distfit] >INFO> [rdist          ] [0.07 sec] [RSS: 0.0410337] [loc=2.887 scale=8.433]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.0533163] [loc=-4.398 scale=5.617]
# [distfit] >INFO> [rice           ] [0.14 sec] [RSS: 0.0533161] [loc=-4.398 scale=5.610]
# [distfit] >INFO> [recipinvgauss  ] [1.67 sec] [RSS: 0.0438694] [loc=-37.914 scale=0.216]
# [distfit] >INFO> [semicircular   ] [0.01 sec] [RSS: 0.0545707] [loc=2.878 scale=7.231]
# [distfit] >INFO> [t              ] [0.34 sec] [RSS: 0.0437587] [loc=2.984 scale=2.933]
# [distfit] >INFO> [triang         ] [0.12 sec] [RSS: 0.0433115] [loc=-4.659 scale=14.827]
# [distfit] >INFO> [truncexpon     ] [0.02 sec] [RSS: 0.0948322] [loc=-4.313 scale=16.501]
# [distfit] >INFO> [truncnorm      ] [0.09 sec] [RSS: 0.043167] [loc=2.915 scale=3.018]
# [distfit] >INFO> [tukeylambda    ] [4.38 sec] [RSS: 0.0409578] [loc=2.889 scale=2.498]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.081735] [loc=-4.313 scale=14.413]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 0.263162] [loc=0.154 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.41 sec] [RSS: 0.0437651] [loc=2.986 scale=97.795]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 0.0958341] [loc=-4.852 scale=10.428]
# [distfit] >INFO> [weibull_min    ] [0.02 sec] [RSS: 0.0427273] [loc=-7.243 scale=11.303]
# [distfit] >INFO> [weibull_max    ] [0.09 sec] [RSS: 0.455224] [loc=10.100 scale=1.486]
# [distfit] >INFO> [wrapcauchy     ] [0.08 sec] [RSS: 0.0817467] [loc=-4.332 scale=2.316]
# Best fitted distribution: gennorm
# Parameters: (3.0672798861891533, 2.9280837571034892, 4.817275049490474)

# %%
newlat=distlat.generate(9393)

# %%
newlon=distlon.generate(9393)

# %%
newfrpix=hp.ang2pix(128,newlon,newlat,lonlat=True)
newmap=np.zeros(hp.nside2npix(128))
for pp in newfrpix:
    newmap[pp]+=1
hp.mollview(newmap,flip='geo',min=20)

# %%
plt.hist(newmap,bins=np.linspace(0,1000,100))
plt.show()

# %%
plt.hist(newlon)
# Out:
# (array([  92.,  328.,  723., 1226., 1641., 1798., 1639., 1175.,  602.,
#          169.]),
#  array([-5.20810266, -3.66950918, -2.1309157 , -0.59232222,  0.94627126,
#          2.48486474,  4.02345822,  5.5620517 ,  7.10064518,  8.63923866,
#         10.17783214]),
#  <BarContainer object of 10 artists>)

# %%
np.size(np.argwhere(Tx_num_128))
