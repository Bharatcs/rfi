# %%
import numpy as np 
import healpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import tifffile as tiff
import glob
import seaborn as sns
# sns.set_style("darkgrid")
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from num2words import num2words
from scipy.optimize import curve_fit
from mpl_toolkits import mplot3d
import os
from distfit import distfit
import sys
import scipy
import rasterio
# sns.set(rc={"xtick.bottom": True, "ytick.left": True})
# %matplotlib inline
# %matplotlib notebook

# %% [markdown]
# ## Read Country DB parameters

# %%
csv_files = ['./database/France.csv']


#France has 9393 Tx
#DB has 


# --Create an empty dataframe to store the combined data-- #
df = pd.DataFrame()

# Loop through each CSV file and append its contents to the combined dataframe
for csv_file in (csv_files):
    df_temp = pd.read_csv(csv_file)
    df = pd.concat([df, df_temp],ignore_index=True)

df=df.dropna()
power=df['EIRP'].to_numpy()
lat_128=df['Latitude in degrees'].to_numpy()
lon_128=df['Longitude in degrees'].to_numpy()

pix=hp.ang2pix(128,lon_128,lat_128,lonlat=True)

# %%
Tx_num_128=np.zeros(hp.nside2npix(128))
for pi in pix:
    Tx_num_128[pi]+=1
hp.mollview(Tx_num_128,flip='geo',cmap='plasma',norm='hist')
plt.show()

# %%
Tx_pow_128=np.zeros(hp.nside2npix(128))
for index,p in enumerate(pix):
    Tx_pow_128[p]+=(power[index])
hp.mollview(Tx_pow_128,flip='geo',cmap='viridis',norm='hist',min=300)
plt.show()

# %% [markdown]
# # Fitting PDF to Tx params

# %%
fr_df=pd.read_csv('./database/France.csv')
fr_df=fr_df.dropna()
lat=fr_df['Latitude in degrees'].to_numpy()
lon=fr_df['Longitude in degrees'].to_numpy()
power=fr_df['EIRP'].to_numpy()
freq=fr_df['Frequency(MHz)'].to_numpy()

# %%
#bin width using Freedman Diaconis rule#
def FDrule(data):
    # Calculate interquartile range
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    
    # Calculate Freedman-Diaconis bin width
    n = len(data)
    bin_width = 2 * iqr / (n ** (1/3))

    # Calculate number of bins
    data_range = max(data) - min(data)
    num_bins = int(data_range / bin_width) + 1
    
    return num_bins

# %% [markdown]
# ## Country HEALPix map as mask

# %%
# Open the GeoTIFF file
file_path = '/home/pratush/Desktop/France_raster.tif'
src = rasterio.open(file_path)

# Read the raster data as a numpy array
data = src.read(1)  # Assuming a single-band raster

# Find pixels with non-zero values
non_zero_pixels = np.where(data != 0)

# Get the coordinates (latitude, longitude) of non-zero pixels
templat=[]
templon=[]
for y, x in zip(*non_zero_pixels):
    lonval, latval = src.xy(y, x)  # Get the longitude and latitude of the pixel
    templat.append(latval)
    templon.append(lonval)

# %%
temppix=hp.ang2pix(128,templon,templat,lonlat=True)
template=np.zeros(hp.nside2npix(128))
for pi in temppix:
    template[pi]+=1
template=np.where(template != 0, 1, 0)
hp.mollview(template,flip='geo')

# %% [markdown]
# ### Modelling Latitude

# %%
binw=FDrule(lat)
# Fit a probability density function
distlat = distfit(distr='full',bins=binw)
distlat.fit_transform(lat)

# Plot the fitted distribution
distlat.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlat.model['name'])
print("Parameters:", distlat.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.07 sec] [RSS: 0.0947988] [loc=-11.878 scale=1476.418]
# [distfit] >INFO> [anglit         ] [0.01 sec] [RSS: 0.0823979] [loc=46.072 scale=6.449]
# [distfit] >INFO> [arcsine        ] [0.03 sec] [RSS: 0.232186] [loc=41.231 scale=9.796]
# [distfit] >INFO> [beta           ] [0.06 sec] [RSS: 0.0799361] [loc=41.133 scale=10.022]
# [distfit] >INFO> [betaprime      ] [0.11 sec] [RSS: 0.0957183] [loc=-34.461 scale=31.892]
# [distfit] >INFO> [bradford       ] [0.05 sec] [RSS: 0.116328] [loc=41.231 scale=9.790]
# [distfit] >INFO> [burr           ] [0.29 sec] [RSS: 0.0944142] [loc=-0.293 scale=43.384]
# [distfit] >INFO> [cauchy         ] [0.00 sec] [RSS: 0.124966] [loc=45.699 scale=1.639]
# [distfit] >INFO> [chi            ] [0.02 sec] [RSS: 0.0882194] [loc=40.730 scale=3.432]
# [distfit] >INFO> [chi2           ] [0.05 sec] [RSS: 0.203828] [loc=41.231 scale=3.662]
# [distfit] >INFO> [cosine         ] [0.01 sec] [RSS: 0.089221] [loc=46.024 scale=1.894]
# [distfit] >INFO> [dgamma         ] [0.01 sec] [RSS: 0.101714] [loc=45.871 scale=0.904]
# [distfit] >INFO> [dweibull       ] [0.02 sec] [RSS: 0.0911248] [loc=45.897 scale=2.187]
# [distfit] >INFO> [erlang         ] [0.07 sec] [RSS: 0.0955516] [loc=13.512 scale=0.158]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.19015] [loc=41.231 scale=4.758]
# [distfit] >INFO> [exponnorm      ] [0.03 sec] [RSS: 0.0968565] [loc=45.780 scale=2.256]
# [distfit] >INFO> [exponweib      ] [0.25 sec] [RSS: 0.606669] [loc=41.231 scale=0.879]
# [distfit] >INFO> [exponpow       ] [0.14 sec] [RSS: 0.565852] [loc=41.231 scale=1.401]
# [distfit] >INFO> [f              ] [0.11 sec] [RSS: 0.0947885] [loc=14.497 scale=31.386]
# [distfit] >INFO> [fatiguelife    ] [0.06 sec] [RSS: 0.0940618] [loc=24.131 scale=21.741]
# [distfit] >INFO> [fisk           ] [0.11 sec] [RSS: 0.102798] [loc=-0.301 scale=46.217]
# [distfit] >INFO> [foldcauchy     ] [0.04 sec] [RSS: 0.124832] [loc=-0.138 scale=1.640]
# [distfit] >INFO> [foldnorm       ] [0.04 sec] [RSS: 0.0936546] [loc=41.231 scale=2.346]
# [distfit] >INFO> [genlogistic    ] [0.03 sec] [RSS: 0.092846] [loc=41.555 scale=1.875]
# [distfit] >INFO> [genpareto      ] [0.11 sec] [RSS: 0.265124] [loc=0.135 scale=130.027]
# [distfit] >INFO> [gennorm        ] [0.03 sec] [RSS: 0.0745582] [loc=46.072 scale=3.957]
# [distfit] >INFO> [genexpon       ] [0.24 sec] [RSS: 0.086267] [loc=41.231 scale=1.149]
# [distfit] >INFO> [genextreme     ] [0.09 sec] [RSS: 0.093849] [loc=45.218 scale=2.240]
# [distfit] >INFO> [gausshyper     ] [0.43 sec] [RSS: 0.110965] [loc=41.229 scale=9.792]
# [distfit] >INFO> [gamma          ] [0.06 sec] [RSS: 0.0955587] [loc=15.231 scale=0.166]
# [distfit] >INFO> [gengamma       ] [0.17 sec] [RSS: 0.554335] [loc=41.231 scale=0.806]
# [distfit] >INFO> [genhalflogistic] [0.10 sec] [RSS: 0.0911069] [loc=41.229 scale=5.582]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 0.136113] [loc=41.184 scale=4.123]
# [distfit] >INFO> [gompertz       ] [0.09 sec] [RSS: 0.12439] [loc=41.231 scale=1.897]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.0908615] [loc=44.873 scale=2.034]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.105794] [loc=47.128 scale=2.123]
# [distfit] >INFO> [halfcauchy     ] [0.03 sec] [RSS: 0.173585] [loc=41.231 scale=4.268]
# [distfit] >INFO> [halflogistic   ] [0.02 sec] [RSS: 0.147427] [loc=41.231 scale=3.244]
# [distfit] >INFO> [halfnorm       ] [0.01 sec] [RSS: 0.139834] [loc=41.231 scale=5.273]
# [distfit] >INFO> [halfgennorm    ] [0.14 sec] [RSS: 0.0988488] [loc=41.231 scale=8.989]
# [distfit] >INFO> [hypsecant      ] [0.01 sec] [RSS: 0.110195] [loc=45.906 scale=1.671]
# [distfit] >INFO> [invgamma       ] [0.06 sec] [RSS: 0.0961885] [loc=-78.257 scale=374249.945]
# [distfit] >INFO> [invgauss       ] [0.07 sec] [RSS: 0.0918613] [loc=32.618 scale=438.886]
# [distfit] >INFO> [invweibull     ] [0.16 sec] [RSS: 0.0910412] [loc=-713744078.468 scale=713744123.339]
# [distfit] >INFO> [johnsonsb      ] [0.15 sec] [RSS: 0.0781989] [loc=40.920 scale=10.440]
# [distfit] >INFO> [johnsonsu      ] [0.17 sec] [RSS: 0.0945707] [loc=21.013 scale=5.626]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.119104] [loc=45.544 scale=1.946]
# [distfit] >INFO> [levy           ] [0.03 sec] [RSS: 0.186683] [loc=41.096 scale=3.272]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.104042] [loc=45.950 scale=1.368]
# [distfit] >INFO> [loggamma       ] [0.06 sec] [RSS: 0.0968423] [loc=-395.700 scale=65.676]
# [distfit] >INFO> [loglaplace     ] [0.04 sec] [RSS: 0.119416] [loc=-0.168 scale=45.712]
# [distfit] >INFO> [lognorm        ] [0.00 sec] [RSS: 0.0945301] [loc=20.496 scale=25.393]
# [distfit] >INFO> [lomax          ] [0.06 sec] [RSS: 0.258939] [loc=41.231 scale=27835289359.560]
# [distfit] >INFO> [maxwell        ] [0.00 sec] [RSS: 0.0889339] [loc=40.560 scale=3.397]
# [distfit] >INFO> [mielke         ] [0.19 sec] [RSS: 0.0939419] [loc=-1.359 scale=44.178]
# [distfit] >INFO> [nakagami       ] [0.02 sec] [RSS: 0.0882197] [loc=40.730 scale=5.727]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 0.0968668] [loc=45.990 scale=2.265]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.19015] [loc=-268435414.769 scale=268435456.000]
# [distfit] >INFO> [pearson3       ] [0.06 sec] [RSS: 0.0930657] [loc=45.990 scale=2.288]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.114816] [loc=41.229 scale=9.792]
# [distfit] >INFO> [powerlognorm   ] [0.45 sec] [RSS: 0.0888375] [loc=-13.972 scale=56.339]
# [distfit] >INFO> [powernorm      ] [0.13 sec] [RSS: 0.0879692] [loc=42.028 scale=0.562]
# [distfit] >INFO> [rdist          ] [0.06 sec] [RSS: 0.0807686] [loc=46.086 scale=5.026]
# [distfit] >INFO> [reciprocal     ] [0.03 sec] [RSS: 0.116702] [loc=-0.865 scale=1.000]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.0853816] [loc=41.176 scale=3.762]
# [distfit] >INFO> [rice           ] [0.06 sec] [RSS: 0.088399] [loc=41.057 scale=2.653]
# [distfit] >INFO> [recipinvgauss  ] [1.68 sec] [RSS: 0.0932948] [loc=27.629 scale=0.282]
# [distfit] >INFO> [semicircular   ] [0.01 sec] [RSS: 0.0832574] [loc=46.126 scale=4.912]
# [distfit] >INFO> [t              ] [0.34 sec] [RSS: 0.0968947] [loc=45.990 scale=2.265]
# [distfit] >INFO> [triang         ] [0.09 sec] [RSS: 0.0860092] [loc=41.037 scale=10.375]
# [distfit] >INFO> [truncexpon     ] [0.02 sec] [RSS: 0.12695] [loc=41.231 scale=12.660]
# [distfit] >INFO> [truncnorm      ] [0.13 sec] [RSS: 0.206433] [loc=1.532 scale=13.783]
# [distfit] >INFO> [tukeylambda    ] [2.93 sec] [RSS: 0.0802061] [loc=46.081 scale=2.297]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.116636] [loc=41.231 scale=9.790]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 0.25014] [loc=-0.692 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.41 sec] [RSS: 0.0962142] [loc=46.127 scale=1.558]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 0.127072] [loc=40.960 scale=6.416]
# [distfit] >INFO> [weibull_min    ] [0.02 sec] [RSS: 0.0895998] [loc=40.674 scale=5.998]
# [distfit] >INFO> [weibull_max    ] [0.05 sec] [RSS: 0.0938486] [loc=52.471 scale=7.253]
# [distfit] >INFO> [wrapcauchy     ] [0.05 sec] [RSS: 0.117101] [loc=40.770 scale=1.632]
# Best fitted distribution: gennorm
# Parameters: (5.575675860356261, 46.07245709990866, 3.9566240429450907)

# %% [markdown]
# ### Model longitude

# %%
binwi=FDrule(lon)
# Fit a probability density function
distlon = distfit(distr='full',bins=binwi)
distlon.fit_transform(lon)

# Plot the fitted distribution
distlon.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distlon.model['name'])
print("Parameters:", distlon.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.06 sec] [RSS: 0.0500738] [loc=-15.783 scale=105.272]
# [distfit] >INFO> [anglit         ] [0.02 sec] [RSS: 0.0432508] [loc=2.819 scale=9.332]
# [distfit] >INFO> [arcsine        ] [0.04 sec] [RSS: 0.155358] [loc=-4.314 scale=14.414]
# [distfit] >INFO> [beta           ] [0.03 sec] [RSS: 0.0405821] [loc=-6.124 scale=16.726]
# [distfit] >INFO> [betaprime      ] [0.12 sec] [RSS: 0.0436675] [loc=-181.684 scale=74.333]
# [distfit] >INFO> [bradford       ] [0.03 sec] [RSS: 0.0954641] [loc=-4.313 scale=14.413]
# [distfit] >INFO> [burr           ] [0.36 sec] [RSS: 0.0411165] [loc=-4.606 scale=11.526]
# [distfit] >INFO> [cauchy         ] [0.00 sec] [RSS: 0.0627086] [loc=2.980 scale=2.004]
# [distfit] >INFO> [chi            ] [0.07 sec] [RSS: 0.0437558] [loc=-32.382 scale=4.174]
# [distfit] >INFO> [chi2           ] [0.07 sec] [RSS: 0.0440233] [loc=-25.033 scale=0.157]
# [distfit] >INFO> [cosine         ] [0.01 sec] [RSS: 0.0411121] [loc=2.879 scale=2.589]
# [distfit] >INFO> [dgamma         ] [0.01 sec] [RSS: 0.0503623] [loc=2.839 scale=1.346]
# [distfit] >INFO> [dweibull       ] [0.02 sec] [RSS: 0.0462071] [loc=2.851 scale=2.710]
# [distfit] >INFO> [erlang         ] [0.07 sec] [RSS: 0.0437754] [loc=-66.867 scale=0.124]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.130724] [loc=-4.313 scale=7.297]
# [distfit] >INFO> [exponnorm      ] [0.03 sec] [RSS: 0.0437587] [loc=2.981 scale=2.933]
# [distfit] >INFO> [exponweib      ] [0.22 sec] [RSS: 0.333532] [loc=-4.313 scale=1.638]
# [distfit] >INFO> [exponpow       ] [0.14 sec] [RSS: 0.330389] [loc=-4.313 scale=1.623]
# [distfit] >INFO> [f              ] [0.12 sec] [RSS: 0.0443287] [loc=-20.573 scale=23.341]
# [distfit] >INFO> [fatiguelife    ] [0.09 sec] [RSS: 0.0438276] [loc=-329.797 scale=332.770]
# [distfit] >INFO> [fisk           ] [0.27 sec] [RSS: 0.0476516] [loc=-338947806.502 scale=338947809.519]
# [distfit] >INFO> [foldcauchy     ] [0.03 sec] [RSS: 0.217862] [loc=-4.313 scale=3.283]
# [distfit] >INFO> [foldnorm       ] [0.10 sec] [RSS: 0.100181] [loc=-4.313 scale=7.672]
# [distfit] >INFO> [genlogistic    ] [0.02 sec] [RSS: 0.0474233] [loc=2.748 scale=1.787]
# [distfit] >INFO> [genpareto      ] [0.07 sec] [RSS: 0.297667] [loc=-4.313 scale=3.388]
# [distfit] >INFO> [gennorm        ] [0.02 sec] [RSS: 0.0394024] [loc=2.928 scale=4.817]
# [distfit] >INFO> [genexpon       ] [0.21 sec] [RSS: 0.0563663] [loc=-4.419 scale=2.237]
# [distfit] >INFO> [genextreme     ] [0.09 sec] [RSS: 0.0419483] [loc=2.031 scale=3.002]
# [distfit] >INFO> [gausshyper     ] [0.37 sec] [RSS: 0.040541] [loc=-4.935 scale=15.237]
# [distfit] >INFO> [gamma          ] [0.06 sec] [RSS: 0.0437991] [loc=-69.299 scale=0.120]
# [distfit] >INFO> [gengamma       ] [0.26 sec] [RSS: 0.0439608] [loc=-20.071 scale=0.435]
# [distfit] >INFO> [genhalflogistic] [0.10 sec] [RSS: 0.115298] [loc=-6.245 scale=17.053]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 0.101247] [loc=-4.445 scale=6.599]
# [distfit] >INFO> [gompertz       ] [0.12 sec] [RSS: 0.403726] [loc=-4.313 scale=862650516327.282]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.0484015] [loc=1.504 scale=2.878]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.0458082] [loc=4.431 scale=2.707]
# [distfit] >INFO> [halfcauchy     ] [0.02 sec] [RSS: 0.119321] [loc=-4.313 scale=6.791]
# [distfit] >INFO> [halflogistic   ] [0.02 sec] [RSS: 0.10491] [loc=-4.313 scale=4.911]
# [distfit] >INFO> [halfnorm       ] [0.01 sec] [RSS: 0.100338] [loc=-4.313 scale=7.864]
# [distfit] >INFO> [halfgennorm    ] [0.14 sec] [RSS: 0.0677902] [loc=-4.313 scale=12.796]
# [distfit] >INFO> [hypsecant      ] [0.01 sec] [RSS: 0.0510655] [loc=3.017 scale=2.097]
# [distfit] >INFO> [invgamma       ] [0.06 sec] [RSS: 0.0443691] [loc=-41.393 scale=9890.866]
# [distfit] >INFO> [invgauss       ] [0.07 sec] [RSS: 0.0449337] [loc=-20.055 scale=1322.349]
# [distfit] >INFO> [invweibull     ] [0.16 sec] [RSS: 0.0478295] [loc=-2616267769.395 scale=2616267770.930]
# [distfit] >INFO> [johnsonsb      ] [0.16 sec] [RSS: 0.0404403] [loc=-6.895 scale=18.291]
# [distfit] >INFO> [johnsonsu      ] [0.17 sec] [RSS: 0.0437765] [loc=-52743591.017 scale=612260190.719]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.0628054] [loc=3.065 scale=2.446]
# [distfit] >INFO> [levy           ] [0.01 sec] [RSS: 0.130242] [loc=-4.622 scale=5.398]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.0476409] [loc=3.016 scale=1.730]
# [distfit] >INFO> [loggamma       ] [0.04 sec] [RSS: 0.0437747] [loc=-54.851 scale=16.658]
# [distfit] >INFO> [loglaplace     ] [0.12 sec] [RSS: 0.0631358] [loc=-111431956.218 scale=111431959.282]
# [distfit] >INFO> [lognorm        ] [0.15 sec] [RSS: 0.0438181] [loc=-190.354 scale=193.316]
# [distfit] >INFO> [lomax          ] [0.07 sec] [RSS: 0.122876] [loc=-4.313 scale=707692841968.408]
# [distfit] >INFO> [maxwell        ] [0.01 sec] [RSS: 0.0452634] [loc=-4.853 scale=4.831]
# [distfit] >INFO> [mielke         ] [0.19 sec] [RSS: 0.0475136] [loc=-33052742.776 scale=33052738.862]
# [distfit] >INFO> [nakagami       ] [0.06 sec] [RSS: 0.0437179] [loc=-461.602 scale=464.596]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 0.0437587] [loc=2.984 scale=2.933]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.130724] [loc=-536870916.313 scale=536870912.000]
# [distfit] >INFO> [pearson3       ] [0.05 sec] [RSS: 0.0437069] [loc=2.984 scale=2.939]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.0785964] [loc=-4.328 scale=14.428]
# [distfit] >INFO> [powerlognorm   ] [0.44 sec] [RSS: 0.0439964] [loc=-125.202 scale=131.865]
# [distfit] >INFO> [powernorm      ] [0.11 sec] [RSS: 0.043927] [loc=4.951 scale=3.544]
# [distfit] >INFO> [rdist          ] [0.07 sec] [RSS: 0.0410337] [loc=2.887 scale=8.433]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.0533163] [loc=-4.398 scale=5.617]
# [distfit] >INFO> [rice           ] [0.14 sec] [RSS: 0.0533161] [loc=-4.398 scale=5.610]
# [distfit] >INFO> [recipinvgauss  ] [1.74 sec] [RSS: 0.0438694] [loc=-37.914 scale=0.216]
# [distfit] >INFO> [semicircular   ] [0.01 sec] [RSS: 0.0545707] [loc=2.878 scale=7.231]
# [distfit] >INFO> [t              ] [0.34 sec] [RSS: 0.0437587] [loc=2.984 scale=2.933]
# [distfit] >INFO> [triang         ] [0.13 sec] [RSS: 0.0433115] [loc=-4.659 scale=14.827]
# [distfit] >INFO> [truncexpon     ] [0.02 sec] [RSS: 0.0948322] [loc=-4.313 scale=16.501]
# [distfit] >INFO> [truncnorm      ] [0.10 sec] [RSS: 0.043167] [loc=2.915 scale=3.018]
# [distfit] >INFO> [tukeylambda    ] [4.49 sec] [RSS: 0.0409578] [loc=2.889 scale=2.498]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.081735] [loc=-4.313 scale=14.413]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 0.263162] [loc=0.154 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.44 sec] [RSS: 0.0437651] [loc=2.986 scale=97.795]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 0.0958341] [loc=-4.852 scale=10.428]
# [distfit] >INFO> [weibull_min    ] [0.02 sec] [RSS: 0.0427273] [loc=-7.243 scale=11.303]
# [distfit] >INFO> [weibull_max    ] [0.09 sec] [RSS: 0.455224] [loc=10.100 scale=1.486]
# [distfit] >INFO> [wrapcauchy     ] [0.10 sec] [RSS: 0.0817467] [loc=-4.332 scale=2.316]
# Best fitted distribution: gennorm
# Parameters: (3.0672798861891533, 2.9280837571034892, 4.817275049490474)

# %% [markdown]
# ### Model Tx power

# %%
powbin=FDrule(power)
# Fit a probability density function
distpow = distfit(distr='full',bins=powbin)
distpow.fit_transform(power)

# Plot the fitted distribution
distpow.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distpow.model['name'])
print("Parameters:", distpow.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.03 sec] [RSS: 2.04941e-05] [loc=-0.925 scale=2.483]
# [distfit] >INFO> [anglit         ] [0.03 sec] [RSS: 2.08775e-05] [loc=46476.566 scale=195627.138]
# [distfit] >INFO> [arcsine        ] [0.05 sec] [RSS: 2.04222e-05] [loc=-0.000 scale=399449.765]
# [distfit] >INFO> [beta           ] [0.13 sec] [RSS: 1.51668e-05] [loc=-0.000 scale=1719228.803]
# [distfit] >INFO> [betaprime      ] [0.06 sec] [RSS: 2.09633e-05] [loc=-0.167 scale=2.663]
# [distfit] >INFO> [bradford       ] [0.07 sec] [RSS: 2.05852e-05] [loc=-4296.867 scale=402296.867]
# [distfit] >INFO> [burr           ] [0.37 sec] [RSS: 1.91856e-05] [loc=-0.000 scale=1.775]
# [distfit] >INFO> [cauchy         ] [0.01 sec] [RSS: 1.48234e-05] [loc=356.890 scale=326.337]
# [distfit] >INFO> [chi            ] [0.08 sec] [RSS: 1.7439e-05] [loc=-0.000 scale=19299.060]
# [distfit] >INFO> [chi2           ] [0.08 sec] [RSS: 1.7592e-05] [loc=-0.000 scale=30996.787]
# [distfit] >INFO> [cosine         ] [0.04 sec] [RSS: 2.08597e-05] [loc=30470.897 scale=54041.668]
# [distfit] >INFO> [dgamma         ] [0.07 sec] [RSS: 1.27032e-05] [loc=1000.000 scale=7499.743]
# [distfit] >INFO> [dweibull       ] [0.07 sec] [RSS: 1.32545e-05] [loc=1000.000 scale=1101.694]
# [distfit] >INFO> [erlang         ] [0.07 sec] [RSS: 1.54878e-05] [loc=-0.000 scale=2772.407]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 1.69501e-05] [loc=0.000 scale=2779.365]
# [distfit] >INFO> [exponnorm      ] [0.10 sec] [RSS: 1.69369e-05] [loc=-1.468 scale=2.246]
# [distfit] >INFO> [exponweib      ] [0.29 sec] [RSS: 1.63507e-05] [loc=-0.000 scale=4473.009]
# [distfit] >INFO> [exponpow       ] [0.19 sec] [RSS: 1.79563e-05] [loc=-0.000 scale=83129.237]
# [distfit] >INFO> [f              ] [0.06 sec] [RSS: 1.91917e-05] [loc=-0.021 scale=2.875]
# [distfit] >INFO> [fatiguelife    ] [0.05 sec] [RSS: 1.49672e-05] [loc=-14.687 scale=1025.192]
# [distfit] >INFO> [fisk           ] [0.28 sec] [RSS: 1.89268e-05] [loc=-0.000 scale=3.057]
# [distfit] >INFO> [foldcauchy     ] [0.05 sec] [RSS: 2.0794e-05] [loc=-0.000 scale=4.328]
# [distfit] >INFO> [foldnorm       ] [0.09 sec] [RSS: 2.0341e-05] [loc=-0.000 scale=17723.653]
# [distfit] >INFO> [genlogistic    ] [0.09 sec] [RSS: 1.86331e-05] [loc=-16422.127 scale=2270.866]
# [distfit] >INFO> [genpareto      ] [0.12 sec] [RSS: 1.93948e-05] [loc=-0.000 scale=8.444]
# [distfit] >INFO> [gennorm        ] [0.05 sec] [RSS: 1.4721e-05] [loc=1000.000 scale=91.819]
# [distfit] >INFO> [genexpon       ] [0.23 sec] [RSS: 1.69501e-05] [loc=-0.000 scale=6086.873]
# [distfit] >INFO> [genextreme     ] [0.19 sec] [RSS: 1.91805e-05] [loc=2.947 scale=11.726]
# [distfit] >INFO> [gausshyper     ] [0.45 sec] [RSS: 1.77813e-05] [loc=-0.000 scale=430025.261]
# [distfit] >INFO> [gamma          ] [0.07 sec] [RSS: 2.09413e-05] [loc=-0.000 scale=4.280]
# [distfit] >INFO> [gengamma       ] [0.30 sec] [RSS: 1.63192e-05] [loc=-0.000 scale=5125.449]
# [distfit] >INFO> [genhalflogistic] [0.11 sec] [RSS: 1.82378e-05] [loc=-0.000 scale=2317.664]
# [distfit] >INFO> [gibrat         ] [0.03 sec] [RSS: 1.30453e-05] [loc=-38.738 scale=537.707]
# [distfit] >INFO> [gompertz       ] [0.12 sec] [RSS: 1.60571e-05] [loc=-0.000 scale=16485845922316764.000]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 1.86361e-05] [loc=677.324 scale=2275.263]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 2.08526e-05] [loc=17561.031 scale=69140.095]
# [distfit] >INFO> [halfcauchy     ] [0.03 sec] [RSS: 2.04867e-05] [loc=0.000 scale=1.947]
# [distfit] >INFO> [halflogistic   ] [0.03 sec] [RSS: 1.82366e-05] [loc=-0.000 scale=2316.462]
# [distfit] >INFO> [halfnorm       ] [0.02 sec] [RSS: 2.0341e-05] [loc=-0.000 scale=17723.654]
# [distfit] >INFO> [halfgennorm    ] [0.16 sec] [RSS: 1.53054e-05] [loc=-0.000 scale=69.072]
# [distfit] >INFO> [hypsecant      ] [0.02 sec] [RSS: 1.88354e-05] [loc=744.636 scale=2293.011]
# [distfit] >INFO> [invgamma       ] [0.03 sec] [RSS: 2.09307e-05] [loc=-0.827 scale=3.087]
# [distfit] >INFO> [invgauss       ] [0.03 sec] [RSS: 1.40103e-05] [loc=-19.884 scale=287.629]
# [distfit] >INFO> [invweibull     ] [0.08 sec] [RSS: 1.91848e-05] [loc=-0.004 scale=2.476]
# [distfit] >INFO> [johnsonsb      ] [0.26 sec] [RSS: 1.70218e-05] [loc=-0.098 scale=402519.977]
# [distfit] >INFO> [johnsonsu      ] [0.12 sec] [RSS: 1.24754e-05] [loc=87.071 scale=21.930]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 1.8265e-05] [loc=500.000 scale=2583.971]
# [distfit] >INFO> [levy           ] [0.03 sec] [RSS: 1.46058e-05] [loc=-16.588 scale=251.414]
# [distfit] >INFO> [logistic       ] [0.01 sec] [RSS: 1.92056e-05] [loc=862.784 scale=2210.146]
# [distfit] >INFO> [loggamma       ] [0.06 sec] [RSS: 2.05948e-05] [loc=-4938028.159 scale=689401.395]
# [distfit] >INFO> [loglaplace     ] [0.13 sec] [RSS: 1.91909e-05] [loc=-0.000 scale=2.435]
# [distfit] >INFO> [lognorm        ] [0.07 sec] [RSS: 1.40191e-05] [loc=-3.384 scale=468.303]
# [distfit] >INFO> [lomax          ] [0.03 sec] [RSS: 1.99937e-05] [loc=-0.000 scale=2.433]
# [distfit] >INFO> [maxwell        ] [0.01 sec] [RSS: 2.04428e-05] [loc=-24508.754 scale=18717.592]
# [distfit] >INFO> [mielke         ] [0.15 sec] [RSS: 1.27112e-05] [loc=-45.079 scale=15.111]
# [distfit] >INFO> [nakagami       ] [0.09 sec] [RSS: 1.76026e-05] [loc=2.000 scale=17225.422]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 2.05686e-05] [loc=2779.365 scale=17504.379]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 1.4554e-05] [loc=-719.238 scale=719.238]
# [distfit] >INFO> [pearson3       ] [0.18 sec] [RSS: 1.50259e-05] [loc=1537.143 scale=1787.061]
# [distfit] >INFO> [powerlaw       ] [0.06 sec] [RSS: 1.83412e-05] [loc=-0.000 scale=398000.000]
# [distfit] >INFO> [powerlognorm   ] [0.41 sec] [RSS: 1.34489e-05] [loc=-27.846 scale=66.879]
# [distfit] >INFO> [powernorm      ] [0.24 sec] [RSS: nan] [loc=-16512.703 scale=62.292]
# [distfit] >INFO> [rdist          ] [0.10 sec] [RSS: 2.05687e-05] [loc=2753.801 scale=15458452.491]
# [distfit] >INFO> [reciprocal     ] [0.07 sec] [RSS: 1.8477e-05] [loc=-0.005 scale=1.000]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 2.04262e-05] [loc=-16535.226 scale=18431.721]
# [distfit] >INFO> [rice           ] [0.11 sec] [RSS: 2.04262e-05] [loc=-16535.226 scale=18431.721]
# [distfit] >INFO> [recipinvgauss  ] [1.65 sec] [RSS: 1.57749e-05] [loc=-2.262 scale=2607.490]
# [distfit] >INFO> [semicircular   ] [0.03 sec] [RSS: 2.08897e-05] [loc=67683.655 scale=132376.639]
# [distfit] >INFO> [t              ] [0.28 sec] [RSS: 1.49888e-05] [loc=391.374 scale=356.082]
# [distfit] >INFO> [triang         ] [0.22 sec] [RSS: 2.0871e-05] [loc=-1.582 scale=400854.447]
# [distfit] >INFO> [truncexpon     ] [0.05 sec] [RSS: 2.08849e-05] [loc=-38482.288 scale=328365.927]
# [distfit] >INFO> [truncnorm      ] [0.12 sec] [RSS: 2.0336e-05] [loc=-150.073 scale=17710.935]
# [distfit] >INFO> [tukeylambda    ] [3.98 sec] [RSS: 1.52867e-05] [loc=262.788 scale=503.595]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 2.09144e-05] [loc=0.000 scale=398000.000]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 125.161] [loc=-0.373 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.42 sec] [RSS: 2.04124e-05] [loc=2068.570 scale=78919.025]
# [distfit] >INFO> [wald           ] [0.01 sec] [RSS: 1.52228e-05] [loc=-332.663 scale=1937.670]
# [distfit] >INFO> [weibull_min    ] [0.12 sec] [RSS: 1.56864e-05] [loc=-0.000 scale=1703.721]
# [distfit] >INFO> [weibull_max    ] [0.08 sec] [RSS: 2.12354e-05] [loc=398000.000 scale=1.759]
# [distfit] >INFO> [wrapcauchy     ] [0.05 sec] [RSS: 1.73543e-05] [loc=-0.001 scale=63343.668]
# Best fitted distribution: johnsonsu
# Parameters: (-1.6240952788964944, 0.5078625610177918, 87.07104628670575, 21.930287753261602)

# %% [markdown]
# ### Model Tx Freq

# %%
freqbin=FDrule(freq)
# Fit a probability density function
distfreq = distfit(distr='full',bins=freqbin)
distfreq.fit_transform(freq)

# Plot the fitted distribution
distfreq.plot()
plt.title('Fitted Probability Density Function')
plt.show()

# Get information about the best-fitted distribution
print("Best fitted distribution:", distfreq.model['name'])
print("Parameters:", distfreq.model['params'])
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [0.07 sec] [RSS: 0.0114086] [loc=-160.908 scale=14652.781]
# [distfit] >INFO> [anglit         ] [0.01 sec] [RSS: 0.224711] [loc=52.450 scale=9.617]
# [distfit] >INFO> [arcsine        ] [0.05 sec] [RSS: 0.0748261] [loc=44.281 scale=55.619]
# [distfit] >INFO> [beta           ] [0.05 sec] [RSS: 0.0161868] [loc=-777.626 scale=879.238]
# [distfit] >INFO> [betaprime      ] [0.12 sec] [RSS: 0.0114021] [loc=-267.159 scale=31.239]
# [distfit] >INFO> [bradford       ] [0.04 sec] [RSS: 0.0872523] [loc=44.900 scale=55.000]
# [distfit] >INFO> [burr           ] [0.29 sec] [RSS: 0.0180364] [loc=-0.694 scale=95.968]
# [distfit] >INFO> [cauchy         ] [0.01 sec] [RSS: 0.0279014] [loc=93.699 scale=2.653]
# [distfit] >INFO> [chi            ] [0.05 sec] [RSS: 0.0122173] [loc=87.446 scale=6.034]
# [distfit] >INFO> [chi2           ] [0.07 sec] [RSS: 0.0117942] [loc=-2.504 scale=0.111]
# [distfit] >INFO> [cosine         ] [0.02 sec] [RSS: 0.248954] [loc=52.450 scale=2.405]
# [distfit] >INFO> [dgamma         ] [0.02 sec] [RSS: 0.0178852] [loc=93.550 scale=1.848]
# [distfit] >INFO> [dweibull       ] [0.02 sec] [RSS: 0.0151966] [loc=93.648 scale=3.463]
# [distfit] >INFO> [erlang         ] [0.07 sec] [RSS: 0.0178574] [loc=37.574 scale=0.665]
# [distfit] >INFO> [expon          ] [0.00 sec] [RSS: 0.104085] [loc=44.900 scale=48.683]
# [distfit] >INFO> [exponnorm      ] [0.03 sec] [RSS: 0.0119361] [loc=93.581 scale=4.096]
# [distfit] >INFO> [exponweib      ] [0.22 sec] [RSS: 0.178806] [loc=44.900 scale=0.601]
# [distfit] >INFO> [exponpow       ] [0.15 sec] [RSS: 0.13706] [loc=50.000 scale=1.556]
# [distfit] >INFO> [f              ] [0.11 sec] [RSS: 0.0116186] [loc=-444.637 scale=538.200]
# [distfit] >INFO> [fatiguelife    ] [0.09 sec] [RSS: 0.011993] [loc=-1686.376 scale=1779.926]
# [distfit] >INFO> [fisk           ] [0.26 sec] [RSS: 0.0174792] [loc=-83787672.309 scale=83787765.974]
# [distfit] >INFO> [foldcauchy     ] [0.05 sec] [RSS: 0.0278741] [loc=-0.234 scale=2.655]
# [distfit] >INFO> [foldnorm       ] [0.13 sec] [RSS: 1.45636] [loc=44.852 scale=0.329]
# [distfit] >INFO> [genlogistic    ] [0.02 sec] [RSS: 0.0176277] [loc=94.152 scale=2.117]
# [distfit] >INFO> [genpareto      ] [0.10 sec] [RSS: 0.0594621] [loc=-1.120 scale=263.828]
# [distfit] >INFO> [gennorm        ] [0.02 sec] [RSS: 0.0169542] [loc=93.644 scale=4.822]
# [distfit] >INFO> [genexpon       ] [0.23 sec] [RSS: 0.0877733] [loc=44.900 scale=5.562]
# [distfit] >INFO> [genextreme     ] [0.06 sec] [RSS: 0.0144238] [loc=92.864 scale=4.496]
# [distfit] >INFO> [gausshyper     ] [0.27 sec] [RSS: 0.0524051] [loc=44.109 scale=55.791]
# [distfit] >INFO> [gamma          ] [0.06 sec] [RSS: 0.0122446] [loc=16.784 scale=0.305]
# [distfit] >INFO> [gengamma       ] [0.27 sec] [RSS: 0.161502] [loc=44.900 scale=0.345]
# [distfit] >INFO> [genhalflogistic] [0.10 sec] [RSS: 0.0465888] [loc=44.841 scale=87.983]
# [distfit] >INFO> [gibrat         ] [0.04 sec] [RSS: 0.0981106] [loc=44.843 scale=48.436]
# [distfit] >INFO> [gompertz       ] [0.15 sec] [RSS: 0.00755811] [loc=87.600 scale=4.627]
# [distfit] >INFO> [gumbel_r       ] [0.00 sec] [RSS: 0.0422903] [loc=91.110 scale=9.212]
# [distfit] >INFO> [gumbel_l       ] [0.00 sec] [RSS: 0.0174478] [loc=95.419 scale=3.281]
# [distfit] >INFO> [halfcauchy     ] [0.03 sec] [RSS: 0.101969] [loc=44.900 scale=48.543]
# [distfit] >INFO> [halflogistic   ] [0.03 sec] [RSS: 0.0997342] [loc=44.900 scale=31.598]
# [distfit] >INFO> [halfnorm       ] [0.01 sec] [RSS: 0.0991115] [loc=44.900 scale=48.736]
# [distfit] >INFO> [halfgennorm    ] [0.10 sec] [RSS: 0.118048] [loc=44.900 scale=1.460]
# [distfit] >INFO> [hypsecant      ] [0.01 sec] [RSS: 0.0197316] [loc=93.670 scale=2.718]
# [distfit] >INFO> [invgamma       ] [0.06 sec] [RSS: 0.0116372] [loc=-154.592 scale=820880.867]
# [distfit] >INFO> [invgauss       ] [0.07 sec] [RSS: 0.0503972] [loc=40.172 scale=1274.125]
# [distfit] >INFO> [invweibull     ] [0.17 sec] [RSS: 0.0422951] [loc=-10410060066.649 scale=10410060157.760]
# [distfit] >INFO> [johnsonsb      ] [0.25 sec] [RSS: 0.0163382] [loc=-444.225 scale=551.683]
# [distfit] >INFO> [johnsonsu      ] [0.16 sec] [RSS: 0.0162538] [loc=108.003 scale=1.118]
# [distfit] >INFO> [laplace        ] [0.00 sec] [RSS: 0.0283608] [loc=93.700 scale=3.175]
# [distfit] >INFO> [levy           ] [0.03 sec] [RSS: 0.102382] [loc=44.418 scale=47.399]
# [distfit] >INFO> [logistic       ] [0.00 sec] [RSS: 0.0173095] [loc=93.665 scale=2.226]
# [distfit] >INFO> [loggamma       ] [0.01 sec] [RSS: 0.0160336] [loc=90.462 scale=5.275]
# [distfit] >INFO> [loglaplace     ] [0.05 sec] [RSS: 0.0277732] [loc=-0.331 scale=94.031]
# [distfit] >INFO> [lognorm        ] [0.00 sec] [RSS: 0.0119361] [loc=-8388563.100 scale=8388656.683]
# [distfit] >INFO> [lomax          ] [0.07 sec] [RSS: 0.104056] [loc=44.900 scale=6470.823]
# [distfit] >INFO> [maxwell        ] [0.02 sec] [RSS: 0.0776133] [loc=44.879 scale=28.218]
# [distfit] >INFO> [mielke         ] [0.14 sec] [RSS: 0.0180123] [loc=-6.865 scale=102.056]
# [distfit] >INFO> [nakagami       ] [0.06 sec] [RSS: 0.0119301] [loc=-6461.532 scale=6555.112]
# [distfit] >INFO> [norm           ] [0.00 sec] [RSS: 0.0119361] [loc=93.583 scale=4.096]
# [distfit] >INFO> [pareto         ] [0.00 sec] [RSS: 0.104085] [loc=-4294967251.100 scale=4294967296.000]
# [distfit] >INFO> [pearson3       ] [0.08 sec] [RSS: 0.0162106] [loc=93.583 scale=4.076]
# [distfit] >INFO> [powerlaw       ] [0.00 sec] [RSS: 0.0266319] [loc=37.899 scale=62.001]
# [distfit] >INFO> [powerlognorm   ] [0.38 sec] [RSS: 0.0108475] [loc=-11.253 scale=101.265]
# [distfit] >INFO> [powernorm      ] [0.19 sec] [RSS: 0.0160368] [loc=138.374 scale=12.477]
# [distfit] >INFO> [rdist          ] [0.06 sec] [RSS: 0.200122] [loc=52.451 scale=7.551]
# [distfit] >INFO> [reciprocal     ] [0.06 sec] [RSS: 0.0920772] [loc=-133.820 scale=1.000]
# [distfit] >INFO> [rayleigh       ] [0.00 sec] [RSS: 0.0857129] [loc=44.890 scale=34.553]
# [distfit] >INFO> [rice           ] [0.19 sec] [RSS: 0.546789] [loc=44.896 scale=0.208]
# [distfit] >INFO> [recipinvgauss  ] [1.66 sec] [RSS: 0.0113718] [loc=-53.528 scale=0.132]
# [distfit] >INFO> [semicircular   ] [0.01 sec] [RSS: 0.210892] [loc=52.450 scale=7.552]
# [distfit] >INFO> [t              ] [0.32 sec] [RSS: 0.0118724] [loc=93.565 scale=4.125]
# [distfit] >INFO> [triang         ] [0.11 sec] [RSS: 0.0568885] [loc=44.887 scale=55.013]
# [distfit] >INFO> [truncexpon     ] [0.03 sec] [RSS: 0.0982891] [loc=44.859 scale=96.483]
# [distfit] >INFO> [truncnorm      ] [0.08 sec] [RSS: 0.0598402] [loc=94.172 scale=21.079]
# [distfit] >INFO> [tukeylambda    ] [2.59 sec] [RSS: 0.000483367] [loc=93.750 scale=6.567]
# [distfit] >INFO> [uniform        ] [0.00 sec] [RSS: 0.0872144] [loc=44.900 scale=55.000]
# [distfit] >INFO> [vonmises       ] [0.00 sec] [RSS: 1.59928] [loc=2.152 scale=1.000]
# [distfit] >INFO> [vonmises_line  ] [0.39 sec] [RSS: 0.264644] [loc=52.450 scale=2.403]
# [distfit] >INFO> [wald           ] [0.02 sec] [RSS: 0.0953202] [loc=44.269 scale=77.991]
# [distfit] >INFO> [weibull_min    ] [0.07 sec] [RSS: 0.172517] [loc=44.900 scale=1.538]
# [distfit] >INFO> [weibull_max    ] [0.12 sec] [RSS: 0.17447] [loc=99.900 scale=1.413]
# [distfit] >INFO> [wrapcauchy     ] [0.03 sec] [RSS: 0.0696413] [loc=44.900 scale=8.754]
# Best fitted distribution: tukeylambda
# Parameters: (1.0678065194840398, 93.75041638112864, 6.567454709310677)

# %% [markdown]
# ## Generating data within country

# %%
validpix = np.nonzero(template)[0] 
finval = 9402-np.size(lat)
for i in range(10000):
    newlat = distlat.generate(3000+i)
    newlon = distlon.generate(3000+i)
    newpix = hp.ang2pix(128, newlon, newlat, lonlat=True)
    finpix = []
    for pixie in newpix:
        if pixie in validpix:  
            finpix.append(pixie)
    if len(finpix)==finval:
        break

# %%
print(len(finpix))
print(finval)
print(i)
# Out:
# 4420
# 4420
# 2168

# %%
newwww=np.zeros(hp.nside2npix(128))
for pppp in finpix:
    newwww[pppp]+=1
