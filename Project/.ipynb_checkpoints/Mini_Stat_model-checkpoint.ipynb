# %%
import numpy as np 
import healpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import tifffile as tiff
import glob
import seaborn as sns
# sns.set_style("darkgrid")
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from num2words import num2words
from scipy.optimize import curve_fit
from mpl_toolkits import mplot3d
# sns.set(rc={"xtick.bottom": True, "ytick.left": True})
# %matplotlib inline
# %matplotlib notebook

# %%
##---------Read the tif file---------##
image = tiff.imread('./gpw_v4_population_density_adjusted_to_2015_unwpp_country_totals_rev11_2020_15_min.tif')
image_array = np.array(image)


#----------Define the spherical coordinates----------#
theta = np.linspace(np.radians(0), np.radians(180), num=image_array.shape[0],endpoint=False)
phi = np.linspace(-np.radians(180), np.radians(180), num=image_array.shape[1],endpoint=False)

#---------- Set angular resolution----------#
nside = 128

##--------Make empty healpix mask and pixel values vector--------##
healpix_map = np.zeros(hp.nside2npix(nside), dtype=np.double)
pixel_counts = np.zeros(hp.nside2npix(nside), dtype=int)


for i in range(len(theta)):
    for j in range(len(phi)):
        pixel = hp.ang2pix(nside, theta[i], phi[j])
        healpix_map[pixel] += image_array[i, j]
        pixel_counts[pixel] += 1

#--------Average value of each pixel--------#
healpix_map[pixel_counts>0] /= pixel_counts[pixel_counts>0 ]


healpix_map[healpix_map<1e-2]=0

# %%
hp.mollview(healpix_map, cmap="inferno", xsize=3000, flip="geo", norm="hist", min=10)
plt.show()

# %%
csv_files = ['./database/Argentina.csv','./database/France.csv','./database/Russia.csv','./database/China.csv','./database/Brazil.csv','./database/Spain.csv']





# --Create an empty dataframe to store the combined data-- #
df = pd.DataFrame()

# Loop through each CSV file and append its contents to the combined dataframe
for csv_file in (csv_files):
    df_temp = pd.read_csv(csv_file)
    df = pd.concat([df, df_temp],ignore_index=True)

df=df.dropna()
power=df['EIRP'].to_numpy()
lat_128=df['Latitude in degrees'].to_numpy()
lon_128=df['Longitude in degrees'].to_numpy()

pix=hp.ang2pix(128,lon_128,lat_128,lonlat=True)

# %%
Tx_num_128=np.zeros(hp.nside2npix(128))
for pi in pix:
    Tx_num_128[pi]+=1
hp.cartview(Tx_num_128,flip='geo',cmap='plasma',norm='hist')
plt.show()

# %%
Tx_pow_128=np.zeros(hp.nside2npix(128))
for index,p in enumerate(pix):
    Tx_pow_128[p]+=(power[index])
hp.mollview(Tx_pow_128,flip='geo',cmap='viridis',norm='hist',min=300)
plt.show()

# %%
hp.mollview(healpix_map-Tx_pow_128,flip='geo',norm='hist',cmap='inferno',min=0)

# %%
x=healpix_map[pix]
plt.scatter(healpix_map[pix],Tx_pow_128[pix],linewidths=0.4,marker='1')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
import os



for file in csv_files:
    filename = os.path.basename(file)  
    tempdf = pd.read_csv(file)
    data = tempdf['EIRP'].to_numpy()
    plt.hist(data, stacked=True, bins=np.linspace(1e3, 4e5, int(np.sqrt(len(power)))), label=filename)

plt.yscale('log')
plt.legend()
plt.show()

# %%
n, bins,_ = plt.hist(Tx_pow_128[pix],bins=np.linspace(0.01e6,1.4e6,int(np.sqrt(len(Tx_pow_128[pix])))))

# Finding the midpoints of each bin
bin_centers = 0.5 * (bins[:-1] + bins[1:])




# Plotting the histogram bars
# plt.hist(Tx_pow_128[pix],bins=np.linspace(0.01e6,1.4e6,150))

# Plotting the line representing the histogram
plt.plot(bin_centers, n, linestyle='-', color='red', linewidth=2)


plt.show()

# %%
def power_law(x, a, b):
    return a * np.power(x, b)

# %%
x_data =  bin_centers
y_data = n
# Fit the power law curve to the data
params, covariance = curve_fit(power_law, x_data, y_data)

# Get the fitted parameters
a_fit, b_fit = params

# Generate points for the fitted curve
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = power_law(x_fit, a_fit, b_fit)

# Plotting the original data and the fitted curve
plt.scatter(x_data, y_data, label='Original Data',marker='*')
plt.plot(x_fit, y_fit, 'r-', label='Fitted Power Law Curve')

plt.legend()

plt.show()

print(f"Fitted parameters: a = {a_fit}, b = {b_fit}")
# Out:
# Fitted parameters: a = 105374755.72799793, b = -1.0980238152653106

# %% [markdown]
# ## Trends in Tx distribution coordinate wise

# %%
fr_df=pd.read_csv('./database/France.csv')
fr_df=fr_df.dropna()
lat=fr_df['Latitude in degrees'].to_numpy()
lon=fr_df['Longitude in degrees'].to_numpy()

# %%
n1,bins1,_= plt.hist(lat,bins=np.linspace(41,52,30))
plt.title('France lat histogram with one deg bins')
plt.show()

# %%
np.min(lat)
# Out:
# 41.2314

# %%
plt.hist(lon,bins=np.linspace(-5,11,30))
plt.title('France lon histogram with one deg bins')
plt.show()

# %%
len(b)
# Out:
# 11

# %%
bin_centers = np.array([1, 2, 3, 4, 5])  
hist_values = np.array([5, 12, 18, 10, 6])  

# Normalize the histogram to obtain a PDF
bin_width = np.diff(bin_centers)[0]
pdf = hist_values / (np.sum(hist_values) * bin_width)

# Define a function to scale and fit the histogram as a model
def scaled_histogram_model(x, scale):
    scaled_pdf = scale * pdf
    return np.interp(x, bin_centers, scaled_pdf, left=0.0, right=0.0)

# Generate sample data to fit
np.random.seed(42)
data = np.random.normal(loc=3.0, scale=1.5, size=1000)  # Replace with your own data

# Fit the scaled histogram model to the sample data
popt, pcov = curve_fit(scaled_histogram_model, data, np.zeros_like(data) + 1)

# Plot the original data and the scaled histogram model
plt.hist(data, bins=30, density=True, alpha=0.6, label='Sample Data')
x = np.linspace(min(data), max(data), 100)
plt.plot(x, scaled_histogram_model(x, *popt), 'r-', label='Scaled Histogram Model')

plt.legend()
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Fitting Histogram as Model')
plt.show()
