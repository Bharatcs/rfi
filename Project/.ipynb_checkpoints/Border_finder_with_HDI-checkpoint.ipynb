# %%
import json

# Load the GEOJSON data from your file
with open('/home/pratush/Yogen_STARFIRE/output.geojson', 'r') as geojson_file:
    geojson_data = json.load(geojson_file)

# Initialize empty lists to store lon, lat, and Value
lon_list = []
lat_list = []
value_list = []

# Extract data from the features
for feature in geojson_data['features']:
    geometry = feature['geometry']
    if geometry['type'] == 'MultiPolygon':
        coordinates = geometry['coordinates']
        for polygon in coordinates:
            for ring in polygon:
                for lon, lat in ring:
                    lon_list.append(lon)
                    lat_list.append(lat)
                    value_list.append(feature['properties']['Value'])
    elif geometry['type'] == 'Polygon':
        coordinates = geometry['coordinates']
        for ring in coordinates:
            for lon, lat in ring:
                lon_list.append(lon)
                lat_list.append(lat)
                value_list.append(feature['properties']['Value'])

# %%
import numpy as np
import healpy as hp
HDI_map=np.zeros(hp.nside2npix(128))
for i in range(len(lat_list)):
    pixels=hp.ang2pix(128,lon_list[i],lat_list[i],lonlat=True)
    HDI_map[pixels]+=value_list[i]

# %%
hp.mollview(HDI_map,flip='geo',norm='hist')

# %%
output_file = "HDI_border_map.fits"

# Save the HEALPix map to a FITS file
hp.write_map(output_file, HDI_map)
# Out:
# setting the output map dtype to [dtype('float64')]
