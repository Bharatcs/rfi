# %% [markdown]
# ### Imports

# %%
import os
import pandas as pd
import numpy as np
import healpy as hp
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")
sns.set(rc={"xtick.bottom": True, "ytick.left": True})
from astropy.constants import c, k_B, R_earth
import src.read_database as read_database
import src.map_properties as map_properties
import src.satellite_properties as satellite_properties
import src.store_FOV_indices as store_FOV_indices
import src.Friis as Friis
import src.power_3D_cube as power_3D_cube
import time
# %matplotlib inline

# %%
start_time=time.time()

# %% [markdown]
# #### Schematic representation of the architecture

# %% [markdown]
# ![image](./rfi_framework.png)

# %% [markdown]
# ### Read FM Transmitter Database

# %%
n = str(input("Enter the number of countries to include"))
# Out:
# Enter the number of countries to includeAll

# %%
df = read_database.read_FM_database(countries=read_database.get_countries(n))
# Out:
# /home/saurabhs/Documents/Yogen_starfire/STARFIRE_2_backup/Project/src/read_database.py:76: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, read_csv(f"./database/{countries[i+1]}")], ignore_index=True)
# /home/saurabhs/Documents/Yogen_starfire/STARFIRE_2_backup/Project/src/read_database.py:76: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, read_csv(f"./database/{countries[i+1]}")], ignore_index=True)

# %% [markdown]
# ### Define frequency range

# %%
freq_range = read_database.get_freq_range()
# Out:
# Please enter the minimum value of the frequency range (in MHz): 55
# Please enter the maximum value of the frequency range (in MHz): 110
# Please enter the resolution of the frequency (in MHz): 0.244

# %%
df = read_database.extract_common_freq(df, freq_range)

# %% [markdown]
# ### Define resolution of the Healpy map

# %%
print('----------- Resolution of the map -----------')

# The default value of nside is 16
nside = int(input("Enter the NSIDE of the healpy map"))
npix, pix_array, phi, theta = map_properties.get_map(nside)

print(f"The number of pixels for the given NSIDE: {(hp.nside2npix(nside))}")
print(f"Approximate resolution in degrees for given nside {np.degrees(hp.nside2resol(nside)):.2f}")
print(f"Pixel area: {hp.nside2pixarea(nside, degrees=True):.2f} square degrees")
# Out:
# ----------- Resolution of the map -----------
# Enter the NSIDE of the healpy map32
# The number of pixels for the given NSIDE: 12288
# Approximate resolution in degrees for given nside 1.83
# Pixel area: 3.36 square degrees

# %%
beam_pattern=str(input('Enter desired beam pattern:'))
# Out:
# Enter desired beam pattern:sin square

# %% [markdown]
# ### Allocate pixel number to the Latitude and Longitude of each FM transmitter in the database

# %%
df, pixel_indices = read_database.allocate_pixel_num(nside, df)

# %% [markdown]
# ### Define altitude of the satellite orbit

# %%
altitudes = satellite_properties.get_altitudes()
# Out:
# Enter the minimum altitude of the satellite: 705
# Enter the maximum altitude of the satellite: 36000
# Enter number of data points : 3

# %% [markdown]
# ### Calculation of Elevation angle

# %%
elev_angle = satellite_properties.calc_elev_angle(npix, phi, theta, altitudes)
# Out:
# /home/saurabhs/Documents/Yogen_starfire/STARFIRE_2_backup/Project/src/satellite_properties.py:43: RuntimeWarning: divide by zero encountered in scalar divide
#   elev_ang[k,i,j]=-(np.degrees(np.arctan((B-np.cos(np.radians(y_ang[i,j])))/np.sin(np.radians(y_ang[i,j])))))
# /home/saurabhs/Documents/Yogen_starfire/STARFIRE_2_backup/Project/src/satellite_properties.py:41: RuntimeWarning: invalid value encountered in arccos
#   y_ang[i,j]=(np.arccos(x_ang[i,j]))

# %% [markdown]
# ### Define radiation pattern of the satellite antenna beam [optional]

# %%
np.shape(elev_angle)
# Out:
# (3, 12288, 12288)

# %%
beam = satellite_properties.get_beam_pattern("sin square", theta)
az = 0 # Assuming the satellite antenna beam to be symmetric across azimuth

# %% [markdown]
# ###  Calculation of Field of view (FOV) and Radius of the FOV of the satellite

# %%
FOV = satellite_properties.calc_field_of_view(altitudes)
# Out:
# The Field of view of the satellite at a height of 705.00 km is 2.24 radians
# The Field of view of the satellite at a height of 5037.86 km is 1.19 radians
# The Field of view of the satellite at a height of 36000.00 km is 0.30 radians

# %%
Central_angle, Rad_of_FOV = satellite_properties.calc_central_angle(altitudes)
# Out:
# The Radius of the Field of View for a height of 705.00 km in radians is 0.45
# The Radius of the Field of View for a height of 5037.86 km in radians is 0.98
# The Radius of the Field of View for a height of 36000.00 km in radians is 1.42

# %% [markdown]
# # Create power cube

# %%
disc = store_FOV_indices.get_disc(nside, phi, theta, Rad_of_FOV, pix_array)

# %%
pix_common = store_FOV_indices.get_common_pix(pix_array, Rad_of_FOV, disc, df)

# %%
found_common = store_FOV_indices.get_common_Tx(pixel_indices, pix_common, Rad_of_FOV)

# %% [markdown]
# ## Plot Healpy map of beam-weighted FOV of a satellite overhead a particular location

# %% [markdown]
# <b> Transmitter locations from the FM Transmitter database and the received power at different altitudes has not been taken into account for these plots <b>

# %%
i=1500
xx4=disc[i][0]  # For Hanle at an altitude of 400 km
xx5=disc[686][1]
xx6=disc[i][2]

y4=satellite_properties.get_beam_pattern("cos square", elev_angle[0,i,xx4])
y5=satellite_properties.get_beam_pattern("cos square", elev_angle[1,686,xx5])
y6=satellite_properties.get_beam_pattern("sin square", elev_angle[2,i,xx6])

data4= np.zeros(hp.nside2npix(nside))
data5= np.zeros(hp.nside2npix(nside))
data6= np.zeros(hp.nside2npix(nside))

data4[xx4]=y4
data5[xx5]=y5

data6[xx6]=y6

hp.mollview(data4,flip='geo')
# hp.mollview(data5,flip='geo')
hp.mollview(data6,flip='geo')

# %%
Rx_Power_in_Kelvin = Friis.calc_Friis(df, altitudes)[2]
# print(df)
# Out:
# /home/saurabhs/Documents/Yogen_starfire/STARFIRE_2_backup/Project/src/Friis.py:30: RuntimeWarning: divide by zero encountered in log10
#   Rx_Power_in_dBm[j][i]= 10.*np.log10( Rx_Power[j][i])+30
# /home/saurabhs/Documents/Yogen_starfire/STARFIRE_2_backup/Project/src/Friis.py:32: RuntimeWarning: divide by zero encountered in log10
#   Rx_Power_in_dBW[j][i]= 10.*np.log10( Rx_Power[j][i])

# %%
df_fov = power_3D_cube.get_dataframe_fov(Rx_Power_in_Kelvin, df, found_common, Rad_of_FOV, elev_angle,beam_pattern)

# %%
power_output = power_3D_cube.get_power_output(npix, Rad_of_FOV, freq_range, df_fov)

# %%
end_time=time.time()

# %% [markdown]
# ## Plot  Spectrum

# %% [markdown]
# <b> The first index represents altitude of the satellite <b>\
# <b> The second index represents location of the satellite(pixel number) <b>\
# <b> The third index represents range of frequencies <b>

# %%
sns.set_style("darkgrid")
sns.set(rc={"xtick.bottom": True, "ytick.left": True,
            "xtick.direction": "out", "ytick.direction": "in"}) #, "axes.edgecolor": "black"})
munpix=hp.ang2pix(nside, 11.580224258292716,48.13469781361046,lonlat=True)
plt.plot(freq_range,power_output[0,munpix,:], label='Munich at 400 km', color='darkorange') 
plt.xlabel('Frequency [in MHz]')
plt.ylabel('Brightness temperature of RFI [in Kelvin]')
plt.yscale('log')
plt.tight_layout()
plt.legend(facecolor="white", edgecolor="black", bbox_to_anchor=(0.46, 1.01),fancybox=True, shadow=True)
# plt.savefig("/home/sonia/Documents/RFI_PAPER/Munich_36000_new.pdf")

# %%
sns.set_style("darkgrid")
sns.set(rc={"xtick.bottom": True, "ytick.left": True,
            "xtick.direction": "out", "ytick.direction": "in"}) #, "axes.edgecolor": "black"})
hanlepix=hp.ang2pix(nside, 79.00064650939689,32.79063979504319,lonlat=True)
plt.plot(freq_range,power_output[0,hanlepix,:], label='Hanle at 400 km', color='darkgreen') 
plt.xlabel('Frequency [in MHz]')
plt.ylabel('Brightness temperature of RFI [in Kelvin]')
plt.yscale('log')
plt.tight_layout()
plt.legend(facecolor="white", edgecolor="black", bbox_to_anchor=(0.46, 1.01),fancybox=True, shadow=True)
# plt.savefig("/home/sonia/Documents/RFI_PAPER/Hanle_36000_new.pdf")

# %%
num_of_rfi_chan=len(freq_range[power_output[0,13,:]!=0])
num_of_rfi_chan


#NUM_OF_RFI_CHANNEL=96 (Arctic Ocean at 36000 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa)
#NUM_OF_RFI_CHANNEL=84 (Arctic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa)
#NUM_OF_RFI_CHANNEL=0 (Arctic Ocean at 400 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa)



#NUM_OF_RFI_CHANNEL=83 (Pacific Ocean at 36000 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa)
#NUM_OF_RFI_CHANNEL=3 (Pacific Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa)
#NUM_OF_RFI_CHANNEL=0 (Pacic Ocean at 400 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa)




#NUM_OF_RFI_CHANNEL=96 (Arctic Ocean at 36000 km (Tokyo, USA, Germany,\n Canada, Australia)
#NUM_OF_RFI_CHANNEL=84 (Arctic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, Australia)
#NUM_OF_RFI_CHANNEL=0 (Arctic Ocean at 400 km (Tokyo, USA, Germany,\n Canada, Australia)

#NUM_OF_RFI_CHANNEL=83 (Pacific Ocean at 36000 km (Tokyo, USA, Germany,\n Canada, Australia)
#NUM_OF_RFI_CHANNEL=3 (Paciic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, Australia)
#NUM_OF_RFI_CHANNEL=0 (Pacitic Ocean at 400 km (Tokyo, USA, Germany,\n Canada, Australia)





#NUM_OF_RFI_CHANNEL=96 (Arctic Ocean at 36000 km (Tokyo, USA, Germany,\n Canada)
#NUM_OF_RFI_CHANNEL=84 (Arctic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada)
#NUM_OF_RFI_CHANNEL=0 (Arctic Ocean at 400 km (Tokyo, USA, Germany,\n Canada,)

#NUM_OF_RFI_CHANNEL=83 (Pacific Ocean at 36000 km (Tokyo, USA, Germany,\n Canada,)
#NUM_OF_RFI_CHANNEL=3 (Paciic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada,)
#NUM_OF_RFI_CHANNEL=0 (Pacitic Ocean at 400 km (Tokyo, USA, Germany,\n Canada)







#NUM_OF_RFI_CHANNEL=96 (Arctic Ocean at 36000 km (Tokyo, USA, Germany)
#NUM_OF_RFI_CHANNEL=84 (Arctic Ocean at 3795 km (Tokyo, USA, Germany)
#NUM_OF_RFI_CHANNEL=0 (Arctic Ocean at 400 km (Tokyo, USA, Germany)

#NUM_OF_RFI_CHANNEL=13 (Pacific Ocean at 36000 km (Tokyo, USA, Germany)
#NUM_OF_RFI_CHANNEL=3 (Paciic Ocean at 3795 km (Tokyo, USA, Germany)
#NUM_OF_RFI_CHANNEL=0 (Pacitic Ocean at 400 km (Tokyo, USA, Germany)






#NUM_OF_RFI_CHANNEL=32 (Arctic Ocean at 36000 km (Tokyo, USA)
#NUM_OF_RFI_CHANNEL=12 (Arctic Ocean at 3795 km (Tokyo, USA)
#NUM_OF_RFI_CHANNEL=0 (Arctic Ocean at 400 km (Tokyo, USA)

#NUM_OF_RFI_CHANNEL=12 (Pacific Ocean at 36000 km (Tokyo, USA)
#NUM_OF_RFI_CHANNEL=2 (Paciic Ocean at 3795 km (Tokyo, USA)
#NUM_OF_RFI_CHANNEL=0 (Pacitic Ocean at 400 km (Tokyo, USA)




#NUM_OF_RFI_CHANNEL=31 (Arctic Ocean at 36000 km (Tokyo)
#NUM_OF_RFI_CHANNEL=11 (Arctic Ocean at 3795 km (Tokyo)
#NUM_OF_RFI_CHANNEL=0 (Arctic Ocean at 400 km (Tokyo)

#NUM_OF_RFI_CHANNEL=10 (Pacific Ocean at 36000 km (Tokyo)
#NUM_OF_RFI_CHANNEL=0(Paciic Ocean at 3795 km (Tokyo)
#NUM_OF_RFI_CHANNEL=0 (Pacitic Ocean at 400 km (Tokyo)
# Out:
# 120

# %%
rfi_band=244*num_of_rfi_chan # in kHz
rfi_band_inMHz=rfi_band*1e-3
rfi_band_inMHz
# Out:
# 29.28

# %%
tot_band=freq_range[-1]-freq_range[0]
usable_band=tot_band-rfi_band_inMHz
usable_band


#USABLE_BW=31.576(Arctic Ocean at 36000 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa)
#USABLE_BW_CHANNEL=34.504000000000005 (Arctic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa)
#USABLE_BW=55 (Arctic Ocean at 400 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa)

#USABLE_BW=34.748000000000005(PACIFIC Ocean at 36000 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa)
#USABLE_BW_CHANNEL=54.268(Pacific Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa)
#USABLE_BW=55 (Pacific Ocean at 400 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa)



#USABLE_BW=31.576(Arctic Ocean at 36000 km (Tokyo, USA, Germany,\n Canada, Australia )
#USABLE_BW_CHANNEL=34.504000000000005 (Arctic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, Australia)
#USABLE_BW=55 (Arctic Ocean at 400 km (Tokyo, USA, Germany,\n Canada, Australia )

#USABLE_BW=34.748000000000005(PACIFIC Ocean at 36000 km (Tokyo, USA, Germany,\n Canada, Australia 
#USABLE_BW_CHANNEL=54.268(Pacific Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, Australia)
#USABLE_BW=55 (Pacific Ocean at 400 km (Tokyo, USA, Germany,\n Canada, Australia)




#USABLE_BW=31.576(Arctic Ocean at 36000 km (Tokyo, USA, Germany,\n Canada)
#USABLE_BW_CHANNEL=34.504000000000005 (Arctic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada)
#USABLE_BW=55 (Arctic Ocean at 400 km (Tokyo, USA, Germany,\n Canada)

#USABLE_BW=34.748000000000005(PACIFIC Ocean at 36000 km (Tokyo, USA, Germany,\n Canada,
#USABLE_BW_CHANNEL=54.268(Pacific Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, 
#USABLE_BW=55 (Pacific Ocean at 400 km (Tokyo, USA, Germany,\n Canada, )






#USABLE_BW=31.576(Arctic Ocean at 36000 km (Tokyo, USA,, Germany)
#USABLE_BW_CHANNEL=34.504000000000005 (Arctic Ocean at 3795 km (Tokyo, USA, Germany)
#USABLE_BW=55 (Arctic Ocean at 400 km (Tokyo, USA, Germany)

#USABLE_BW=51.828(Pacific Ocean at 36000 km (Tokyo, USA, Germany)
#USABLE_BW_CHANNEL=54.268(Pacifc Ocean at 3795 km (Tokyo, USA, Germany)
#USABLE_BW=55 (Pacific Ocean at 400 km (Tokyo, USA, Germany)





#USABLE_BW=47.192(Arctic Ocean at 36000 km (Tokyo, USA)
#USABLE_BW_CHANNEL=52.072 (Arctic Ocean at 3795 km (Tokyo, USA)
#USABLE_BW=55 (Arctic Ocean at 400 km (Tokyo, USA)

#USABLE_BW=52.072(Pacific Ocean at 36000 km (Tokyo, USA)
#USABLE_BW_CHANNEL=54.512(Pacifc Ocean at 3795 km (Tokyo, USA)
#USABLE_BW=55 (Pacific Ocean at 400 km (Tokyo, USA)





#USABLE_BW=47.436(Arctic Ocean at 36000 km (Tokyo)
#USABLE_BW_CHANNEL=52.316 (Arctic Ocean at 3795 km (Tokyo)
#USABLE_BW=55 (Arctic Ocean at 400 km (Tokyo)

#USABLE_BW=52.56(Pacific Ocean at 36000 km (Tokyo)
#USABLE_BW_CHANNEL=55(Pacifc Ocean at 3795 km (Tokyo)
#USABLE_BW=55 (Pacific Ocean at 400 km (Tokyo)
# Out:
# 25.619999999999948

# %%
time=1
FOM=time*usable_band
FOM

#FOM=31.576(Arctic Ocean at 36000 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa) 31.576
#FOM=34.504000000000005(Arctic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa) 34.504000000000005
#FOM=55(Arctic Ocean at 400 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa) 53.048


#FOM=34.748000000000005(Pacific Ocean at 36000 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa) 34.748000000000005
#FOM=54.268(Paciic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa) 34.748000000000005
#FOM=55(Pacific Ocean at 400 km (Tokyo, USA, Germany,\n Canada, Australia and South Africa) 55.0
#---------------------------------------------------------------------------------------------------------

#FOM=31.576(Arctic Ocean at 36000 km (Tokyo, USA, Germany,\n Canada, Australia ) 31.576
#FOM=34.504000000000005(Arctic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, Australia )34.504000000000005
#FOM=55(Arctic Ocean at 400 km (Tokyo, USA, Germany,\n Canada, Australia )53.048


#FOM=34.748000000000005(Pacific Ocean at 36000 km (Tokyo, USA, Germany,\n Canada, Australia ) 34.748000000000005
#FOM=54.268(Paciic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada, Australia ) 34.748000000000005
#FOM=55(Pacific Ocean at 400 km (Tokyo, USA, Germany,\n Canada, Australia ) 55

#------------------------------------------------------------------------------------------------------------



#FOM=31.576(Arctic Ocean at 36000 km (Tokyo, USA, Germany,\n Canada) 31.576
#FOM=34.504000000000005(Arctic Ocean at 3795 km (Tokyo, USA, Germany) 34.504000000000005
#FOM=55(Arctic Ocean at 400 km (Tokyo, USA, Germany,\n Canada,) 53.048


#FOM=34.748000000000005(Pacific Ocean at 36000 km (Tokyo, USA, Germany,\n Canada) 34.748000000000005
#FOM=54.268(Paciic Ocean at 3795 km (Tokyo, USA, Germany,\n Canada ) 34.748000000000005
#FOM=55(Pacific Ocean at 400 km (Tokyo, USA, Germany,\n Canada ) 55

#---------------------------------------------------------------------------------------------------------------

#FOM=31.576(Arctic Ocean at 36000 km (Tokyo, USA, Germany,) 31.576
#FOM=34.504000000000005(Arctic Ocean at 3795 km (Tokyo, USA, Germany) 34.50
#FOM=55(Arctic Ocean at 400 km (Tokyo, USA, Germany) 53.048


#FOM=51.828(Pacific Ocean at 36000 km (Tokyo, USA, Germany) 34.748000000000005
#FOM=54.268(Paciic Ocean at 3795 km (Tokyo, USA, Germany ) 34.748000000000005
#FOM=55(Pacific Ocean at 400 km (Tokyo, USA, Germany) 55

#---------------------------------------------------------------------------------------------------------------


#FOM=47.192(Arctic Ocean at 36000 km (Tokyo, USA,) 31.576
#FOM=52.072(Arctic Ocean at 3795 km (Tokyo, USA) 34.992
#FOM=55(Arctic Ocean at 400 km (Tokyo, USA) 53.048


#FOM=52.072(Pacific Ocean at 36000 km (Tokyo, USA) 34.748
#FOM=54.512(Paciic Ocean at 3795 km (Tokyo, USA )34.748
#FOM=55(Pacific Ocean at 400 km (Tokyo, USA) 55

#------------------------------------------------------------------------------------------------------------


#FOM=47.436(Arctic Ocean at 36000 km (Tokyo,) 47.192
#FOM=52.316(Arctic Ocean at 3795 km (Tokyo) 52.316
#FOM=55(Arctic Ocean at 400 km (Tokyo) 55


#FOM=52.56(Pacific Ocean at 36000 km (Tokyo) 52.316
#FOM=55(Paciic Ocean at 3795 km (Tokyo ) 54.756
#FOM=55(Pacific Ocean at 400 km (Tokyo) 55
# Out:
# 25.619999999999948

# %%
FOM_map=np.zeros(hp.nside2npix(nside))
for i in range(len(FOM_map)):
	num_of_rfi_chan=len(freq_range[power_output[0,i,:]!=0])
	rfi_band=0.244*num_of_rfi_chan 
	usable_band=tot_band-rfi_band
	FOM_map[i]+=usable_band

# %%
hp.mollview(FOM_map,flip='geo',cmap='inferno',title='')
# plt.savefig('/home/saurabhs/Documents/Yogen_starfire/SF_images/FOM_map.pdf',dpi=600)

# %%
good_spots=np.where(FOM_map==max(FOM_map))

# %%
from src2.shapecheck import shapecheck
goodlon,goodlat=hp.pix2ang(nside,good_spots,lonlat=True)
shapecheck(goodlon,goodlat,'')

# %%
np.max(FOM_map)
# Out:
# 34.403999999999954

# %%
sns.set_style("darkgrid")
sns.set(rc={"xtick.bottom": True, "ytick.left": True,
            "xtick.direction": "out", "ytick.direction": "in"}) #, "axes.edgecolor": "black"})
pix_req=hp.ang2pix(nside,-10,-25,lonlat=True)
plt.plot(freq_range,power_output[0,pix_req,:], label='Sydney at 400 km', color='darkblue') 
plt.xlabel('Frequency [in MHz]')
plt.ylabel('Brightness temperature of RFI [in Kelvin]')
plt.yscale('log')
plt.tight_layout()
plt.legend(facecolor="white", edgecolor="black", bbox_to_anchor=(0.46, 1.01),fancybox=True, shadow=True)

# plt.savefig("/home/sonia/Documents/RFI_PAPER/Sydney_400_new.pdf")

# %%
import seaborn as sns
sns.set_style("darkgrid")
sns.set(rc={"xtick.bottom": True, "ytick.left": True})

plt.plot(freq_range,power_output[2,2363,:], label='Sydney at 36000 km', color='darkblue') 
plt.xlabel('Frequency [in MHz]')
plt.ylabel('Brightness temperature of RFI [in Kelvin]')
plt.yscale('log')
plt.tight_layout()
plt.legend(facecolor="white", edgecolor="black", bbox_to_anchor=(0.44, 1.01),fancybox=True, shadow=True)
# plt.savefig("/home/sonia/Documents/RFI_PAPER/Sydney_36000_new.pdf")

# %% [markdown]
# ## Optimal orbit RFI

# %%
# pratushfreq=200
# test_plot = np.zeros(hp.nside2npix(nside))
# test_plot[0:np.size(power_output[0,:,100])] = power_output[0,:,pratushfreq]

# %%
# dff=pd.read_csv('/home/saurabhs/Documents/Yogen_starfire/neworbit.csv')
# Lon=dff['Lon'].to_numpy()
# Lat=dff['Lat'].to_numpy()

# %%
# orbitpix=hp.ang2pix(nside,Lon,Lat,lonlat=True)

# %%
# plt.plot(range(len(pix)),test_plot[pix])
# plt.title(str(freq_range[pratushfreq]))
# plt.show()

# %%
# hp.pix2ang(nside,orbitpix[50],lonlat=True)

# %%
# #from healpy.newvisufunc import projview, newprojplot
# test_plot[orbitpix]=hp.UNSEEN

# hp.mollview(test_plot,cmap='plasma',unit="in Kelvin",flip='geo',norm="hist",format= '%.2e',max=1.21e9)
# hp.graticule()
# sns.set(font_scale=2)
# plt.show()

# %%
# x=freq_range
# y=np.arange(0,len(orbitpix),1)
# xx,yy=np.meshgrid(x,y)
# power_val=np.zeros((len(y),len(x)))
# for i in range(len(x)):
#     for index,j in enumerate(orbitpix):
#         power_val[index,i]+=power_output[0,j,i]

# %%
# plt.pcolormesh(xx,yy,power_val,cmap='viridis',norm='log',vmin=1,rasterized=True)
# plt.xlabel('Frequency(MHz)')
# plt.ylabel('Orbit pixel number')
# plt.colorbar()
# # plt.savefig('/home/saurabhs/Documents/Yogen_starfire/SF_images/New_waterfallplot.pdf',bbox_inches='tight',dpi=600)
# plt.show()

# %% [markdown]
# ## Evaluate time spent in different FOM regions

# %%
import pytz
from datetime import datetime
from dateutil.relativedelta import relativedelta
from skyfield.api import load, wgs84, EarthSatellite

# %%
# open TLE archive
file=open('../landsat_archive')
content=file.read()
ts = load.timescale()
eph=load('de421.bsp')

# %% [markdown]
# ### Slice one year of TLEs

# %%
lineone=[]
linetwo=[]
num=2000
year=np.zeros(num)
month=np.zeros(num)
days=np.zeros((num))
hour=np.zeros((num))
minute=np.zeros((num))
second=np.zeros((num))
for i in range(2000):
    line11=(content[((2*i)*70):((2*i)*70)+69])
    line22=(content[((2*i+1)*70):((2*i+1)*70)+69])
    sate=EarthSatellite(line11,line22,'Landsat7',ts)
#     print(sate)
    lineone.append(line11)
    linetwo.append(line22)
    year=sate.epoch.utc.year
    month=sate.epoch.utc.month
    day=sate.epoch.utc.day
    days[i]+=day
    if year==2000.0:
        if month==4.0:
            if day==15.0:
                   break

# %% [markdown]
# ### Get one TLE per day for one year

# %%
uniq_idx=[]
uniq_idx.append(0)
for i in range(len(lineone)):
    if i>0:
        if days[i]!=days[i-1]:
            uniq_idx.append(i)

# %%
# ground track with new TLE everyday
subpoints=[]
sunlit=[]
for i in uniq_idx:
    line1=lineone[i]
    line2=linetwo[i]
    satellite = EarthSatellite(line1, line2, 'Landsat-8', ts)
    print(satellite)
    tz = pytz.timezone('UTC')
    st=satellite.epoch.utc
    dt=tz.fromutc(datetime(st.year,st.month,st.day,st.hour,st.minute,0))
    t0 = ts.utc(dt)
    t1 = ts.utc(dt + relativedelta(hours=24))
    timescales = ts.linspace(t0,t1, 10000)
    # calculate the subpoints.

    geocentrics = satellite.at(timescales)
    sunlit.append(geocentrics.is_sunlit(eph))
    subpoints.append(wgs84.subpoint_of(geocentrics))
# Out:
# Landsat-8 catalog #25682 epoch 1999-04-15 21:10:29 UTC
# Landsat-8 catalog #25682 epoch 1999-04-16 05:22:56 UTC
# Landsat-8 catalog #25682 epoch 1999-04-17 04:21:48 UTC
# Landsat-8 catalog #25682 epoch 1999-04-18 03:20:40 UTC
# Landsat-8 catalog #25682 epoch 1999-04-19 03:58:01 UTC
# Landsat-8 catalog #25682 epoch 1999-04-20 04:35:23 UTC
# Landsat-8 catalog #25682 epoch 1999-04-21 03:34:14 UTC
# Landsat-8 catalog #25682 epoch 1999-04-22 04:11:36 UTC
# Landsat-8 catalog #25682 epoch 1999-04-23 03:10:29 UTC
# Landsat-8 catalog #25682 epoch 1999-04-24 00:31:13 UTC
# Landsat-8 catalog #25682 epoch 1999-04-25 04:25:50 UTC
# Landsat-8 catalog #25682 epoch 1999-04-26 03:24:58 UTC
# Landsat-8 catalog #25682 epoch 1999-04-27 04:02:37 UTC
# Landsat-8 catalog #25682 epoch 1999-04-28 04:41:44 UTC
# Landsat-8 catalog #25682 epoch 1999-04-29 03:42:11 UTC
# Landsat-8 catalog #25682 epoch 1999-04-30 02:42:37 UTC
# Landsat-8 catalog #25682 epoch 1999-05-01 05:01:43 UTC
# Landsat-8 catalog #25682 epoch 1999-05-02 04:03:22 UTC
# Landsat-8 catalog #25682 epoch 1999-05-03 03:05:00 UTC
# Landsat-8 catalog #25682 epoch 1999-05-04 03:45:20 UTC
# Landsat-8 catalog #25682 epoch 1999-05-05 04:25:40 UTC
# Landsat-8 catalog #25682 epoch 1999-05-06 03:27:19 UTC
# Landsat-8 catalog #25682 epoch 1999-05-07 04:07:38 UTC
# Landsat-8 catalog #25682 epoch 1999-05-08 04:47:58 UTC
# Landsat-8 catalog #25682 epoch 1999-05-09 08:45:40 UTC
# Landsat-8 catalog #25682 epoch 1999-05-10 02:51:14 UTC
# Landsat-8 catalog #25682 epoch 1999-05-11 03:31:34 UTC
# Landsat-8 catalog #25682 epoch 1999-05-12 04:11:53 UTC
# Landsat-8 catalog #25682 epoch 1999-05-13 04:52:12 UTC
# Landsat-8 catalog #25682 epoch 1999-05-14 03:53:50 UTC
# Landsat-8 catalog #25682 epoch 1999-05-15 04:34:09 UTC
# Landsat-8 catalog #25682 epoch 1999-05-16 05:14:28 UTC
# Landsat-8 catalog #25682 epoch 1999-05-17 04:16:06 UTC
# Landsat-8 catalog #25682 epoch 1999-05-18 04:56:24 UTC
# Landsat-8 catalog #25682 epoch 1999-05-19 03:58:02 UTC
# Landsat-8 catalog #25682 epoch 1999-05-20 04:38:21 UTC
# Landsat-8 catalog #25682 epoch 1999-05-21 03:39:58 UTC
# Landsat-8 catalog #25682 epoch 1999-05-22 04:20:17 UTC
# Landsat-8 catalog #25682 epoch 1999-05-23 03:21:54 UTC
# Landsat-8 catalog #25682 epoch 1999-05-24 04:02:12 UTC
# Landsat-8 catalog #25682 epoch 1999-05-25 03:03:49 UTC
# Landsat-8 catalog #25682 epoch 1999-05-26 03:44:08 UTC
# Landsat-8 catalog #25682 epoch 1999-05-27 04:24:26 UTC
# Landsat-8 catalog #25682 epoch 1999-05-28 05:04:44 UTC
# Landsat-8 catalog #25682 epoch 1999-05-29 05:45:03 UTC
# Landsat-8 catalog #25682 epoch 1999-05-30 03:07:58 UTC
# Landsat-8 catalog #25682 epoch 1999-05-31 03:48:16 UTC
# Landsat-8 catalog #25682 epoch 1999-06-01 06:07:16 UTC
# Landsat-8 catalog #25682 epoch 1999-06-02 03:30:11 UTC
# Landsat-8 catalog #25682 epoch 1999-06-03 04:10:29 UTC
# Landsat-8 catalog #25682 epoch 1999-06-04 01:33:24 UTC
# Landsat-8 catalog #25682 epoch 1999-06-05 03:52:23 UTC
# Landsat-8 catalog #25682 epoch 1999-06-06 02:54:00 UTC
# Landsat-8 catalog #25682 epoch 1999-06-07 05:12:58 UTC
# Landsat-8 catalog #25682 epoch 1999-06-08 04:14:35 UTC
# Landsat-8 catalog #25682 epoch 1999-06-09 04:54:52 UTC
# Landsat-8 catalog #25682 epoch 1999-06-10 03:56:28 UTC
# Landsat-8 catalog #25682 epoch 1999-06-11 04:36:45 UTC
# Landsat-8 catalog #25682 epoch 1999-06-12 03:38:21 UTC
# Landsat-8 catalog #25682 epoch 1999-06-13 04:18:38 UTC
# Landsat-8 catalog #25682 epoch 1999-06-14 03:20:14 UTC
# Landsat-8 catalog #25682 epoch 1999-06-15 05:39:12 UTC
# Landsat-8 catalog #25682 epoch 1999-06-16 03:02:06 UTC
# Landsat-8 catalog #25682 epoch 1999-06-17 03:42:23 UTC
# Landsat-8 catalog #25682 epoch 1999-06-18 01:22:47 UTC
# Landsat-8 catalog #25682 epoch 1999-06-19 03:26:01 UTC
# Landsat-8 catalog #25682 epoch 1999-06-20 04:07:51 UTC
# Landsat-8 catalog #25682 epoch 1999-06-21 04:50:15 UTC
# Landsat-8 catalog #25682 epoch 1999-06-22 03:53:52 UTC
# Landsat-8 catalog #25682 epoch 1999-06-23 02:57:58 UTC
# Landsat-8 catalog #25682 epoch 1999-06-24 03:40:56 UTC
# Landsat-8 catalog #25682 epoch 1999-06-25 04:24:02 UTC
# Landsat-8 catalog #25682 epoch 1999-06-26 03:28:20 UTC
# Landsat-8 catalog #25682 epoch 1999-06-27 04:11:35 UTC
# Landsat-8 catalog #25682 epoch 1999-06-28 13:09:19 UTC
# Landsat-8 catalog #25682 epoch 1999-06-29 03:59:13 UTC
# Landsat-8 catalog #25682 epoch 1999-06-30 03:03:37 UTC
# Landsat-8 catalog #25682 epoch 1999-07-01 05:25:47 UTC
# Landsat-8 catalog #25682 epoch 1999-07-02 04:30:10 UTC
# Landsat-8 catalog #25682 epoch 1999-07-03 03:34:34 UTC
# Landsat-8 catalog #25682 epoch 1999-07-04 04:17:50 UTC
# Landsat-8 catalog #25682 epoch 1999-07-05 03:22:13 UTC
# Landsat-8 catalog #25682 epoch 1999-07-06 04:05:30 UTC
# Landsat-8 catalog #25682 epoch 1999-07-07 03:09:53 UTC
# Landsat-8 catalog #25682 epoch 1999-07-08 03:53:09 UTC
# Landsat-8 catalog #25682 epoch 1999-07-09 04:36:25 UTC
# Landsat-8 catalog #25682 epoch 1999-07-10 03:40:48 UTC
# Landsat-8 catalog #25682 epoch 1999-07-11 04:24:04 UTC
# Landsat-8 catalog #25682 epoch 1999-07-12 03:28:26 UTC
# Landsat-8 catalog #25682 epoch 1999-07-13 04:11:42 UTC
# Landsat-8 catalog #25682 epoch 1999-07-14 04:54:58 UTC
# Landsat-8 catalog #25682 epoch 1999-07-15 03:59:21 UTC
# Landsat-8 catalog #25682 epoch 1999-07-16 04:42:37 UTC
# Landsat-8 catalog #25682 epoch 1999-07-17 03:46:59 UTC
# Landsat-8 catalog #25682 epoch 1999-07-18 06:09:08 UTC
# Landsat-8 catalog #25682 epoch 1999-07-19 03:34:37 UTC
# Landsat-8 catalog #25682 epoch 1999-07-20 04:17:53 UTC
# Landsat-8 catalog #25682 epoch 1999-07-21 03:22:15 UTC
# Landsat-8 catalog #25682 epoch 1999-07-22 04:05:31 UTC
# Landsat-8 catalog #25682 epoch 1999-07-23 04:48:47 UTC
# Landsat-8 catalog #25682 epoch 1999-07-24 03:53:11 UTC
# Landsat-8 catalog #25682 epoch 1999-07-25 04:36:27 UTC
# Landsat-8 catalog #25682 epoch 1999-07-26 03:40:51 UTC
# Landsat-8 catalog #25682 epoch 1999-07-27 04:24:08 UTC
# Landsat-8 catalog #25682 epoch 1999-07-28 05:07:24 UTC
# Landsat-8 catalog #25682 epoch 1999-07-29 04:11:47 UTC
# Landsat-8 catalog #25682 epoch 1999-07-30 03:16:10 UTC
# Landsat-8 catalog #25682 epoch 1999-07-31 03:59:27 UTC
# Landsat-8 catalog #25682 epoch 1999-08-01 03:03:50 UTC
# Landsat-8 catalog #25682 epoch 1999-08-02 03:47:06 UTC
# Landsat-8 catalog #25682 epoch 1999-08-03 04:30:21 UTC
# Landsat-8 catalog #25682 epoch 1999-08-04 03:34:44 UTC
# Landsat-8 catalog #25682 epoch 1999-08-05 04:18:00 UTC
# Landsat-8 catalog #25682 epoch 1999-08-06 05:01:16 UTC
# Landsat-8 catalog #25682 epoch 1999-08-07 04:05:38 UTC
# Landsat-8 catalog #25682 epoch 1999-08-08 04:48:54 UTC
# Landsat-8 catalog #25682 epoch 1999-08-09 03:53:16 UTC
# Landsat-8 catalog #25682 epoch 1999-08-10 04:36:32 UTC
# Landsat-8 catalog #25682 epoch 1999-08-11 03:40:54 UTC
# Landsat-8 catalog #25682 epoch 1999-08-12 02:45:16 UTC
# Landsat-8 catalog #25682 epoch 1999-08-13 03:28:32 UTC
# Landsat-8 catalog #25682 epoch 1999-08-14 04:11:47 UTC
# Landsat-8 catalog #25682 epoch 1999-08-15 04:55:02 UTC
# Landsat-8 catalog #25682 epoch 1999-08-16 05:38:17 UTC
# Landsat-8 catalog #25682 epoch 1999-08-17 04:42:40 UTC
# Landsat-8 catalog #25682 epoch 1999-08-18 03:47:02 UTC
# Landsat-8 catalog #25682 epoch 1999-08-19 04:30:17 UTC
# Landsat-8 catalog #25682 epoch 1999-08-20 03:34:40 UTC
# Landsat-8 catalog #25682 epoch 1999-08-21 04:17:56 UTC
# Landsat-8 catalog #25682 epoch 1999-08-22 03:22:20 UTC
# Landsat-8 catalog #25682 epoch 1999-08-23 05:44:30 UTC
# Landsat-8 catalog #25682 epoch 1999-08-24 04:48:54 UTC
# Landsat-8 catalog #25682 epoch 1999-08-25 03:53:17 UTC
# Landsat-8 catalog #25682 epoch 1999-08-26 04:36:34 UTC
# Landsat-8 catalog #25682 epoch 1999-08-27 03:40:57 UTC
# Landsat-8 catalog #25682 epoch 1999-08-28 04:24:14 UTC
# Landsat-8 catalog #25682 epoch 1999-08-29 05:07:29 UTC
# Landsat-8 catalog #25682 epoch 1999-08-30 04:11:53 UTC
# Landsat-8 catalog #25682 epoch 1999-08-31 04:55:07 UTC
# Landsat-8 catalog #25682 epoch 1999-09-01 03:59:30 UTC
# Landsat-8 catalog #25682 epoch 1999-09-02 03:03:53 UTC
# Landsat-8 catalog #25682 epoch 1999-09-03 03:47:08 UTC
# Landsat-8 catalog #25682 epoch 1999-09-04 04:30:23 UTC
# Landsat-8 catalog #25682 epoch 1999-09-05 05:13:39 UTC
# Landsat-8 catalog #25682 epoch 1999-09-06 05:56:54 UTC
# Landsat-8 catalog #25682 epoch 1999-09-07 03:22:23 UTC
# Landsat-8 catalog #25682 epoch 1999-09-08 04:05:38 UTC
# Landsat-8 catalog #25682 epoch 1999-09-09 04:48:53 UTC
# Landsat-8 catalog #25682 epoch 1999-09-10 03:53:15 UTC
# Landsat-8 catalog #25682 epoch 1999-09-11 04:36:30 UTC
# Landsat-8 catalog #25682 epoch 1999-09-12 03:40:52 UTC
# Landsat-8 catalog #25682 epoch 1999-09-13 04:24:07 UTC
# Landsat-8 catalog #25682 epoch 1999-09-14 05:07:22 UTC
# Landsat-8 catalog #25682 epoch 1999-09-15 04:11:44 UTC
# Landsat-8 catalog #25682 epoch 1999-09-16 04:54:59 UTC
# Landsat-8 catalog #25682 epoch 1999-09-17 03:59:22 UTC
# Landsat-8 catalog #25682 epoch 1999-09-18 03:03:46 UTC
# Landsat-8 catalog #25682 epoch 1999-09-19 03:47:03 UTC
# Landsat-8 catalog #25682 epoch 1999-09-20 04:30:21 UTC
# Landsat-8 catalog #25682 epoch 1999-09-21 03:34:45 UTC
# Landsat-8 catalog #25682 epoch 1999-09-22 04:18:02 UTC
# Landsat-8 catalog #25682 epoch 1999-09-23 05:01:18 UTC
# Landsat-8 catalog #25682 epoch 1999-09-24 04:05:42 UTC
# Landsat-8 catalog #25682 epoch 1999-09-25 04:48:58 UTC
# Landsat-8 catalog #25682 epoch 1999-09-26 05:32:14 UTC
# Landsat-8 catalog #25682 epoch 1999-09-27 04:36:38 UTC
# Landsat-8 catalog #25682 epoch 1999-09-28 05:19:54 UTC
# Landsat-8 catalog #25682 epoch 1999-09-29 04:24:17 UTC
# Landsat-8 catalog #25682 epoch 1999-09-30 03:28:40 UTC
# Landsat-8 catalog #25682 epoch 1999-10-01 05:50:49 UTC
# Landsat-8 catalog #25682 epoch 1999-10-02 04:55:12 UTC
# Landsat-8 catalog #25682 epoch 1999-10-03 05:38:28 UTC
# Landsat-8 catalog #25682 epoch 1999-10-04 04:42:51 UTC
# Landsat-8 catalog #25682 epoch 1999-10-05 03:47:14 UTC
# Landsat-8 catalog #25682 epoch 1999-10-06 06:09:23 UTC
# Landsat-8 catalog #25682 epoch 1999-10-07 03:34:52 UTC
# Landsat-8 catalog #25682 epoch 1999-10-08 04:18:08 UTC
# Landsat-8 catalog #25682 epoch 1999-10-09 03:22:30 UTC
# Landsat-8 catalog #25682 epoch 1999-10-10 04:05:46 UTC
# Landsat-8 catalog #25682 epoch 1999-10-11 04:49:01 UTC
# Landsat-8 catalog #25682 epoch 1999-10-12 03:53:23 UTC
# Landsat-8 catalog #25682 epoch 1999-10-13 01:18:53 UTC
# Landsat-8 catalog #25682 epoch 1999-10-14 05:19:53 UTC
# Landsat-8 catalog #25682 epoch 1999-10-15 04:24:15 UTC
# Landsat-8 catalog #25682 epoch 1999-10-16 03:28:37 UTC
# Landsat-8 catalog #25682 epoch 1999-10-17 04:11:51 UTC
# Landsat-8 catalog #25682 epoch 1999-10-18 04:55:06 UTC
# Landsat-8 catalog #25682 epoch 1999-10-19 03:59:27 UTC
# Landsat-8 catalog #25682 epoch 1999-10-20 03:03:49 UTC
# Landsat-8 catalog #25682 epoch 1999-10-21 03:47:03 UTC
# Landsat-8 catalog #25682 epoch 1999-10-22 06:09:10 UTC
# Landsat-8 catalog #25682 epoch 1999-10-23 05:13:34 UTC
# Landsat-8 catalog #25682 epoch 1999-10-24 04:17:57 UTC
# Landsat-8 catalog #25682 epoch 1999-10-25 03:22:20 UTC
# Landsat-8 catalog #25682 epoch 1999-10-26 04:05:36 UTC
# Landsat-8 catalog #25682 epoch 1999-10-27 04:48:52 UTC
# Landsat-8 catalog #25682 epoch 1999-10-28 03:53:15 UTC
# Landsat-8 catalog #25682 epoch 1999-10-29 02:57:38 UTC
# Landsat-8 catalog #25682 epoch 1999-10-30 03:40:54 UTC
# Landsat-8 catalog #25682 epoch 1999-10-31 06:03:02 UTC
# Landsat-8 catalog #25682 epoch 1999-11-01 05:07:25 UTC
# Landsat-8 catalog #25682 epoch 1999-11-02 04:11:47 UTC
# Landsat-8 catalog #25682 epoch 1999-11-03 04:55:03 UTC
# Landsat-8 catalog #25682 epoch 1999-11-04 05:38:18 UTC
# Landsat-8 catalog #25682 epoch 1999-11-05 04:42:41 UTC
# Landsat-8 catalog #25682 epoch 1999-11-06 00:29:18 UTC
# Landsat-8 catalog #25682 epoch 1999-11-07 04:30:21 UTC
# Landsat-8 catalog #25682 epoch 1999-11-08 05:13:38 UTC
# Landsat-8 catalog #25682 epoch 1999-11-09 04:18:01 UTC
# Landsat-8 catalog #25682 epoch 1999-11-10 05:01:16 UTC
# Landsat-8 catalog #25682 epoch 1999-11-11 04:05:38 UTC
# Landsat-8 catalog #25682 epoch 1999-11-12 04:48:52 UTC
# Landsat-8 catalog #25682 epoch 1999-11-13 03:53:15 UTC
# Landsat-8 catalog #25682 epoch 1999-11-14 04:36:31 UTC
# Landsat-8 catalog #25682 epoch 1999-11-15 03:40:54 UTC
# Landsat-8 catalog #25682 epoch 1999-11-16 04:24:10 UTC
# Landsat-8 catalog #25682 epoch 1999-11-17 05:07:25 UTC
# Landsat-8 catalog #25682 epoch 1999-11-18 04:11:47 UTC
# Landsat-8 catalog #25682 epoch 1999-11-19 04:55:02 UTC
# Landsat-8 catalog #25682 epoch 1999-11-20 05:38:17 UTC
# Landsat-8 catalog #25682 epoch 1999-11-21 04:42:38 UTC
# Landsat-8 catalog #25682 epoch 1999-11-22 03:47:00 UTC
# Landsat-8 catalog #25682 epoch 1999-11-23 04:30:14 UTC
# Landsat-8 catalog #25682 epoch 1999-11-24 05:13:28 UTC
# Landsat-8 catalog #25682 epoch 1999-11-25 04:17:52 UTC
# Landsat-8 catalog #25682 epoch 1999-11-26 05:01:08 UTC
# Landsat-8 catalog #25682 epoch 1999-11-27 05:44:23 UTC
# Landsat-8 catalog #25682 epoch 1999-11-28 04:48:46 UTC
# Landsat-8 catalog #25682 epoch 1999-11-29 03:53:09 UTC
# Landsat-8 catalog #25682 epoch 1999-11-30 04:36:24 UTC
# Landsat-8 catalog #25682 epoch 1999-12-01 05:19:40 UTC
# Landsat-8 catalog #25682 epoch 1999-12-02 04:24:04 UTC
# Landsat-8 catalog #25682 epoch 1999-12-03 05:07:21 UTC
# Landsat-8 catalog #25682 epoch 1999-12-04 04:11:45 UTC
# Landsat-8 catalog #25682 epoch 1999-12-05 04:55:02 UTC
# Landsat-8 catalog #25682 epoch 1999-12-06 03:59:26 UTC
# Landsat-8 catalog #25682 epoch 1999-12-07 04:42:43 UTC
# Landsat-8 catalog #25682 epoch 1999-12-08 03:47:06 UTC
# Landsat-8 catalog #25682 epoch 1999-12-09 04:30:23 UTC
# Landsat-8 catalog #25682 epoch 1999-12-10 05:13:39 UTC
# Landsat-8 catalog #25682 epoch 1999-12-11 04:18:02 UTC
# Landsat-8 catalog #25682 epoch 1999-12-12 05:01:18 UTC
# Landsat-8 catalog #25682 epoch 1999-12-13 04:05:41 UTC
# Landsat-8 catalog #25682 epoch 1999-12-14 04:48:57 UTC
# Landsat-8 catalog #25682 epoch 1999-12-15 05:32:13 UTC
# Landsat-8 catalog #25682 epoch 1999-12-16 04:36:35 UTC
# Landsat-8 catalog #25682 epoch 1999-12-17 05:19:51 UTC
# Landsat-8 catalog #25682 epoch 1999-12-18 04:24:13 UTC
# Landsat-8 catalog #25682 epoch 1999-12-19 05:07:28 UTC
# Landsat-8 catalog #25682 epoch 1999-12-20 04:11:50 UTC
# Landsat-8 catalog #25682 epoch 1999-12-21 04:55:05 UTC
# Landsat-8 catalog #25682 epoch 1999-12-22 05:38:20 UTC
# Landsat-8 catalog #25682 epoch 1999-12-23 04:42:42 UTC
# Landsat-8 catalog #25682 epoch 1999-12-24 05:25:56 UTC
# Landsat-8 catalog #25682 epoch 1999-12-25 04:30:18 UTC
# Landsat-8 catalog #25682 epoch 1999-12-26 05:13:32 UTC
# Landsat-8 catalog #25682 epoch 1999-12-27 04:17:54 UTC
# Landsat-8 catalog #25682 epoch 1999-12-28 05:01:08 UTC
# Landsat-8 catalog #25682 epoch 1999-12-29 02:26:36 UTC
# Landsat-8 catalog #25682 epoch 1999-12-30 04:48:45 UTC
# Landsat-8 catalog #25682 epoch 1999-12-31 05:32:03 UTC
# Landsat-8 catalog #25682 epoch 2000-01-01 02:57:33 UTC
# Landsat-8 catalog #25682 epoch 2000-01-02 05:19:42 UTC
# Landsat-8 catalog #25682 epoch 2000-01-03 04:24:05 UTC
# Landsat-8 catalog #25682 epoch 2000-01-04 05:07:21 UTC
# Landsat-8 catalog #25682 epoch 2000-01-05 04:11:44 UTC
# Landsat-8 catalog #25682 epoch 2000-01-06 04:55:00 UTC
# Landsat-8 catalog #25682 epoch 2000-01-07 03:59:23 UTC
# Landsat-8 catalog #25682 epoch 2000-01-08 04:42:39 UTC
# Landsat-8 catalog #25682 epoch 2000-01-09 05:25:55 UTC
# Landsat-8 catalog #25682 epoch 2000-01-10 04:30:17 UTC
# Landsat-8 catalog #25682 epoch 2000-01-11 05:13:33 UTC
# Landsat-8 catalog #25682 epoch 2000-01-12 04:17:56 UTC
# Landsat-8 catalog #25682 epoch 2000-01-13 05:01:11 UTC
# Landsat-8 catalog #25682 epoch 2000-01-14 04:05:33 UTC
# Landsat-8 catalog #25682 epoch 2000-01-15 03:09:56 UTC
# Landsat-8 catalog #25682 epoch 2000-01-16 03:53:11 UTC
# Landsat-8 catalog #25682 epoch 2000-01-17 04:36:26 UTC
# Landsat-8 catalog #25682 epoch 2000-01-18 05:19:40 UTC
# Landsat-8 catalog #25682 epoch 2000-01-19 04:24:02 UTC
# Landsat-8 catalog #25682 epoch 2000-01-20 05:07:19 UTC
# Landsat-8 catalog #25682 epoch 2000-01-21 00:53:56 UTC
# Landsat-8 catalog #25682 epoch 2000-01-22 03:16:05 UTC
# Landsat-8 catalog #25682 epoch 2000-01-23 03:59:21 UTC
# Landsat-8 catalog #25682 epoch 2000-01-24 04:42:37 UTC
# Landsat-8 catalog #25682 epoch 2000-01-25 03:47:00 UTC
# Landsat-8 catalog #25682 epoch 2000-01-26 04:30:15 UTC
# Landsat-8 catalog #25682 epoch 2000-01-27 05:13:31 UTC
# Landsat-8 catalog #25682 epoch 2000-01-28 04:17:54 UTC
# Landsat-8 catalog #25682 epoch 2000-01-29 05:01:09 UTC
# Landsat-8 catalog #25682 epoch 2000-01-30 04:05:32 UTC
# Landsat-8 catalog #25682 epoch 2000-01-31 04:48:47 UTC
# Landsat-8 catalog #25682 epoch 2000-02-01 05:32:03 UTC
# Landsat-8 catalog #25682 epoch 2000-02-02 04:36:25 UTC
# Landsat-8 catalog #25682 epoch 2000-02-03 05:19:41 UTC
# Landsat-8 catalog #25682 epoch 2000-02-04 04:24:03 UTC
# Landsat-8 catalog #25682 epoch 2000-02-05 05:07:18 UTC
# Landsat-8 catalog #25682 epoch 2000-02-06 05:50:33 UTC
# Landsat-8 catalog #25682 epoch 2000-02-07 04:54:55 UTC
# Landsat-8 catalog #25682 epoch 2000-02-08 13:52:35 UTC
# Landsat-8 catalog #25682 epoch 2000-02-09 04:42:32 UTC
# Landsat-8 catalog #25682 epoch 2000-02-10 03:46:54 UTC
# Landsat-8 catalog #25682 epoch 2000-02-11 04:30:11 UTC
# Landsat-8 catalog #25682 epoch 2000-02-12 05:13:27 UTC
# Landsat-8 catalog #25682 epoch 2000-02-13 05:56:42 UTC
# Landsat-8 catalog #25682 epoch 2000-02-14 05:01:05 UTC
# Landsat-8 catalog #25682 epoch 2000-02-15 04:05:27 UTC
# Landsat-8 catalog #25682 epoch 2000-02-16 04:48:42 UTC
# Landsat-8 catalog #25682 epoch 2000-02-17 03:53:04 UTC
# Landsat-8 catalog #25682 epoch 2000-02-18 04:36:19 UTC
# Landsat-8 catalog #25682 epoch 2000-02-19 05:19:34 UTC
# Landsat-8 catalog #25682 epoch 2000-02-20 04:23:55 UTC
# Landsat-8 catalog #25682 epoch 2000-02-21 05:07:10 UTC
# Landsat-8 catalog #25682 epoch 2000-02-22 05:50:25 UTC
# Landsat-8 catalog #25682 epoch 2000-02-23 04:54:46 UTC
# Landsat-8 catalog #25682 epoch 2000-02-24 05:38:03 UTC
# Landsat-8 catalog #25682 epoch 2000-02-25 04:42:26 UTC
# Landsat-8 catalog #25682 epoch 2000-02-26 03:46:49 UTC
# Landsat-8 catalog #25682 epoch 2000-02-27 04:30:05 UTC
# Landsat-8 catalog #25682 epoch 2000-02-28 05:13:21 UTC
# Landsat-8 catalog #25682 epoch 2000-02-29 05:56:37 UTC
# Landsat-8 catalog #25682 epoch 2000-03-01 05:00:59 UTC
# Landsat-8 catalog #25682 epoch 2000-03-02 05:44:15 UTC
# Landsat-8 catalog #25682 epoch 2000-03-03 04:48:37 UTC
# Landsat-8 catalog #25682 epoch 2000-03-04 03:52:59 UTC
# Landsat-8 catalog #25682 epoch 2000-03-05 04:36:14 UTC
# Landsat-8 catalog #25682 epoch 2000-03-06 03:40:36 UTC
# Landsat-8 catalog #25682 epoch 2000-03-07 04:23:50 UTC
# Landsat-8 catalog #25682 epoch 2000-03-08 05:07:05 UTC
# Landsat-8 catalog #25682 epoch 2000-03-09 00:53:42 UTC
# Landsat-8 catalog #25682 epoch 2000-03-10 04:54:45 UTC
# Landsat-8 catalog #25682 epoch 2000-03-11 02:20:15 UTC
# Landsat-8 catalog #25682 epoch 2000-03-12 01:24:38 UTC
# Landsat-8 catalog #25682 epoch 2000-03-13 03:46:45 UTC
# Landsat-8 catalog #25682 epoch 2000-03-14 04:30:01 UTC
# Landsat-8 catalog #25682 epoch 2000-03-15 03:34:23 UTC
# Landsat-8 catalog #25682 epoch 2000-03-16 04:17:40 UTC
# Landsat-8 catalog #25682 epoch 2000-03-17 05:00:56 UTC
# Landsat-8 catalog #25682 epoch 2000-03-18 04:05:19 UTC
# Landsat-8 catalog #25682 epoch 2000-03-19 04:48:35 UTC
# Landsat-8 catalog #25682 epoch 2000-03-20 05:31:51 UTC
# Landsat-8 catalog #25682 epoch 2000-03-21 04:36:14 UTC
# Landsat-8 catalog #25682 epoch 2000-03-22 03:40:37 UTC
# Landsat-8 catalog #25682 epoch 2000-03-23 04:23:53 UTC
# Landsat-8 catalog #25682 epoch 2000-03-24 05:07:08 UTC
# Landsat-8 catalog #25682 epoch 2000-03-25 04:11:30 UTC
# Landsat-8 catalog #25682 epoch 2000-03-26 04:54:45 UTC
# Landsat-8 catalog #25682 epoch 2000-03-27 03:59:07 UTC
# Landsat-8 catalog #25682 epoch 2000-03-28 04:42:21 UTC
# Landsat-8 catalog #25682 epoch 2000-03-29 03:46:43 UTC
# Landsat-8 catalog #25682 epoch 2000-03-30 04:29:58 UTC
# Landsat-8 catalog #25682 epoch 2000-03-31 01:55:28 UTC
# Landsat-8 catalog #25682 epoch 2000-04-01 04:17:36 UTC
# Landsat-8 catalog #25682 epoch 2000-04-02 05:00:51 UTC
# Landsat-8 catalog #25682 epoch 2000-04-03 04:05:13 UTC
# Landsat-8 catalog #25682 epoch 2000-04-04 04:48:27 UTC
# Landsat-8 catalog #25682 epoch 2000-04-05 03:52:48 UTC
# Landsat-8 catalog #25682 epoch 2000-04-06 02:57:11 UTC
# Landsat-8 catalog #25682 epoch 2000-04-07 03:40:26 UTC
# Landsat-8 catalog #25682 epoch 2000-04-08 02:44:48 UTC
# Landsat-8 catalog #25682 epoch 2000-04-09 03:28:02 UTC
# Landsat-8 catalog #25682 epoch 2000-04-10 04:11:16 UTC
# Landsat-8 catalog #25682 epoch 2000-04-11 03:15:38 UTC
# Landsat-8 catalog #25682 epoch 2000-04-12 03:58:51 UTC
# Landsat-8 catalog #25682 epoch 2000-04-13 04:42:08 UTC
# Landsat-8 catalog #25682 epoch 2000-04-14 03:46:30 UTC
# Landsat-8 catalog #25682 epoch 2000-04-15 02:50:52 UTC

# %%
# calculate delta t 
deltaT=timescales.utc[5,1]-timescales.utc[5,0]

# %% [markdown]
# ### Save all params of one year orbit

# %%
year_lon=[]
year_lat=[]
for i in range(len(subpoints)):
    year_lon.append(subpoints[i].longitude.degrees)
    year_lat.append(subpoints[i].latitude.degrees)

# %%
delta_T=np.full(np.shape(year_lat),deltaT)

# %%
sunlit=np.array(sunlit)

# %%
FOMtime=np.zeros(55)

# %%
year_lon=np.array(year_lon)
year_lat=np.array(year_lat)

# %%
len(year_lat[0])
# Out:
# 10000

# %%
fomvals=[]
for i in range(len(year_lat)):
    for j in range(len(year_lat[0])):
        orbpix=hp.ang2pix(nside,year_lon[i,j],year_lat[i,j],lonlat=True)
        fomval=int(FOM_map[orbpix])
        if sunlit[i,j]==True:
            FOMtime[fomval]+=0
        else:
            FOMtime[fomval]+=deltaT

# %%
fomvals=np.linspace(0,55,55)

# %%
plt.scatter(fomvals,(FOMtime/3600))
plt.show()

# %% [markdown]
# ## FOM values along the orbit

# %%
orbitfom=[]
for i in orbitpix:
	num_of_rfi_chan=len(freq_range[power_output[0,i,:]!=0])
	rfi_band=0.244*num_of_rfi_chan 
	usable_band=tot_band-rfi_band
	orbitfom.append(usable_band)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 orbitfom=[]
# ----> 2 for i in orbitpix:
#       3 	num_of_rfi_chan=len(freq_range[power_output[0,i,:]!=0])
#       4 	rfi_band=0.244*num_of_rfi_chan
#
# NameError: name 'orbitpix' is not defined

# %%
orbitfom=np.array(orbitfom)
goodpix=orbitpix[np.where(orbitfom>50)]

# %%
# quietlon,quietlat=hp.pix2ang(nside,goodpix,lonlat=True)
# quietlon[quietlon>180]-=360
# quietdf=pd.DataFrame({'Lon':quietlon,'Lat':quietlat})
# quietdf.to_csv('/home/saurabhs/Documents/Yogen_starfire/quitpoints.csv')

# %% [markdown]
# ## Plot Healpy map of brightness temperature of RFI

# %%
test_plot1 = np.zeros(hp.nside2npix(nside)) 
test_plot1[0:np.size(power_output[2,:,150])] = power_output[0,:,180]
hp.mollview(test_plot1,cmap='plasma',unit="in Kelvin",norm='hist',flip='geo',format= '%.8e')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()
plt.show()

# %%
freq_range[190]

# %%
powercube_df=pd.DataFrame(power_output[0,:,:])
# powercube_df.to_csv('/home/saurabhs/Documents/Yogen_starfire/RFInosynth_cubeLeo')

# %%
execution_time = end_time - start_time

print(f"Execution time: {execution_time} seconds")

# %% [markdown]
# ## RFI power recieved in different orbits

# %% [markdown]
# ## Polar orbit RFI waterfall plots

# %%
# Set time resolution
# Average velocity of satellite in LEO is ~8 km/s
time_res=10000
polat=np.linspace(-90,90,time_res)
polon=np.zeros(len(polat))
# Define trajectory pixels
pol_traj_pix=hp.ang2pix(nside,polon,polat,lonlat=True)

# %%
# waterfall plots of pixel vs frequency and power as the weight
x=freq_range
y=polat
xx,yy=np.meshgrid(x,y)
power_val=np.zeros((len(pol_traj_pix),len(x)))
for i in range(len(x)):
    for index,j in enumerate(pol_traj_pix):
        power_val[index,i]+=power_output[0,j,i]

# %%
plt.pcolormesh(xx,yy,power_val,cmap='viridis',norm='log',vmin=1,rasterized=True)
plt.xlabel('Frequency(MHz)')
plt.ylabel('Latitude in degrees')
plt.colorbar()
# plt.savefig('/home/saurabhs/Documents/Yogen_starfire/SF_images/polar_waterfall.pdf',dpi=600,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Equatorial orbit RFI waterfall plots

# %%
# Set time resolution
# Average velocity of satellite in LEO is ~8 km/s
time_res=10000
eqlon=np.linspace(-180,180,time_res)
eqlat=np.zeros(len(eqlon))

# Define trajectory pixels
eq_traj_pix=hp.ang2pix(nside,eqlon,eqlat,lonlat=True)

# %%
# waterfall plots of pixel vs frequency and power as the weight
x=freq_range
y=eqlon
xx,yy=np.meshgrid(x,y)
power_val=np.zeros((len(eq_traj_pix),len(x)))
for i in range(len(x)):
    for index,j in enumerate(eq_traj_pix):
        power_val[index,i]+=power_output[0,j,i]

# %%
plt.pcolormesh(yy,xx,power_val,cmap='viridis',norm='log',vmin=1e0,rasterized=True)
plt.colorbar()
plt.xlabel('Longitude in degrees')
plt.ylabel('Frequency(MHz)')
# plt.savefig('/home/saurabhs/Documents/Yogen_starfire/SF_images/equisynth_waterfall_1.pdf',dpi=600,bbox_inches='tight')
plt.show()

# %%
print(yy.shape,xx.shape,power_val.shape)

# plt.imshow(np.array([yy,xx,power_val]))

# %%
def shapecheck(lon,lat,name):
    checkpix=hp.ang2pix(nside,lon,lat,lonlat=True)
    checkmap=np.zeros(hp.nside2npix(nside))
    for pi in checkpix:
        checkmap[pi]+=1
    checkmap=np.where(checkmap != 0, 1, 0)
    return hp.mollview(checkmap,flip='geo',title=name,cmap='inferno')

# %%
eqlat=np.full((np.shape(eqlon)),-40)

shapecheck(eqlon,eqlat,'')

# %% [markdown]
# ## RFI freq summed power per pixel

# %% [markdown]
# ### Polar orbit

# %%
#GS for LEO
GS=np.zeros(len(freq_range))
for i in range(len(GS)):
    GS[i]+=np.mean(power_output[0,i,:])

# %%
plt.plot(freq_range,GS)
plt.show()

# %%
fomdf=pd.DataFrame({'FOM':FOM_map})

# %%
# fomdf.to_csv('/home/saurabhs/Documents/Yogen_starfire/FOM_Nosynth.csv')
