# %%
import pandas as pd

# %%
path='./database/updated_file_sweden.csv'

# %%
df=pd.read_csv(path)
df['popdens'] = None  # Initialize the new column with NaN values

# Assign a value to the first row in the new column
df.loc[0, 'popdens'] = 25.699778








  # You can replace 42 with the desired value

# %%
df.to_csv(path)
