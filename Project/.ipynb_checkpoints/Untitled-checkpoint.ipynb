# %%
import healpy as hp
import numpy as np
import pandas as pd

# %%
usa_data=pd.read_csv('./database/updated_USA_file_final.csv')

# %%
train_lon=usa_data['Longitude in degrees'].to_numpy()
train_lat=usa_data['Latitude in degrees'].to_numpy()
# train_pix=hp.ang2pix(128,train_lon,train_lat,lonlat=True)

# %%
# len(train_pix)

# %%
# lon_sample=np.random.choice(train_pix,size=5000)
long_sample=np.random.choice(train_lon,size=5000)
lati_sample=np.random.choice(train_lat,size=5000)

# %%
# test_lon,test_lat=hp.pix2ang(128,lon_sample,lonlat=True)
# test_lon[test_lon>180]-=360

# %%
data={'Lat':long_sample,'Lon':lati_sample}
df=pd.DataFrame(data)
df.to_csv('/home/pratush/Desktop/USA_training2.csv')

# %%
print(lon_sample)
