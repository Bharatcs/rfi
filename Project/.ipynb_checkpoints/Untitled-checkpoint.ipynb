# %%
import healpy as hp

# %%
# Out:
# (253.26923076923077, 61.18977627871704)

# %%
validpix = np.nonzero(template)[0] 
vallon,vallat=hp.pix2ang(128,validpix,lonlat=True)
for lon in vallon:
    if lon>180:
        lon=lon-360
