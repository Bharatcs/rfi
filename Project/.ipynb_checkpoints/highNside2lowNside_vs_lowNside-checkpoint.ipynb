# %%
##import libraries##
import numpy as np
import matplotlib.pyplot as plt
import tifffile as tiff
import healpy as hp

# %%
##Read the tif file##
image = tiff.imread('./gpw_v4_population_density_adjusted_to_2015_unwpp_country_totals_rev11_2020_15_min.tif')
image_array = np.array(image)

# %%
# Define the spherical coordinates#
theta = np.linspace(np.radians(0), np.radians(180), num=image_array.shape[0],endpoint=False)
phi = np.linspace(-np.radians(180), np.radians(180), num=image_array.shape[1],endpoint=False)

# Set angular resolution#
nside = 128

## Make empty healpix mask and pixel values vector##
healpix_map = np.zeros(hp.nside2npix(nside), dtype=np.double)
pixel_counts = np.zeros(hp.nside2npix(nside), dtype=int)

# %%
for i in range(len(theta)):
    for j in range(len(phi)):
        pixel = hp.ang2pix(nside, theta[i], phi[j])
        healpix_map[pixel] += image_array[i, j]
        pixel_counts[pixel] += 1

# Average value of each pixel#
healpix_map[pixel_counts>0] /= pixel_counts[pixel_counts>0 ]


hp.mollview(healpix_map, cmap="inferno", xsize=3000, flip="geo", norm="hist", min=0)
plt.show()
print(pixel_counts)
# Out:
# [887 887 887 ... 527 527 527]

# %%
degraded_128=hp.ud_grade(healpix_map,32)
hp.mollview(degraded_128,cmap="inferno", xsize=3000, flip="geo", norm="hist",min=0)

# %%
theta = np.linspace(np.radians(0), np.radians(180), num=image_array.shape[0],endpoint=False)
phi = np.linspace(-np.radians(180), np.radians(180), num=image_array.shape[1],endpoint=False)

# Set angular resolution#
nside_new = 16

## Make empty healpix mask and pixel values vector##
healpix_map_32 = np.zeros(hp.nside2npix(nside_new), dtype=np.double)
pixel_counts_32 = np.zeros(hp.nside2npix(nside_new), dtype=int)
for i in range(len(theta)):
    for j in range(len(phi)):
        pixel = hp.ang2pix(nside_new, theta[i], phi[j])
        healpix_map_32[pixel] += image_array[i, j]
        pixel_counts_32[pixel] += 1

# Average value of each pixel#
healpix_map_32[pixel_counts_32>0] /= pixel_counts_32[pixel_counts_32>0 ]


hp.mollview(healpix_map_32, cmap="inferno", xsize=3000, flip="geo", norm="hist", min=0)

# %%
healpix_map_32[healpix_map_32<0]=0
degraded_128[degraded_128<0]=0

# %%
diffmap=-1*(degraded_128-healpix_map_32)
hp.mollview(diffmap,cmap="inferno", xsize=3000, flip="geo", norm="hist",min=0)

# %%
diffmap=(degraded_128-healpix_map_32)
hp.mollview(diffmap,cmap="inferno", xsize=3000, flip="geo", norm="hist",min=0)

# %%
if np.array_equal(healpix_map_32, degraded_128):
    print('yes')
else:
    print('no')
nonzeromask=diffmap>0
nzdiff=diffmap[nonzeromask]
print(np.shape(nzdiff))
# Out:
# no
# (293,)

# %%
map32=0
degrad32=0
for i in range(len(diffmap)):
    if diffmap[i] > 0:
        print(f"Pixel {i} is from healpix_map_32.")
        map32+=1
    elif diffmap[i] < 0:
        print(f"Pixel {i} is from degraded_128.")
        degrad32+=1
    else:
        print(f"Pixel {i} has no difference.")
print(map32,degrad32)
# Out:
# Pixel 0 has no difference.
# Pixel 1 has no difference.
# Pixel 2 has no difference.
# Pixel 3 has no difference.
# Pixel 4 has no difference.
# Pixel 5 has no difference.
# Pixel 6 has no difference.
# Pixel 7 has no difference.
# Pixel 8 has no difference.
# Pixel 9 has no difference.
# Pixel 10 has no difference.
# Pixel 11 has no difference.
# Pixel 12 has no difference.
# Pixel 13 has no difference.
# Pixel 14 has no difference.
# Pixel 15 has no difference.
# Pixel 16 has no difference.
# Pixel 17 has no difference.
# Pixel 18 has no difference.
# Pixel 19 has no difference.
# Pixel 20 has no difference.
# Pixel 21 has no difference.
# Pixel 22 has no difference.
# Pixel 23 has no difference.
# Pixel 24 has no difference.
# Pixel 25 has no difference.
# Pixel 26 has no difference.
# Pixel 27 has no difference.
# Pixel 28 has no difference.
# Pixel 29 has no difference.
# Pixel 30 has no difference.
# Pixel 31 has no difference.
# Pixel 32 has no difference.
# Pixel 33 has no difference.
# Pixel 34 has no difference.
# Pixel 35 has no difference.
# Pixel 36 has no difference.
# Pixel 37 has no difference.
# Pixel 38 has no difference.
# Pixel 39 has no difference.
# Pixel 40 has no difference.
# Pixel 41 has no difference.
# Pixel 42 has no difference.
# Pixel 43 has no difference.
# Pixel 44 has no difference.
# Pixel 45 has no difference.
# Pixel 46 has no difference.
# Pixel 47 has no difference.
# Pixel 48 has no difference.
# Pixel 49 has no difference.
# Pixel 50 has no difference.
# Pixel 51 has no difference.
# Pixel 52 has no difference.
# Pixel 53 has no difference.
# Pixel 54 has no difference.
# Pixel 55 has no difference.
# Pixel 56 has no difference.
# Pixel 57 has no difference.
# Pixel 58 has no difference.
# Pixel 59 has no difference.
# Pixel 60 has no difference.
# Pixel 61 has no difference.
# Pixel 62 has no difference.
# Pixel 63 has no difference.
# Pixel 64 has no difference.
# Pixel 65 has no difference.
# Pixel 66 is from degraded_128.
# Pixel 67 has no difference.
# Pixel 68 has no difference.
# Pixel 69 has no difference.
# Pixel 70 has no difference.
# Pixel 71 has no difference.
# Pixel 72 has no difference.
# Pixel 73 has no difference.
# Pixel 74 has no difference.
# Pixel 75 has no difference.
# Pixel 76 has no difference.
# Pixel 77 has no difference.
# Pixel 78 has no difference.
# Pixel 79 has no difference.
# Pixel 80 has no difference.
# Pixel 81 has no difference.
# Pixel 82 has no difference.
# Pixel 83 has no difference.
# Pixel 84 has no difference.
# Pixel 85 has no difference.
# Pixel 86 has no difference.
# Pixel 87 has no difference.
# Pixel 88 has no difference.
# Pixel 89 has no difference.
# Pixel 90 is from healpix_map_32.
# Pixel 91 is from degraded_128.
# Pixel 92 is from degraded_128.
# Pixel 93 is from healpix_map_32.
# Pixel 94 has no difference.
# Pixel 95 has no difference.
# Pixel 96 has no difference.
# Pixel 97 has no difference.
# Pixel 98 has no difference.
# Pixel 99 has no difference.
# Pixel 100 has no difference.
# Pixel 101 has no difference.
# Pixel 102 has no difference.
# Pixel 103 has no difference.
# Pixel 104 has no difference.
# Pixel 105 has no difference.
# Pixel 106 has no difference.
# Pixel 107 has no difference.
# Pixel 108 is from degraded_128.
# Pixel 109 has no difference.
# Pixel 110 has no difference.
# Pixel 111 has no difference.
# Pixel 112 has no difference.
# Pixel 113 has no difference.
# Pixel 114 is from degraded_128.
# Pixel 115 has no difference.
# Pixel 116 has no difference.
# Pixel 117 is from healpix_map_32.
# Pixel 118 has no difference.
# Pixel 119 is from degraded_128.
# Pixel 120 is from degraded_128.
# Pixel 121 is from healpix_map_32.
# Pixel 122 is from healpix_map_32.
# Pixel 123 is from healpix_map_32.
# Pixel 124 is from healpix_map_32.
# Pixel 125 is from healpix_map_32.
# Pixel 126 is from degraded_128.
# Pixel 127 is from degraded_128.
# Pixel 128 has no difference.
# Pixel 129 has no difference.
# Pixel 130 is from healpix_map_32.
# Pixel 131 is from degraded_128.
# Pixel 132 is from degraded_128.
# Pixel 133 has no difference.
# Pixel 134 has no difference.
# Pixel 135 has no difference.
# Pixel 136 has no difference.
# Pixel 137 has no difference.
# Pixel 138 has no difference.
# Pixel 139 has no difference.
# Pixel 140 has no difference.
# Pixel 141 has no difference.
# Pixel 142 has no difference.
# Pixel 143 has no difference.
# Pixel 144 has no difference.
# Pixel 145 has no difference.
# Pixel 146 has no difference.
# Pixel 147 has no difference.
# Pixel 148 is from healpix_map_32.
# Pixel 149 is from degraded_128.
# Pixel 150 is from healpix_map_32.
# Pixel 151 is from healpix_map_32.
# Pixel 152 is from healpix_map_32.
# Pixel 153 is from degraded_128.
# Pixel 154 is from healpix_map_32.
# Pixel 155 is from healpix_map_32.
# Pixel 156 is from healpix_map_32.
# Pixel 157 is from healpix_map_32.
# Pixel 158 is from healpix_map_32.
# Pixel 159 is from healpix_map_32.
# Pixel 160 has no difference.
# Pixel 161 has no difference.
# Pixel 162 has no difference.
# Pixel 163 has no difference.
# Pixel 164 is from degraded_128.
# Pixel 165 is from degraded_128.
# Pixel 166 is from healpix_map_32.
# Pixel 167 is from degraded_128.
# Pixel 168 is from degraded_128.
# Pixel 169 is from healpix_map_32.
# Pixel 170 has no difference.
# Pixel 171 has no difference.
# Pixel 172 has no difference.
# Pixel 173 has no difference.
# Pixel 174 has no difference.
# Pixel 175 has no difference.
# Pixel 176 has no difference.
# Pixel 177 has no difference.
# Pixel 178 has no difference.
# Pixel 179 has no difference.
# Pixel 180 has no difference.
# Pixel 181 is from healpix_map_32.
# Pixel 182 has no difference.
# Pixel 183 has no difference.
# Pixel 184 is from healpix_map_32.
# Pixel 185 is from healpix_map_32.
# Pixel 186 is from healpix_map_32.
# Pixel 187 is from degraded_128.
# Pixel 188 is from degraded_128.
# Pixel 189 is from degraded_128.
# Pixel 190 is from healpix_map_32.
# Pixel 191 is from healpix_map_32.
# Pixel 192 is from degraded_128.
# Pixel 193 is from degraded_128.
# Pixel 194 is from degraded_128.
# Pixel 195 is from degraded_128.
# Pixel 196 has no difference.
# Pixel 197 has no difference.
# Pixel 198 has no difference.
# Pixel 199 has no difference.
# Pixel 200 has no difference.
# Pixel 201 has no difference.
# Pixel 202 has no difference.
# Pixel 203 has no difference.
# Pixel 204 has no difference.
# Pixel 205 is from degraded_128.
# Pixel 206 is from degraded_128.
# Pixel 207 is from healpix_map_32.
# Pixel 208 is from healpix_map_32.
# Pixel 209 has no difference.
# Pixel 210 has no difference.
# Pixel 211 has no difference.
# Pixel 212 has no difference.
# Pixel 213 has no difference.
# Pixel 214 has no difference.
# Pixel 215 has no difference.
# Pixel 216 has no difference.
# Pixel 217 has no difference.
# Pixel 218 has no difference.
# Pixel 219 has no difference.
# Pixel 220 has no difference.
# Pixel 221 has no difference.
# Pixel 222 has no difference.
# Pixel 223 has no difference.
# Pixel 224 is from healpix_map_32.
# Pixel 225 is from healpix_map_32.
# Pixel 226 is from healpix_map_32.
# Pixel 227 is from degraded_128.
# Pixel 228 is from healpix_map_32.
# Pixel 229 is from healpix_map_32.
# Pixel 230 is from healpix_map_32.
# Pixel 231 is from healpix_map_32.
# Pixel 232 is from healpix_map_32.
# Pixel 233 is from degraded_128.
# Pixel 234 is from degraded_128.
# Pixel 235 is from degraded_128.
# Pixel 236 has no difference.
# Pixel 237 has no difference.
# Pixel 238 has no difference.
# Pixel 239 has no difference.
# Pixel 240 has no difference.
# Pixel 241 has no difference.
# Pixel 242 has no difference.
# Pixel 243 has no difference.
# Pixel 244 has no difference.
# Pixel 245 has no difference.
# Pixel 246 has no difference.
# Pixel 247 has no difference.
# Pixel 248 is from healpix_map_32.
# Pixel 249 is from healpix_map_32.
# Pixel 250 is from healpix_map_32.
# Pixel 251 is from healpix_map_32.
# Pixel 252 has no difference.
# Pixel 253 has no difference.
# Pixel 254 has no difference.
# Pixel 255 is from degraded_128.
# Pixel 256 has no difference.
# Pixel 257 has no difference.
# Pixel 258 has no difference.
# Pixel 259 has no difference.
# Pixel 260 has no difference.
# Pixel 261 has no difference.
# Pixel 262 has no difference.
# Pixel 263 has no difference.
# Pixel 264 has no difference.
# Pixel 265 has no difference.
# Pixel 266 has no difference.
# Pixel 267 is from degraded_128.
# Pixel 268 is from healpix_map_32.
# Pixel 269 is from degraded_128.
# Pixel 270 is from healpix_map_32.
# Pixel 271 is from healpix_map_32.
# Pixel 272 is from degraded_128.
# Pixel 273 is from healpix_map_32.
# Pixel 274 is from healpix_map_32.
# Pixel 275 is from healpix_map_32.
# Pixel 276 is from degraded_128.
# Pixel 277 is from degraded_128.
# Pixel 278 is from healpix_map_32.
# Pixel 279 is from healpix_map_32.
# Pixel 280 is from healpix_map_32.
# Pixel 281 is from degraded_128.
# Pixel 282 has no difference.
# Pixel 283 has no difference.
# Pixel 284 has no difference.
# Pixel 285 has no difference.
# Pixel 286 has no difference.
# Pixel 287 has no difference.
# Pixel 288 has no difference.
# Pixel 289 has no difference.
# Pixel 290 has no difference.
# Pixel 291 has no difference.
# Pixel 292 has no difference.
# Pixel 293 has no difference.
# Pixel 294 has no difference.
# Pixel 295 is from healpix_map_32.
# Pixel 296 is from degraded_128.
# Pixel 297 is from healpix_map_32.
# Pixel 298 is from healpix_map_32.
# Pixel 299 is from healpix_map_32.
# Pixel 300 has no difference.
# Pixel 301 has no difference.
# Pixel 302 is from healpix_map_32.
# Pixel 303 is from healpix_map_32.
# Pixel 304 has no difference.
# Pixel 305 has no difference.
# Pixel 306 has no difference.
# Pixel 307 has no difference.
# Pixel 308 has no difference.
# Pixel 309 has no difference.
# Pixel 310 has no difference.
# Pixel 311 has no difference.
# Pixel 312 has no difference.
# Pixel 313 has no difference.
# Pixel 314 is from healpix_map_32.
# Pixel 315 is from healpix_map_32.
# Pixel 316 is from degraded_128.
# Pixel 317 is from healpix_map_32.
# Pixel 318 is from healpix_map_32.
# Pixel 319 is from healpix_map_32.
# Pixel 320 is from healpix_map_32.
# Pixel 321 is from degraded_128.
# Pixel 322 is from healpix_map_32.
# Pixel 323 is from healpix_map_32.
# Pixel 324 is from degraded_128.
# Pixel 325 is from degraded_128.
# Pixel 326 is from degraded_128.
# Pixel 327 is from healpix_map_32.
# Pixel 328 is from degraded_128.
# Pixel 329 is from degraded_128.
# Pixel 330 is from healpix_map_32.
# Pixel 331 is from healpix_map_32.
# Pixel 332 has no difference.
# Pixel 333 has no difference.
# Pixel 334 has no difference.
# Pixel 335 has no difference.
# Pixel 336 has no difference.
# Pixel 337 has no difference.
# Pixel 338 has no difference.
# Pixel 339 has no difference.
# Pixel 340 has no difference.
# Pixel 341 has no difference.
# Pixel 342 has no difference.
# Pixel 343 has no difference.
# Pixel 344 has no difference.
# Pixel 345 has no difference.
# Pixel 346 is from healpix_map_32.
# Pixel 347 is from healpix_map_32.
# Pixel 348 is from degraded_128.
# Pixel 349 is from degraded_128.
# Pixel 350 is from degraded_128.
# Pixel 351 is from degraded_128.
# Pixel 352 has no difference.
# Pixel 353 is from degraded_128.
# Pixel 354 has no difference.
# Pixel 355 has no difference.
# Pixel 356 has no difference.
# Pixel 357 has no difference.
# Pixel 358 has no difference.
# Pixel 359 has no difference.
# Pixel 360 has no difference.
# Pixel 361 has no difference.
# Pixel 362 has no difference.
# Pixel 363 has no difference.
# Pixel 364 has no difference.
# Pixel 365 is from healpix_map_32.
# Pixel 366 is from degraded_128.
# Pixel 367 is from degraded_128.
# Pixel 368 has no difference.
# Pixel 369 has no difference.
# Pixel 370 is from healpix_map_32.
# Pixel 371 has no difference.
# Pixel 372 is from healpix_map_32.
# Pixel 373 is from healpix_map_32.
# Pixel 374 is from healpix_map_32.
# Pixel 375 is from degraded_128.
# Pixel 376 is from healpix_map_32.
# Pixel 377 is from healpix_map_32.
# Pixel 378 is from healpix_map_32.
# Pixel 379 is from healpix_map_32.
# Pixel 380 is from healpix_map_32.
# Pixel 381 is from healpix_map_32.
# Pixel 382 is from degraded_128.
# Pixel 383 is from healpix_map_32.
# Pixel 384 is from degraded_128.
# Pixel 385 has no difference.
# Pixel 386 has no difference.
# Pixel 387 has no difference.
# Pixel 388 has no difference.
# Pixel 389 has no difference.
# Pixel 390 has no difference.
# Pixel 391 has no difference.
# Pixel 392 has no difference.
# Pixel 393 has no difference.
# Pixel 394 has no difference.
# Pixel 395 has no difference.
# Pixel 396 has no difference.
# Pixel 397 has no difference.
# Pixel 398 has no difference.
# Pixel 399 has no difference.
# Pixel 400 has no difference.
# Pixel 401 is from degraded_128.
# Pixel 402 is from healpix_map_32.
# Pixel 403 is from degraded_128.
# Pixel 404 is from degraded_128.
# Pixel 405 is from healpix_map_32.
# Pixel 406 is from degraded_128.
# Pixel 407 is from degraded_128.
# Pixel 408 is from healpix_map_32.
# Pixel 409 has no difference.
# Pixel 410 has no difference.
# Pixel 411 has no difference.
# Pixel 412 has no difference.
# Pixel 413 has no difference.
# Pixel 414 has no difference.
# Pixel 415 has no difference.
# Pixel 416 has no difference.
# Pixel 417 has no difference.
# Pixel 418 has no difference.
# Pixel 419 has no difference.
# Pixel 420 has no difference.
# Pixel 421 has no difference.
# Pixel 422 has no difference.
# Pixel 423 is from degraded_128.
# Pixel 424 has no difference.
# Pixel 425 has no difference.
# Pixel 426 has no difference.
# Pixel 427 has no difference.
# Pixel 428 has no difference.
# Pixel 429 is from healpix_map_32.
# Pixel 430 is from healpix_map_32.
# Pixel 431 is from healpix_map_32.
# Pixel 432 is from degraded_128.
# Pixel 433 is from degraded_128.
# Pixel 434 is from degraded_128.
# Pixel 435 is from degraded_128.
# Pixel 436 is from degraded_128.
# Pixel 437 is from degraded_128.
# Pixel 438 is from healpix_map_32.
# Pixel 439 is from healpix_map_32.
# Pixel 440 is from degraded_128.
# Pixel 441 is from healpix_map_32.
# Pixel 442 has no difference.
# Pixel 443 has no difference.
# Pixel 444 has no difference.
# Pixel 445 has no difference.
# Pixel 446 has no difference.
# Pixel 447 has no difference.
# Pixel 448 has no difference.
# Pixel 449 has no difference.
# Pixel 450 has no difference.
# Pixel 451 has no difference.
# Pixel 452 has no difference.
# Pixel 453 has no difference.
# Pixel 454 has no difference.
# Pixel 455 has no difference.
# Pixel 456 has no difference.
# Pixel 457 has no difference.
# Pixel 458 has no difference.
# Pixel 459 has no difference.
# Pixel 460 is from degraded_128.
# Pixel 461 is from degraded_128.
# Pixel 462 is from healpix_map_32.
# Pixel 463 is from degraded_128.
# Pixel 464 is from healpix_map_32.
# Pixel 465 is from healpix_map_32.
# Pixel 466 is from healpix_map_32.
# Pixel 467 is from degraded_128.
# Pixel 468 has no difference.
# Pixel 469 has no difference.
# Pixel 470 has no difference.
# Pixel 471 has no difference.
# Pixel 472 has no difference.
# Pixel 473 has no difference.
# Pixel 474 has no difference.
# Pixel 475 has no difference.
# Pixel 476 has no difference.
# Pixel 477 has no difference.
# Pixel 478 has no difference.
# Pixel 479 has no difference.
# Pixel 480 has no difference.
# Pixel 481 has no difference.
# Pixel 482 has no difference.
# Pixel 483 has no difference.
# Pixel 484 has no difference.
# Pixel 485 has no difference.
# Pixel 486 has no difference.
# Pixel 487 has no difference.
# Pixel 488 has no difference.
# Pixel 489 has no difference.
# Pixel 490 is from healpix_map_32.
# Pixel 491 is from healpix_map_32.
# Pixel 492 is from degraded_128.
# Pixel 493 is from healpix_map_32.
# Pixel 494 is from healpix_map_32.
# Pixel 495 is from healpix_map_32.
# Pixel 496 is from degraded_128.
# Pixel 497 is from healpix_map_32.
# Pixel 498 is from healpix_map_32.
# Pixel 499 is from degraded_128.
# Pixel 500 is from healpix_map_32.
# Pixel 501 has no difference.
# Pixel 502 is from degraded_128.
# Pixel 503 has no difference.
# Pixel 504 has no difference.
# Pixel 505 has no difference.
# Pixel 506 has no difference.
# Pixel 507 has no difference.
# Pixel 508 has no difference.
# Pixel 509 has no difference.
# Pixel 510 has no difference.
# Pixel 511 has no difference.
# Pixel 512 has no difference.
# Pixel 513 has no difference.
# Pixel 514 has no difference.
# Pixel 515 has no difference.
# Pixel 516 has no difference.
# Pixel 517 has no difference.
# Pixel 518 has no difference.
# Pixel 519 has no difference.
# Pixel 520 has no difference.
# Pixel 521 has no difference.
# Pixel 522 is from healpix_map_32.
# Pixel 523 is from healpix_map_32.
# Pixel 524 is from healpix_map_32.
# Pixel 525 is from healpix_map_32.
# Pixel 526 is from degraded_128.
# Pixel 527 is from healpix_map_32.
# Pixel 528 is from degraded_128.
# Pixel 529 is from healpix_map_32.
# Pixel 530 is from degraded_128.
# Pixel 531 has no difference.
# Pixel 532 has no difference.
# Pixel 533 has no difference.
# Pixel 534 has no difference.
# Pixel 535 has no difference.
# Pixel 536 has no difference.
# Pixel 537 has no difference.
# Pixel 538 has no difference.
# Pixel 539 has no difference.
# Pixel 540 has no difference.
# Pixel 541 has no difference.
# Pixel 542 has no difference.
# Pixel 543 has no difference.
# Pixel 544 has no difference.
# Pixel 545 has no difference.
# Pixel 546 has no difference.
# Pixel 547 has no difference.
# Pixel 548 has no difference.
# Pixel 549 has no difference.
# Pixel 550 has no difference.
# Pixel 551 has no difference.
# Pixel 552 is from healpix_map_32.
# Pixel 553 has no difference.
# Pixel 554 has no difference.
# Pixel 555 is from degraded_128.
# Pixel 556 is from healpix_map_32.
# Pixel 557 is from degraded_128.
# Pixel 558 is from healpix_map_32.
# Pixel 559 is from healpix_map_32.
# Pixel 560 is from degraded_128.
# Pixel 561 is from degraded_128.
# Pixel 562 is from degraded_128.
# Pixel 563 is from healpix_map_32.
# Pixel 564 is from degraded_128.
# Pixel 565 has no difference.
# Pixel 566 has no difference.
# Pixel 567 has no difference.
# Pixel 568 has no difference.
# Pixel 569 has no difference.
# Pixel 570 has no difference.
# Pixel 571 has no difference.
# Pixel 572 has no difference.
# Pixel 573 has no difference.
# Pixel 574 has no difference.
# Pixel 575 has no difference.
# Pixel 576 has no difference.
# Pixel 577 has no difference.
# Pixel 578 has no difference.
# Pixel 579 has no difference.
# Pixel 580 has no difference.
# Pixel 581 has no difference.
# Pixel 582 has no difference.
# Pixel 583 has no difference.
# Pixel 584 has no difference.
# Pixel 585 has no difference.
# Pixel 586 has no difference.
# Pixel 587 is from healpix_map_32.
# Pixel 588 is from healpix_map_32.
# Pixel 589 is from degraded_128.
# Pixel 590 is from healpix_map_32.
# Pixel 591 is from healpix_map_32.
# Pixel 592 is from healpix_map_32.
# Pixel 593 is from degraded_128.
# Pixel 594 is from degraded_128.
# Pixel 595 has no difference.
# Pixel 596 has no difference.
# Pixel 597 has no difference.
# Pixel 598 has no difference.
# Pixel 599 has no difference.
# Pixel 600 has no difference.
# Pixel 601 has no difference.
# Pixel 602 has no difference.
# Pixel 603 has no difference.
# Pixel 604 has no difference.
# Pixel 605 has no difference.
# Pixel 606 has no difference.
# Pixel 607 has no difference.
# Pixel 608 has no difference.
# Pixel 609 has no difference.
# Pixel 610 has no difference.
# Pixel 611 has no difference.
# Pixel 612 has no difference.
# Pixel 613 has no difference.
# Pixel 614 has no difference.
# Pixel 615 has no difference.
# Pixel 616 is from degraded_128.
# Pixel 617 has no difference.
# Pixel 618 is from degraded_128.
# Pixel 619 is from healpix_map_32.
# Pixel 620 is from healpix_map_32.
# Pixel 621 is from healpix_map_32.
# Pixel 622 is from degraded_128.
# Pixel 623 is from degraded_128.
# Pixel 624 is from healpix_map_32.
# Pixel 625 is from healpix_map_32.
# Pixel 626 is from healpix_map_32.
# Pixel 627 is from healpix_map_32.
# Pixel 628 is from degraded_128.
# Pixel 629 has no difference.
# Pixel 630 has no difference.
# Pixel 631 has no difference.
# Pixel 632 has no difference.
# Pixel 633 has no difference.
# Pixel 634 has no difference.
# Pixel 635 has no difference.
# Pixel 636 has no difference.
# Pixel 637 has no difference.
# Pixel 638 has no difference.
# Pixel 639 has no difference.
# Pixel 640 has no difference.
# Pixel 641 has no difference.
# Pixel 642 has no difference.
# Pixel 643 has no difference.
# Pixel 644 has no difference.
# Pixel 645 has no difference.
# Pixel 646 has no difference.
# Pixel 647 has no difference.
# Pixel 648 has no difference.
# Pixel 649 has no difference.
# Pixel 650 has no difference.
# Pixel 651 is from healpix_map_32.
# Pixel 652 is from healpix_map_32.
# Pixel 653 is from healpix_map_32.
# Pixel 654 is from degraded_128.
# Pixel 655 is from degraded_128.
# Pixel 656 is from healpix_map_32.
# Pixel 657 is from degraded_128.
# Pixel 658 has no difference.
# Pixel 659 has no difference.
# Pixel 660 has no difference.
# Pixel 661 has no difference.
# Pixel 662 has no difference.
# Pixel 663 has no difference.
# Pixel 664 has no difference.
# Pixel 665 has no difference.
# Pixel 666 has no difference.
# Pixel 667 has no difference.
# Pixel 668 has no difference.
# Pixel 669 has no difference.
# Pixel 670 has no difference.
# Pixel 671 has no difference.
# Pixel 672 is from degraded_128.
# Pixel 673 is from degraded_128.
# Pixel 674 has no difference.
# Pixel 675 has no difference.
# Pixel 676 has no difference.
# Pixel 677 has no difference.
# Pixel 678 has no difference.
# Pixel 679 is from degraded_128.
# Pixel 680 is from healpix_map_32.
# Pixel 681 is from degraded_128.
# Pixel 682 is from degraded_128.
# Pixel 683 is from degraded_128.
# Pixel 684 is from degraded_128.
# Pixel 685 is from degraded_128.
# Pixel 686 is from degraded_128.
# Pixel 687 is from healpix_map_32.
# Pixel 688 is from degraded_128.
# Pixel 689 is from healpix_map_32.
# Pixel 690 is from degraded_128.
# Pixel 691 is from healpix_map_32.
# Pixel 692 is from degraded_128.
# Pixel 693 is from healpix_map_32.
# Pixel 694 has no difference.
# Pixel 695 has no difference.
# Pixel 696 has no difference.
# Pixel 697 has no difference.
# Pixel 698 has no difference.
# Pixel 699 has no difference.
# Pixel 700 has no difference.
# Pixel 701 has no difference.
# Pixel 702 has no difference.
# Pixel 703 has no difference.
# Pixel 704 has no difference.
# Pixel 705 has no difference.
# Pixel 706 has no difference.
# Pixel 707 has no difference.
# Pixel 708 has no difference.
# Pixel 709 has no difference.
# Pixel 710 has no difference.
# Pixel 711 has no difference.
# Pixel 712 has no difference.
# Pixel 713 has no difference.
# Pixel 714 has no difference.
# Pixel 715 has no difference.
# Pixel 716 has no difference.
# Pixel 717 is from healpix_map_32.
# Pixel 718 is from healpix_map_32.
# Pixel 719 is from healpix_map_32.
# Pixel 720 is from degraded_128.
# Pixel 721 is from degraded_128.
# Pixel 722 has no difference.
# Pixel 723 has no difference.
# Pixel 724 has no difference.
# Pixel 725 has no difference.
# Pixel 726 has no difference.
# Pixel 727 has no difference.
# Pixel 728 has no difference.
# Pixel 729 has no difference.
# Pixel 730 has no difference.
# Pixel 731 has no difference.
# Pixel 732 has no difference.
# Pixel 733 has no difference.
# Pixel 734 has no difference.
# Pixel 735 is from degraded_128.
# Pixel 736 is from degraded_128.
# Pixel 737 is from healpix_map_32.
# Pixel 738 is from healpix_map_32.
# Pixel 739 has no difference.
# Pixel 740 has no difference.
# Pixel 741 has no difference.
# Pixel 742 is from healpix_map_32.
# Pixel 743 is from healpix_map_32.
# Pixel 744 has no difference.
# Pixel 745 is from healpix_map_32.
# Pixel 746 is from healpix_map_32.
# Pixel 747 is from healpix_map_32.
# Pixel 748 is from healpix_map_32.
# Pixel 749 is from healpix_map_32.
# Pixel 750 is from healpix_map_32.
# Pixel 751 is from healpix_map_32.
# Pixel 752 is from degraded_128.
# Pixel 753 is from degraded_128.
# Pixel 754 is from degraded_128.
# Pixel 755 is from healpix_map_32.
# Pixel 756 is from degraded_128.
# Pixel 757 has no difference.
# Pixel 758 has no difference.
# Pixel 759 has no difference.
# Pixel 760 has no difference.
# Pixel 761 has no difference.
# Pixel 762 has no difference.
# Pixel 763 has no difference.
# Pixel 764 has no difference.
# Pixel 765 has no difference.
# Pixel 766 has no difference.
# Pixel 767 has no difference.
# Pixel 768 has no difference.
# Pixel 769 has no difference.
# Pixel 770 has no difference.
# Pixel 771 has no difference.
# Pixel 772 has no difference.
# Pixel 773 has no difference.
# Pixel 774 has no difference.
# Pixel 775 has no difference.
# Pixel 776 has no difference.
# Pixel 777 has no difference.
# Pixel 778 has no difference.
# Pixel 779 has no difference.
# Pixel 780 is from degraded_128.
# Pixel 781 is from degraded_128.
# Pixel 782 is from degraded_128.
# Pixel 783 has no difference.
# Pixel 784 has no difference.
# Pixel 785 has no difference.
# Pixel 786 has no difference.
# Pixel 787 has no difference.
# Pixel 788 has no difference.
# Pixel 789 has no difference.
# Pixel 790 has no difference.
# Pixel 791 has no difference.
# Pixel 792 has no difference.
# Pixel 793 has no difference.
# Pixel 794 has no difference.
# Pixel 795 has no difference.
# Pixel 796 has no difference.
# Pixel 797 has no difference.
# Pixel 798 has no difference.
# Pixel 799 is from healpix_map_32.
# Pixel 800 is from healpix_map_32.
# Pixel 801 is from healpix_map_32.
# Pixel 802 is from degraded_128.
# Pixel 803 is from healpix_map_32.
# Pixel 804 is from degraded_128.
# Pixel 805 is from healpix_map_32.
# Pixel 806 has no difference.
# Pixel 807 is from degraded_128.
# Pixel 808 is from degraded_128.
# Pixel 809 has no difference.
# Pixel 810 has no difference.
# Pixel 811 has no difference.
# Pixel 812 is from healpix_map_32.
# Pixel 813 is from degraded_128.
# Pixel 814 is from degraded_128.
# Pixel 815 is from degraded_128.
# Pixel 816 is from healpix_map_32.
# Pixel 817 is from degraded_128.
# Pixel 818 is from healpix_map_32.
# Pixel 819 is from healpix_map_32.
# Pixel 820 is from degraded_128.
# Pixel 821 is from degraded_128.
# Pixel 822 has no difference.
# Pixel 823 has no difference.
# Pixel 824 has no difference.
# Pixel 825 has no difference.
# Pixel 826 has no difference.
# Pixel 827 has no difference.
# Pixel 828 has no difference.
# Pixel 829 has no difference.
# Pixel 830 has no difference.
# Pixel 831 has no difference.
# Pixel 832 has no difference.
# Pixel 833 has no difference.
# Pixel 834 has no difference.
# Pixel 835 has no difference.
# Pixel 836 has no difference.
# Pixel 837 has no difference.
# Pixel 838 has no difference.
# Pixel 839 has no difference.
# Pixel 840 has no difference.
# Pixel 841 has no difference.
# Pixel 842 has no difference.
# Pixel 843 has no difference.
# Pixel 844 has no difference.
# Pixel 845 is from healpix_map_32.
# Pixel 846 is from healpix_map_32.
# Pixel 847 has no difference.
# Pixel 848 has no difference.
# Pixel 849 has no difference.
# Pixel 850 has no difference.
# Pixel 851 has no difference.
# Pixel 852 has no difference.
# Pixel 853 has no difference.
# Pixel 854 has no difference.
# Pixel 855 has no difference.
# Pixel 856 has no difference.
# Pixel 857 has no difference.
# Pixel 858 has no difference.
# Pixel 859 has no difference.
# Pixel 860 has no difference.
# Pixel 861 has no difference.
# Pixel 862 has no difference.
# Pixel 863 is from healpix_map_32.
# Pixel 864 is from degraded_128.
# Pixel 865 is from degraded_128.
# Pixel 866 is from healpix_map_32.
# Pixel 867 is from healpix_map_32.
# Pixel 868 is from degraded_128.
# Pixel 869 is from degraded_128.
# Pixel 870 has no difference.
# Pixel 871 is from healpix_map_32.
# Pixel 872 is from healpix_map_32.
# Pixel 873 has no difference.
# Pixel 874 has no difference.
# Pixel 875 has no difference.
# Pixel 876 is from healpix_map_32.
# Pixel 877 is from healpix_map_32.
# Pixel 878 is from healpix_map_32.
# Pixel 879 is from healpix_map_32.
# Pixel 880 is from degraded_128.
# Pixel 881 is from degraded_128.
# Pixel 882 is from degraded_128.
# Pixel 883 is from degraded_128.
# Pixel 884 has no difference.
# Pixel 885 has no difference.
# Pixel 886 has no difference.
# Pixel 887 has no difference.
# Pixel 888 has no difference.
# Pixel 889 has no difference.
# Pixel 890 has no difference.
# Pixel 891 has no difference.
# Pixel 892 has no difference.
# Pixel 893 has no difference.
# Pixel 894 has no difference.
# Pixel 895 has no difference.
# Pixel 896 has no difference.
# Pixel 897 has no difference.
# Pixel 898 has no difference.
# Pixel 899 has no difference.
# Pixel 900 has no difference.
# Pixel 901 has no difference.
# Pixel 902 has no difference.
# Pixel 903 has no difference.
# Pixel 904 has no difference.
# Pixel 905 has no difference.
# Pixel 906 has no difference.
# Pixel 907 has no difference.
# Pixel 908 has no difference.
# Pixel 909 is from degraded_128.
# Pixel 910 has no difference.
# Pixel 911 has no difference.
# Pixel 912 has no difference.
# Pixel 913 has no difference.
# Pixel 914 has no difference.
# Pixel 915 has no difference.
# Pixel 916 has no difference.
# Pixel 917 has no difference.
# Pixel 918 has no difference.
# Pixel 919 has no difference.
# Pixel 920 has no difference.
# Pixel 921 has no difference.
# Pixel 922 has no difference.
# Pixel 923 has no difference.
# Pixel 924 has no difference.
# Pixel 925 has no difference.
# Pixel 926 is from healpix_map_32.
# Pixel 927 is from healpix_map_32.
# Pixel 928 is from healpix_map_32.
# Pixel 929 is from healpix_map_32.
# Pixel 930 is from healpix_map_32.
# Pixel 931 is from degraded_128.
# Pixel 932 is from degraded_128.
# Pixel 933 is from healpix_map_32.
# Pixel 934 is from degraded_128.
# Pixel 935 has no difference.
# Pixel 936 is from healpix_map_32.
# Pixel 937 is from degraded_128.
# Pixel 938 is from healpix_map_32.
# Pixel 939 has no difference.
# Pixel 940 has no difference.
# Pixel 941 has no difference.
# Pixel 942 is from degraded_128.
# Pixel 943 is from degraded_128.
# Pixel 944 has no difference.
# Pixel 945 is from degraded_128.
# Pixel 946 is from healpix_map_32.
# Pixel 947 has no difference.
# Pixel 948 has no difference.
# Pixel 949 has no difference.
# Pixel 950 has no difference.
# Pixel 951 has no difference.
# Pixel 952 has no difference.
# Pixel 953 has no difference.
# Pixel 954 has no difference.
# Pixel 955 has no difference.
# Pixel 956 has no difference.
# Pixel 957 has no difference.
# Pixel 958 has no difference.
# Pixel 959 has no difference.
# Pixel 960 has no difference.
# Pixel 961 has no difference.
# Pixel 962 has no difference.
# Pixel 963 has no difference.
# Pixel 964 has no difference.
# Pixel 965 has no difference.
# Pixel 966 has no difference.
# Pixel 967 has no difference.
# Pixel 968 has no difference.
# Pixel 969 has no difference.
# Pixel 970 has no difference.
# Pixel 971 has no difference.
# Pixel 972 has no difference.
# Pixel 973 has no difference.
# Pixel 974 is from healpix_map_32.
# Pixel 975 has no difference.
# Pixel 976 has no difference.
# Pixel 977 has no difference.
# Pixel 978 has no difference.
# Pixel 979 has no difference.
# Pixel 980 has no difference.
# Pixel 981 has no difference.
# Pixel 982 has no difference.
# Pixel 983 has no difference.
# Pixel 984 has no difference.
# Pixel 985 has no difference.
# Pixel 986 has no difference.
# Pixel 987 has no difference.
# Pixel 988 has no difference.
# Pixel 989 has no difference.
# Pixel 990 has no difference.
# Pixel 991 is from degraded_128.
# Pixel 992 is from healpix_map_32.
# Pixel 993 is from degraded_128.
# Pixel 994 is from degraded_128.
# Pixel 995 is from healpix_map_32.
# Pixel 996 is from degraded_128.
# Pixel 997 is from degraded_128.
# Pixel 998 has no difference.
# Pixel 999 has no difference.
# Pixel 1000 is from degraded_128.
# Pixel 1001 is from degraded_128.
# Pixel 1002 has no difference.
# Pixel 1003 has no difference.
# Pixel 1004 has no difference.
# Pixel 1005 is from degraded_128.
# Pixel 1006 is from healpix_map_32.
# Pixel 1007 has no difference.
# Pixel 1008 has no difference.
# Pixel 1009 is from healpix_map_32.
# Pixel 1010 has no difference.
# Pixel 1011 has no difference.
# Pixel 1012 has no difference.
# Pixel 1013 has no difference.
# Pixel 1014 has no difference.
# Pixel 1015 has no difference.
# Pixel 1016 has no difference.
# Pixel 1017 has no difference.
# Pixel 1018 has no difference.
# Pixel 1019 has no difference.
# Pixel 1020 has no difference.
# Pixel 1021 has no difference.
# Pixel 1022 has no difference.
# Pixel 1023 has no difference.
# Pixel 1024 has no difference.
# Pixel 1025 has no difference.
# Pixel 1026 has no difference.
# Pixel 1027 has no difference.
# Pixel 1028 has no difference.
# Pixel 1029 has no difference.
# Pixel 1030 has no difference.
# Pixel 1031 has no difference.
# Pixel 1032 has no difference.
# Pixel 1033 has no difference.
# Pixel 1034 has no difference.
# Pixel 1035 has no difference.
# Pixel 1036 has no difference.
# Pixel 1037 has no difference.
# Pixel 1038 has no difference.
# Pixel 1039 has no difference.
# Pixel 1040 has no difference.
# Pixel 1041 has no difference.
# Pixel 1042 has no difference.
# Pixel 1043 has no difference.
# Pixel 1044 has no difference.
# Pixel 1045 has no difference.
# Pixel 1046 has no difference.
# Pixel 1047 has no difference.
# Pixel 1048 has no difference.
# Pixel 1049 has no difference.
# Pixel 1050 has no difference.
# Pixel 1051 has no difference.
# Pixel 1052 has no difference.
# Pixel 1053 has no difference.
# Pixel 1054 is from degraded_128.
# Pixel 1055 is from degraded_128.
# Pixel 1056 is from degraded_128.
# Pixel 1057 is from healpix_map_32.
# Pixel 1058 is from degraded_128.
# Pixel 1059 is from degraded_128.
# Pixel 1060 is from healpix_map_32.
# Pixel 1061 is from healpix_map_32.
# Pixel 1062 is from degraded_128.
# Pixel 1063 has no difference.
# Pixel 1064 is from degraded_128.
# Pixel 1065 has no difference.
# Pixel 1066 has no difference.
# Pixel 1067 has no difference.
# Pixel 1068 has no difference.
# Pixel 1069 has no difference.
# Pixel 1070 is from degraded_128.
# Pixel 1071 has no difference.
# Pixel 1072 has no difference.
# Pixel 1073 has no difference.
# Pixel 1074 is from degraded_128.
# Pixel 1075 has no difference.
# Pixel 1076 has no difference.
# Pixel 1077 has no difference.
# Pixel 1078 has no difference.
# Pixel 1079 has no difference.
# Pixel 1080 has no difference.
# Pixel 1081 has no difference.
# Pixel 1082 has no difference.
# Pixel 1083 has no difference.
# Pixel 1084 has no difference.
# Pixel 1085 has no difference.
# Pixel 1086 has no difference.
# Pixel 1087 has no difference.
# Pixel 1088 has no difference.
# Pixel 1089 has no difference.
# Pixel 1090 has no difference.
# Pixel 1091 has no difference.
# Pixel 1092 has no difference.
# Pixel 1093 has no difference.
# Pixel 1094 has no difference.
# Pixel 1095 has no difference.
# Pixel 1096 has no difference.
# Pixel 1097 has no difference.
# Pixel 1098 has no difference.
# Pixel 1099 has no difference.
# Pixel 1100 has no difference.
# Pixel 1101 has no difference.
# Pixel 1102 has no difference.
# Pixel 1103 has no difference.
# Pixel 1104 has no difference.
# Pixel 1105 has no difference.
# Pixel 1106 has no difference.
# Pixel 1107 has no difference.
# Pixel 1108 has no difference.
# Pixel 1109 has no difference.
# Pixel 1110 has no difference.
# Pixel 1111 has no difference.
# Pixel 1112 has no difference.
# Pixel 1113 has no difference.
# Pixel 1114 has no difference.
# Pixel 1115 has no difference.
# Pixel 1116 has no difference.
# Pixel 1117 has no difference.
# Pixel 1118 is from degraded_128.
# Pixel 1119 is from healpix_map_32.
# Pixel 1120 is from healpix_map_32.
# Pixel 1121 is from healpix_map_32.
# Pixel 1122 is from healpix_map_32.
# Pixel 1123 is from healpix_map_32.
# Pixel 1124 is from healpix_map_32.
# Pixel 1125 is from degraded_128.
# Pixel 1126 is from degraded_128.
# Pixel 1127 has no difference.
# Pixel 1128 has no difference.
# Pixel 1129 has no difference.
# Pixel 1130 has no difference.
# Pixel 1131 has no difference.
# Pixel 1132 has no difference.
# Pixel 1133 has no difference.
# Pixel 1134 has no difference.
# Pixel 1135 has no difference.
# Pixel 1136 has no difference.
# Pixel 1137 has no difference.
# Pixel 1138 is from degraded_128.
# Pixel 1139 has no difference.
# Pixel 1140 has no difference.
# Pixel 1141 has no difference.
# Pixel 1142 has no difference.
# Pixel 1143 has no difference.
# Pixel 1144 has no difference.
# Pixel 1145 has no difference.
# Pixel 1146 has no difference.
# Pixel 1147 has no difference.
# Pixel 1148 has no difference.
# Pixel 1149 has no difference.
# Pixel 1150 has no difference.
# Pixel 1151 has no difference.
# Pixel 1152 has no difference.
# Pixel 1153 has no difference.
# Pixel 1154 has no difference.
# Pixel 1155 has no difference.
# Pixel 1156 has no difference.
# Pixel 1157 has no difference.
# Pixel 1158 has no difference.
# Pixel 1159 has no difference.
# Pixel 1160 has no difference.
# Pixel 1161 has no difference.
# Pixel 1162 has no difference.
# Pixel 1163 has no difference.
# Pixel 1164 has no difference.
# Pixel 1165 has no difference.
# Pixel 1166 has no difference.
# Pixel 1167 has no difference.
# Pixel 1168 has no difference.
# Pixel 1169 has no difference.
# Pixel 1170 has no difference.
# Pixel 1171 has no difference.
# Pixel 1172 has no difference.
# Pixel 1173 has no difference.
# Pixel 1174 has no difference.
# Pixel 1175 has no difference.
# Pixel 1176 has no difference.
# Pixel 1177 has no difference.
# Pixel 1178 has no difference.
# Pixel 1179 has no difference.
# Pixel 1180 has no difference.
# Pixel 1181 is from healpix_map_32.
# Pixel 1182 is from degraded_128.
# Pixel 1183 is from degraded_128.
# Pixel 1184 is from healpix_map_32.
# Pixel 1185 is from degraded_128.
# Pixel 1186 is from degraded_128.
# Pixel 1187 is from healpix_map_32.
# Pixel 1188 is from healpix_map_32.
# Pixel 1189 is from degraded_128.
# Pixel 1190 is from degraded_128.
# Pixel 1191 is from degraded_128.
# Pixel 1192 has no difference.
# Pixel 1193 has no difference.
# Pixel 1194 has no difference.
# Pixel 1195 has no difference.
# Pixel 1196 has no difference.
# Pixel 1197 has no difference.
# Pixel 1198 has no difference.
# Pixel 1199 has no difference.
# Pixel 1200 has no difference.
# Pixel 1201 has no difference.
# Pixel 1202 has no difference.
# Pixel 1203 has no difference.
# Pixel 1204 has no difference.
# Pixel 1205 has no difference.
# Pixel 1206 has no difference.
# Pixel 1207 has no difference.
# Pixel 1208 has no difference.
# Pixel 1209 has no difference.
# Pixel 1210 has no difference.
# Pixel 1211 has no difference.
# Pixel 1212 has no difference.
# Pixel 1213 has no difference.
# Pixel 1214 has no difference.
# Pixel 1215 has no difference.
# Pixel 1216 has no difference.
# Pixel 1217 has no difference.
# Pixel 1218 has no difference.
# Pixel 1219 has no difference.
# Pixel 1220 has no difference.
# Pixel 1221 has no difference.
# Pixel 1222 has no difference.
# Pixel 1223 has no difference.
# Pixel 1224 has no difference.
# Pixel 1225 has no difference.
# Pixel 1226 has no difference.
# Pixel 1227 has no difference.
# Pixel 1228 has no difference.
# Pixel 1229 has no difference.
# Pixel 1230 has no difference.
# Pixel 1231 has no difference.
# Pixel 1232 has no difference.
# Pixel 1233 has no difference.
# Pixel 1234 has no difference.
# Pixel 1235 has no difference.
# Pixel 1236 has no difference.
# Pixel 1237 has no difference.
# Pixel 1238 has no difference.
# Pixel 1239 has no difference.
# Pixel 1240 has no difference.
# Pixel 1241 has no difference.
# Pixel 1242 has no difference.
# Pixel 1243 has no difference.
# Pixel 1244 has no difference.
# Pixel 1245 has no difference.
# Pixel 1246 is from healpix_map_32.
# Pixel 1247 is from healpix_map_32.
# Pixel 1248 is from healpix_map_32.
# Pixel 1249 is from healpix_map_32.
# Pixel 1250 is from healpix_map_32.
# Pixel 1251 is from healpix_map_32.
# Pixel 1252 is from degraded_128.
# Pixel 1253 is from degraded_128.
# Pixel 1254 is from healpix_map_32.
# Pixel 1255 is from degraded_128.
# Pixel 1256 has no difference.
# Pixel 1257 has no difference.
# Pixel 1258 has no difference.
# Pixel 1259 has no difference.
# Pixel 1260 has no difference.
# Pixel 1261 has no difference.
# Pixel 1262 has no difference.
# Pixel 1263 has no difference.
# Pixel 1264 has no difference.
# Pixel 1265 has no difference.
# Pixel 1266 has no difference.
# Pixel 1267 has no difference.
# Pixel 1268 has no difference.
# Pixel 1269 has no difference.
# Pixel 1270 has no difference.
# Pixel 1271 has no difference.
# Pixel 1272 has no difference.
# Pixel 1273 has no difference.
# Pixel 1274 has no difference.
# Pixel 1275 has no difference.
# Pixel 1276 has no difference.
# Pixel 1277 has no difference.
# Pixel 1278 has no difference.
# Pixel 1279 has no difference.
# Pixel 1280 has no difference.
# Pixel 1281 has no difference.
# Pixel 1282 has no difference.
# Pixel 1283 has no difference.
# Pixel 1284 has no difference.
# Pixel 1285 has no difference.
# Pixel 1286 has no difference.
# Pixel 1287 has no difference.
# Pixel 1288 has no difference.
# Pixel 1289 has no difference.
# Pixel 1290 has no difference.
# Pixel 1291 has no difference.
# Pixel 1292 has no difference.
# Pixel 1293 has no difference.
# Pixel 1294 has no difference.
# Pixel 1295 has no difference.
# Pixel 1296 has no difference.
# Pixel 1297 has no difference.
# Pixel 1298 has no difference.
# Pixel 1299 has no difference.
# Pixel 1300 has no difference.
# Pixel 1301 has no difference.
# Pixel 1302 has no difference.
# Pixel 1303 has no difference.
# Pixel 1304 has no difference.
# Pixel 1305 has no difference.
# Pixel 1306 has no difference.
# Pixel 1307 has no difference.
# Pixel 1308 has no difference.
# Pixel 1309 has no difference.
# Pixel 1310 is from healpix_map_32.
# Pixel 1311 has no difference.
# Pixel 1312 has no difference.
# Pixel 1313 has no difference.
# Pixel 1314 is from healpix_map_32.
# Pixel 1315 is from degraded_128.
# Pixel 1316 is from healpix_map_32.
# Pixel 1317 is from degraded_128.
# Pixel 1318 is from healpix_map_32.
# Pixel 1319 is from degraded_128.
# Pixel 1320 is from healpix_map_32.
# Pixel 1321 has no difference.
# Pixel 1322 has no difference.
# Pixel 1323 has no difference.
# Pixel 1324 has no difference.
# Pixel 1325 has no difference.
# Pixel 1326 has no difference.
# Pixel 1327 has no difference.
# Pixel 1328 has no difference.
# Pixel 1329 has no difference.
# Pixel 1330 has no difference.
# Pixel 1331 has no difference.
# Pixel 1332 has no difference.
# Pixel 1333 has no difference.
# Pixel 1334 has no difference.
# Pixel 1335 has no difference.
# Pixel 1336 has no difference.
# Pixel 1337 has no difference.
# Pixel 1338 has no difference.
# Pixel 1339 has no difference.
# Pixel 1340 has no difference.
# Pixel 1341 has no difference.
# Pixel 1342 has no difference.
# Pixel 1343 has no difference.
# Pixel 1344 has no difference.
# Pixel 1345 has no difference.
# Pixel 1346 has no difference.
# Pixel 1347 has no difference.
# Pixel 1348 has no difference.
# Pixel 1349 has no difference.
# Pixel 1350 has no difference.
# Pixel 1351 has no difference.
# Pixel 1352 has no difference.
# Pixel 1353 has no difference.
# Pixel 1354 has no difference.
# Pixel 1355 has no difference.
# Pixel 1356 has no difference.
# Pixel 1357 has no difference.
# Pixel 1358 has no difference.
# Pixel 1359 has no difference.
# Pixel 1360 has no difference.
# Pixel 1361 has no difference.
# Pixel 1362 has no difference.
# Pixel 1363 is from healpix_map_32.
# Pixel 1364 is from healpix_map_32.
# Pixel 1365 is from degraded_128.
# Pixel 1366 has no difference.
# Pixel 1367 has no difference.
# Pixel 1368 has no difference.
# Pixel 1369 has no difference.
# Pixel 1370 has no difference.
# Pixel 1371 has no difference.
# Pixel 1372 has no difference.
# Pixel 1373 has no difference.
# Pixel 1374 has no difference.
# Pixel 1375 has no difference.
# Pixel 1376 has no difference.
# Pixel 1377 has no difference.
# Pixel 1378 is from degraded_128.
# Pixel 1379 is from degraded_128.
# Pixel 1380 is from healpix_map_32.
# Pixel 1381 is from healpix_map_32.
# Pixel 1382 is from degraded_128.
# Pixel 1383 is from healpix_map_32.
# Pixel 1384 has no difference.
# Pixel 1385 has no difference.
# Pixel 1386 has no difference.
# Pixel 1387 has no difference.
# Pixel 1388 has no difference.
# Pixel 1389 has no difference.
# Pixel 1390 has no difference.
# Pixel 1391 has no difference.
# Pixel 1392 has no difference.
# Pixel 1393 has no difference.
# Pixel 1394 has no difference.
# Pixel 1395 has no difference.
# Pixel 1396 has no difference.
# Pixel 1397 has no difference.
# Pixel 1398 has no difference.
# Pixel 1399 has no difference.
# Pixel 1400 has no difference.
# Pixel 1401 has no difference.
# Pixel 1402 has no difference.
# Pixel 1403 has no difference.
# Pixel 1404 has no difference.
# Pixel 1405 has no difference.
# Pixel 1406 has no difference.
# Pixel 1407 has no difference.
# Pixel 1408 has no difference.
# Pixel 1409 has no difference.
# Pixel 1410 has no difference.
# Pixel 1411 has no difference.
# Pixel 1412 has no difference.
# Pixel 1413 has no difference.
# Pixel 1414 has no difference.
# Pixel 1415 has no difference.
# Pixel 1416 has no difference.
# Pixel 1417 has no difference.
# Pixel 1418 has no difference.
# Pixel 1419 has no difference.
# Pixel 1420 has no difference.
# Pixel 1421 has no difference.
# Pixel 1422 has no difference.
# Pixel 1423 has no difference.
# Pixel 1424 has no difference.
# Pixel 1425 has no difference.
# Pixel 1426 has no difference.
# Pixel 1427 is from degraded_128.
# Pixel 1428 is from degraded_128.
# Pixel 1429 is from healpix_map_32.
# Pixel 1430 has no difference.
# Pixel 1431 has no difference.
# Pixel 1432 has no difference.
# Pixel 1433 has no difference.
# Pixel 1434 has no difference.
# Pixel 1435 has no difference.
# Pixel 1436 has no difference.
# Pixel 1437 has no difference.
# Pixel 1438 has no difference.
# Pixel 1439 has no difference.
# Pixel 1440 has no difference.
# Pixel 1441 has no difference.
# Pixel 1442 has no difference.
# Pixel 1443 is from degraded_128.
# Pixel 1444 is from healpix_map_32.
# Pixel 1445 is from degraded_128.
# Pixel 1446 is from healpix_map_32.
# Pixel 1447 is from degraded_128.
# Pixel 1448 has no difference.
# Pixel 1449 has no difference.
# Pixel 1450 has no difference.
# Pixel 1451 has no difference.
# Pixel 1452 has no difference.
# Pixel 1453 has no difference.
# Pixel 1454 has no difference.
# Pixel 1455 has no difference.
# Pixel 1456 has no difference.
# Pixel 1457 has no difference.
# Pixel 1458 has no difference.
# Pixel 1459 has no difference.
# Pixel 1460 has no difference.
# Pixel 1461 has no difference.
# Pixel 1462 has no difference.
# Pixel 1463 has no difference.
# Pixel 1464 has no difference.
# Pixel 1465 has no difference.
# Pixel 1466 has no difference.
# Pixel 1467 has no difference.
# Pixel 1468 has no difference.
# Pixel 1469 has no difference.
# Pixel 1470 has no difference.
# Pixel 1471 has no difference.
# Pixel 1472 has no difference.
# Pixel 1473 has no difference.
# Pixel 1474 has no difference.
# Pixel 1475 has no difference.
# Pixel 1476 has no difference.
# Pixel 1477 has no difference.
# Pixel 1478 has no difference.
# Pixel 1479 has no difference.
# Pixel 1480 has no difference.
# Pixel 1481 has no difference.
# Pixel 1482 has no difference.
# Pixel 1483 has no difference.
# Pixel 1484 has no difference.
# Pixel 1485 has no difference.
# Pixel 1486 has no difference.
# Pixel 1487 has no difference.
# Pixel 1488 has no difference.
# Pixel 1489 has no difference.
# Pixel 1490 has no difference.
# Pixel 1491 is from degraded_128.
# Pixel 1492 is from degraded_128.
# Pixel 1493 is from degraded_128.
# Pixel 1494 is from healpix_map_32.
# Pixel 1495 has no difference.
# Pixel 1496 has no difference.
# Pixel 1497 has no difference.
# Pixel 1498 has no difference.
# Pixel 1499 has no difference.
# Pixel 1500 has no difference.
# Pixel 1501 has no difference.
# Pixel 1502 has no difference.
# Pixel 1503 has no difference.
# Pixel 1504 has no difference.
# Pixel 1505 has no difference.
# Pixel 1506 is from healpix_map_32.
# Pixel 1507 is from healpix_map_32.
# Pixel 1508 is from healpix_map_32.
# Pixel 1509 is from healpix_map_32.
# Pixel 1510 is from healpix_map_32.
# Pixel 1511 has no difference.
# Pixel 1512 has no difference.
# Pixel 1513 has no difference.
# Pixel 1514 has no difference.
# Pixel 1515 has no difference.
# Pixel 1516 has no difference.
# Pixel 1517 has no difference.
# Pixel 1518 has no difference.
# Pixel 1519 has no difference.
# Pixel 1520 has no difference.
# Pixel 1521 has no difference.
# Pixel 1522 has no difference.
# Pixel 1523 has no difference.
# Pixel 1524 has no difference.
# Pixel 1525 has no difference.
# Pixel 1526 has no difference.
# Pixel 1527 has no difference.
# Pixel 1528 has no difference.
# Pixel 1529 has no difference.
# Pixel 1530 has no difference.
# Pixel 1531 has no difference.
# Pixel 1532 has no difference.
# Pixel 1533 has no difference.
# Pixel 1534 has no difference.
# Pixel 1535 has no difference.
# Pixel 1536 has no difference.
# Pixel 1537 has no difference.
# Pixel 1538 has no difference.
# Pixel 1539 has no difference.
# Pixel 1540 has no difference.
# Pixel 1541 has no difference.
# Pixel 1542 has no difference.
# Pixel 1543 has no difference.
# Pixel 1544 has no difference.
# Pixel 1545 has no difference.
# Pixel 1546 has no difference.
# Pixel 1547 has no difference.
# Pixel 1548 has no difference.
# Pixel 1549 has no difference.
# Pixel 1550 has no difference.
# Pixel 1551 has no difference.
# Pixel 1552 has no difference.
# Pixel 1553 has no difference.
# Pixel 1554 is from healpix_map_32.
# Pixel 1555 is from healpix_map_32.
# Pixel 1556 is from healpix_map_32.
# Pixel 1557 is from healpix_map_32.
# Pixel 1558 is from degraded_128.
# Pixel 1559 has no difference.
# Pixel 1560 has no difference.
# Pixel 1561 has no difference.
# Pixel 1562 has no difference.
# Pixel 1563 has no difference.
# Pixel 1564 has no difference.
# Pixel 1565 has no difference.
# Pixel 1566 has no difference.
# Pixel 1567 has no difference.
# Pixel 1568 has no difference.
# Pixel 1569 has no difference.
# Pixel 1570 has no difference.
# Pixel 1571 is from degraded_128.
# Pixel 1572 has no difference.
# Pixel 1573 is from healpix_map_32.
# Pixel 1574 is from healpix_map_32.
# Pixel 1575 has no difference.
# Pixel 1576 has no difference.
# Pixel 1577 has no difference.
# Pixel 1578 has no difference.
# ...
# Pixel 2540 has no difference.
# Pixel 2541 has no difference.
# Pixel 2542 has no difference.
# Pixel 2543 has no difference.
# Pixel 2544 has no difference.
# Pixel 2545 has no difference.
# Pixel 2546 has no difference.
# Pixel 2547 has no difference.
# Pixel 2548 has no difference.
# Pixel 2549 has no difference.
# Pixel 2550 has no difference.
# Pixel 2551 has no difference.
# Pixel 2552 has no difference.
# Pixel 2553 has no difference.
# Pixel 2554 has no difference.
# Pixel 2555 has no difference.
# Pixel 2556 has no difference.
# Pixel 2557 has no difference.
# Pixel 2558 has no difference.
# Pixel 2559 has no difference.
# Pixel 2560 has no difference.
# Pixel 2561 has no difference.
# Pixel 2562 has no difference.
# Pixel 2563 has no difference.
# Pixel 2564 has no difference.
# Pixel 2565 has no difference.
# Pixel 2566 has no difference.
# Pixel 2567 has no difference.
# Pixel 2568 has no difference.
# Pixel 2569 has no difference.
# Pixel 2570 has no difference.
# Pixel 2571 has no difference.
# Pixel 2572 has no difference.
# Pixel 2573 has no difference.
# Pixel 2574 has no difference.
# Pixel 2575 has no difference.
# Pixel 2576 has no difference.
# Pixel 2577 has no difference.
# Pixel 2578 has no difference.
# Pixel 2579 is from healpix_map_32.
# Pixel 2580 has no difference.
# Pixel 2581 has no difference.
# Pixel 2582 has no difference.
# Pixel 2583 has no difference.
# Pixel 2584 has no difference.
# Pixel 2585 has no difference.
# Pixel 2586 has no difference.
# Pixel 2587 has no difference.
# Pixel 2588 has no difference.
# Pixel 2589 has no difference.
# Pixel 2590 has no difference.
# Pixel 2591 has no difference.
# Pixel 2592 has no difference.
# Pixel 2593 has no difference.
# Pixel 2594 has no difference.
# Pixel 2595 has no difference.
# Pixel 2596 has no difference.
# Pixel 2597 has no difference.
# Pixel 2598 has no difference.
# Pixel 2599 has no difference.
# Pixel 2600 has no difference.
# Pixel 2601 has no difference.
# Pixel 2602 has no difference.
# Pixel 2603 has no difference.
# Pixel 2604 has no difference.
# Pixel 2605 has no difference.
# Pixel 2606 has no difference.
# Pixel 2607 has no difference.
# Pixel 2608 has no difference.
# Pixel 2609 has no difference.
# Pixel 2610 has no difference.
# Pixel 2611 has no difference.
# Pixel 2612 has no difference.
# Pixel 2613 has no difference.
# Pixel 2614 has no difference.
# Pixel 2615 has no difference.
# Pixel 2616 has no difference.
# Pixel 2617 has no difference.
# Pixel 2618 has no difference.
# Pixel 2619 has no difference.
# Pixel 2620 has no difference.
# Pixel 2621 has no difference.
# Pixel 2622 has no difference.
# Pixel 2623 has no difference.
# Pixel 2624 has no difference.
# Pixel 2625 has no difference.
# Pixel 2626 has no difference.
# Pixel 2627 has no difference.
# Pixel 2628 has no difference.
# Pixel 2629 has no difference.
# Pixel 2630 has no difference.
# Pixel 2631 has no difference.
# Pixel 2632 has no difference.
# Pixel 2633 has no difference.
# Pixel 2634 has no difference.
# Pixel 2635 has no difference.
# Pixel 2636 has no difference.
# Pixel 2637 has no difference.
# Pixel 2638 has no difference.
# Pixel 2639 has no difference.
# Pixel 2640 has no difference.
# Pixel 2641 has no difference.
# Pixel 2642 has no difference.
# Pixel 2643 has no difference.
# Pixel 2644 has no difference.
# Pixel 2645 has no difference.
# Pixel 2646 has no difference.
# Pixel 2647 has no difference.
# Pixel 2648 has no difference.
# Pixel 2649 has no difference.
# Pixel 2650 has no difference.
# Pixel 2651 has no difference.
# Pixel 2652 has no difference.
# Pixel 2653 has no difference.
# Pixel 2654 has no difference.
# Pixel 2655 has no difference.
# Pixel 2656 has no difference.
# Pixel 2657 has no difference.
# Pixel 2658 has no difference.
# Pixel 2659 has no difference.
# Pixel 2660 has no difference.
# Pixel 2661 has no difference.
# Pixel 2662 has no difference.
# Pixel 2663 has no difference.
# Pixel 2664 has no difference.
# Pixel 2665 has no difference.
# Pixel 2666 has no difference.
# Pixel 2667 has no difference.
# Pixel 2668 has no difference.
# Pixel 2669 has no difference.
# Pixel 2670 has no difference.
# Pixel 2671 has no difference.
# Pixel 2672 has no difference.
# Pixel 2673 has no difference.
# Pixel 2674 has no difference.
# Pixel 2675 has no difference.
# Pixel 2676 has no difference.
# Pixel 2677 has no difference.
# Pixel 2678 has no difference.
# Pixel 2679 has no difference.
# Pixel 2680 has no difference.
# Pixel 2681 has no difference.
# Pixel 2682 has no difference.
# Pixel 2683 has no difference.
# Pixel 2684 has no difference.
# Pixel 2685 has no difference.
# Pixel 2686 has no difference.
# Pixel 2687 has no difference.
# Pixel 2688 has no difference.
# Pixel 2689 has no difference.
# Pixel 2690 has no difference.
# Pixel 2691 has no difference.
# Pixel 2692 has no difference.
# Pixel 2693 has no difference.
# Pixel 2694 has no difference.
# Pixel 2695 has no difference.
# Pixel 2696 has no difference.
# Pixel 2697 has no difference.
# Pixel 2698 has no difference.
# Pixel 2699 has no difference.
# Pixel 2700 has no difference.
# Pixel 2701 has no difference.
# Pixel 2702 has no difference.
# Pixel 2703 has no difference.
# Pixel 2704 has no difference.
# Pixel 2705 has no difference.
# Pixel 2706 has no difference.
# Pixel 2707 has no difference.
# Pixel 2708 has no difference.
# Pixel 2709 has no difference.
# Pixel 2710 has no difference.
# Pixel 2711 has no difference.
# Pixel 2712 has no difference.
# Pixel 2713 has no difference.
# Pixel 2714 has no difference.
# Pixel 2715 has no difference.
# Pixel 2716 has no difference.
# Pixel 2717 has no difference.
# Pixel 2718 has no difference.
# Pixel 2719 has no difference.
# Pixel 2720 has no difference.
# Pixel 2721 has no difference.
# Pixel 2722 has no difference.
# Pixel 2723 has no difference.
# Pixel 2724 has no difference.
# Pixel 2725 has no difference.
# Pixel 2726 has no difference.
# Pixel 2727 has no difference.
# Pixel 2728 has no difference.
# Pixel 2729 has no difference.
# Pixel 2730 has no difference.
# Pixel 2731 has no difference.
# Pixel 2732 has no difference.
# Pixel 2733 has no difference.
# Pixel 2734 has no difference.
# Pixel 2735 has no difference.
# Pixel 2736 has no difference.
# Pixel 2737 has no difference.
# Pixel 2738 has no difference.
# Pixel 2739 has no difference.
# Pixel 2740 has no difference.
# Pixel 2741 has no difference.
# Pixel 2742 has no difference.
# Pixel 2743 has no difference.
# Pixel 2744 has no difference.
# Pixel 2745 has no difference.
# Pixel 2746 has no difference.
# Pixel 2747 has no difference.
# Pixel 2748 has no difference.
# Pixel 2749 has no difference.
# Pixel 2750 has no difference.
# Pixel 2751 has no difference.
# Pixel 2752 has no difference.
# Pixel 2753 has no difference.
# Pixel 2754 has no difference.
# Pixel 2755 has no difference.
# Pixel 2756 has no difference.
# Pixel 2757 has no difference.
# Pixel 2758 has no difference.
# Pixel 2759 has no difference.
# Pixel 2760 has no difference.
# Pixel 2761 has no difference.
# Pixel 2762 has no difference.
# Pixel 2763 has no difference.
# Pixel 2764 has no difference.
# Pixel 2765 has no difference.
# Pixel 2766 has no difference.
# Pixel 2767 has no difference.
# Pixel 2768 has no difference.
# Pixel 2769 has no difference.
# Pixel 2770 has no difference.
# Pixel 2771 has no difference.
# Pixel 2772 has no difference.
# Pixel 2773 has no difference.
# Pixel 2774 has no difference.
# Pixel 2775 has no difference.
# Pixel 2776 has no difference.
# Pixel 2777 has no difference.
# Pixel 2778 has no difference.
# Pixel 2779 has no difference.
# Pixel 2780 has no difference.
# Pixel 2781 has no difference.
# Pixel 2782 has no difference.
# Pixel 2783 has no difference.
# Pixel 2784 has no difference.
# Pixel 2785 has no difference.
# Pixel 2786 has no difference.
# Pixel 2787 has no difference.
# Pixel 2788 has no difference.
# Pixel 2789 has no difference.
# Pixel 2790 has no difference.
# Pixel 2791 has no difference.
# Pixel 2792 has no difference.
# Pixel 2793 has no difference.
# Pixel 2794 has no difference.
# Pixel 2795 has no difference.
# Pixel 2796 has no difference.
# Pixel 2797 has no difference.
# Pixel 2798 has no difference.
# Pixel 2799 has no difference.
# Pixel 2800 has no difference.
# Pixel 2801 has no difference.
# Pixel 2802 has no difference.
# Pixel 2803 has no difference.
# Pixel 2804 has no difference.
# Pixel 2805 has no difference.
# Pixel 2806 has no difference.
# Pixel 2807 has no difference.
# Pixel 2808 has no difference.
# Pixel 2809 has no difference.
# Pixel 2810 has no difference.
# Pixel 2811 has no difference.
# Pixel 2812 has no difference.
# Pixel 2813 has no difference.
# Pixel 2814 has no difference.
# Pixel 2815 has no difference.
# Pixel 2816 has no difference.
# Pixel 2817 has no difference.
# Pixel 2818 has no difference.
# Pixel 2819 has no difference.
# Pixel 2820 has no difference.
# Pixel 2821 has no difference.
# Pixel 2822 has no difference.
# Pixel 2823 has no difference.
# Pixel 2824 has no difference.
# Pixel 2825 has no difference.
# Pixel 2826 has no difference.
# Pixel 2827 has no difference.
# Pixel 2828 has no difference.
# Pixel 2829 has no difference.
# Pixel 2830 has no difference.
# Pixel 2831 has no difference.
# Pixel 2832 has no difference.
# Pixel 2833 has no difference.
# Pixel 2834 has no difference.
# Pixel 2835 has no difference.
# Pixel 2836 has no difference.
# Pixel 2837 has no difference.
# Pixel 2838 has no difference.
# Pixel 2839 has no difference.
# Pixel 2840 has no difference.
# Pixel 2841 has no difference.
# Pixel 2842 has no difference.
# Pixel 2843 has no difference.
# Pixel 2844 has no difference.
# Pixel 2845 has no difference.
# Pixel 2846 has no difference.
# Pixel 2847 has no difference.
# Pixel 2848 has no difference.
# Pixel 2849 has no difference.
# Pixel 2850 has no difference.
# Pixel 2851 has no difference.
# Pixel 2852 has no difference.
# Pixel 2853 has no difference.
# Pixel 2854 has no difference.
# Pixel 2855 has no difference.
# Pixel 2856 has no difference.
# Pixel 2857 has no difference.
# Pixel 2858 has no difference.
# Pixel 2859 has no difference.
# Pixel 2860 has no difference.
# Pixel 2861 has no difference.
# Pixel 2862 has no difference.
# Pixel 2863 has no difference.
# Pixel 2864 has no difference.
# Pixel 2865 has no difference.
# Pixel 2866 has no difference.
# Pixel 2867 has no difference.
# Pixel 2868 has no difference.
# Pixel 2869 has no difference.
# Pixel 2870 has no difference.
# Pixel 2871 has no difference.
# Pixel 2872 has no difference.
# Pixel 2873 has no difference.
# Pixel 2874 has no difference.
# Pixel 2875 has no difference.
# Pixel 2876 has no difference.
# Pixel 2877 has no difference.
# Pixel 2878 has no difference.
# Pixel 2879 has no difference.
# Pixel 2880 has no difference.
# Pixel 2881 has no difference.
# Pixel 2882 has no difference.
# Pixel 2883 has no difference.
# Pixel 2884 has no difference.
# Pixel 2885 has no difference.
# Pixel 2886 has no difference.
# Pixel 2887 has no difference.
# Pixel 2888 has no difference.
# Pixel 2889 has no difference.
# Pixel 2890 has no difference.
# Pixel 2891 has no difference.
# Pixel 2892 has no difference.
# Pixel 2893 has no difference.
# Pixel 2894 has no difference.
# Pixel 2895 has no difference.
# Pixel 2896 has no difference.
# Pixel 2897 has no difference.
# Pixel 2898 has no difference.
# Pixel 2899 has no difference.
# Pixel 2900 has no difference.
# Pixel 2901 has no difference.
# Pixel 2902 has no difference.
# Pixel 2903 has no difference.
# Pixel 2904 has no difference.
# Pixel 2905 has no difference.
# Pixel 2906 has no difference.
# Pixel 2907 has no difference.
# Pixel 2908 has no difference.
# Pixel 2909 has no difference.
# Pixel 2910 has no difference.
# Pixel 2911 has no difference.
# Pixel 2912 has no difference.
# Pixel 2913 has no difference.
# Pixel 2914 has no difference.
# Pixel 2915 has no difference.
# Pixel 2916 has no difference.
# Pixel 2917 has no difference.
# Pixel 2918 has no difference.
# Pixel 2919 has no difference.
# Pixel 2920 has no difference.
# Pixel 2921 has no difference.
# Pixel 2922 has no difference.
# Pixel 2923 has no difference.
# Pixel 2924 has no difference.
# Pixel 2925 has no difference.
# Pixel 2926 has no difference.
# Pixel 2927 has no difference.
# Pixel 2928 has no difference.
# Pixel 2929 has no difference.
# Pixel 2930 has no difference.
# Pixel 2931 has no difference.
# Pixel 2932 has no difference.
# Pixel 2933 has no difference.
# Pixel 2934 has no difference.
# Pixel 2935 has no difference.
# Pixel 2936 has no difference.
# Pixel 2937 has no difference.
# Pixel 2938 has no difference.
# Pixel 2939 has no difference.
# Pixel 2940 has no difference.
# Pixel 2941 has no difference.
# Pixel 2942 has no difference.
# Pixel 2943 has no difference.
# Pixel 2944 has no difference.
# Pixel 2945 has no difference.
# Pixel 2946 has no difference.
# Pixel 2947 has no difference.
# Pixel 2948 has no difference.
# Pixel 2949 has no difference.
# Pixel 2950 has no difference.
# Pixel 2951 has no difference.
# Pixel 2952 has no difference.
# Pixel 2953 has no difference.
# Pixel 2954 has no difference.
# Pixel 2955 has no difference.
# Pixel 2956 has no difference.
# Pixel 2957 has no difference.
# Pixel 2958 has no difference.
# Pixel 2959 has no difference.
# Pixel 2960 has no difference.
# Pixel 2961 has no difference.
# Pixel 2962 has no difference.
# Pixel 2963 has no difference.
# Pixel 2964 has no difference.
# Pixel 2965 has no difference.
# Pixel 2966 has no difference.
# Pixel 2967 has no difference.
# Pixel 2968 has no difference.
# Pixel 2969 has no difference.
# Pixel 2970 has no difference.
# Pixel 2971 has no difference.
# Pixel 2972 has no difference.
# Pixel 2973 has no difference.
# Pixel 2974 has no difference.
# Pixel 2975 has no difference.
# Pixel 2976 has no difference.
# Pixel 2977 has no difference.
# Pixel 2978 has no difference.
# Pixel 2979 has no difference.
# Pixel 2980 has no difference.
# Pixel 2981 has no difference.
# Pixel 2982 has no difference.
# Pixel 2983 has no difference.
# Pixel 2984 has no difference.
# Pixel 2985 has no difference.
# Pixel 2986 has no difference.
# Pixel 2987 has no difference.
# Pixel 2988 has no difference.
# Pixel 2989 has no difference.
# Pixel 2990 has no difference.
# Pixel 2991 has no difference.
# Pixel 2992 has no difference.
# Pixel 2993 has no difference.
# Pixel 2994 has no difference.
# Pixel 2995 has no difference.
# Pixel 2996 has no difference.
# Pixel 2997 has no difference.
# Pixel 2998 has no difference.
# Pixel 2999 has no difference.
# Pixel 3000 has no difference.
# Pixel 3001 has no difference.
# Pixel 3002 has no difference.
# Pixel 3003 has no difference.
# Pixel 3004 has no difference.
# Pixel 3005 has no difference.
# Pixel 3006 has no difference.
# Pixel 3007 has no difference.
# Pixel 3008 has no difference.
# Pixel 3009 has no difference.
# Pixel 3010 has no difference.
# Pixel 3011 has no difference.
# Pixel 3012 has no difference.
# Pixel 3013 has no difference.
# Pixel 3014 has no difference.
# Pixel 3015 has no difference.
# Pixel 3016 has no difference.
# Pixel 3017 has no difference.
# Pixel 3018 has no difference.
# Pixel 3019 has no difference.
# Pixel 3020 has no difference.
# Pixel 3021 has no difference.
# Pixel 3022 has no difference.
# Pixel 3023 has no difference.
# Pixel 3024 has no difference.
# Pixel 3025 has no difference.
# Pixel 3026 has no difference.
# Pixel 3027 has no difference.
# Pixel 3028 has no difference.
# Pixel 3029 has no difference.
# Pixel 3030 has no difference.
# Pixel 3031 has no difference.
# Pixel 3032 has no difference.
# Pixel 3033 has no difference.
# Pixel 3034 has no difference.
# Pixel 3035 has no difference.
# Pixel 3036 has no difference.
# Pixel 3037 has no difference.
# Pixel 3038 has no difference.
# Pixel 3039 has no difference.
# Pixel 3040 has no difference.
# Pixel 3041 has no difference.
# Pixel 3042 has no difference.
# Pixel 3043 has no difference.
# Pixel 3044 has no difference.
# Pixel 3045 has no difference.
# Pixel 3046 has no difference.
# Pixel 3047 has no difference.
# Pixel 3048 has no difference.
# Pixel 3049 has no difference.
# Pixel 3050 has no difference.
# Pixel 3051 has no difference.
# Pixel 3052 has no difference.
# Pixel 3053 has no difference.
# Pixel 3054 has no difference.
# Pixel 3055 has no difference.
# Pixel 3056 has no difference.
# Pixel 3057 has no difference.
# Pixel 3058 has no difference.
# Pixel 3059 has no difference.
# Pixel 3060 has no difference.
# Pixel 3061 has no difference.
# Pixel 3062 has no difference.
# Pixel 3063 has no difference.
# Pixel 3064 has no difference.
# Pixel 3065 has no difference.
# Pixel 3066 has no difference.
# Pixel 3067 has no difference.
# Pixel 3068 has no difference.
# Pixel 3069 has no difference.
# Pixel 3070 has no difference.
# Pixel 3071 has no difference.
# 293 259

# %%
np.min(healpix_map_32)
# Out:
# 0.0

# %%
np.min(degraded_128)
# Out:
# 0.0

# %%
import sys
pixindex=[]
for i in range(np.shape(image_array)[1]):
    for j in range(np.shape(image_array)[0]):
        pixindex+=(np.where(image_array[j,i]))
        
np.set_printoptions(threshold=sys.maxsize)     
print(pixindex)
# Out:
# /tmp/ipykernel_2684/4163712024.py:5: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(arr).nonzero()` if the old behavior was intended.
#   pixindex+=(np.where(image_array[j,i]))
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
