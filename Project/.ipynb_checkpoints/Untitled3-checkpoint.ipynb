# %%
import numpy as np
import pandas as pd
import tifffile as tiff
import healpy as hp
from scipy import interpolate

# %%
df=pd.read_json('./france_lon_lat_arrays.json')
df.to_csv('./france_lon_lat_arrays.csv')
