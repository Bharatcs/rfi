# %%
import numpy as np 
import healpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import tifffile as tiff
import glob
import seaborn as sns
sns.set_style("darkgrid")
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from num2words import num2words as n2
from scipy.optimize import curve_fit
from mpl_toolkits import mplot3d
import os
from distfit import distfit
import sys
import scipy
import rasterio
from scipy.interpolate import interp2d
from scipy.integrate import quad
from scipy.stats import multivariate_normal
from src2.country_choice import country_select
from src2.shapecheck import shapecheck as sc
from src2.get_nside import get_nside
sns.set(rc={"xtick.bottom": True, "ytick.left": True})
# %matplotlib inline
# %matplotlib notebook

# %%
selval,path=country_select()
# Out:
# Select 5k country: Brazil
# 9201 Tx in total

# %%
nside=get_nside()
# Out:
# Enter nside value:128

# %% [markdown]
# ## sample 5000 pixels from complete USA database

# %%
usa_data=pd.read_csv(path)
usa_data=usa_data.dropna()

# %%
train_lon=usa_data['Longitude in degrees'].to_numpy()
train_lat=usa_data['Latitude in degrees'].to_numpy()
power=usa_data['EIRP'].to_numpy()
frequency=usa_data['Frequency(MHz)'].to_numpy()

# %%
valididx=np.nonzero(power)

# %%
train_lon=train_lon[valididx]
train_lat=train_lat[valididx]
power=power[valididx]
frequency=frequency[valididx]
train_pix=hp.ang2pix(nside,train_lon,train_lat,lonlat=True)

# %%
finval=selval-len(train_lon)

# %%
power.min()
# Out:
# 5

# %% [markdown]
# ## CDF of pixels

# %%
sns.jointplot(x='Longitude in degrees',y='Latitude in degrees',data=usa_data)
plt.show()

# %%
# Bin width using Freedman Diaconis rule
def FDrule(data):
    # Calculate interquartile range
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    
    # Calculate Freedman-Diaconis bin width
    n = len(data)
    bin_width = 2 * iqr / (n ** (1/3))

    # Calculate number of bins
    data_range = max(data) - min(data)
    num_bins = int(data_range / bin_width) + 1
    
    return num_bins

# %% [markdown]
# ## 2D histogram sampling

# %%
data=np.column_stack((train_lon,train_lat))

# %%
### from mpl_toolkits.axes_grid1 import make_axes_locatable
np.random.seed(42)


x, y = data.T
BIN_COUNT1 = FDrule(x)
BIN_COUNT2=FDrule(y)
hist, bins= np.histogramdd(data,bins=(BIN_COUNT1,BIN_COUNT2))
x_bins=bins[0]
y_bins=bins[1]
x_bin_midpoints = (x_bins[:-1] + x_bins[1:])/2
y_bin_midpoints = (y_bins[:-1] + y_bins[1:])/2

cdf = np.cumsum(hist.flatten())
cdf = cdf / cdf[-1]

values = np.random.rand(finval)
value_bins = np.searchsorted(cdf, values)
x_idx, y_idx = np.unravel_index(value_bins,
                                (len(x_bin_midpoints),
                                 len(y_bin_midpoints)))
random_from_cdf = np.column_stack((x_bin_midpoints[x_idx],
                                   y_bin_midpoints[y_idx]))
new_x, new_y = random_from_cdf.T


fig, axs = plt.subplots(1, 2, figsize=(9, 3))

axs[0].hist2d(x, y, bins=(BIN_COUNT1, BIN_COUNT2),norm='log')
axs[0].set_title('Original data histogram')
axs[1].hist2d(new_x, new_y, bins=(BIN_COUNT1, BIN_COUNT2),norm='log')
axs[1].set_title('New sampled data histogram')
for ax in axs:    
    ax.set(aspect='equal')

# %%
cdf=cdf.reshape(BIN_COUNT1,BIN_COUNT2)

# %%
cdf[0,:].shape
# Out:
# (24,)

# %%
np.sum(cdf)
# Out:
# 360.54861572535987

# %%
# new_xx=scipy.interpolate.RectBivariateSpline(x_bins[:-1],y_bins[:-1],cdf)

# %%
# new_xx=np.interp(np.random.uniform(0, 1, 300), cdf[what], bins[1][:-1])
# Out:
#   Cell In[18], line 1
#     new_xx=np.interp(np.random.uniform(0, 1, 300), cdf[#what], bins[1][:-1])
#                                                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
(new_xx.tck)

# %% [markdown]
# ## interpolation 2d trial

# %%
from scipy.interpolate import RegularGridInterpolator
x=x_bins[:-1]
y=y_bins[:-1]
V=cdf

fn=RegularGridInterpolator((x,y),V)

# %%
pts=[np.max(x),np.min(y)]

# %%
# desired_vals= [0.85]
# x_trial=np.linspace(x.min(),x.max(),10000)
# y_trial=np.linspace(y.min(),y.max(),10000)
# genx=[]
# geny=[]
# for i in range(len(x_trial)-1):
#         for j in range(len(y_trial)-1):
#             test_val=fn([x_trial[i],y_trial[j]])
#             if abs(test_val-k)<1e-5:
#                 genx.append(x_trial[i])
#                 geny.append(y_trial[j])
#             else:
#                 if i<len(x_trial)&j<len(y_trial):
#                     i+=1
#                     j+=1
#                 else:
#                     break

# %%
# import numpy as np

# desired_vals = [0.85]
# x_trial = np.linspace(x.min(), x.max(), 10000)
# y_trial = np.linspace(y.min(), y.max(), 10000)
# genx = []
# geny = []

# for i in range(len(x_trial) - 1):
#     for j in range(len(y_trial) - 1):
#         test_val = fn([x_trial[i], y_trial[j]])
#         if abs(test_val - k) < 1e-3:
#             genx.append(x_trial[i])
#             geny.append(y_trial[j])

# %% [markdown]
# ## Checking pixel wise median power trends

# %%
pixel_128=hp.ang2pix(nside,train_lon,train_lat,lonlat=True)
Tx_pow_128=np.zeros(hp.nside2npix(nside))
for index,p in enumerate(pixel_128):
    Tx_pow_128[p]+=(power[index])
hp.mollview(Tx_pow_128,flip='geo',cmap='viridis',title='',norm='hist')
# plt.savefig('/home/pratush/Yogen_STARFIRE/STARFIRE_paper images/new_Txpow',dpi=600)


plt.show()

# %%
sc(new_x,new_y,'sampled from 2d hist using bin midpoints only')

# %%
df = pd.DataFrame({'Pixel': pixel_128, 'Power': power})

median_power_values = df.groupby('Pixel')['Power'].max().reset_index()

median_power_df = pd.DataFrame({'Pixel': median_power_values['Pixel'], 'Median_Power': median_power_values['Power']})

# %%
pixvals=median_power_df['Pixel'].to_numpy()
medpower=median_power_df['Median_Power'].to_numpy()

# %%
median_heatmap=np.zeros(hp.nside2npix(nside))
for index,p in enumerate(pixvals):
    median_heatmap[p]=medpower[index]
median_heatmap[median_heatmap==0]=hp.UNSEEN

# %%
hp.mollview(median_heatmap,flip='geo',norm='hist',cmap='inferno')

# %%
FDrule(train_lon)
# Out:
# 41

# %%
(max(train_lat)-min(train_lat))/FDrule(train_lat)
# Out:
# 1.5390791666666666

# %%
## no other choice but to model using pixels
Tx_num_128=np.zeros(hp.nside2npix(128))
for pix in pixel_128:
    Tx_num_128[pix]+=1
hp.mollview(Tx_num_128,flip='geo',min=0,cmap='plasma',norm='hist',title='')
# plt.savefig('/home/pratush/Yogen_STARFIRE/STARFIRE_paper images/new_Txnum',dpi=600)
plt.show()

# %%
# I have all possible pixel index values within a country.
# X axis is pix idx and Y is number of Tx from existing inc DB

# %%
# France shapefile was downloaded from https://gadm.org/download_country.html and rasterized using QGIS
# Open the GeoTIFF file
file_path = '/home/pratush/5kRasters/Brazil_raster.tif'
src = rasterio.open(file_path)

# Read the raster data as a numpy array
data = src.read(1)  # Assuming a single-band raster

# Find pixels with non-zero values
non_zero_pixels = np.where(data != 0)

# Get the coordinates of non zero pixels
templat=[]
templon=[]
for y, x in zip(*non_zero_pixels):
    lonval, latval = src.xy(y, x)  # Get the longitude and latitude of the pixel
    templat.append(latval)
    templon.append(lonval)

# %%
# country raster 
# Making a mask for generated data
temppix=hp.ang2pix(128,templon,templat,lonlat=True)
template=np.zeros(hp.nside2npix(128))
for pi in temppix:
    template[pi]+=1
template=np.where(template != 0, 1, 0)
hp.mollview(template,flip='geo',min=0)
# plt.savefig('/home/pratush/Yogen_STARFIRE/STARFIRE_paper images/Country_shp.pdf',dpi=600)

# %%
hp.mollview(template,flip='geo',min=0)

# %%
pop_pix=np.argwhere(template)
pop_pix=np.sort(pop_pix)
allon,allat=hp.pix2ang(128,pop_pix,lonlat=True)        
allon[allon>180]-=360

# %%
max(train_lat)
# Out:
# 3.5259
