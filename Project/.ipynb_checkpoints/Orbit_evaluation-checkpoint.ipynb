# %%
import pytz
from datetime import datetime
from dateutil.relativedelta import relativedelta
from skyfield.api import load, wgs84, EarthSatellite
import numpy as np
import pandas as pd

# %%
file=open('../landsat_archive')
lines=file.read()

# %%
type(content)
# Out:
# str

# %%
line1=content[140:209]
line2=content[210:279]

# %%
ts = load.timescale()

satellite = EarthSatellite(line1, line2, 'Landsat-8', ts)

# %%
line1
# Out:
# '1 25682U 99020A   99106.22426197  .00081448  00000-0  15679-1 0    20'

# %%
#line one is odd multiples of 70
#line two is even multiples of 70

# %%
#read line

# %%
year=satellite.epoch.utc.year
# Out:
# 1999

# %%
line11=[]
for i in range(100):
    line11.append(content[((2*i)*70):((2*i)*70)+69])
    line22.append(content[((2*i+1)*70):((2*i+1)*70)+69])
