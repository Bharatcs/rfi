# %%
import numpy as np
import pandas as pd

# %%
# df=pd.read_csv('../Project/database/updated_USA_file_final.csv')
# val=0.921
# df['HDI']=val
# df.to_csv("../Project/database/updated_USA_file_final.csv",index=False)
