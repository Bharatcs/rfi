# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('/home/pratush/Downloads/Fin_HDI.csv')
# Out:
# /tmp/ipykernel_80882/3298903431.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('/home/pratush/Downloads/Fin_HDI.csv')

# %%
data['Country'] = data['Country'].str.ljust(32, ' ')  # Ensure it's 32 characters wide with spaces

# Then save the updated DataFrame to a CSV file
data.to_csv('HDI_corr.csv', index=False)
