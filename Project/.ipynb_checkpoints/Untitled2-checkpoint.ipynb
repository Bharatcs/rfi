# %%
from distfit import distfit
import numpy as np

X = np.random.normal(0, 2, 1000)
y = [-8,-6,0,1,2,3,4,5,6]

# Initialize model
dfit = distfit()

# Find best theoretical distribution for empirical data X
dfit.fit_transform(X)
dfit.plot()

# Make prediction
dfit.predict(y)
dfit.plot()
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm      ] [0.00 sec] [RSS: 0.00337271] [loc=-0.013 scale=1.960]
# [distfit] >INFO> [expon     ] [0.00 sec] [RSS: 0.2084] [loc=-6.172 scale=6.159]
# [distfit] >INFO> [pareto    ] [0.06 sec] [RSS: 0.259033] [loc=-193308624.492 scale=193308618.319]
# [distfit] >INFO> [dweibull  ] [0.01 sec] [RSS: 0.0032493] [loc=-0.016 scale=1.647]
# [distfit] >INFO> [t         ] [0.02 sec] [RSS: 0.00301682] [loc=-0.015 scale=1.904]
# [distfit] >INFO> [genextreme] [0.09 sec] [RSS: 0.00465008] [loc=-0.728 scale=1.955]
# [distfit] >INFO> [gamma     ] [0.04 sec] [RSS: 0.00332224] [loc=-101.842 scale=0.038]
# [distfit] >INFO> [lognorm   ] [0.09 sec] [RSS: 0.00331139] [loc=-114.796 scale=114.768]
# [distfit] >INFO> [beta      ] [0.02 sec] [RSS: 0.00332449] [loc=-63.930 scale=1106667.862]
# [distfit] >INFO> [uniform   ] [0.00 sec] [RSS: 0.127499] [loc=-6.172 scale=11.679]
# [distfit] >INFO> [loggamma  ] [0.04 sec] [RSS: 0.00347148] [loc=-393.696 scale=58.110]
# (<Figure size 2000x1500 with 1 Axes>,
#  <Axes: title={'center': '\nt(df=35.1988, loc=-0.0153544, scale=1.90399)'}, xlabel='Values', ylabel='Frequency'>)

# %%
from distfit import distfit
import numpy as np

# Create dataset
X = np.random.normal(0, 2, 1000)
y = [-8,-6,0,1,2,3,4,5,6]

# Initialize
dfit = distfit()
# Fit
dfit.fit_transform(X)

# Create syntethic data using fitted distribution.
Xnew = dfit.generate(100)
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm      ] [0.00 sec] [RSS: 0.00233488] [loc=0.081 scale=2.005]
# [distfit] >INFO> [expon     ] [0.00 sec] [RSS: 0.183385] [loc=-6.387 scale=6.469]
# [distfit] >INFO> [pareto    ] [0.06 sec] [RSS: 0.184468] [loc=-78546.583 scale=78540.195]
# [distfit] >INFO> [dweibull  ] [0.01 sec] [RSS: 0.00417416] [loc=0.073 scale=1.706]
# [distfit] >INFO> [t         ] [0.02 sec] [RSS: 0.00231312] [loc=0.082 scale=1.996]
# [distfit] >INFO> [genextreme] [0.04 sec] [RSS: 0.00337682] [loc=-0.631 scale=2.030]
# [distfit] >INFO> [gamma     ] [0.04 sec] [RSS: 0.00267028] [loc=-61.936 scale=0.065]
# [distfit] >INFO> [lognorm   ] [0.09 sec] [RSS: 0.00246807] [loc=-228.890 scale=228.957]
# [distfit] >INFO> [beta      ] [0.04 sec] [RSS: 0.00211285] [loc=-110738031.076 scale=110738076.205]
# [distfit] >INFO> [uniform   ] [0.00 sec] [RSS: 0.113741] [loc=-6.387 scale=12.315]
# [distfit] >INFO> [loggamma  ] [0.03 sec] [RSS: 0.0021135] [loc=-114.199 scale=23.297]

# %%
Xnew
# Out:
# array([-1.12495004, -1.6172066 ,  3.31286983, -2.56132598,  0.01933461,
#         1.9729681 , -0.13016078, -4.47170763, -1.38299625, -0.31629555,
#         1.42053428, -5.02177642, -0.15867509,  0.08832176,  3.07682467,
#         0.94247572,  2.27380168, -2.81944886,  1.13344853, -3.52912343,
#         3.44038273,  0.2303376 , -1.22893611,  1.39120004, -0.28355552,
#        -1.25497229,  2.01506385,  2.77104807, -0.7217163 ,  2.18031576,
#         0.33279759,  0.72152844,  0.41103896, -1.85109571, -0.20610557,
#        -0.25665464, -1.66520642, -0.19523962,  3.38320494, -0.46329796,
#        -0.33634533,  4.89081849, -0.60118306,  0.24733576,  3.89575861,
#         0.21893631,  1.55617264, -0.23920025, -4.03381082,  0.69958639,
#        -1.47229932, -4.78985915, -0.34981433,  1.70757054,  1.94895931,
#        -0.20238654, -1.41588497,  4.05503717,  4.00608879,  2.7298622 ,
#        -0.68168347, -0.20259099, -1.662405  , -0.474747  ,  2.09905863,
#        -3.05101795, -0.30014353,  1.22119612,  2.31202628, -0.96781904,
#         0.96404365, -0.76587586,  1.54349653, -0.6076747 ,  1.08060548,
#         1.39172469,  0.46626183,  0.45210879, -1.94728586, -0.1360462 ,
#        -1.3961394 , -0.60057987, -1.77850035, -1.07602464, -2.61304983,
#         0.11923988,  2.43983327,  0.68062286, -0.31994586, -1.53259517,
#        -1.14634162, -0.89258006, -2.28064266, -3.48012321, -2.85465094,
#        -0.3484254 ,  1.91144122, -1.81263769, -0.25828849,  2.77796227])
