# %%
import fiona
import rasterio
from rasterio.features import geometry_mask

# Open the vector file and read the features
with fiona.open('/home/pratush/Desktop/HDI_vector.shp', 'r') as src:
    vector_features = [feature for feature in src]

# Create a raster profile
raster_profile = src.profile

# Rasterize the vector data
with rasterio.open('output.tif', 'w', **raster_profile) as dst:
    for feature in vector_features:
        mask = geometry_mask([feature['geometry']], out_shape=dst.shape, transform=dst.transform, invert=True)
        dst.write(mask, 1)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Unable to open /home/pratush/Desktop/HDI_vector.shx or /home/pratush/Desktop/HDI_vector.SHX. Set SHAPE_RESTORE_SHX config option to YES to restore or create it.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[15], line 6
#       3 from rasterio.features import geometry_mask
#       5 # Open the vector file and read the features
# ----> 6 with fiona.open('/home/pratush/Desktop/HDI_vector.shp', 'r') as src:
#       7     vector_features = [feature for feature in src]
#       9 # Create a raster profile
#
# ...
