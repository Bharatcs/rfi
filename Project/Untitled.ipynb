# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('/home/yogen14/Project/database/Sweden.csv')

# Assuming 'column_name' is the name of the column you want to convert
df['EIRP'] = df['EIRP'].str.replace(' ', '').astype(int)

# Save the updated DataFrame back to a CSV file if needed
df.to_csv('updated_file_sw1.csv', index=False)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('/home/yogen14/Project/database/Sweden.csv')

# Assuming 'column_name' is the name of the column you want to convert
df['EIRP'] = df['EIRP'].astype(int)

# Save the updated DataFrame back to a CSV file if needed
df.to_csv('updated_file_sweden.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 7
#       4 df = pd.read_csv('/home/yogen14/Project/database/Sweden.csv')
#       6 # Assuming 'column_name' is the name of the column you want to convert
# ----> 7 df['EIRP'] = df['EIRP'].astype(int)
#       9 # Save the updated DataFrame back to a CSV file if needed
#      10 df.to_csv('updated_file_sweden.csv', index=False)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...
