# %%
# !pip install svgwrite
# !pip install cairosvg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 KB 229.8 kB/s eta 0:00:001m546.7 kB/s eta 0:00:01
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 KB 310.3 kB/s eta 0:00:001m514.4 kB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 KB 589.2 kB/s eta 0:00:00 kB/s eta 0:00:01
# ...

# %%
import numpy as np
import svgwrite
import cairosvg

# Read the SVG data from a file
with open('map.svg', 'rb') as svg_file:
    svg_data = svg_file.read()

# Convert SVG to PNG using cairosvg
png_data = cairosvg.svg2png(bytestring=svg_data)

# Save the PNG data to a file (optional)
with open('map.png', 'wb') as png_file:
    png_file.write(png_data)

# Load the PNG image using a library like PIL
from PIL import Image

image = Image.open(io.BytesIO(png_data))

# Convert the image to a NumPy array
numpy_array = np.array(image)

# Now, numpy_array contains the pixel-based representation of the SVG image
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 import cairosvg
#       5 # Read the SVG data from a file
# ----> 6 with open('map.svg', 'rb') as svg_file:
#       7     svg_data = svg_file.read()
#       9 # Convert SVG to PNG using cairosvg
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'map.svg'
